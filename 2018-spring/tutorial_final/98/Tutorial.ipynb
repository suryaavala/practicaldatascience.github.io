# %% [markdown]
# # Tutorial Introduction:
# When studying data science, the best way to learn a particular topic is to teach it to others. This assignment is aimed to gives students the opportunity to do just that by requiring a tutorial of a suitable data science project.
#
# The state of Mississippi is traditionally viewed in the U.S. as one of the least educated states (at the high school level). Year end year out rankings forecast the state in a negative light typically placing easily in the bottom 10 of states. Recently, the state has started to place in the bottom 5 (46-50) coming in at 48/50 on USA Today ranking. https://www.usatoday.com/story/money/economy/2018/02/08/geographic-disparity-states-best-and-worst-schools/1079181001/
# The ranking systems typically look at factors such as high school graduation rate, public school spending, 8th grade NAEP proficiency scores, adults with at least a bachelor's degree, highest high school grade, lowest high school grade, and many more. Two additional credible sources, CNBC and Forbes, land the state of Mississippi dead last in their rankings.
# https://www.cnbc.com/2018/01/23/the-10-most-and-least-educated-states-in-2018.html
# https://www.forbes.com/sites/karstenstrauss/2018/02/01/the-most-and-least-educated-states-in-the-u-s-in-2018/#4d0fc9e451e1
# What if there was a way to geographically represent some of this data and begin to attempt to draw some tentative conclusions relating this data to other factors (income levels, etc.).
#
# Here we aim to not only show students how to utilize and implement some basic geopandas features but we apply those features to a data science for social good themed problem.

# %% [markdown]
# ## GeoPandas
# GeoPandas is an open source project that works with data that can be represented geospatially and makes it represented in python easier. It works by combining the functionality of pandas and shapely together. The geospatial implementation allows users to use pandas datatypes to visualize spatial operations on geometric features(latitude and longitude data). GeoPandas can allow users to potentially find spatial patterns in data that may be present.
# www.goepandas.org
#
# ## Shapefile
# Shapefile is an open vector formatting specification platform developed by ESRI. It is useful for the exchange and storing of GIS information consisting of files with the same base name. When using shapefile, there are three mandatory files. The first main file is the .shp file which is the shape format containing the feature geometry. The next mandatory file is the .shx file which shapes the index format which allows seeking to be done quickly. The last mandatory file when using shapefile is the .dbf file. This file is a columnar attributes format of each shape. Make sure that these files are in an uncompressed folder with the jupyter notebook file that you are using. The shapefile will contain pertinent information that will outline the state of Mississippi.

# %% [markdown]
# ### Tutorial Content
# In this tutorial, we will show how to implement and represent basis graphical and geospatial analysis in Pyton with the help of built-in libraries.
#
# Data that will be used to help support this study was collected from the Mississippi Automated Resource Information System (MARIS) http://www.maris.state.ms.us/HTM/DownloadData/Statewide.html and Mississippi Today (MT) "2017 Public School District Grades" https://mississippitoday.org/data/2017-public-school-district-grades/. The two sources are pivotal for the implementation of the example portion of this study. The MARIS Dataset was helpful in possessing the neccessary shape length, shape area, and geometry information as it relates to a given school district. The MT Dataset was helpful in supplying the public school district grades for 2016 and 2017 and other interesting parameters such as graduation rate, change in graduation rate (last 3 school years), and the enrollment numbers for a given school to name a few. The data will need to be downloaded. The MARIS data will come in a zip file that will need to be unzipped before using. This process was completed with the help of 7 Zip File Mangager. The MT data will be in the form of a CSV file. Later in the study there will be a section detailing how to combine these two files together.
#
# This study will aim to address and cover the following topics:
# 1. loading and analyzing data to understand before using
# 2. reading in a specific shapefile to be used for geopandas application
# 3. represent data geospatially in a generic way
# 4. explanation of how to convert csv file into shapefile
# 5. merge two datasets
# 6. graphically and geospatially showcase data to gain further insight into the data

# %% [markdown]
# ## Initial Steps: Library Installation
# To begin this tutorial, it is imperative that geopandas and shapely are installed on your machine. To test if geopandas is installed on the system, we simply ask the system.

# %%
import sys
import geopandas as gpd
#'shapely' in sys.modules
'geopandas' in sys.modules
# Out:
# True

# %% [markdown]
# If the request had retrun False, then one would need to install the needed library. This can be done in the command window by using pip install and "the name of the needed library". Now that it is confirmed that both geopandas and shapely are installed, we import in additional libraries that may be of assistance.
#
# * If additinal assistance is needed with help with installing packages, simply google installing in python and you should get tons of help and feedback.

# %%
import csv
import sqlite3
import pandas as pd
import math
import numpy as np
# Use svg backend for better quality
import matplotlib
# AUTOLAB_IGNORE_START
matplotlib.use("svg")
# AUTOLAB_IGNORE_STOP
import matplotlib.pyplot as plt
#from shapely.geometry import Point

# %% [markdown]
# ### Loading and Analyzing Data to Understand the Dataset
# Before working with any data, it is important that it is analyzed before used. The first step is to import the shapefile that has columns of data related to a geospatial location. The data is essentially assigned to a lat/long geometry polygon value. Here in this section, the code is requesting basis information to understand what features are present. Here individualized entries can be isolated to see exactly what parameters are there for a specific county without all the other data being present.

# %%
#importing shapefile to be able to read shapefile data
import osgeo.ogr
#import shapefile
shapefile = osgeo.ogr.Open("psd15_16.shp")
#tracts = gpd.GeoDataFrame.from_file(shapefile)
numLayers = shapefile.GetLayerCount()
print("Shapefile contains %d layers" % numLayers)


for layerNum in range(numLayers):  
    layer = shapefile.GetLayer(layerNum)  
    spatialRef = layer.GetSpatialRef().ExportToProj4()  
    numFeatures = layer.GetFeatureCount()  
    print ("Layer %d has spatial reference %s" % (layerNum, spatialRef))
    print ("Layer %d has %d features:" % (layerNum, numFeatures))
    print
# Out:
# Shapefile contains 1 layers
# Layer 0 has spatial reference +proj=tmerc +lat_0=32.5 +lon_0=-89.75 +k=0.9998335 +x_0=500000 +y_0=1300000 +datum=NAD83 +units=m +no_defs
# Layer 0 has 144 features:

# %%
#Specifically isolating 1 feature to analyze the information only related to that feature 
feature = layer.GetFeature(0)
print("Feature 2 has the following attributes:")
attributes = feature.items()
print(attributes)
for key,value in attributes.items():
    print("  %s = %s" % (key, value))
geometry = feature.GetGeometryRef() 
geometryName = geometry.GetGeometryName()
print("Feature's geometry data consists of a %s" % geometryName)
# Out:
# Feature 2 has the following attributes:
# {'NAME': 'Aberdeen School District', 'FID_12': 72, 'STATEFP': '28', 'UNSDLEA': '00360', 'GEOID': '2800360', 'LSAD': '00', 'LOGRADE': 'PK', 'HIGRADE': '12', 'MTFCC': 'G5420', 'SDTYP': None, 'FUNCSTAT': 'E', 'ALAND': 557125576.0, 'AWATER': 4010989.0, 'INTPTLAT': '+33.8031740', 'INTPTLON': '-088.6071574', 'Shape_Leng': 127849.314587, 'Shape_Area': 561104504.074, 'test': None, 'test_1': None, 'test_2': None, 'test_3': None, 'test_4': None}
#   NAME = Aberdeen School District
#   FID_12 = 72
#   STATEFP = 28
#   UNSDLEA = 00360
#   GEOID = 2800360
#   LSAD = 00
#   LOGRADE = PK
#   HIGRADE = 12
#   MTFCC = G5420
#   SDTYP = None
#   FUNCSTAT = E
#   ALAND = 557125576.0
#   AWATER = 4010989.0
#   INTPTLAT = +33.8031740
#   INTPTLON = -088.6071574
#   Shape_Leng = 127849.314587
#   Shape_Area = 561104504.074
#   test = None
#   test_1 = None
#   test_2 = None
#   test_3 = None
#   test_4 = None
# Feature's geometry data consists of a POLYGON

# %%
#Specifically showcasing all the data that is present in psd15_16.shp
read = gpd.read_file('psd15_16.shp')#to_crs({'init' :'epsg:4326'})
#dista = gpd.read_file(gpd.datasets.get_path('rpublic_schools15.shp'))
read.head()
# %matplotlib inline
#dista.plot(column='f13', categorical=True)
print(read)
# Out:
#                                                   NAME  FID_12 STATEFP  \
# 0                             Aberdeen School District      72      28
# 1                               Alcorn School District     130      28
# 2                         Amite County School District      47      28
# 3                                Amory School District      71      28
# 4                        Attala County School District     104      28
# 5                              Baldwyn School District      52      28
# 6                        Bay St. Louis School District     141      28
# 7                        Benton County School District     109      28
# 8                        Biloxi Public School District      79      28
# 9                           Booneville School District      51      28
# 10                          Brookhaven School District     101      28
# 11                      Calhoun County School District     118      28
# 12                       Canton Public School District      89      28
# 13                      Carroll County School District       1      28
# 14                    Chickasaw County School District     132      28
# 15                      Choctaw County School District      80      28
# 16                    Claiborne County School District      34      28
# 17                Clarksdale Municipal School District     126      28
# 18                           Cleveland School District      37      28
# 19                      Clinton Public School District      42      28
# 20                      Coahoma County School District     125      28
# 21                         Coffeeville School District      11      28
# 22                            Columbia School District      15      28
# 23                  Columbus Municipal School District      62      28
# 24                       Copiah County School District      91      28
# 25                             Corinth School District     129      28
# 26                    Covington County School District     133      28
# 27                       DeSoto County School District      58      28
# 28                       Durant Public School District      23      28
# 29                         East Jasper School District      74      28
# ..                                                 ...     ...     ...
# 112                Senatobia Municipal School District      44      28
# 113                     Simpson County School District     142      28
# 114                       Smith County School District      49      28
# 115                        South Delta School District       3      28
# 116                       South Panola School District     127      28
# 117                         South Pike School District      18      28
# 118                       South Tippah School District      31      28
# 119  Starkville - Oktibbeha Consolidated School Dis...      25      28
# 120                       Stone County School District      98      28
# 121                   Sunflower County School District      59      28
# 122                        Tate County School District      43      28
# 123                          Tishomingo County Schools      92      28
# 124                      Tunica County School District      26      28
# 125                      Tupelo Public School District      55      28
# 126                       Union County School District     110      28
# 127                       Union Public School District      21      28
# 128                   Vicksburg Warren School District      93      28
# 129                    Walthall County School District      35      28
# 130                       Water Valley School District      10      28
# 131                       Wayne County School District     117      28
# 132                     Webster County School District      64      28
# 133                       West Bolivar School District      39      28
# 134                        West Jasper School District      73      28
# 135            West Point Consolidated School District      83      28
# 136                           West Tallahatchie School     119      28
# 137                       Western Line School District       2      28
# 138                   Wilkinson County School District     121      28
# 139                    Winona Separate School District     122      28
# 140               Yazoo City Municipal School District     115      28
# 141                       Yazoo County School District     116      28
#
#     UNSDLEA    GEOID LSAD LOGRADE HIGRADE  MTFCC SDTYP FUNCSTAT         ALAND  \
# 0     00360  2800360   00      PK      12  G5420  None        E  5.571256e+08
# 1     00390  2800390   00      PK      12  G5420  None        E  9.571163e+08
# 2     00420  2800420   00      KG      12  G5420  None        E  1.890951e+09
# 3     00450  2800450   00      PK      12  G5420  None        E  1.992620e+08
# 4     00510  2800510   00      PK      12  G5420  None        E  1.507495e+09
# 5     00540  2800540   00      KG      12  G5420  None        E  1.703722e+08
# 6     00570  2800570   00      KG      12  G5420  None        E  4.864186e+07
# 7     00600  2800600   00      PK      12  G5420  None        E  1.053131e+09
# 8     00630  2800630   00      PK      12  G5420  None        E  4.977718e+07
# 9     00820  2800820   00      KG      12  G5420  None        E  1.784075e+07
# 10    00840  2800840   00      PK      12  G5420  None        E  3.888038e+08
# 11    00870  2800870   00      PK      12  G5420  None        E  1.519218e+09
# 12    00900  2800900   00      PK      12  G5420  None        E  4.881376e+08
# 13    00930  2800930   00      KG      12  G5420  None        E  1.627141e+09
# 14    00960  2800960   00      PK      12  G5420  None        E  3.083514e+08
# 15    00990  2800990   00      PK      12  G5420  None        E  1.083074e+09
# 16    01020  2801020   00      PK      12  G5420  None        E  1.262400e+09
# 17    01050  2801050   00      PK      12  G5420  None        E  3.596820e+07
# 18    00750  2800750   00      PK      12  G5420  None        E  2.783083e+08
# 19    01090  2801090   00      PK      12  G5420  None        E  3.468083e+08
# 20    01110  2801110   00      PK      12  G5420  None        E  1.394850e+09
# 21    01140  2801140   00      PK      12  G5420  None        E  8.708218e+08
# 22    01170  2801170   00      PK      12  G5420  None        E  1.715735e+08
# 23    01200  2801200   00      PK      12  G5420  None        E  1.706312e+08
# 24    01220  2801220   00      KG      12  G5420  None        E  1.157508e+09
# 25    01260  2801260   00      PK      12  G5420  None        E  7.898432e+07
# 26    01290  2801290   00      PK      12  G5420  None        E  1.071728e+09
# 27    01320  2801320   00      PK      12  G5420  None        E  1.233415e+09
# 28    01360  2801360   00      KG      12  G5420  None        E  5.800935e+06
# 29    01380  2801380   00      PK      12  G5420  None        E  8.555084e+08
# ..      ...      ...  ...     ...     ...    ...   ...      ...           ...
# 112   03930  2803930   00      KG      12  G5420  None        E  1.144648e+08
# 113   03990  2803990   00      KG      12  G5420  None        E  1.525931e+09
# 114   04020  2804020   00      KG      12  G5420  None        E  1.647926e+09
# 115   03960  2803960   00      PK      12  G5420  None        E  2.055442e+09
# 116   04050  2804050   00      PK      12  G5420  None        E  1.001820e+09
# 117   04080  2804080   00      KG      12  G5420  None        E  6.198848e+08
# 118   04110  2804110   00      PK      12  G5420  None        E  6.803731e+08
# 119   03420  2803420   00      KG      12  G5420  None        E  9.113303e+08
# 120   04170  2804170   00      PK      12  G5420  None        E  1.153800e+09
# 121   04200  2804200   00      PK      12  G5420  None        E  1.064922e+09
# 122   04230  2804230   00      PK      12  G5420  None        E  9.338551e+08
# 123   04260  2804260   00      PK      12  G5420  None        E  1.098962e+09
# 124   04290  2804290   00      PK      12  G5420  None        E  1.177584e+09
# 125   04320  2804320   00      PK      12  G5420  None        E  1.864016e+08
# 126   04350  2804350   00      KG      12  G5420  None        E  8.780453e+08
# 127   04380  2804380   00      PK      12  G5420  None        E  1.840226e+08
# 128   04470  2804470   00      PK      12  G5420  None        E  1.524248e+09
# 129   04440  2804440   00      PK      12  G5420  None        E  1.046210e+09
# 130   04500  2804500   00      PK      12  G5420  None        E  3.390365e+08
# 119  POLYGON ((600125.0719565088 1418630.215025725,...
# 120  POLYGON ((539107.5350676812 1123604.649502961,...
# 121  POLYGON ((420059.3025088087 1465248.942045143,...
# 122  POLYGON ((454678.7775490507 1533140.266012371,...
# 123  POLYGON ((626552.0140611203 1576918.758981142,...
# 124  POLYGON ((423143.0760796815 1536152.916831177,...
# 125  POLYGON ((585108.8231745232 1499268.390076825,...
# 126  POLYGON ((546796.5260508424 1532734.213467993,...
# 127  POLYGON ((546611.0093786698 1311865.815630293,...
# 128  POLYGON ((365632.8449861202 1262635.112928443,...
# 129  POLYGON ((451355.6031459561 1161700.47872244, ...
# 130  POLYGON ((497535.7628049646 1477989.028201006,...
# 131  POLYGON ((576362.8926703781 1225397.874237763,...
# 132  POLYGON ((522659.740556363 1435510.447041446, ...
# 133  POLYGON ((400740.3794828169 1475415.929318611,...
# 134  POLYGON ((540327.1783328177 1269420.225382762,...
# 135  POLYGON ((595354.7515040655 1445854.82797908, ...
# 136  POLYGON ((435055.0494667748 1445656.225418895,...
# 137  POLYGON ((361846.4506145939 1405287.343333298,...
# 138  POLYGON ((319826.6585754603 1135184.262761746,...
# 139  POLYGON ((496670.3514121585 1406446.469734378,...
# 140  POLYGON ((435064.0353867831 1339376.754087914,...
# 141  POLYGON ((405479.2097592307 1335360.256484173,...
#
# [142 rows x 23 columns]

# %% [markdown]
# #### Data Showcase
# The following shows the data represented geospatialially as it relates to the different county districts.
# 1. The first is represented with the ID information of each county. Each county is its own entity which is the reasoning for the multi colored graph.
# 2. The second graph is represented with the lowest school grade for a given county. The lowest school grade chart only has two colors as the only options here are binary between kindergarden and pre-kindergarden.
# 3. The last graph shown here is a representation of the highest school grade for a given county. The highest school grade chart only has one possilbe answer as each county goes up to the 12th grade.

# %%
read.plot(column = 'FID_12', categorical= True);
read.plot(column = 'LOGRADE', categorical= True);
read.plot(column = 'HIGRADE', categorical = True);

# %% [markdown]
# The entire data set represents data that is describes and tagged to a specific county(school district name). The various school districts are represented below with their ID in the above graph and their lowest grade offered in the bottom graph.

# %%
#dista.plot(column='f13',categorical=True)
#shple = []
#shpare = []
#geo = []
    
#for line in dista:
#    shpl = line[3]
#    shpar = line[2]
        
#    shple.append(shpl)
#     shpare.append(shpar)
#print(shple)
#print(shpare)

# %% [markdown]
# By chance, if one is interested in viewing the data geometry in centroid form, simply uncomment the next three lines and you should be good to go. There are other ways to represent the data, this is just one alternative option.

# %%
#read['centroid_column'] = dista.centroid
#read = dista.set_geometry('centroid_column')
#read.plot(column ='FID_12', categorical=True)

# %% [markdown]
# ## CSV Data and Limitations
# CSV stands for comman-separated values that store tabular data of numbers and text in plain text. Each entry in the data file is separated by commas.There are a few limitations when dealing with files of different types. CSV.reader does not present the file in scriptable form so one would need to change the file format to make the file scriptable. Here below is importing the csv file into the notebook and manipulating it to only return the first three columns of the dataset. This analyzes is to verify that the data that is wanted for future exercises is present before proceeding with the conversion of the file. Once this is shown to be true, we proceed to converting the file. This will be discussed in the next text section.

# %%
import csv
#ifile = open('mshsdata.csv', "r")
# %%
import ogr
source = ogr.Open('psd15_16.shp', update=True)
layer = source.GetLayer()
#print(source)

#Add an ID field
idField = ogr.FieldDefn("test", ogr.OFTInteger)
layer.CreateField(idField)

#Check the feature and set values
featureDefn = layer.GetLayerDefn()
feature = ogr.Feature(featureDefn)
#feature.SetGeometry(poly)
feature.SetField("test", 1)
layer.CreateFeature(feature)
feature = None
print(featureDefn)
print(source)
# Out:
# <osgeo.ogr.FeatureDefn; proxy of <Swig Object of type 'OGRFeatureDefnShadow *' at 0x000002301CA3C870> >
# <osgeo.ogr.DataSource; proxy of <Swig Object of type 'OGRDataSourceShadow *' at 0x000002301CA3C540> >

# %% [markdown]
# # Merging Data
# Pandas provides various capabilities for easily and successfully combining dataframes with set logic that allows user to join exactly the desired datasets however they would like. Pandas has full-featured, high performance operations very similar to SQL. Merge is a entry point for all standard databases to join. To further understand ways to merge data, visit https://pandas.pydata.org/pandas-docs/stable/merging.html
#
# After converting the mshsdata.csv to a shapefile, msdata.dbf, the data is loaded into the geopandas by the read_file option. Based upon certain columns in the two tables, the spatial join merges together files from msdata.ddf with data from psd15_16.shp. With both files possessing the same NAME column, it was easy to have that be the merge column. This allows data from both data sets to be combined based upon that one given column into a new dataset that is called read below.
#
# ** Conversion of the csv file to dbf format was done on the following webpage. Loading the data set is straight forward and the entire process takes about 2 minutes max.
# https://mygeodata.cloud/converter/csv-to-shp

# %%
newdat= gpd.read_file('mshsdata.dbf')
print(newdat)
newdat.head()
# %matplotlib inline
from geopandas import GeoDataFrame
from shapely.geometry import Polygon
#first data set
read = gpd.read_file('psd15_16.shp')#to_crs({'init' :'epsg:4326'})
left = pd.DataFrame(read)
print(left['NAME'])
print(left)
#second data set converted from a csv file
right = pd.DataFrame(newdat)
right = right.drop('geometry', axis = 1)
print(right['NAME'])
#both data sets merged into one to gain more insight from the data
read = pd.merge(left,right, left_index=True, right_index=True, how='inner', on=['NAME'])
print(read['geometry'])
pd.set_option('display.max_columns', 41)
crs = {'init': 'epsg:4326'}


#result.plot(column ='FID_12', categorical=True)
#geometry = [Polygon(xy) for xy in dista
#georesults = GeoDataFrame(result, crs=crs, geometry=geometry)
#left.plot(column ='FID_12', categorical=True)
# Out:
#                                                   NAME 2017 _OG 2016_OG  \
# 0                             Aberdeen School District        C       C
# 1                               Alcorn School District        B       B
# 2                         Amite County School District        D       F
# 3                                Amory School District        B       C
# 4                        Attala County School District        C       C
# 5                              Baldwyn School District        B       B
# 6                Bay St Louis Waveland School District        B       B
# 7                        Benton County School District        B       C
# 8                        Biloxi Public School District        A       B
# 9                           Booneville School District        A       A
# 10                          Brookhaven School District        C       C
# 11                      Calhoun County School District        C       C
# 12                       Canton Public School District        D       F
# 13                      Carroll County School District        C       D
# 14                    Chickasaw County School District        D       D
# 15                      Choctaw County School District        C       C
# 16                    Claiborne County School District        D       F
# 17                Clarksdale Municipal School District        D       F
# 18                           Cleveland School District        D       C
# 19                      Clinton Public School District        A       A
# 20                                  Coahoma County Ahs        B       C
# 21                      Coahoma County School District        D       F
# 22                         Coffeeville School District        C       D
# 23                            Columbia School District        C       B
# 24                  Columbus Municipal School District        D       D
# 25                       Copiah County School District        C       C
# 26                            Covington County Schools        D       C
# 27                       DeSoto County School District        A       A
# 28                       Durant Public School District        D       D
# 29            East Jasper Consolidated School District        C       D
# ..                                                 ...      ...     ...
# 116                Senatobia Municipal School District        C       B
# 117                     Simpson County School District        C       C
# 118                       Smith County School District        C       C
# 119                        South Delta School District        C       D
# 120                       South Panola School District        C       D
# 121                         South Pike School District        D       D
# 122                       South Tippah School District        B       B
# 123  Starkville- Oktibbeha Consolidated School Dist...        C       C
# 124                       Stone County School District        B       B
# 125      Sunflower County Consolidated School District        F       D
# 126                        Tate County School District        C       C
# 127           Tishomingo County Sp Mun School District        B       B
# 128                      Tunica County School District        D       C
# 129                      Tupelo Public School District        B       B
# 130                       Union County School District        A       B
# 131                       Union Public School District        B       A
# 132                   Vicksburg Warren School District        D       D
# 133                    Walthall County School District        D       D
# 134                       Water Valley School District        C       C
# 135                       Wayne County School District        D       C
# 136                     Webster County School District        B       B
# 137                   West Bolivar Consolidated School        C       D
# 138                   West Jasper Consolidated Schools        B       C
# 139            West Point Consolidated School District        C       D
# 140                  West Tallahatchie School District        C       D
# 141                       Western Line School District        C       D
# 142                   Wilkinson County School District        F       F
# 143                    Winona Separate School District        B       D
# 144               Yazoo City Municipal School District        D       F
# 145                       Yazoo County School District        C       D
#
#     2017_GR    CGR Enrollment          Superinten  \
# 0        82   13.3      1,298           Jeff Clay
# 1      90.8    7.7      3,262      Larry Mitchell
# 2        80    0.5      1,053  Scotty Whittington
# 3      84.1   -2.5      1,778       Kenneth Byars
# 4      72.9    1.8      1,078        Bryan Weaver
# 5      90.2      7        782         Jason Mckay
# 6      82.8   -6.6      1,865      Rebecca Ladner
# 7      85.8   -8.3      1,165    Fredrick Bostick
# 8      82.3   -1.3      6,184     Arthur Mcmillan
# 9      89.1   -1.4      1,304        Todd English
# 10     71.3      2      2,966      Murray Carlock
# 11     88.1   14.6      2,533       Michael Moore
# 12     74.1   21.7      3,583  Cassandra Williams
# 13     76.4    4.5      1,032      Billy Ferguson
# 14     72.9    8.8        507       Betsy Collums
# 15     82.2    3.7      1,370       Stewart Beard
# 16     81.1   11.8      1,487    Cardell Williams
# 17     82.7    9.3      2,675       Dennis Dupree
# 18     79.8    8.6      3,565   Jacquelyn Thigpen
# 19     85.7   -0.7      3,262  Phillip Burchfield
# 20     79.1    1.1        302  Valmadge T. Towner
# 21     75.1    7.9      1,495  Xandra Brooks-Keys
# 22     86.2   15.5        510       Vivian Mclean
# 23     86.1     -4      1,701      Marietta James
# 24     80.8   10.5      4,001      Philip Hickman
# 25     87.7    7.4      2,752      Rickey Clopton
# 26     77.2   11.7      2,905      Arnetta Crosby
# 27     89.1    0.3     33,537        Cory Uselton
# 28     65.1   12.4        526    Glennie Carlisle
# 29       80   10.4        915    Nadene Arrington
# ..      ...    ...        ...                 ...
# 116    80.5   -1.4      1,785        James Foster
# 132             Vicksburg High School: 70.6%
# 133           Salem Attendance Center: 72.4%
# 134          Water Valley High School: 80.4%
# 135          Wayne County High School: 82.2%
# 136          East Webster High School: 88.2%
# 137          West Bolivar High School: 88.6%
# 138           Bay Springs High School: 79.5%
# 139            West Point High School: 90.3%
# 140     West Tallahatchie High School: 92.5%
# 141             Riverside High School: 78.5%
# 142             Wilkinson County High: 70.8%
# 143           Winona Secondary School: 84.9%
# 144            Yazoo City High School: 74.3%
# 145          Yazoo County High School: 82.9%
#
#                                          field_9  \
# 0                                           None
# 1                     Kossuth High School: 92.7%
# 2                                           None
# 3                                           None
# 4               Mcadams Attendance Center: 82.3%
# 5                                           None
# 6                                           None
# 7          Hickory Flat Attendance Center: 83.2%
# 8                                           None
# 9                                           None
# 10                                          None
# 11               Calhoun City High School: 83.8%
# 12                                          None
# 13                                          None
# 14                                          None
# 15                                          None
# 16                                          None
# 17   Jerome W. Stampley 9Th Grade Academy: 85.1%
# 18                  Cleveland High School: 80.6%
# 19                 Sumner Hill Jr Hi School: 90%
# 20                                          None
# 21                                          None
# 22                                          None
# 23                                          None
# 24                                          None
# 25               Wesson Attendance Center: 92.2%
# 26                   Seminary High School: 78.2%
# 27                    Lake Cormorant High: 83.9%
# 28                                          None
# 29                                          None
# ..                                           ...
# 116                                         None
# 117                     Magee High School: 75.7%
# 118                  Mize Attendance Center: 78%
# 119                                         None
# 120                                         None
# 121                                         None
# 122                    Ripley High School: 87.7%
# 123                                         None
# 124                                         None
# 125                    Gentry High School: 82.5%
# 126              Independence High School: 73.6%
# 127         Tishomingo County High School: 82.8%
# 128                                         None
# 129                                         None
# 130             Ingomar Attendance Center: 89.3%
# 131                                         None
# 132                                         None
# 133                 Tylertown High School: 71.9%
# 134                                         None
# 135                                         None
# 136                    Eupora High School: 78.6%
# 137                     Ray Brooks School: 91.1%
# 138            Stringer Attendance Center: 97.1%
# 139                                         None
# 140                                         None
# 141                  O'Bannon High School: 84.9%
# 142                                         None
# 143                                         None
# 144                                         None
# 145                                         None
#
#                                   field_10                         field_11  \
# 0                                     None                             None
# 1                       Biggersville 83.5%                             None
# 2                                     None                             None
# 3                                     None                             None
# 4                                     None                             None
# 5                                     None                             None
# 6                                     None                             None
# 7                                     None                             None
# 8                                     None                             None
# 9                                     None                             None
# 10                                    None                             None
# 11                  Bruce High School: 91%                             None
# 12                                    None                             None
# 13                                    None                             None
# 14                                    None                             None
# 15                                    None                             None
# 16                                    None                             None
# 17                                    None                             None
# 18                                    None                             None
# 19                                    None                             None
# 20                                    None                             None
# 21                                    None                             None
# 22                                    None                             None
# 23                                    None                             None
# 24                                    None                             None
# 25                                    None                             None
# 26    Mount Olive Attendance Center: 93.2%                             None
# 27               Hernando High School: 91%  Olive Branch High School: 92.3%
# 28                                    None                             None
# 29                                    None                             None
# ..                                     ...                              ...
# 116                                   None                             None
# 117                                   None                             None
# 118  Taylorsville Attendance Center: 73.5%                             None
# 119                                   None                             None
# 120                                   None                             None
# 121                                   None                             None
# 122         Blue Mountain High School: 79%                             None
# 123                                   None                             None
# 124                                   None                             None
# 125                                   None                             None
# 126           Strayhorn High School: 83.7%                             None
# 127                                   None                             None
# 128                                   None                             None
# 129                                   None                             None
# 130    East Union Attendance Center: 79.3%  Myrtle Attendance Center: 86.2%
# 131                                   None                             None
# 132                                   None                             None
# 133                                   None                             None
# 134                                   None                             None
# 135                                   None                             None
# 136                                   None                             None
# 137                Shaw High School: 97.4%                             None
# 138                                   None                             None
# 139                                   None                             None
# 140                                   None                             None
# 141                                   None                             None
# 142                                   None                             None
# 143                                   None                             None
# 144                                   None                             None
# 145                                   None                             None
#
#                          field_12                           field_13  \
# 0                            None                               None
# 1                            None                               None
# 2                            None                               None
# 3                            None                               None
# 4                            None                               None
# 5                            None                               None
# 6                            None                               None
# 7                            None                               None
# 8                            None                               None
# 9                            None                               None
# 10                           None                               None
# 11                           None                               None
# 12                           None                               None
# 13                           None                               None
# 14                           None                               None
# 15                           None                               None
# 16                           None                               None
# 17                           None                               None
# 18                           None                               None
# 19                           None                               None
# 20                           None                               None
# 21                           None                               None
# 22                           None                               None
# 23                           None                               None
# 24                           None                               None
# 25                           None                               None
# 26                           None                               None
# 27   Lewisburg High School: 93.9%  Desoto Central High School: 94.7%
# 28                           None                               None
# 29                           None                               None
# ..                            ...                                ...
# 116                          None                               None
# 117                          None                               None
# 118                          None                               None
# 119                          None                               None
# 120                          None                               None
# 121                          None                               None
# 122                          None                               None
# 123                          None                               None
# 124                          None                               None
# 125                          None                               None
# 126                          None                               None
# 127                          None                               None
# 128                          None                               None
# 129                          None                               None
# 130                          None                               None
# 131                          None                               None
# 132                          None                               None
# 133                          None                               None
# 134                          None                               None
# 135                          None                               None
# 136                          None                               None
# 137                          None                               None
# 138                          None                               None
# 139                          None                               None
# 140                          None                               None
# 141                          None                               None
# 142                          None                               None
# 143                          None                               None
# 144                          None                               None
# 145                          None                               None
#
#                            field_14  \
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# 5                              None
# 6                              None
# 7                              None
# 8                              None
# 9                              None
# 10                             None
# 11                             None
# 12                             None
# 13                             None
# 14                             None
# 15                             None
# 16                             None
# 17                             None
# 18                             None
# 19                             None
# 20                             None
# 21                             None
# 22                             None
# 23                             None
# 24                             None
# 25                             None
# 26                             None
# 27   Center Hill High School: 90.8%
# 28                             None
# 29                             None
# ..                              ...
# 116                            None
# 117                            None
# 118                            None
# 119                            None
# 120                            None
# 121                            None
# 122                            None
# 123                            None
# 124                            None
# 125                            None
# 126                            None
# 127                            None
# 128                            None
# 129                            None
# 130                            None
# 131                            None
# 132                            None
# 133                            None
# 134                            None
# 135                            None
# 136                            None
# 137                            None
# 138                            None
# 139                            None
# 140                            None
# 141                            None
# 142                            None
# 143                            None
# 144                            None
# 145                            None
#
#                                      Enrollme_1 geometry
# 0    CGR=Change in Graduation rate last 3 years     None
# 1                                          None     None
# 2                                          None     None
# 3                                          None     None
# 4                                          None     None
# 5                                          None     None
# 6                                          None     None
# 7                                          None     None
# 8                                          None     None
# 9                                          None     None
# 10                                         None     None
# 11                                         None     None
# 12                                         None     None
# 13                                         None     None
# 14                                         None     None
# 15                                         None     None
# 16                                         None     None
# 17                                         None     None
# 18                                         None     None
# 19                                         None     None
# 20                                         None     None
# 21                                         None     None
# 22                                         None     None
# 23                                         None     None
# 24                                         None     None
# 25                                         None     None
# 26                                         None     None
# 27                         Horn Lake High 86.8%     None
# 28                                         None     None
# 29                                         None     None
# ..                                          ...      ...
# 116                                        None     None
# 117                                        None     None
# 118                                        None     None
# 119                                        None     None
# 120                                        None     None
# 121                                        None     None
# 122                                        None     None
# 123                                        None     None
# 124                                        None     None
# 125                                        None     None
# 126                                        None     None
# 127                                        None     None
# 128                                        None     None
# 129                                        None     None
# 130                                        None     None
# 131                                        None     None
# 132                                        None     None
# 133                                        None     None
# 134                                        None     None
# 135                                        None     None
# 136                                        None     None
# 137                                        None     None
# 138                                        None     None
# 139                                        None     None
# 140                                        None     None
# 141                                        None     None
# 142                                        None     None
# 143                                        None     None
# 144                                        None     None
# 145                                        None     None
#
# [146 rows x 16 columns]
# 0                               Aberdeen School District
# 1                                 Alcorn School District
# 2                           Amite County School District
# 3                                  Amory School District
# 4                          Attala County School District
# 5                                Baldwyn School District
# 6                          Bay St. Louis School District
# 7                          Benton County School District
# 8                          Biloxi Public School District
# 9                             Booneville School District
# 10                            Brookhaven School District
# 11                        Calhoun County School District
# 12                         Canton Public School District
# 13                        Carroll County School District
# 14                      Chickasaw County School District
# 15                        Choctaw County School District
# 16                      Claiborne County School District
# 17                  Clarksdale Municipal School District
# 18                             Cleveland School District
# 19                        Clinton Public School District
# 20                        Coahoma County School District
# 21                           Coffeeville School District
# 22                              Columbia School District
# 23                    Columbus Municipal School District
# 24                         Copiah County School District
# 25                               Corinth School District
# 26                      Covington County School District
# 27                         DeSoto County School District
# 28                         Durant Public School District
# 29                           East Jasper School District
#                              ...
# 112                  Senatobia Municipal School District
# 113                       Simpson County School District
# 114                         Smith County School District
# 115                          South Delta School District
# 116                         South Panola School District
# 117                           South Pike School District
# 118                         South Tippah School District
# 119    Starkville - Oktibbeha Consolidated School Dis...
# 120                         Stone County School District
# 121                     Sunflower County School District
# 122                          Tate County School District
# 123                            Tishomingo County Schools
# 124                        Tunica County School District
# 125                        Tupelo Public School District
# 126                         Union County School District
# 127                         Union Public School District
# 128                     Vicksburg Warren School District
# 129                      Walthall County School District
# 130                         Water Valley School District
# 131                         Wayne County School District
# 132                       Webster County School District
# 133                         West Bolivar School District
# 134                          West Jasper School District
# 135              West Point Consolidated School District
# 136                             West Tallahatchie School
# 137                         Western Line School District
# 138                     Wilkinson County School District
# 139                      Winona Separate School District
# 140                 Yazoo City Municipal School District
# 141                         Yazoo County School District
# Name: NAME, Length: 142, dtype: object
# 0                               Aberdeen School District
# 1                                 Alcorn School District
# 2                           Amite County School District
# 3                                  Amory School District
# 4                          Attala County School District
# 5                                Baldwyn School District
# 6                  Bay St Louis Waveland School District
# 7                          Benton County School District
# 8                          Biloxi Public School District
# 9                             Booneville School District
# 10                            Brookhaven School District
# 11                        Calhoun County School District
# 12                         Canton Public School District
# 13                        Carroll County School District
# 14                      Chickasaw County School District
# 15                        Choctaw County School District
# 16                      Claiborne County School District
# 17                  Clarksdale Municipal School District
# 18                             Cleveland School District
# 19                        Clinton Public School District
# 20                                    Coahoma County Ahs
# 21                        Coahoma County School District
# 22                           Coffeeville School District
# 23                              Columbia School District
# 24                    Columbus Municipal School District
# 25                         Copiah County School District
# 26                              Covington County Schools
# 27                         DeSoto County School District
# 28                         Durant Public School District
# 29              East Jasper Consolidated School District
#                              ...
# 116                  Senatobia Municipal School District
# 117                       Simpson County School District
# 118                         Smith County School District
# 119                          South Delta School District
# 120                         South Panola School District
# 121                           South Pike School District
# 122                         South Tippah School District
# 123    Starkville- Oktibbeha Consolidated School Dist...
# 124                         Stone County School District
# 125        Sunflower County Consolidated School District
# 126                          Tate County School District
# 127             Tishomingo County Sp Mun School District
# 128                        Tunica County School District
# 129                        Tupelo Public School District
# 130                         Union County School District
# 131                         Union Public School District
# 132                     Vicksburg Warren School District
# 133                      Walthall County School District
# 134                         Water Valley School District
# 135                         Wayne County School District
# 136                       Webster County School District
# 137                     West Bolivar Consolidated School
# 138                     West Jasper Consolidated Schools
# 139              West Point Consolidated School District
# 140                    West Tallahatchie School District
# 141                         Western Line School District
# 142                     Wilkinson County School District
# 143                      Winona Separate School District
# 144                 Yazoo City Municipal School District
# 145                         Yazoo County School District
# Name: NAME, Length: 146, dtype: object

# %% [markdown]
# ## Graphically Expressing Enrollment Numbers and District Grades
# This next section looks at the data and compares district scores with enrollment numbers. To ensure that there is no bias towards enrollment numbers, we look at these two factors. First we simply show via a histogram the official grades for both 2016 and 2017 to get a sense of the distribution of weights of A-F. Next we analyze the combination of enrollment and district grades by representing the data in a scatter plot. We analyzed the first 40 samples from 2016 and 2017 segmenting the data into 10 points per graph. The data shows that there is no coorelation between enrollment numbers and official grades. There are cases where enrollment <1000 returns an A official grade and cases where enrollment < 1000 returns a D. So there is no way to definitely relate how a school will perform based upon the enrollment numbers that said school may have. This is a question that has to be analyzed much deeper and maybe able to be answered from a data perspective.

# %%
read['2017 _OG'].hist(bins=20)

# %%
read['2016_OG'].hist(bins=20)

# %%
#Printing out all the Enrollment Numbers for Each District
print(read.loc[:,"Enrollment"].sum())
#Printing out all the Official Grades for a Given District in Order for 2017
print(read.loc[:,"2017 _OG"].sum())
#Printing out all the Official Grades for a Given District in Order for 2016
read.loc[:,"2016_OG"].sum()
# Out:
# 1,2983,2621,0531,7781,0787821,8651,1656,1841,3042,9662,5333,5831,0325071,3701,4872,6753,5653,2623021,4955101,7014,0012,7522,90533,5375269151,2169951,6885882,2891,3334,0822,0105,0452,7414,0166,3004,55214,7734,2891,5466,0045881,3722,8121,7571,7083,5909,27826,9481,2821,4201228,6721,1002,4722,8469,8936,5063,1772,2112,9126,9782,3928313,2213,2852,8745,30057713,1712,0613,1442,6765,5571652,3582641,9333,4603,3611,3122,1841,8159371,0841,4522,4751,2931,6355,7966344,2977,2562,0214,2223,2401,0894,1121,0823,6172,3003,6671,8552,3991,0721,94019,2052367074,0771,7853,6412,7018704,4261,6752,7855,1752,5563,9462,6493,0782,0956,9952,8301,0198,3111,9411,1383,2951,8181,3301,4033,1477731,953
# CBDBCBBBAACCDCDCDDDABDCCDCDADCDADBBCBBFCBBBBDDCCCFBFBBFCCDBDBBABDCCBFDBACBDABCDDFBDDDCCBACDDCCFADABBABCACCBBABDDBDBCCCCCCDBCBFCBDBABDDCDBCBCCC
# 'CBFCCBBCBACCFDDCFFCACFDBDCCADDDACABBBBFDCBBBDDCDCFCFBAFFDN/ABFCBBBDCDCDFCACBDABCDDN/ABFDFBCBBDDDCCFAFABABBCACBBBBBFDAN/ACBBCCDDDBCBDCBCBBADDCCBDCDDD'

# %%
plt.bar(read.loc[0:10,"Enrollment"], read.loc[0:10,"2017 _OG"], color='r',  alpha=.8)
# Out:
# <Container object of 11 artists>

# %%
plt.bar(read.loc[11:20,"Enrollment"], read.loc[11:20,"2017 _OG"], color='r',  alpha=.8)
# Out:
# <Container object of 10 artists>

# %%
plt.bar(read.loc[21:30,"Enrollment"], read.loc[21:30,"2017 _OG"], color='r',  alpha=.8)
# Out:
# <Container object of 10 artists>

# %%
plt.bar(read.loc[31:40,"Enrollment"], read.loc[31:40,"2017 _OG"], color='r',  alpha=.8)
# Out:
# <Container object of 9 artists>

# %%
plt.bar(read.loc[41:49,"Enrollment"], read.loc[41:49,"2017 _OG"], color='r',  alpha=.8)
# Out:
# <Container object of 9 artists>

# %%
plt.bar(read.loc[0:10,"Enrollment"], read.loc[0:10,"2016_OG"], color='r',  alpha=.8)
# Out:
# <Container object of 11 artists>

# %%
plt.bar(read.loc[11:20,"Enrollment"], read.loc[11:20,"2016_OG"], color='r',  alpha=.8)
# Out:
# <Container object of 10 artists>

# %%
plt.bar(read.loc[21:30,"Enrollment"], read.loc[21:30,"2016_OG"], color='r',  alpha=.8)
# Out:
# <Container object of 10 artists>

# %%
plt.bar(read.loc[31:40,"Enrollment"], read.loc[31:40,"2016_OG"], color='r',  alpha=.8)
# Out:
# <Container object of 9 artists>

# %%
plt.bar(read.loc[41:49,"Enrollment"], read.loc[41:49,"2016_OG"], color='r',  alpha=.8)
# Out:
# <Container object of 9 artists>

# %%
officialgrade = gpd.GeoDataFrame(read)
print(stations)
# Out:
#                                                   NAME  FID_12 STATEFP  \
# 0                             Aberdeen School District      72      28
# 1                               Alcorn School District     130      28
# 2                         Amite County School District      47      28
# 3                                Amory School District      71      28
# 4                        Attala County School District     104      28
# 5                              Baldwyn School District      52      28
# 6                        Bay St. Louis School District     141      28
# 7                        Benton County School District     109      28
# 8                        Biloxi Public School District      79      28
# 9                           Booneville School District      51      28
# 10                          Brookhaven School District     101      28
# 11                      Calhoun County School District     118      28
# 12                       Canton Public School District      89      28
# 13                      Carroll County School District       1      28
# 14                    Chickasaw County School District     132      28
# 15                      Choctaw County School District      80      28
# 16                    Claiborne County School District      34      28
# 17                Clarksdale Municipal School District     126      28
# 18                           Cleveland School District      37      28
# 19                      Clinton Public School District      42      28
# 20                      Coahoma County School District     125      28
# 21                         Coffeeville School District      11      28
# 22                            Columbia School District      15      28
# 23                  Columbus Municipal School District      62      28
# 24                       Copiah County School District      91      28
# 25                             Corinth School District     129      28
# 26                    Covington County School District     133      28
# 27                       DeSoto County School District      58      28
# 28                       Durant Public School District      23      28
# 29                         East Jasper School District      74      28
# ..                                                 ...     ...     ...
# 112                Senatobia Municipal School District      44      28
# 113                     Simpson County School District     142      28
# 114                       Smith County School District      49      28
# 115                        South Delta School District       3      28
# 116                       South Panola School District     127      28
# 117                         South Pike School District      18      28
# 118                       South Tippah School District      31      28
# 119  Starkville - Oktibbeha Consolidated School Dis...      25      28
# 120                       Stone County School District      98      28
# 121                   Sunflower County School District      59      28
# 122                        Tate County School District      43      28
# 123                          Tishomingo County Schools      92      28
# 124                      Tunica County School District      26      28
# 125                      Tupelo Public School District      55      28
# 126                       Union County School District     110      28
# 127                       Union Public School District      21      28
# 128                   Vicksburg Warren School District      93      28
# 129                    Walthall County School District      35      28
# 130                       Water Valley School District      10      28
# 131                       Wayne County School District     117      28
# 132                     Webster County School District      64      28
# 133                       West Bolivar School District      39      28
# 134                        West Jasper School District      73      28
# 135            West Point Consolidated School District      83      28
# 136                           West Tallahatchie School     119      28
# 137                       Western Line School District       2      28
# 138                   Wilkinson County School District     121      28
# 139                    Winona Separate School District     122      28
# 140               Yazoo City Municipal School District     115      28
# 141                       Yazoo County School District     116      28
#
#     UNSDLEA    GEOID LSAD LOGRADE HIGRADE  MTFCC SDTYP FUNCSTAT         ALAND  \
# 0     00360  2800360   00      PK      12  G5420  None        E  5.571256e+08
# 1     00390  2800390   00      PK      12  G5420  None        E  9.571163e+08
# 2     00420  2800420   00      KG      12  G5420  None        E  1.890951e+09
# 3     00450  2800450   00      PK      12  G5420  None        E  1.992620e+08
# 4     00510  2800510   00      PK      12  G5420  None        E  1.507495e+09
# 5     00540  2800540   00      KG      12  G5420  None        E  1.703722e+08
# 6     00570  2800570   00      KG      12  G5420  None        E  4.864186e+07
# 7     00600  2800600   00      PK      12  G5420  None        E  1.053131e+09
# 8     00630  2800630   00      PK      12  G5420  None        E  4.977718e+07
# 9     00820  2800820   00      KG      12  G5420  None        E  1.784075e+07
# 10    00840  2800840   00      PK      12  G5420  None        E  3.888038e+08
# 11    00870  2800870   00      PK      12  G5420  None        E  1.519218e+09
# 12    00900  2800900   00      PK      12  G5420  None        E  4.881376e+08
# 13    00930  2800930   00      KG      12  G5420  None        E  1.627141e+09
# 14    00960  2800960   00      PK      12  G5420  None        E  3.083514e+08
# 15    00990  2800990   00      PK      12  G5420  None        E  1.083074e+09
# 16    01020  2801020   00      PK      12  G5420  None        E  1.262400e+09
# 17    01050  2801050   00      PK      12  G5420  None        E  3.596820e+07
# 18    00750  2800750   00      PK      12  G5420  None        E  2.783083e+08
# 19    01090  2801090   00      PK      12  G5420  None        E  3.468083e+08
# 20    01110  2801110   00      PK      12  G5420  None        E  1.394850e+09
# 21    01140  2801140   00      PK      12  G5420  None        E  8.708218e+08
# 22    01170  2801170   00      PK      12  G5420  None        E  1.715735e+08
# 23    01200  2801200   00      PK      12  G5420  None        E  1.706312e+08
# 24    01220  2801220   00      KG      12  G5420  None        E  1.157508e+09
# 25    01260  2801260   00      PK      12  G5420  None        E  7.898432e+07
# 26    01290  2801290   00      PK      12  G5420  None        E  1.071728e+09
# 27    01320  2801320   00      PK      12  G5420  None        E  1.233415e+09
# 28    01360  2801360   00      KG      12  G5420  None        E  5.800935e+06
# 29    01380  2801380   00      PK      12  G5420  None        E  8.555084e+08
# ..      ...      ...  ...     ...     ...    ...   ...      ...           ...
# 112   03930  2803930   00      KG      12  G5420  None        E  1.144648e+08
# 113   03990  2803990   00      KG      12  G5420  None        E  1.525931e+09
# 114   04020  2804020   00      KG      12  G5420  None        E  1.647926e+09
# 115   03960  2803960   00      PK      12  G5420  None        E  2.055442e+09
# 116   04050  2804050   00      PK      12  G5420  None        E  1.001820e+09
# 117   04080  2804080   00      KG      12  G5420  None        E  6.198848e+08
# 118   04110  2804110   00      PK      12  G5420  None        E  6.803731e+08
# 119   03420  2803420   00      KG      12  G5420  None        E  9.113303e+08
# 120   04170  2804170   00      PK      12  G5420  None        E  1.153800e+09
# 121   04200  2804200   00      PK      12  G5420  None        E  1.064922e+09
# 122   04230  2804230   00      PK      12  G5420  None        E  9.338551e+08
# 123   04260  2804260   00      PK      12  G5420  None        E  1.098962e+09
# 124   04290  2804290   00      PK      12  G5420  None        E  1.177584e+09
# 125   04320  2804320   00      PK      12  G5420  None        E  1.864016e+08
# 126   04350  2804350   00      KG      12  G5420  None        E  8.780453e+08
# 127   04380  2804380   00      PK      12  G5420  None        E  1.840226e+08
# 128   04470  2804470   00      PK      12  G5420  None        E  1.524248e+09
# 129   04440  2804440   00      PK      12  G5420  None        E  1.046210e+09
# 130   04500  2804500   00      PK      12  G5420  None        E  3.390365e+08
# 131   04530  2804530   00      KG      12  G5420  None        E  2.099745e+09
# 132   04560  2804560   00      KG      12  G5420  None        E  1.090234e+09
# 133   00660  2800660   00      KG      12  G5420  None        E  6.011603e+08
# 134   04590  2804590   00      PK      12  G5420  None        E  8.959359e+08
# 135   01080  2801080   00      PK      12  G5420  None        E  4.435308e+08
# 136   04650  2804650   00      PK      12  G5420  None        E  7.187616e+08
# 137   04680  2804680   00      PK      12  G5420  None        E  9.236076e+08
# 138   04710  2804710   00      PK      12  G5420  None        E  1.756287e+09
# 139   04740  2804740   00      KG      12  G5420  None        E  6.222327e+07
# 140   04770  2804770   00      PK      12  G5420  None        E  2.547940e+07
# 141   04800  2804800   00      KG      12  G5420  None        E -2.147484e+09
#
#          AWATER     INTPTLAT      INTPTLON     Shape_Leng    Shape_Area  test  \
# 0     4010989.0  +33.8031740  -088.6071574  127849.314587  5.611045e+08  None
# 1     3045419.0  +34.8703808  -088.5901763  175630.777263  9.601134e+08  None
# 2     3877870.0  +31.2039333  -090.7955421  185427.386700  1.894679e+09  None
# 3     3467446.0  +33.9753329  -088.5644047   97964.526608  2.027219e+08  None
# 4     3351896.0  +33.1855748  -089.4725612  371997.759826  1.510363e+09  None
# 5      282590.0  +34.5159774  -088.6490381   79300.978074  1.706411e+08  None
# 6    30673606.0  +30.3081211  -089.3541882   53044.332489  7.929189e+07  None
# 7     5279201.0  +34.8107726  -089.2000291  152453.124083  1.058128e+09  None
# 8    16247883.0  +30.4151145  -088.9378568   52154.685095  6.601307e+07  None
# 5    POLYGON ((593105.0289419703 1532957.7800602, 5...        B       B
# 6    POLYGON ((531264.3137483764 1059552.613475308,...        B       B
# 7    POLYGON ((536263.5124730328 1575386.734979715,...        B       C
# 8    POLYGON ((571535.6598978825 1067289.223530512,...        A       B
# 9    POLYGON ((606531.3753864747 1541291.729123963,...        A       A
# 10   POLYGON ((422647.6018392192 1197400.066851689,...        C       C
# 11   POLYGON ((522123.6025718637 1480425.451499276,...        C       C
# 12   POLYGON ((454462.4850048497 1314207.147216473,...        D       F
# 13   POLYGON ((460469.0276024435 1396986.917277569,...        C       D
# 14   POLYGON ((556428.1743798126 1474724.315109966,...        D       D
# 15   POLYGON ((527524.717456894 1403516.220131649, ...        C       C
# 16   POLYGON ((358435.671731418 1231228.005187193, ...        D       F
# 17   POLYGON ((420170.9618369127 1484817.921071367,...        D       F
# 18   POLYGON ((399433.7687296001 1448908.022157924,...        D       C
# 19   POLYGON ((431015.6942630131 1300254.444931479,...        A       A
# 20   POLYGON ((388463.9272473836 1481452.565292234,...        B       C
# 21   POLYGON ((483241.9349516528 1482448.854189161,...        D       F
# 22   POLYGON ((479293.6000999752 1175164.211598979,...        C       D
# 23   (POLYGON ((617935.399077096 1429324.964155685,...        C       B
# 24   POLYGON ((406468.9862721525 1212131.537457408,...        D       D
# 25   POLYGON ((607178.0379150771 1570241.247614924,...        C       C
# 26   POLYGON ((499449.5546147469 1201704.247399697,...        D       C
# 27   POLYGON ((448742.2241355218 1563459.001336608,...        A       A
# 28   POLYGON ((488734.971820768 1363346.924734239, ...        D       D
# 29   POLYGON ((556678.9757240461 1242129.526413346,...        C       D
# ..                                                 ...      ...     ...
# 112  POLYGON ((473286.9338543816 1537473.224416407,...        B       A
# 113  POLYGON ((452973.7429234628 1248166.702098968,...        D     N/A
# 114  POLYGON ((501774.027064912 1265538.840931147, ...        B       C
# 115  POLYGON ((367343.8197717136 1329476.218270693,...        C       B
# 116  POLYGON ((458825.1232809126 1504667.299841853,...        C       B
# 117  POLYGON ((423819.6116323108 1134304.196392925,...        C       C
# 118  POLYGON ((560593.5475036921 1553707.553391526,...        C       C
# 119  POLYGON ((600125.0719565088 1418630.215025725,...        C       D
# 120  POLYGON ((539107.5350676812 1123604.649502961,...        C       D
# 121  POLYGON ((420059.3025088087 1465248.942045143,...        D       D
# 122  POLYGON ((454678.7775490507 1533140.266012371,...        B       B
# 123  POLYGON ((626552.0140611203 1576918.758981142,...        C       C
# 124  POLYGON ((423143.0760796815 1536152.916831177,...        B       B
# 125  POLYGON ((585108.8231745232 1499268.390076825,...        F       D
# 126  POLYGON ((546796.5260508424 1532734.213467993,...        C       C
# 127  POLYGON ((546611.0093786698 1311865.815630293,...        B       B
# 128  POLYGON ((365632.8449861202 1262635.112928443,...        D       C
# 129  POLYGON ((451355.6031459561 1161700.47872244, ...        B       B
# 130  POLYGON ((497535.7628049646 1477989.028201006,...        A       B
# 131  POLYGON ((576362.8926703781 1225397.874237763,...        B       A
# 132  POLYGON ((522659.740556363 1435510.447041446, ...        D       D
# 133  POLYGON ((400740.3794828169 1475415.929318611,...        D       D
# 134  POLYGON ((540327.1783328177 1269420.225382762,...        C       C
# 135  POLYGON ((595354.7515040655 1445854.82797908, ...        D       C
# 136  POLYGON ((435055.0494667748 1445656.225418895,...        B       B
# 137  POLYGON ((361846.4506145939 1405287.343333298,...        C       D
# 138  POLYGON ((319826.6585754603 1135184.262761746,...        B       C
# 139  POLYGON ((496670.3514121585 1406446.469734378,...        C       D
# 140  POLYGON ((435064.0353867831 1339376.754087914,...        C       D
# 141  POLYGON ((405479.2097592307 1335360.256484173,...        C       D
#
#     2017_GR    CGR Enrollment          Superinten  \
# 0        82   13.3      1,298           Jeff Clay
# 1      90.8    7.7      3,262      Larry Mitchell
# 2        80    0.5      1,053  Scotty Whittington
# 3      84.1   -2.5      1,778       Kenneth Byars
# 4      72.9    1.8      1,078        Bryan Weaver
# 5      90.2      7        782         Jason Mckay
# 6      82.8   -6.6      1,865      Rebecca Ladner
# 7      85.8   -8.3      1,165    Fredrick Bostick
# 8      82.3   -1.3      6,184     Arthur Mcmillan
# 9      89.1   -1.4      1,304        Todd English
# 10     71.3      2      2,966      Murray Carlock
# 11     88.1   14.6      2,533       Michael Moore
# 12     74.1   21.7      3,583  Cassandra Williams
# 13     76.4    4.5      1,032      Billy Ferguson
# 14     72.9    8.8        507       Betsy Collums
# 15     82.2    3.7      1,370       Stewart Beard
# 16     81.1   11.8      1,487    Cardell Williams
# 17     82.7    9.3      2,675       Dennis Dupree
# 18     79.8    8.6      3,565   Jacquelyn Thigpen
# 19     85.7   -0.7      3,262  Phillip Burchfield
# 20     79.1    1.1        302  Valmadge T. Towner
# 21     75.1    7.9      1,495  Xandra Brooks-Keys
# 22     86.2   15.5        510       Vivian Mclean
# 23     86.1     -4      1,701      Marietta James
# 24     80.8   10.5      4,001      Philip Hickman
# 25     87.7    7.4      2,752      Rickey Clopton
# 26     77.2   11.7      2,905      Arnetta Crosby
# 27     89.1    0.3     33,537        Cory Uselton
# 28     65.1   12.4        526    Glennie Carlisle
# 29       80   10.4        915    Nadene Arrington
# ..      ...    ...        ...                 ...
# 112    87.7    2.3     19,205     Evelyn Townsend
# 113     N/A    N/A        236                 N/A
# 114    87.4    5.4        707        James Anglin
# 115    86.6    5.3      4,077          Tony Mcgee
# 116    80.5   -1.4      1,785        James Foster
# 117    78.9    7.7      3,641        Gregory Paes
# 118      78    0.4      2,701       Jimmy Hancock
# 119    78.7    6.3        870          Sammie Ivy
# 120    79.6    5.8      4,426       Robert Wilder
# 121    68.8  -13.1      1,675         Johnny Vick
# 122    85.3   -0.3      2,785      Frank Campbell
# 123    87.5   10.4      5,175      Lewis Holloway
# 124    83.4   12.6      2,556          Inita Owen
# 125    79.9   20.9      3,946          Debra Dace
# 126    77.4    6.7      2,649       Daryl Scoggin
# 127    85.6    2.1      3,078      Christie Holly
# 128    74.1    6.1      2,095       Margie Pulley
# 129    86.6    7.9      6,995        Hubert Loden
# 130    85.2   -2.3      2,830         James Basil
# 131    84.7   -0.1      1,019    William Brantley
# 132    70.7    4.8      8,311       Donald Shealy
# 133    72.6    5.5      1,941         Wade Carney
# 19                 Sumner Hill Jr Hi School: 90%
# 20                                          None
# 21                                          None
# 22                                          None
# 23                                          None
# 24                                          None
# 25               Wesson Attendance Center: 92.2%
# 26                   Seminary High School: 78.2%
# 27                    Lake Cormorant High: 83.9%
# 28                                          None
# 29                                          None
# ..                                           ...
# 112          Northwest Rankin High School: 85.6%
# 113                                         None
# 114                                         None
# 115                      Lake High School: 92.8%
# 116                                         None
# 117                     Magee High School: 75.7%
# 118                  Mize Attendance Center: 78%
# 119                                         None
# 120                                         None
# 121                                         None
# 122                    Ripley High School: 87.7%
# 123                                         None
# 124                                         None
# 125                    Gentry High School: 82.5%
# 126              Independence High School: 73.6%
# 127         Tishomingo County High School: 82.8%
# 128                                         None
# 129                                         None
# 130             Ingomar Attendance Center: 89.3%
# 131                                         None
# 132                                         None
# 133                 Tylertown High School: 71.9%
# 134                                         None
# 135                                         None
# 136                    Eupora High School: 78.6%
# 137                     Ray Brooks School: 91.1%
# 138            Stringer Attendance Center: 97.1%
# 139                                         None
# 140                                         None
# 141                  O'Bannon High School: 84.9%
#
#                                   field_10  \
# 0                                     None
# 1                       Biggersville 83.5%
# 2                                     None
# 3                                     None
# 4                                     None
# 5                                     None
# 6                                     None
# 7                                     None
# 8                                     None
# 9                                     None
# 10                                    None
# 11                  Bruce High School: 91%
# 12                                    None
# 13                                    None
# 14                                    None
# 15                                    None
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None
# 20                                    None
# 21                                    None
# 22                                    None
# 23                                    None
# 24                                    None
# 25                                    None
# 26    Mount Olive Attendance Center: 93.2%
# 27               Hernando High School: 91%
# 28                                    None
# 29                                    None
# ..                                     ...
# 112      Mclaurin Attendance Center: 80.5%
# 113                                   None
# 114                                   None
# 115    Sebastopol Attendance Center: 89.2%
# 116                                   None
# 117                                   None
# 118  Taylorsville Attendance Center: 73.5%
# 119                                   None
# 120                                   None
# 121                                   None
# 122         Blue Mountain High School: 79%
# 123                                   None
# 124                                   None
# 125                                   None
# 126           Strayhorn High School: 83.7%
# 127                                   None
# 128                                   None
# 129                                   None
# 130    East Union Attendance Center: 79.3%
# 131                                   None
# 132                                   None
# 133                                   None
# 134                                   None
# 135                                   None
# 136                                   None
# 137                Shaw High School: 97.4%
# 138                                   None
# 139                                   None
# 140                                   None
# 141                                   None
#
#                                    field_11  \
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
# 5                                      None
# 6                                      None
# 7                                      None
# 8                                      None
# 9                                      None
# 10                                     None
# 11                                     None
# 12                                     None
# 13                                     None
# 14                                     None
# 15                                     None
# 16                                     None
# 17                                     None
# 18                                     None
# 19                                     None
# 20                                     None
# 21                                     None
# 22                                     None
# 23                                     None
# 24                                     None
# 25                                     None
# 26                                     None
# 27          Olive Branch High School: 92.3%
# 28                                     None
# 29                                     None
# ..                                      ...
# 112              Brandon High School: 90.9%
# 113                                    None
# 114                                    None
# 115  Scott Central Attendance Center: 85.6%
# 116                                    None
# 117                                    None
# 118                                    None
# 119                                    None
# 120                                    None
# 121                                    None
# 122                                    None
# 123                                    None
# 124                                    None
# 125                                    None
# 126                                    None
# 127                                    None
# 128                                    None
# 129                                    None
# 130         Myrtle Attendance Center: 86.2%
# 131                                    None
# 132                                    None
# 133                                    None
# 134                                    None
# 135                                    None
# 136                                    None
# 137                                    None
# 138                                    None
# 139                                    None
# 140                                    None
# 141                                    None
#
#                                  field_12                           field_13  \
# 0                                    None                               None
# 1                                    None                               None
# 2                                    None                               None
# 3                                    None                               None
# 4                                    None                               None
# 5                                    None                               None
# 6                                    None                               None
# 7                                    None                               None
# 8                                    None                               None
# 9                                    None                               None
# 10                                   None                               None
# 11                                   None                               None
# 12                                   None                               None
# 13                                   None                               None
# 14                                   None                               None
# 15                                   None                               None
# 16                                   None                               None
# 17                                   None                               None
# 18                                   None                               None
# 19                                   None                               None
# 20                                   None                               None
# 21                                   None                               None
# 22                                   None                               None
# 23                                   None                               None
# 24                                   None                               None
# 25                                   None                               None
# 26                                   None                               None
# 27           Lewisburg High School: 93.9%  Desoto Central High School: 94.7%
# 28                                   None                               None
# 29                                   None                               None
# ..                                    ...                                ...
# 112  Pelahatchie Attendance Center: 88.5%          Pisgah High School: 88.1%
# 113                                  None                               None
# 114                                  None                               None
# 115                                  None                               None
# 116                                  None                               None
# 117                                  None                               None
# 118                                  None                               None
# 119                                  None                               None
# 120                                  None                               None
# 121                                  None                               None
# 122                                  None                               None
# 123                                  None                               None
# 124                                  None                               None
# 125                                  None                               None
# 126                                  None                               None
# 127                                  None                               None
# 128                                  None                               None
# 129                                  None                               None
# 130                                  None                               None
# 131                                  None                               None
# 132                                  None                               None
# 133                                  None                               None
# 134                                  None                               None
# 135                                  None                               None
# 136                                  None                               None
# 137                                  None                               None
# 138                                  None                               None
# 139                                  None                               None
# 140                                  None                               None
# 141                                  None                               None
#
#                              field_14  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
# 5                                None
# 6                                None
# 7                                None
# 8                                None
# 9                                None
# 10                               None
# 11                               None
# 12                               None
# 13                               None
# 14                               None
# 15                               None
# 16                               None
# 17                               None
# 18                               None
# 19                               None
# 20                               None
# 21                               None
# 22                               None
# 23                               None
# 24                               None
# 25                               None
# 26                               None
# 27     Center Hill High School: 90.8%
# 28                               None
# 29                               None
# ..                                ...
# 112  Puckett Attendance Center: 93.5%
# 113                              None
# 114                              None
# 115                              None
# 116                              None
# 117                              None
# 118                              None
# 119                              None
# 120                              None
# 121                              None
# 122                              None
# 123                              None
# 124                              None
# 125                              None
# 126                              None
# 127                              None
# 128                              None
# 129                              None
# 130                              None
# 131                              None
# 132                              None
# 133                              None
# 134                              None
# 135                              None
# 136                              None
# 137                              None
# 138                              None
# 139                              None
# 140                              None
# 141                              None
#
#                                      Enrollme_1
# 0    CGR=Change in Graduation rate last 3 years
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# 5                                          None
# 6                                          None
# 7                                          None
# 8                                          None
# 9                                          None
# 10                                         None
# 11                                         None
# 12                                         None
# 13                                         None
# 14                                         None
# 15                                         None
# 16                                         None
# 17                                         None
# 18                                         None
# 19                                         None
# 20                                         None
# 21                                         None
# 22                                         None
# 23                                         None
# 24                                         None
# 25                                         None
# 26                                         None
# 27                         Horn Lake High 86.8%
# 28                                         None
# 29                                         None
# ..                                          ...
# 112                 Richland High School: 88.2%
# 113                                        None
# 114                                        None
# 115                                        None
# 116                                        None
# 117                                        None
# 118                                        None
# 119                                        None
# 120                                        None
# 121                                        None
# 122                                        None
# 123                                        None
# 124                                        None
# 125                                        None
# 126                                        None
# 127                                        None
# 128                                        None
# 129                                        None
# 130                                        None
# 131                                        None
# 132                                        None
# 133                                        None
# 134                                        None
# 135                                        None
# 136                                        None
# 137                                        None
# 138                                        None
# 139                                        None
# 140                                        None
# 141                                        None
#
# [142 rows x 38 columns]

# %% [markdown]
# Now that we have the color coordinated representation of the official grades with the counties, Geopandas gives us a way to better understand the choosing of colors to better understand the trend. Once can simply modify the choice of color by using the "cmap" which is short for colormaps. To learn more about colormaps, visit https://matplotlib.org/users/colormaps.html. From here, one can find a good representation in 3D colorspace for a given data set. The best choice of a colormap varies depending on a given data set. It is important to look to see what works best for your given audience. Below we implement the cmap function on the same officialgrade data set from 2016.
#
# With the implementation of the colormap, it is also important to understand the colortrend and which way is it descending or ascending (depending on how one wants to look at it). To fully take advantage of the understanding of the colormap feature, one should implement the legend feature. This allows a label assignment to populate directly onto the map that way direct understanding of a county can directly be traced.
#
# The ordering of the geospatial plots below are as follows
# 1. 2016 Official Grade Data
# 2. 2016 Official Grade Data + Specific Colormap+ Legend
# 3. 2016 Official Grade Data + Specific Colormap
# 4. 2017 Official Grade Data
# 5. 2017 Official Grade Data + Specific Colormap + Legend
# 6. 2017 Official Grade Data + Specific Colormap

# %%
officialgrade.plot(column = '2016_OG',categorical=True);

# %%
officialgrade.plot(column = '2016_OG',categorical=True, cmap='Set1', legend=True);

# %%
officialgrade.plot(column = '2016_OG',categorical=True, cmap='Set1',)# legend=True);

# %%
officialgrade.plot(column = '2017 _OG',categorical=True);

# %%
officialgrade.plot(column = '2017 _OG',categorical=True, cmap='Set1', alpha=1, legend=True);

# %%
officialgrade.plot(column = '2017 _OG',categorical=True, cmap='Set1', alpha=1,)# legend=True);

# %% [markdown]
# To manipulate the placement of the legend paramter (to not coverup data), one can visit this website. https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.legend.html

# %% [markdown]
# # Summary Conclusion and References
# This tutorial looked at how data can be analyzed graphically and geospatially in Python. With this tutorial the goal was to not only show a technique of analyzing and visualing data in python but also provide a meaningful example along the way. This project provided the following:
# 1. loading and analyzing data to understand before using
# 2. reading in a specific shapefile to be used for geopandas application
# 3. represent data geospatially in a generic way
# 4. explanation of how to convert csv file into shapefile
# 5. merge two datasets
# 6. graphically and geospatially showcase data to gain further insight into the data
#
#
# The project focused data was obtain from Mississippi databases as the author was curious about the state's datasets. Potentially future directions of this work could begin to look at comparing this data with the highest ranking neighbor state (Tennessee-36th), a middle of the pack state (Colorado-25th), and a shoot for the stars state (either Massachusetts, New Jersey, or Vermont). Parameters of interest may be analyzing public school expenditures and proficiency scores to see if there is some alignment. The human inclination is to simply pour cash onto an issue to solve it, but is this the case? Does Vermont spend that more more on public schools than Mississippi? This would be questions the data could answer. Also looking at the superior districts of Vermont versus the superior districts in Mississippi and other factors that cause one to be rated #3 versus the other being rated #48 (rankings were based upon the USA Today report).
