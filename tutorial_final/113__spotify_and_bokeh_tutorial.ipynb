# %% [markdown]
# # Modeling Spotify Data Using Bokeh
#
# This tutorial will introduce one to some basic methods for visualizing data gathered from an API. An application programming interface (API) allows developers to access the functionality of an application's code through controlled calls. For our purposes, we will be using the [Spotify API](https://beta.developer.spotify.com/documentation/web-api/) with the [spotipy](http://spotipy.readthedocs.io/en/latest/) Python wrapper to gain insight into current trending music. Data visualization is also a key aspect of data science. It allows us to draw conclusions from the information that we have gathered. [Bokeh](https://bokeh.pydata.org/en/latest/) is a Python module that allows us to create captivating, interactive graphs. We will use bokeh to map the data that we have gathered about Spotify to formulate some interesting conclusions.

# %% [markdown]
# ### Tutorial Content
# We will be covering the following content in this tutorial:
# - [Installing the libraries](#Installing-the-libraries)
# - [Accessing the API](#Accessing the API)
# - [Loading the data](#Loading the data)
# - [Plots](#Plots)
# - [Putting it all Together](#Putting it all Together)
# - [Concluding Thoughts](#Concluding Thoughts)

# %% [markdown]
# ## Installing the libraries
# Before getting started, we need to install the libraries that we will be using. We can install both spotipy and bokeh using pip.
#
#     $pip install spotipy
#
#     $pip install bokeh
#
# We will also be using pretty print (pprint) to format the JSON-like (Python dictionary) outputs we may get from our API calls into a more readable format. Since pprint is already included in Python, there is no need to install it. We'll start with accessing the API, so we can check that our applicable modules have been properly installed by running the code below:

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

# %% [markdown]
# ## Accessing the API
# In order to pull data from the Spotify API, we will first need to acquire a client_id and a client_secret. We can acquire these by creating a free Spotify account and logging into the [Spotify Developers site](https://beta.developer.spotify.com/) with our account information. After accepting the terms and conditions, we can then access our developer dashboard and create a new app by selecting Create a new client id or My New App. Then we can get our client id and client secret from our app dashboard.
#
# Spotipy uses oAuth to provide some methods that allow us to easily access the API. Try out these functions:

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='YOUR_ID_HERE', client_secret='YOUR_SECRET_HERE')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# We can test our authentication by searching for all of the artists in Spotify's database that contain the name 'adele' using spotipy's search function.

# %%
query = 'adele'
results = sp.search(query, type='artist')
print(results)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=adele&type=artist&offset=0&limit=10', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'}, 'followers': {'href': None, 'total': 8588748}, 'genres': ['pop'], 'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY', 'id': '4dpARuHxo51G3z768sgnrY', 'images': [{'height': 1000, 'url': 'https://i.scdn.co/image/ccbe7b4fef679f821988c78dbd4734471834e3d9', 'width': 1000}, {'height': 640, 'url': 'https://i.scdn.co/image/f8737f6fda048b45efe91f81c2bda2b601ae689c', 'width': 640}, {'height': 200, 'url': 'https://i.scdn.co/image/df070ad127f62d682596e515ac69d5bef56e0897', 'width': 200}, {'height': 64, 'url': 'https://i.scdn.co/image/cbbdfb209cc38b2999b1882f42ee642555316313', 'width': 64}], 'name': 'Adele', 'popularity': 85, 'type': 'artist', 'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/19RHMn8FFkEFmhPwyDW2ZC'}, 'followers': {'href': None, 'total': 7236}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/19RHMn8FFkEFmhPwyDW2ZC', 'id': '19RHMn8FFkEFmhPwyDW2ZC', 'images': [], 'name': 'Robyn Adele Anderson', 'popularity': 42, 'type': 'artist', 'uri': 'spotify:artist:19RHMn8FFkEFmhPwyDW2ZC'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5zEh5XsQAkg0iUY3vPNU0l'}, 'followers': {'href': None, 'total': 242}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5zEh5XsQAkg0iUY3vPNU0l', 'id': '5zEh5XsQAkg0iUY3vPNU0l', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/175c4c5770408560d431def43ad54eb3306c2222', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/df6812943e54df6c65ec96192a3e3244b947860f', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/29de9c0fbaeb79405a8c63a42aef9523f04fe237', 'width': 160}], 'name': 'Ester Adele', 'popularity': 40, 'type': 'artist', 'uri': 'spotify:artist:5zEh5XsQAkg0iUY3vPNU0l'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yUp79jSBSGdkbufl2hmcY'}, 'followers': {'href': None, 'total': 604}, 'genres': ['violin'], 'href': 'https://api.spotify.com/v1/artists/5yUp79jSBSGdkbufl2hmcY', 'id': '5yUp79jSBSGdkbufl2hmcY', 'images': [{'height': 636, 'url': 'https://i.scdn.co/image/581e634f260b77c93c61266bc6f8f755c2417a67', 'width': 640}, {'height': 298, 'url': 'https://i.scdn.co/image/01aa0f1316ac6cc2f03306aaf851f32b20f50175', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/2051799990aa97da74524fdf9757e499cc51569b', 'width': 64}], 'name': 'Adele Anthony', 'popularity': 28, 'type': 'artist', 'uri': 'spotify:artist:5yUp79jSBSGdkbufl2hmcY'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JqklYXhNfskcLi0rqhcAR'}, 'followers': {'href': None, 'total': 19}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5JqklYXhNfskcLi0rqhcAR', 'id': '5JqklYXhNfskcLi0rqhcAR', 'images': [], 'name': 'Adele;The Raconteurs', 'popularity': 22, 'type': 'artist', 'uri': 'spotify:artist:5JqklYXhNfskcLi0rqhcAR'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7wm3zwQUO1hPk4m4sOUz1E'}, 'followers': {'href': None, 'total': 20}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/7wm3zwQUO1hPk4m4sOUz1E', 'id': '7wm3zwQUO1hPk4m4sOUz1E', 'images': [], 'name': 'Adèle Carlier', 'popularity': 22, 'type': 'artist', 'uri': 'spotify:artist:7wm3zwQUO1hPk4m4sOUz1E'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/06wuY3VLVdOEyRLGGpHIqK'}, 'followers': {'href': None, 'total': 2606}, 'genres': ['lovers rock'], 'href': 'https://api.spotify.com/v1/artists/06wuY3VLVdOEyRLGGpHIqK', 'id': '06wuY3VLVdOEyRLGGpHIqK', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/f0bf77b2d2d3c5b733f59688a37ab81f9ccf28c5', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/746d48e5680712b500ff6e820d7d375148c4af0f', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/01388babaca1d1cc221d8bad1c66d09c2edee6d2', 'width': 64}], 'na ...

# %% [markdown]
# Whoa! That's a lot of hard to read data. Let's try making our output a little prettier...

# %%
pprint.pprint(results)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=adele&type=artist&offset=0&limit=10',
#              'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                         'followers': {'href': None, 'total': 8588748},
#                         'genres': ['pop'],
#                         'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                         'id': '4dpARuHxo51G3z768sgnrY',
#                         'images': [{'height': 1000,
#                                     'url': 'https://i.scdn.co/image/ccbe7b4fef679f821988c78dbd4734471834e3d9',
#                                     'width': 1000},
#                                    {'height': 640,
#                                     'url': 'https://i.scdn.co/image/f8737f6fda048b45efe91f81c2bda2b601ae689c',
#                                     'width': 640},
#                                    {'height': 200,
#                                     'url': 'https://i.scdn.co/image/df070ad127f62d682596e515ac69d5bef56e0897',
#                                     'width': 200},
#                                    {'height': 64,
#                                     'url': 'https://i.scdn.co/image/cbbdfb209cc38b2999b1882f42ee642555316313',
#                                     'width': 64}],
#                         'name': 'Adele',
#                         'popularity': 85,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/19RHMn8FFkEFmhPwyDW2ZC'},
#                         'followers': {'href': None, 'total': 7236},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/19RHMn8FFkEFmhPwyDW2ZC',
#                         'id': '19RHMn8FFkEFmhPwyDW2ZC',
#                         'images': [],
#                         'name': 'Robyn Adele Anderson',
#                         'popularity': 42,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:19RHMn8FFkEFmhPwyDW2ZC'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/5zEh5XsQAkg0iUY3vPNU0l'},
#                         'followers': {'href': None, 'total': 242},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/5zEh5XsQAkg0iUY3vPNU0l',
#                         'id': '5zEh5XsQAkg0iUY3vPNU0l',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/175c4c5770408560d431def43ad54eb3306c2222',
#                                     'width': 640},
#                                    {'height': 320,
#                                     'url': 'https://i.scdn.co/image/df6812943e54df6c65ec96192a3e3244b947860f',
#                                     'width': 320},
#                                    {'height': 160,
#                                     'url': 'https://i.scdn.co/image/29de9c0fbaeb79405a8c63a42aef9523f04fe237',
#                                     'width': 160}],
#                         'name': 'Ester Adele',
#                         'popularity': 40,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:5zEh5XsQAkg0iUY3vPNU0l'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yUp79jSBSGdkbufl2hmcY'},
#                         'followers': {'href': None, 'total': 604},
#                         'genres': ['violin'],
#                         'href': 'https://api.spotify.com/v1/artists/5yUp79jSBSGdkbufl2hmcY',
#                         'id': '5yUp79jSBSGdkbufl2hmcY',
#                         'images': [{'height': 636,
#                                     'url': 'https://i.scdn.co/image/581e634f260b77c93c61266bc6f8f755c2417a67',
#                                     'width': 640},
#                                    {'height': 298,
#                                     'url': 'https://i.scdn.co/image/01aa0f1316ac6cc2f03306aaf851f32b20f50175',
#                                     'width': 300},
#                                    {'height': 64,
#                                     'url': 'https://i.scdn.co/image/2051799990aa97da74524fdf9757e499cc51569b',
#                                     'width': 64}],
#                         'name': 'Adele Anthony',
#                         'popularity': 28,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:5yUp79jSBSGdkbufl2hmcY'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JqklYXhNfskcLi0rqhcAR'},
#                         'followers': {'href': None, 'total': 19},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/5JqklYXhNfskcLi0rqhcAR',
#                         'id': '5JqklYXhNfskcLi0rqhcAR',
#                         'images': [],
#                         'name': 'Adele;The Raconteurs',
#                         'popularity': 22,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:5JqklYXhNfskcLi0rqhcAR'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/7wm3zwQUO1hPk4m4sOUz1E'},
#                         'followers': {'href': None, 'total': 20},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/7wm3zwQUO1hPk4m4sOUz1E',
#                         'id': '7wm3zwQUO1hPk4m4sOUz1E',
#                         'images': [],
#                         'name': 'Adèle Carlier',
#                         'popularity': 22,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:7wm3zwQUO1hPk4m4sOUz1E'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/06wuY3VLVdOEyRLGGpHIqK'},
#                         'followers': {'href': None, 'total': 2606},
#                         'genres': ['lovers rock'],
#                         'href': 'https://api.spotify.com/v1/artists/06wuY3VLVdOEyRLGGpHIqK',
#                         'id': '06wuY3VLVdOEyRLGGpHIqK',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/f0bf77b2d2d3c5b733f59688a37ab81f9ccf28c5',
#                                     'width': 640},
#                                    {'height': 300,
#                                     'url': 'https://i.scdn.co/image/746d48e5680712b500ff6e820d7d375148c4af0f',
#                                     'width': 300},
#                                    {'height': 64,
#                                     'url': 'https://i.scdn.co/image/01388babaca1d1cc221d8bad1c66d09c2edee6d2',
#                                     'width': 64}],
#                         'name': 'Adele Harley',
#                         'popularity': 22,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:06wuY3VLVdOEyRLGGpHIqK'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/0UhoqhbYoPuORgj24VBUcp'},
#                         'followers': {'href': None, 'total': 149},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/0UhoqhbYoPuORgj24VBUcp',
#                         'id': '0UhoqhbYoPuORgj24VBUcp',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/82174eab8a78d13a74feb5f9f5ee1c2ba88eb679',
#                                     'width': 640},
#                                    {'height': 300,
#                                     'url': 'https://i.scdn.co/image/7f834fe4f3eb9e7988b0ab39210fcdf4411c6e73',
#                                     'width': 300},
#                                    {'height': 64,
#                                     'url': 'https://i.scdn.co/image/b2cf1914cac3dff100818e8088077090945cb614',
#                                     'width': 64}],
#                         'name': 'Adèle Anderson',
#                         'popularity': 20,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:0UhoqhbYoPuORgj24VBUcp'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/10UHmKyfLXudqVHU9PnHEZ'},
#                         'followers': {'href': None, 'total': 254},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/10UHmKyfLXudqVHU9PnHEZ',
#                         'id': '10UHmKyfLXudqVHU9PnHEZ',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/58f8174c1088c330cf25c3f1b8b130c3c0fb63d7',
#                                     'width': 640},
#                                    {'height': 300,
#                                     'url': 'https://i.scdn.co/image/2b512cf4130834991c8daff85ba51314208dca47',
#                                     'width': 300},
#                                    {'height': 64,
#                                     'url': 'https://i.scdn.co/image/a7267dd7f0eab86cdf899a0d6c3f875dd743b31d',
#                                     'width': 64}],
#                         'name': 'Laila Adele',
#                         'popularity': 22,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:10UHmKyfLXudqVHU9PnHEZ'},
#                        {'external_urls': {'spotify': 'https://open.spotify.com/artist/6HZ5IH5ksF7cs4mg0HQlSN'},
#                         'followers': {'href': None, 'total': 1368},
#                         'genres': [],
#                         'href': 'https://api.spotify.com/v1/artists/6HZ5IH5ksF7cs4mg0HQlSN',
#                         'id': '6HZ5IH5ksF7cs4mg0HQlSN',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/8cecf2204d2a2225d21337477dee4d5a8a7ea2aa',
#                                     'width': 640},
#                                    {'height': 300,
#                                     'url': 'https://i.scdn.co/image/3a7e6fb6bf477f418dcc471aea3500ce3af24193',
#                                     'width': 300},
#                                    {'height': 64,
#                                     'url': 'https://i.scdn.co/image/23baf9563a97fde23cbf0eeed9981b66630ca925',
#                                     'width': 64}],
#                         'name': 'Adele Adkins',
#                         'popularity': 24,
#                         'type': 'artist',
#                         'uri': 'spotify:artist:6HZ5IH5ksF7cs4mg0HQlSN'}],
#              'limit': 10,
#              'next': 'https://api.spotify.com/v1/search?query=adele&type=artist&offset=10&limit=10',
#              'offset': 0,
#              'previous': None,
#              'total': 169}}

# %% [markdown]
# That's better. As we can see, pprint reformats the dictionary in a much more readable way. We can now scroll to the bottom of the output and see that there are 169 artists in Spotify's database containing the name 'adele'. However, we are currently limited to the first 10 entries. The next 10 can be found at the URL provided, but that's okay! We found the one that we were looking for.

# %%
artist = results['artists']['items'][0]
pprint.pprint(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#  'followers': {'href': None, 'total': 8588748},
#  'genres': ['pop'],
#  'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#  'id': '4dpARuHxo51G3z768sgnrY',
#  'images': [{'height': 1000,
#              'url': 'https://i.scdn.co/image/ccbe7b4fef679f821988c78dbd4734471834e3d9',
#              'width': 1000},
#             {'height': 640,
#              'url': 'https://i.scdn.co/image/f8737f6fda048b45efe91f81c2bda2b601ae689c',
#              'width': 640},
#             {'height': 200,
#              'url': 'https://i.scdn.co/image/df070ad127f62d682596e515ac69d5bef56e0897',
#              'width': 200},
#             {'height': 64,
#              'url': 'https://i.scdn.co/image/cbbdfb209cc38b2999b1882f42ee642555316313',
#              'width': 64}],
#  'name': 'Adele',
#  'popularity': 85,
#  'type': 'artist',
#  'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}

# %% [markdown]
# The first artist in the 'items' list appears to be the popular British singer that we were referring to. We can double check by opening up the link in the 'external_urls' key to view the [artist's page](https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY).
#
# Lo and behold, we have our girl.

# %% [markdown]
# ## Loading the data
# Let's gather some more data. Say we want to answer the question: How has an artist's popularity changed over the years? How does this compare to other Billboard 100 artists?
#
# Now that we know how to access the API, we can use spotipy methods as well as the corresponding object attributes to gather the information needed for our inquiry. For more detailed information, check out the documentation on the [spotipy methods](http://spotipy.readthedocs.io/en/latest/#api-reference) and [object models](https://beta.developer.spotify.com/documentation/web-api/reference/object-model/) in the attached links.
#
# First, we need to make a list of artists that we're interested in. Then we need to find all of their ids to access other data about them.

# %%
# list of artist names, customizable
artist_names = ['adele', 'ed sheeran', 'taylor swift', 'the script', 'maroon 5']

# creating a list of artist ids
# since we have chosen a list of popular artists, we can assume that 
# they will have the greatest popularity out of all the search results
# or in other words we can assume they will be at the top of the results

artists = []
for name in artist_names:
    results = sp.search(name, type='artist')
    artist = results['artists']['items'][0]
    artists.append(artist)
    
#double checking code...
for artist in artists:
    print(artist['name'] + ": " + artist['id'])
    print(str(artist['popularity']))
# Out:
# Adele: 4dpARuHxo51G3z768sgnrY
# 85
# Ed Sheeran: 6eUKZXaKkcviH0Ku9w2n3V
# 96
# Taylor Swift: 06HL4z0CvFAxyc27GXpf02
# 90
# The Script: 3AQRLZ9PuTAozP28Skbq8V
# 80
# Maroon 5: 04gDigrS5kc9YWfZHwBETP
# 89

# %% [markdown]
# Just to double check that they are the artists we are looking for, we have printed out their popularities as well. Spotify ranks popularity on a scale of 0-100, 0 being the lowest popularity score to 100 being the most any object can get. Since these are trending artists, we expect them to be sufficiently popular.
#
# Spotify has already generated popularity for artists, albums, tracks, etc., so we, the developers, are responsible for providing some measure of time to visualize how popularity has changed. The best way to do this is by comparing the popularity of an artist's album to its release date. Thus, we can see how an artist has evolved in the eyes of the populace with every album released.
#
# So we need to get information about albums that an artist has produced. Spotipy has some built in functions like the artist_albums method. We then need to sort the data so that we're getting the information we expect to get. For instance, we need to ensure that each object returned from the artist_albums method is actually an album produced by the artist, rather than a single or an album they contributed to.
#
# Another problem we may encounter lies in querying the database. Spotify limits the artist_albums methods to 20 results at one time. Since most artists appear in more than 20 albums, we need to repeat the query over and over again with an offset until we retrieve all results. This is tedious for us to do manually, so let's write a method to do the work for us.

# %%
def get_artist_albums(artist):
    """This function gets all of the relevant albums for an artist. Relevant includes only actual albums.
    
    Input: artist id (string)
    
    Output: albums (list of dictionaries)
    """
    id = artist['id']
    result = []
    # temporary list to store all album ids
    album_ids = []
    
    offset = 0
    nxt = "start"
    while nxt != None:
        albums = sp.artist_albums(id, offset=offset)
        for album in albums['items']:
            if album['album_group'] == 'album':
                album_ids.append(album['id'])
        nxt = albums['next']
        offset += albums['limit']
            
    for album in album_ids:
        info = sp.album(album)
        result.append(info)
    
    return result

# %% [markdown]
# We can test our function by calling it on our first artist, Adele. Let's take a look at what her albums look like.

# %%
adele = get_artist_albums(artists[0])
print(len(adele))
pprint.pprint(adele)
# Out:
# 11
# [{'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                'id': '4dpARuHxo51G3z768sgnrY',
#                'name': 'Adele',
#                'type': 'artist',
#                'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#   'available_markets': ['AR',
#                         'BO',
#                         'BR',
#                         'CL',
#                         'CO',
#                         'CR',
#                         'DO',
#                         'EC',
#                         'GT',
#                         'HN',
#                         'MX',
#                         'NI',
#                         'PA',
#                         'PE',
#                         'PY',
#                         'SV',
#                         'US',
#                         'UY'],
#   'copyrights': [{'text': '(P) 2015 XL Recordings Ltd., under exclusive '
#                           'license to Columbia Records, a Division of Sony '
#                           'Music Entertainment',
#                   'type': 'P'}],
#   'external_ids': {'upc': '886445568196'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0K4pIOOsfJ9lK8OjrZfXzd'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/0K4pIOOsfJ9lK8OjrZfXzd',
#   'id': '0K4pIOOsfJ9lK8OjrZfXzd',
#   'images': [{'height': 640,
#               'url': 'https://i.scdn.co/image/602102500b9cebde7559a5f9c16daaaef2846440',
#               'width': 640},
#              {'height': 300,
#               'url': 'https://i.scdn.co/image/1ee2055a078d87a5a55366189409b9e1d820972a',
#               'width': 300},
#              {'height': 64,
#               'url': 'https://i.scdn.co/image/7afb855c28a2c8ad5ed9d51460736f4022e60bbf',
#               'width': 64}],
#   'label': 'XL Recordings/Columbia',
#   'name': '25',
#   'popularity': 80,
#   'release_date': '2016-06-24',
#   'release_date_precision': 'day',
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/0K4pIOOsfJ9lK8OjrZfXzd/tracks?offset=0&limit=50',
#              'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 295493,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/4sPmO7WMQUAf45kwMOtONw'},
#                         'href': 'https://api.spotify.com/v1/tracks/4sPmO7WMQUAf45kwMOtONw',
#                         'id': '4sPmO7WMQUAf45kwMOtONw',
#                         'is_local': False,
#                         'name': 'Hello',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/0b90429fd554bad6785faa2b8931d613db4a0ee4?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 1,
#                         'type': 'track',
#                         'uri': 'spotify:track:4sPmO7WMQUAf45kwMOtONw'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 223080,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/4BHzQ9C00ceJxfG16AlNWb'},
#                         'href': 'https://api.spotify.com/v1/tracks/4BHzQ9C00ceJxfG16AlNWb',
#                         'id': '4BHzQ9C00ceJxfG16AlNWb',
#                         'is_local': False,
#                         'name': 'Send My Love (To Your New Lover)',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/2f7c4f6de9f5a25ed2d59d353c62a06c2ac57c96?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 2,
#                         'type': 'track',
#                         'uri': 'spotify:track:4BHzQ9C00ceJxfG16AlNWb'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 348626,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/0QLXkoV7vX86QEibgLe6zQ'},
#                         'href': 'https://api.spotify.com/v1/tracks/0QLXkoV7vX86QEibgLe6zQ',
#                         'id': '0QLXkoV7vX86QEibgLe6zQ',
#                         'is_local': False,
#                         'name': 'I Miss You',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/078f747618e5be9283aa59ee94ba013206400abe?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 3,
#                         'type': 'track',
#                         'uri': 'spotify:track:0QLXkoV7vX86QEibgLe6zQ'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 290906,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/7IWkJwX9C0J7tHurTD7ViL'},
#                         'href': 'https://api.spotify.com/v1/tracks/7IWkJwX9C0J7tHurTD7ViL',
#                         'id': '7IWkJwX9C0J7tHurTD7ViL',
#                         'is_local': False,
#                         'name': 'When We Were Young',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/659a35907dfd65e8da36b1f9129415b749eda99f?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 4,
#                         'type': 'track',
#                         'uri': 'spotify:track:7IWkJwX9C0J7tHurTD7ViL'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 245426,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/7GgQi7JTG4b6J4iEF4RTjF'},
#                         'href': 'https://api.spotify.com/v1/tracks/7GgQi7JTG4b6J4iEF4RTjF',
#                         'id': '7GgQi7JTG4b6J4iEF4RTjF',
#                         'is_local': False,
#                         'name': 'Remedy',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/955d1d2aa1654fc6d385441a6dc2e3ede4456fff?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 5,
#                         'type': 'track',
#                         'uri': 'spotify:track:7GgQi7JTG4b6J4iEF4RTjF'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 240426,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/4vb4mFvYsr2h6enhjJsq9Y'},
#                         'href': 'https://api.spotify.com/v1/tracks/4vb4mFvYsr2h6enhjJsq9Y',
#                         'id': '4vb4mFvYsr2h6enhjJsq9Y',
#                         'is_local': False,
#                         'name': 'Water Under the Bridge',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/e8dcd070b5696c2ebe823644c543ed48e68ec6dd?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 6,
#                         'type': 'track',
#                         'uri': 'spotify:track:4vb4mFvYsr2h6enhjJsq9Y'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 225426,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/60jkAyuEyOnQKlrppOTYYx'},
#                         'href': 'https://api.spotify.com/v1/tracks/60jkAyuEyOnQKlrppOTYYx',
#                         'id': '60jkAyuEyOnQKlrppOTYYx',
#                         'is_local': False,
#                         'name': 'River Lea',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/4fac91f9db67c1d7289ab98d42596caa5000196a?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 7,
#                         'type': 'track',
#                         'uri': 'spotify:track:60jkAyuEyOnQKlrppOTYYx'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 285946,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/6oQRvWaoFDJpTTnaWdzhXt'},
#                         'href': 'https://api.spotify.com/v1/tracks/6oQRvWaoFDJpTTnaWdzhXt',
#                         'id': '6oQRvWaoFDJpTTnaWdzhXt',
#                         'is_local': False,
#                         'name': 'Love in the Dark',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/50ab715b08a4ed5e9c5e6cbc941f7c17b5888712?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 8,
#                         'type': 'track',
#                         'uri': 'spotify:track:6oQRvWaoFDJpTTnaWdzhXt'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 227066,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/5VwSwu1zeiMGAjwe9nUmzZ'},
#                         'href': 'https://api.spotify.com/v1/tracks/5VwSwu1zeiMGAjwe9nUmzZ',
#                         'id': '5VwSwu1zeiMGAjwe9nUmzZ',
#                         'is_local': False,
#                         'name': 'Million Years Ago',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/fe7aaa6467ecb77d624e39c7c0219ff4e30c07fe?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 9,
#                         'type': 'track',
#                         'uri': 'spotify:track:5VwSwu1zeiMGAjwe9nUmzZ'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 271800,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/1wMALZpuqAy7amQsFBWQ8m'},
#                         'href': 'https://api.spotify.com/v1/tracks/1wMALZpuqAy7amQsFBWQ8m',
#                         'id': '1wMALZpuqAy7amQsFBWQ8m',
#                         'is_local': False,
#                         'name': 'All I Ask',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/ea4a13058c5cd0d75af633b6ed8107412b07c94d?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 10,
#                         'type': 'track',
#                         'uri': 'spotify:track:1wMALZpuqAy7amQsFBWQ8m'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AR',
#                                               'BO',
#                                               'BR',
#                                               'CL',
#                                               'CO',
#                                               'CR',
#                                               'DO',
#                                               'EC',
#                                               'GT',
#                                               'HN',
#                                               'MX',
#                                               'NI',
#                                               'PA',
#                                               'PE',
#                                               'PY',
#                                               'SV',
#                                               'US',
#                                               'UY'],
#                         'disc_number': 1,
#                         'duration_ms': 251693,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/7nY8TY0Wk7kBIJi2Zv8JoR'},
#                         'href': 'https://api.spotify.com/v1/tracks/7nY8TY0Wk7kBIJi2Zv8JoR',
#                         'id': '7nY8TY0Wk7kBIJi2Zv8JoR',
#                         'is_local': False,
#                         'name': 'Sweetest Devotion',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/7cc5cbd73063172aea6a04d0a8196cce9b1d3e8f?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 11,
#                         'type': 'track',
#                         'uri': 'spotify:track:7nY8TY0Wk7kBIJi2Zv8JoR'}],
#              'limit': 50,
#              'next': None,
#              'offset': 0,
#              'previous': None,
#              'total': 11},
#   'type': 'album',
#   'uri': 'spotify:album:0K4pIOOsfJ9lK8OjrZfXzd'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                'id': '4dpARuHxo51G3z768sgnrY',
#                'name': 'Adele',
#                'type': 'artist',
#                'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#   'available_markets': ['AD',
#                         'AT',
#                         'AU',
#                         'BE',
#                         'BG',
#                         'CA',
#                         'CH',
#                         'CY',
#                         'CZ',
#                         'DE',
#                         'DK',
#                         'EE',
#                         'ES',
#                         'FI',
#                         'FR',
#                         'GB',
#                         'GR',
#                         'HK',
#                         'HU',
#                         'ID',
#                         'IE',
#                         'IL',
#                         'IS',
#                         'IT',
#                         'JP',
#                         'LI',
#                         'LT',
#                         'LU',
#                         'LV',
#                         'MC',
#                         'MT',
#                         'MY',
#                         'NL',
#                         'NO',
#                         'NZ',
#                         'PH',
#                         'PL',
#                         'PT',
#                         'RO',
#                         'SE',
#                         'SG',
#                         'SK',
#                         'TH',
#                         'TR',
#                         'TW',
#                         'VN',
#                         'ZA'],
#   'copyrights': [{'text': '2015 XL Recordings Limited.', 'type': 'C'},
#                  {'text': '2015 XL Recordings Limited.', 'type': 'P'}],
#   'external_ids': {'upc': '634904074067'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7uwTHXmFa1Ebi5flqBosig'},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/albums/7uwTHXmFa1Ebi5flqBosig',
#   'id': '7uwTHXmFa1Ebi5flqBosig',
#   'images': [{'height': 640,
#               'url': 'https://i.scdn.co/image/c018e59487df998eb8587d312b0b3233fdeff0fc',
#               'width': 640},
#              {'height': 300,
#               'url': 'https://i.scdn.co/image/5fcea2eb9b4735d28ca058d65bf1ded516eb46c8',
#               'width': 300},
#              {'height': 64,
#               'url': 'https://i.scdn.co/image/ed960c43f1681e40bef38a03cde02a36bd6af791',
#               'width': 64}],
#   'label': 'XL Recordings',
#   'name': '25',
#   'popularity': 82,
#   'release_date': '2015-11-20',
#   'release_date_precision': 'day',
#   'tracks': {'href': 'https://api.spotify.com/v1/albums/7uwTHXmFa1Ebi5flqBosig/tracks?offset=0&limit=50',
#              'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 295502,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/4aebBr4JAihzJQR0CiIZJv'},
#                         'href': 'https://api.spotify.com/v1/tracks/4aebBr4JAihzJQR0CiIZJv',
#                         'id': '4aebBr4JAihzJQR0CiIZJv',
#                         'is_local': False,
#                         'name': 'Hello',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/4ab65f9b193ccc37f2059344322462ae5e9dac90?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 1,
#                         'type': 'track',
#                         'uri': 'spotify:track:4aebBr4JAihzJQR0CiIZJv'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 223078,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/3KZcrZ36LW9RnChK1iIkth'},
#                         'href': 'https://api.spotify.com/v1/tracks/3KZcrZ36LW9RnChK1iIkth',
#                         'id': '3KZcrZ36LW9RnChK1iIkth',
#                         'is_local': False,
#                         'name': 'Send My Love (To Your New Lover)',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/bd2259812eb53138a906ab6d746d8f36ca5b942f?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 2,
#                         'type': 'track',
#                         'uri': 'spotify:track:3KZcrZ36LW9RnChK1iIkth'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 348625,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/1YjnEtzEg7D1wwQFhO30Gp'},
#                         'href': 'https://api.spotify.com/v1/tracks/1YjnEtzEg7D1wwQFhO30Gp',
#                         'id': '1YjnEtzEg7D1wwQFhO30Gp',
#                         'is_local': False,
#                         'name': 'I Miss You',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/b1ce472f0ad7061a6c6e293d4058a81fe889d6fe?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 3,
#                         'type': 'track',
#                         'uri': 'spotify:track:1YjnEtzEg7D1wwQFhO30Gp'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 290900,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/0cj2joJcY6b4XSRfj2eZOl'},
#                         'href': 'https://api.spotify.com/v1/tracks/0cj2joJcY6b4XSRfj2eZOl',
#                         'id': '0cj2joJcY6b4XSRfj2eZOl',
#                         'is_local': False,
#                         'name': 'When We Were Young',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/9e8d8e863296a285dac732a697f30491adc4f759?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 4,
#                         'type': 'track',
#                         'uri': 'spotify:track:0cj2joJcY6b4XSRfj2eZOl'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 245426,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/6CGf2aPvKj7497cZ6JMmGT'},
#                         'href': 'https://api.spotify.com/v1/tracks/6CGf2aPvKj7497cZ6JMmGT',
#                         'id': '6CGf2aPvKj7497cZ6JMmGT',
#                         'is_local': False,
#                         'name': 'Remedy',
# ...
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 197346,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/0hcqzsEGHnI40ZYMSHs6JL'},
#                         'href': 'https://api.spotify.com/v1/tracks/0hcqzsEGHnI40ZYMSHs6JL',
#                         'id': '0hcqzsEGHnI40ZYMSHs6JL',
#                         'is_local': False,
#                         'name': 'Right As Rain',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/7dbc84ab977ee679a801626bdb34dd28d40c8204?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 8,
#                         'type': 'track',
#                         'uri': 'spotify:track:0hcqzsEGHnI40ZYMSHs6JL'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 212040,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/0UUj67n9HUbrFcV0IMMXhl'},
#                         'href': 'https://api.spotify.com/v1/tracks/0UUj67n9HUbrFcV0IMMXhl',
#                         'id': '0UUj67n9HUbrFcV0IMMXhl',
#                         'is_local': False,
#                         'name': 'Make You Feel My Love',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/5b3bfc4c3b98df595f623e86bc0296016030ce20?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 9,
#                         'type': 'track',
#                         'uri': 'spotify:track:0UUj67n9HUbrFcV0IMMXhl'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 195653,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/1wxmMXCUJk4JJn8TSrdfuI'},
#                         'href': 'https://api.spotify.com/v1/tracks/1wxmMXCUJk4JJn8TSrdfuI',
#                         'id': '1wxmMXCUJk4JJn8TSrdfuI',
#                         'is_local': False,
#                         'name': 'My Same',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/71424611dd4bc8b046a449a43043da2efaa762f5?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 10,
#                         'type': 'track',
#                         'uri': 'spotify:track:1wxmMXCUJk4JJn8TSrdfuI'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 258853,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/3Tq8j1W18svDctcuQb8ExO'},
#                         'href': 'https://api.spotify.com/v1/tracks/3Tq8j1W18svDctcuQb8ExO',
#                         'id': '3Tq8j1W18svDctcuQb8ExO',
#                         'is_local': False,
#                         'name': 'Tired',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/fc035e9d7ac3cf5d65c4a526061bdf385e17b5cb?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 11,
#                         'type': 'track',
#                         'uri': 'spotify:track:3Tq8j1W18svDctcuQb8ExO'},
#                        {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                      'id': '4dpARuHxo51G3z768sgnrY',
#                                      'name': 'Adele',
#                                      'type': 'artist',
#                                      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                         'available_markets': ['AD',
#                                               'AT',
#                                               'AU',
#                                               'BE',
#                                               'BG',
#                                               'CA',
#                                               'CH',
#                                               'CY',
#                                               'CZ',
#                                               'DE',
#                                               'DK',
#                                               'EE',
#                                               'ES',
#                                               'FI',
#                                               'FR',
#                                               'GB',
#                                               'GR',
#                                               'HK',
#                                               'HU',
#                                               'ID',
#                                               'IE',
#                                               'IL',
#                                               'IS',
#                                               'IT',
#                                               'JP',
#                                               'LI',
#                                               'LT',
#                                               'LU',
#                                               'LV',
#                                               'MC',
#                                               'MT',
#                                               'MY',
#                                               'NL',
#                                               'NO',
#                                               'NZ',
#                                               'PH',
#                                               'PL',
#                                               'PT',
#                                               'RO',
#                                               'SE',
#                                               'SG',
#                                               'SK',
#                                               'TH',
#                                               'TR',
#                                               'TW',
#                                               'VN',
#                                               'ZA'],
#                         'disc_number': 1,
#                         'duration_ms': 271226,
#                         'explicit': False,
#                         'external_urls': {'spotify': 'https://open.spotify.com/track/27sNm0wZGtS9tNeRwYfKV6'},
#                         'href': 'https://api.spotify.com/v1/tracks/27sNm0wZGtS9tNeRwYfKV6',
#                         'id': '27sNm0wZGtS9tNeRwYfKV6',
#                         'is_local': False,
#                         'name': 'Hometown Glory',
#                         'preview_url': 'https://p.scdn.co/mp3-preview/498da426d7a20aaa6bb0d40cb3a88a168e3349c2?cid=c84d10ac23bd4a5a97699ce4b07fa405',
#                         'track_number': 12,
#                         'type': 'track',
#                         'uri': 'spotify:track:27sNm0wZGtS9tNeRwYfKV6'}],
#              'limit': 50,
#              'next': None,
#              'offset': 0,
#              'previous': None,
#              'total': 12},
#   'type': 'album',
#   'uri': 'spotify:album:53Abz0nslwIN4WAvUzuI0E'}]

# %% [markdown]
# According to our current specifications, Adele has 11 actual albums in Spotify. The sp.album method also gave us more information from Spotify's database on the albums. We can start making some conclusions regarding an artist's popularity.
#
# In our next function, we'll format our information with graphs in mind. get_release_popularity will thus take the list of albums we have just found and output a tuple of sorted dates, associated popularities, and album names. Since the release_date is a string in the Spotify database, we need the builtin datetime module so that we can convert the string into a datetime. This will help with formatting the axis when we plot against time.
#
# We also need to filter some dates out. An album's release_date can actually contain more or less information than year-month-date. Some contain only years or may contain specific times. Fortunately, there is also a field called release_date_precision, telling us how precise the release_date. Our function needs to case on this as well and only allows albums with a precision of 'day' to be processed.

# %%
from datetime import datetime

def get_release_popularity(albums):
    '''This function takes in a list of albums and returns a tuple of sorted dates, associated popularities, and album names
    
    Input: albums (album list)
    
    Output: dates, popularities, names (datetime list, int list, str lst)
    '''
    
    result = dict()
    for album in albums:
        if album['release_date_precision'] == "day":
            date = datetime.strptime(album['release_date'], "%Y-%m-%d")
            pop = album['popularity']
            name = album['name']
            if ((date in result and pop > result[date][0]) or 
                date not in result):
                result[date] = [pop,name]

    dates = []
    pops = []
    names = []
    keys = sorted(result.keys())
    for key in keys:
        dates.append(key)
        pops.append(result[key][0])
        names.append(result[key][1])
    return (dates, pops, names)

# %% [markdown]
# If multiple albums are released on the same day, we will take the one with the greatest popularity. Thus we can see how an artist's maximum popularity appears throughout the years.
#
# Great! Now we can run some tests on Adele again.

# %%
a, b, c = get_release_popularity(adele)
print(a)
print(b)
print(c)
# Out:
# [datetime.datetime(2008, 1, 28, 0, 0), datetime.datetime(2011, 1, 19, 0, 0), datetime.datetime(2015, 11, 20, 0, 0), datetime.datetime(2016, 6, 24, 0, 0)]
# [77, 81, 82, 80]
# ['19', '21', '25', '25']

# %% [markdown]
# It appears as though Adele has only released 3 albums total. A quick Google search confirms this fact. Hm. It appears as though we have a repeat for her album '25'. Since the release dates are different, Spotify considers them two separate entities. For now, we'll leave this as be, but it's good to take note of this for future consideration.

# %% [markdown]
# ## Plotting
# Now that we can process the data, we can move onto visualizing it. [Bokeh](https://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html) is a fantastic tool for making line graphs, scatter graphs, geospatial maps, bar graphs, and any other type of data visualization you can imagine! To be honest, it's not that well documented, but it certainly produces better graphs than matplotlib. Or at least more ~aesthetic~ graphs. No offense.
#
# Since we're trying to track the popularity of artists over time, we'll be working mainly with line graphs. Bokeh also allows us to add certain features to a graph, such as a HoverTool or a zoom feature. These tools can be found on the sidebar of a graph. Albeit minor, these small flares engage users by encouraging them to interact with the graphics.
#
# As we saw from the Adele example, we're not working with too many points. Artists produce less than we anticipated. Thus, we'll start with a simple line graph and see how we can build it up from there.
#
# First, we need to import all of our required libraries. For some fancy formatting, we'll include math as well.

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.models import DatetimeTickFormatter, ColumnDataSource, HoverTool
import math

# %% [markdown]
# ## Putting it all Together
# As mentioned above, bokeh lets users interact with the HTML graphs generated. We'll start off by creating the graphs first before adding any type of interactions. Bokeh automatically saves the graphs generated in a file to the filename.html if the output is not specified to be saved under a different HTML filename. We'll let this happen for now since we'll only be working with a single graph.
#
# Before we can do any graphing, we first need to create a figure of a specified width and height. We also want some tools to be included in the toolbar so we'll initialize them as well as different colors for various lines on the graph.

# %%
output_file("test_file.html") #<--if we wanted to save it to a specific file name

TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,save"

p = figure(plot_width = 700, plot_height = 350, 
           title = "Popularity of Artists Over the Years", tools = TOOLS)

COLORS = ["red", "orange", "green", "blue", "purple"]

# %% [markdown]
# Now we can start gathering data and adding lines to our graph. Putting together our get_artist_albums and get_release_popularity, we can finally plot the dates and popularities list resulting from our functions. A bokeh figure can take lists directly, but we want to pass in an album name as well to the graph. So we'll use the [ColumnDataSource](https://bokeh.pydata.org/en/latest/docs/reference/models/sources.html) provided by bokeh to process a dictionary of our inputs. ColumnDataSource actually maps the names of the columns (or keys in the dictionary) to the columns. Thus calling the name of the column is equivalent to calling the data associated. For our purposes, this functionality isn't very helpful. However, if we were working with a large quantity of data, such as a CSV-imported pandas dataFrame, then we could just apply ColumnDataSource onto the dataframe to map each column name to its values. We'll only be using ColumnDataSource so we have an easier way of referencing album names.
#
# ColumnDataSource comes with its own set of problems such as the fact that we cannot put lists of different lengths in the data dictionary. We cannot include an entry for artists names or colors since those lists would be much shorter than the lists holding album information. We'll actually be looping through all the artists anyways, so we can use this index to get artist names from the OG artist_names list and the line color from the color list we just defined.
#
# We're also going to add a legend of all the artist names by using the lists not included in the data dictionary.

# %%
for i in range(len(artists)):
    albums = get_artist_albums(artists[i])
    d, pop, n = get_release_popularity(albums)

    #generates column data
    data = {'date':d,
            'popularity':pop,
            'name':n,
           }
    source = ColumnDataSource(data=data)

    p.line(x = 'date', y = 'popularity', source = source, 
           legend=artist_names[i], color=COLORS[i])

# %% [markdown]
# This function might take a while. We're doing a lot of iterative steps, looping through each artist to find all their albums, filtering them, and formatting all the information.
#
# Afterwards, we can start formatting our graph. Since we went through the trouble of converting all those date strings to datetime, we want to flaunt our datetime abilities. We can do this by formatting our x-axis with another bokeh builtin called DatetimeTickFormatter. And just to add some more flair, we'll format the labels so they're angled rather than flat (this is where the math comes in).
#
# <img src="meme.jpg" style="height:273px">
#
# Let's add some axis labels to our graph and place our legend so it doesn't overlap with too much data. By default, the legend appears in the top right corner. However this covers a lot of important data since we're interested in how the popularity of each artist has changed. Thus we will relocate the legend. We can also add click_policies to the legend such as "hide" or "mute". These policies allow us to click on the legend label and change the graph by hiding or muting that line.

# %%
p.xaxis.formatter=DatetimeTickFormatter()
p.xaxis.major_label_orientation = math.pi/4
p.grid.grid_line_alpha=0.3

p.xaxis.axis_label = 'Year'
p.yaxis.axis_label = 'Popularity'

p.legend.location = "top_left"
p.legend.click_policy= "hide"

# %% [markdown]
# Finally, we'll add our last touch of dynacism. We'll add a HoverTool to our graph that follows our mouse and shows the album name, release date, and popularity associated with a point. Here's where calling ColumnDataSource comes in handy. We can just reference each column with an @ symbol and bokeh will understand that these values should be replaced with the name, date, and popularity at that point. We also need to format our datetime again, so we'll add a formatter feature to our HoverTool.

# %%
hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    ("Album Name", "@name"),
    ("Release Date", "@date{%F}"),
    ("Popularity", "@popularity")
]
hover.formatters = {'date':'datetime'}

show(p)

# %% [markdown]
# Jupyter notebook interprets the show figure call at the bottom of our code by generating the graph in a temporary HTML file in a new tab. Our completed graph should look something like this:

# %%
from IPython.display import IFrame
IFrame('test_file.html', 750, 400)
# Out:
#         <iframe
#             width="750"
#             height="400"
#             src="test_file.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# As we can see, our graph contains all of the features we had hoped to achieve: overlapping lines, an interactive legend, hover features, and a tool bar! Now we can look at the visualization to make conclusions about the artists. Here are some conclusions and subsequent questions we can raise from our results:
#
# - Artist popularity can fluctuate a lot from album to album.
# - It appears that most artists experienced a dip in popularity around 2015.
# - Adele has remained at constant popularity, around 80.
# - Ed Sheeran appears to be the most popular overall, especially with his latest album divide.
# - Taylor Swift, contrary to popular belief, has experienced increasing popularity after her transition from country to pop. Although she may be an online joke, she's definitely doing well enough in her actual field to not give a f***.
# - Maroon 5 is the longest in production, and has stayed relatively popular throughout.
#
# ## Concluding Thoughts
# Bokeh allows us to create interesting visualizations of our data. In addition to its additional features, bokeh also allows for even more dynacism with custom javascript callbacks. For a more robust data set with greater dependencies, we could've added a widget like a slider or text input box or selection tool that would actively change the data set of the graph to reflect these changes. However, since our data is not dependent on any variables other than already existing information, callbacks are not relevant and not covered in this tutorial.
#
# Ultimately, data visualization allows us to formulate some interesting conclusions to pertinent inquiries.

# %% [markdown]
# ### References
# This tutorial only provides partial insight into API accessing and bokeh. More details about the Spotify API, spotipy, and bokeh can be found at the links below:
# - [Spotify API](https://beta.developer.spotify.com/documentation/web-api/)
# - [spotipy- Spotify python wrapper](http://spotipy.readthedocs.io/en/latest/)
# - [bokeh homepage](https://bokeh.pydata.org/en/latest/)
# - [bokeh callbacks](https://bokeh.pydata.org/en/latest/docs/user_guide/interaction.html)
# - [Importance of Data Visualization](https://www.sas.com/en_us/insights/big-data/data-visualization.html)
