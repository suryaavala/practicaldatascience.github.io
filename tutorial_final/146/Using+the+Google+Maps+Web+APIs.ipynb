# %% [markdown]
# # Getting Started
#
# Before you can use any Google API you will need to get an API Key with the relevant APIs enabled
# - Go to https://console.cloud.google.com and log into your Google account
# - Click on "Create Project", select a suitable name for your project
# - From the left side menu, select "Credentials -> Create Credentials -> API Key
# - A new API Key will be generated for your project. Copy it for later use and close the popup window.
# - To be able to use APIs against this key, go to 'Library' in the left side menu. Search for the relevant APIs, select each and click "Enable"
# - For this tutorial, we will be using the "Google Maps Directions API", "Google Maps Distance Matrix API","Google Maps Geocoding API", "Google Places API Web Service", "Google Maps Time Zone API" and "Google Maps Elevation API"
# - Once all these APIs are enabled, any API Keys generated for this project can be used for access.
# - The dashboard can be used to monitor the traffic, errors and latency for API requests made using the API keys.
# - Note that the GoogleMaps API has an upper  limit of 2500 free requests per day and 50 requests per second.

# %%
# importing the googlemaps library and setting up the client with the API key
import googlemaps
import time                                # time.sleep() is required to avoid exceeding the API request rate
gmaps = googlemaps.Client(key="Insert your API KEY Here")

# %% [markdown]
# # Using the Geocoding API
#
#
# The geocoding and reverse geocoding API requests have the following format:
# - *reverse_geocode_result=gmaps.reverse_geocode((lat,long tuple))* and
# - *gmaps.geocode("location_address")*.
#
# Note that the reverse geocoder often returns more than one responses. The first result is the street address while the latter ones refer to larger administrative units i.e city, state, country that the location lies in.
# For most purposes, the first result is useful since it has the highest level of granularity.
#
# Each response returned is in the form of a dictionary having the following keys: 'address_components','formatted_address','geometry','place_id','types'

# %%
# using geocode and reverse_geocode
m='40.714224'
n='-73.961452'
reverse_geocode_result = gmaps.reverse_geocode((m,n))
print(reverse_geocode_result[0])
print(gmaps.geocode('277 Bedford Ave, Brooklyn, NY 11211, USA'))
# Out:
# {'address_components': [{'long_name': '277', 'short_name': '277', 'types': ['street_number']}, {'long_name': 'Bedford Avenue', 'short_name': 'Bedford Ave', 'types': ['route']}, {'long_name': 'Williamsburg', 'short_name': 'Williamsburg', 'types': ['neighborhood', 'political']}, {'long_name': 'Brooklyn', 'short_name': 'Brooklyn', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Kings County', 'short_name': 'Kings County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '11211', 'short_name': '11211', 'types': ['postal_code']}], 'formatted_address': '277 Bedford Ave, Brooklyn, NY 11211, USA', 'geometry': {'location': {'lat': 40.7142205, 'lng': -73.9612903}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.71556948029149, 'lng': -73.95994131970849}, 'southwest': {'lat': 40.7128715197085, 'lng': -73.9626392802915}}}, 'place_id': 'ChIJd8BlQ2BZwokRAFUEcm_qrcA', 'types': ['street_address']}
# [{'address_components': [{'long_name': '277', 'short_name': '277', 'types': ['street_number']}, {'long_name': 'Bedford Avenue', 'short_name': 'Bedford Ave', 'types': ['route']}, {'long_name': 'Williamsburg', 'short_name': 'Williamsburg', 'types': ['neighborhood', 'political']}, {'long_name': 'Brooklyn', 'short_name': 'Brooklyn', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Kings County', 'short_name': 'Kings County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '11211', 'short_name': '11211', 'types': ['postal_code']}], 'formatted_address': '277 Bedford Ave, Brooklyn, NY 11211, USA', 'geometry': {'location': {'lat': 40.7142205, 'lng': -73.9612903}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.71556948029149, 'lng': -73.95994131970849}, 'southwest': {'lat': 40.7128715197085, 'lng': -73.9626392802915}}}, 'place_id': 'ChIJd8BlQ2BZwokRAFUEcm_qrcA', 'types': ['street_address']}]

# %% [markdown]
# # Using the Directions API and the Distance matrix
#
# The function calls have the following format : *gmap.directions(origin, destination)* and
#                                                *gmap.distance_matrix(origin, destination)*.
# The origin and destination can be specified as addresses or as longitude, latitude pairs.
#
# The function call can also be customized by adding a few extra parameters:
# - departure_time
# - arrival_time
# - mode (Can have the following values : 'driving', 'bicycling', 'transit' or 'walking'. Driving is the default option.)
# - units (By default, the unit is determined by the country of origin. Can have the following values: 'metric' and 'imperial')
# - avoid (Can have the following values: "highways","ferries" and "tolls")
# - transit_routing_preference (Can have the following values: "less_walking","fewer_transfers")
# - traffic_model (Can have the following values: "optimistic","pessimistic","best_guess.
#
# #### Response from the direction API
#
# The result object is a dictionary with the following keys:
# bounds,
# copyrights,
# legs,
# overview_polyline,
# summary,
# warnings,
# waypoint_order.
#
# Our field of interest is 'legs' which itself is a dictionary with the following keys:
# distance (the total distance in km of the selected route),
# duration (total duration in hours of the selected route),
# end_address,
# end_location,
# start_address,
# start_location,
# steps (an array containing separate dictionaries containing details of each leg of the journey)
#
# #### Response from the distance_matrix
#
# The result object is a dictionary with the following keys:
# destination_addresses,
# origin_addresses,
# rows (contains the distance and duration as text as well as values (in meters and seconds respectively)),
# status

# %%
#Using the directions API 
directions_result = gmaps.directions("5000 Forbes Ave, Pittsburgh, PA ","1901 Murray Avenue",mode='transit',
                                     departure_time=datetime.datetime.strptime('4/30/2018 03:50',"%m/%d/%Y %H:%M"), 
                                     units='metric')

#List of keys in the result dict 
for i in directions_result[0]:
    print(i)
# the list of 'legs' in the result dict 
for i in directions_result[0]['legs'][0]:
    print(i,directions_result[0]['legs'][0][i],"\n")
# cleaning up the 'steps' for obtaining directions  
for i in directions_result[0]['legs'][0]['steps']:
    print(i)
    print(i['distance'],i['duration'],i['html_instructions'],"\n")

#print(directions_result)
# Out:
# bounds
# copyrights
# legs
# overview_polyline
# summary
# warnings
# waypoint_order
# distance {'text': '2.3 km', 'value': 2346}
#
# duration {'text': '31 mins', 'value': 1876}
#
# end_address 1901 Murray Ave, Pittsburgh, PA 15217, USA
#
# end_location {'lat': 40.43572380000001, 'lng': -79.9228653}
#
# start_address Warner Hall, 5000 Forbes Ave, Pittsburgh, PA 15213, USA
#
# start_location {'lat': 40.4446439, 'lng': -79.9433543}
#
# steps [{'distance': {'text': '2.3 km', 'value': 2346}, 'duration': {'text': '31 mins', 'value': 1876}, 'end_location': {'lat': 40.43572380000001, 'lng': -79.9228653}, 'html_instructions': 'Walk to 1901 Murray Ave, Pittsburgh, PA 15217, USA', 'polyline': {'points': '_jzuF|||fN?G?i@@S@UJoALmABO@OHq@@K@MHw@@KB_@Fg@Fm@j@_GLmAF]BIDITUTUr@o@TUl@i@jAcAzCqC`CuBfA_A|@y@`@_@`CwBdD}Cr@s@bAy@jAeAHKFIFIBI@EBG@I?G@G?O?O?EW{Jg@uQC}BA_B@}K?iA?eC@iBtEI|DG|@A'}, 'start_location': {'lat': 40.4446439, 'lng': -79.9433543}, 'steps': [{'distance': {'text': '2.1 km', 'value': 2087}, 'duration': {'text': '28 mins', 'value': 1680}, 'end_location': {'lat': 40.4380545, 'lng': -79.922969}, 'html_instructions': 'Head <b>east</b> on <b>Forbes Ave</b> toward <b>Morewood Ave</b>', 'polyline': {'points': '_jzuF|||fN?G?i@@S@UJoALmABO@OHq@@K@MHw@@KB_@Fg@Fm@j@_GLmAF]BIDITUTUr@o@TUl@i@jAcAzCqC`CuBfA_A|@y@`@_@`CwBdD}Cr@s@bAy@jAeAHKFIFIBI@EBG@I?G@G?O?O?EW{Jg@uQC}BA_B@}K?iA?eC@iB'}, 'start_location': {'lat': 40.4446439, 'lng': -79.9433543}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 259}, 'duration': {'text': '3 mins', 'value': 196}, 'end_location': {'lat': 40.43572380000001, 'lng': -79.9228653}, 'html_instructions': 'Turn <b>right</b> onto <b>Murray Ave</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-right', 'polyline': {'points': 'y`yuFp}xfNtEI|DG|@A'}, 'start_location': {'lat': 40.4380545, 'lng': -79.922969}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}]
#
# traffic_speed_entry []
#
# via_waypoint []
#
# {'distance': {'text': '2.3 km', 'value': 2346}, 'duration': {'text': '31 mins', 'value': 1876}, 'end_location': {'lat': 40.43572380000001, 'lng': -79.9228653}, 'html_instructions': 'Walk to 1901 Murray Ave, Pittsburgh, PA 15217, USA', 'polyline': {'points': '_jzuF|||fN?G?i@@S@UJoALmABO@OHq@@K@MHw@@KB_@Fg@Fm@j@_GLmAF]BIDITUTUr@o@TUl@i@jAcAzCqC`CuBfA_A|@y@`@_@`CwBdD}Cr@s@bAy@jAeAHKFIFIBI@EBG@I?G@G?O?O?EW{Jg@uQC}BA_B@}K?iA?eC@iBtEI|DG|@A'}, 'start_location': {'lat': 40.4446439, 'lng': -79.9433543}, 'steps': [{'distance': {'text': '2.1 km', 'value': 2087}, 'duration': {'text': '28 mins', 'value': 1680}, 'end_location': {'lat': 40.4380545, 'lng': -79.922969}, 'html_instructions': 'Head <b>east</b> on <b>Forbes Ave</b> toward <b>Morewood Ave</b>', 'polyline': {'points': '_jzuF|||fN?G?i@@S@UJoALmABO@OHq@@K@MHw@@KB_@Fg@Fm@j@_GLmAF]BIDITUTUr@o@TUl@i@jAcAzCqC`CuBfA_A|@y@`@_@`CwBdD}Cr@s@bAy@jAeAHKFIFIBI@EBG@I?G@G?O?O?EW{Jg@uQC}BA_B@}K?iA?eC@iB'}, 'start_location': {'lat': 40.4446439, 'lng': -79.9433543}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 259}, 'duration': {'text': '3 mins', 'value': 196}, 'end_location': {'lat': 40.43572380000001, 'lng': -79.9228653}, 'html_instructions': 'Turn <b>right</b> onto <b>Murray Ave</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-right', 'polyline': {'points': 'y`yuFp}xfNtEI|DG|@A'}, 'start_location': {'lat': 40.4380545, 'lng': -79.922969}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}
# {'text': '2.3 km', 'value': 2346} {'text': '31 mins', 'value': 1876} Walk to 1901 Murray Ave, Pittsburgh, PA 15217, USA

# %%
#Using the distance_matrix API
distance = gmaps.distance_matrix("4 Columbus Cir, New York, NY 10019, USA ","146 E 65th St, New York, NY 10065, USA",
                                 mode='bicycling',
                                 departure_time=datetime.datetime.strptime('4/30/2018 03:50',"%m/%d/%Y %H:%M"), 
                                     units='metric')
print(distance)

#Cleaning up the results 

print(distance['rows'][0]['elements'][0]['distance']['text'])
# Out:
# {'destination_addresses': ['146 E 65th St, New York, NY 10065, USA'], 'origin_addresses': ['4 Columbus Cir, New York, NY 10019, USA'], 'rows': [{'elements': [{'distance': {'text': '2.0 km', 'value': 1996}, 'duration': {'text': '10 mins', 'value': 577}, 'status': 'OK'}]}], 'status': 'OK'}
# 2.0 km

# %% [markdown]
# # Using the Google Places API Web Service
# - #### Nearby Search:
# The format of the API request for nearby search is *gmaps.places_nearby(location,radius,type )*
# The 'location' needs to be in the form of lat/long tuples.
# The 'radius' is specified in metres.
# The 'type' can include keywords from the following list: https://developers.google.com/places/web-service/supported_types
# Other options to customize the query include:
#     - rank_by (Values can be 'distance' or prominence'. If rank_by=distance, the radius cannot be specified in the query)
#     - max_price and min_price (Value can be a number from 0 to 4, 0 being least expensive)
#     - open_now (boolean variable)
#     - keyword (string query)
#
# The reponse of the query is a dictionary with the following keys : html_attributions, results, status and next_page_token.
# Our field of interest is the list of 'results' which is a list of places in the form of dictionaries.
# The maximum number of results that can be returned in a query is 60. If there are more than 20 results, a 'next_page_token' is included in the result dictionary. This can be used for further queries to extract upto the next 20 results for the same search settings. Note that the 'next_page_token' becomes valid after a short time delay of about 2-3 seconds after it's issued.
#
# - #### Text Search:
# The format of the API request is *gmaps.places(search_query)*
# The same options as those in nearby_search are available for the text search as well.
#
#
# - #### Place Details:
# Given a place id which is returned by the place search, the following request can be used for further details on the place:
# *gmaps.place(place_id). *
# The request response is a dictionary with the following details on the place:
# address_components,
# adr_address,
# formatted_address,
# formatted_phone_number,
# geometry,
# icon,
# id,
# international_phone_number,
# name,
# opening_hours,
# photos,
# place_id,
# rating,
# reference,
# reviews,
# types,
# url,
# utc_offset,
# vicinity,
# website.

# %%
#NEARBY SEARCH 1
#List of museums in squirrel hill
museums=gmaps.places_nearby((40.438072,-79.922972),radius=5000,type='museum')
museums_bydistance=gmaps.places_nearby((40.438072,-79.922972),type='museum',rank_by='distance')

# List of most affordable Halal restaurants in Squirrel Hill that are open now 
halal_open_rest=gmaps.places_nearby((40.438072,-79.922972),type='restaurant',rank_by='distance',open_now=1,max_price=1,keyword='halal')

print(halal_open_rest)
# Out:
# {'html_attributions': [], 'results': [{'geometry': {'location': {'lat': 40.4227057, 'lng': -79.88565799999999}, 'viewport': {'northeast': {'lat': 40.42395207989272, 'lng': -79.88446367010728}, 'southwest': {'lat': 40.42125242010728, 'lng': -79.88716332989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': '1123d9241fd4e967c865d4ce6802aa2abaf91a67', 'name': "Arby's", 'opening_hours': {'open_now': True, 'weekday_text': []}, 'photos': [{'height': 1080, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103605950787191922588/photos">Tom tre</a>'], 'photo_reference': 'CmRaAAAAYiPUGbvTl_-KbEqT-U13V-4sNucjqtDcLdXSzpvNMTISmaeT1lcJWedg1d0A2_gWNSUvLU0ubdzqsHTRY7vpAeGGBt46KQ8eEc1lTpkLWwZolanW37Ai94BqbxZyt1JqEhB6FO9wYMr3CHz69jPlWS7gGhRYJsxzV68hB9WzUYkuNaDW9hQFVg', 'width': 1920}], 'place_id': 'ChIJ54icYWXuNIgRdtwfcQa1cX0', 'price_level': 1, 'rating': 3.8, 'reference': 'CmRbAAAA_TB84WEGorE0MW4E3MeZ32i8Ptus35Td7CBxybbyDr1HzHYO73CCFV7uLi0Uj9cI0D5dX6YbKXU4Q7C4JoYFoClKg6bt7P02ToULiDPtFz8mc-Jl4HJtDxVoWB1r_5ReEhCOXoM9XFajMa4Qk5JhHOrIGhSdGQfetk0Rmk47tKCKpqC8EdcxKQ', 'scope': 'GOOGLE', 'types': ['restaurant', 'food', 'point_of_interest', 'establishment'], 'vicinity': '1911 S Braddock Ave, Swissvale'}], 'status': 'OK'}

# %%
#NEARBY SEARCH 2
#Cleaning up the results of the nearby search 
for i in (halal_open_rest['results']):
    print(i['name'],"Price level:",i['price_level'],"Rating:",i['rating'],"Address:",i['vicinity'])

print("Total results:" ,len(halal_open_rest['results']))
# Out:
# Arby's Price level: 1 Rating: 3.8 Address: 1911 S Braddock Ave, Swissvale
# Total results: 1

# %%
#NEARBY SEARCH 3
# using the next_page token to extract all results
museums_nearby=gmaps.places_nearby((40.438072,-79.922972),radius=5000,type='museum')
all_results=[]
yn=1
while yn==1:
    for i in museums_nearby['results']:
        all_results.append(i)
    if ('next_page_token' in museums_nearby.keys()):
        token=(museums_nearby['next_page_token'])
        time.sleep(2)                    # to allow for the time delay for token to become valid
        museums_nearby=gmaps.places_nearby((40.438072,-79.922972),radius=5000,type='museum',page_token=token)
    else:
        yn=0


for i in all_results:
    print(i['name'])
print("Total results:" ,len(all_results))
# Out:
# Carnegie Museum of Natural History
# Carnegie Museums of Pittsburgh
# Carnegie Museum of Art
# Soldiers & Sailors Memorial Hall & Museum
# The Frick Pittsburgh
# Rodef Shalom Congregation
# Kelso Bible Lands Museum
# Trundle Manor
# Hunt Institute
# Bost Building National Historic Landmark, HQ of the Rivers of Steel National Heritage Area
# Nationality Rooms and Intercultural Exchange Programs
# The Clemente Museum
# Maser Galleries
# Car and Carriage Museum
# Steel Industry Heritage Corporation.
# Andy Warhol Boyhood Home
# ALCO Parking
# Boom concepts
# Center for PostNatural History
# Worlds of Discovery
# Greenhouse
# Rodef American Jewish Museum
# Old Baltimore and Ohio Roundhouse
# Jesse Best Gallery
# The Wherehouse
# Ormsby Park
# Joan Shop + Studio
# Morrow Park
# Aquarium
# Total results: 29

# %%
# TEXT SEARCH 
halal_open=gmaps.places("cheapest halal restaurants in Pittsburgh open now")
halal_open_squirrelhill=gmaps.places("cheapest halal restaurants in Pittsburgh open now",location=(40.438072,-79.922972),radius=500)
for i in halal_open['results']:
    print(i['name'],"Rating:",i['rating'])
# Out:
# Kavsar Halal Restaurant Rating: 4.4
# Istanbul Sofra Rating: 4.9
# Dijlah Restaurant and Hookah Lounge Rating: 4.3
# Alihan's Mediterranean Cuisine Rating: 4.4
# Naya Cuisine Rating: 4.7
# Grandma B's Rating: 4.7
# Prince of India Restaurant Rating: 4
# McCormick & Schmick's Seafood & Steaks Rating: 3.8
# Ali Baba Restaurant Rating: 4
# All India Restaurant Rating: 4.2
# Taste of India Rating: 4.3
# Bangal Kabab House & Restaurant Rating: 4.1
# Salim's Middle Eastern Food Rating: 4.6
# Casbah Rating: 4.4
# Franktuary (Lawrenceville) Rating: 4.2
# Coriander India Grill Rating: 3.5
# Eddie Merlot's Prime Aged Beef and Seafood Pittsburgh Rating: 4.6
# Ruth's Chris Steak House Rating: 4.3
# Wings Over Pittsburgh Rating: 4
# People's Indian Restaurant Rating: 4.4

# %%
# PLACE DETAILS
for i in halal_open['results']:
    print(i['name'])
    details=gmaps.place(i['place_id'])
    #print(details['result'],"\n\n")
    for l in details['result']:
        if l not in ('photos','reference','address_components','adr_address','scope'):
            print(l, ":    ",details['result'][l])
    print("\n")
# Out:
# Kavsar Halal Restaurant
# formatted_address :     16 Southern Ave, Pittsburgh, PA 15211, USA
# formatted_phone_number :     (412) 488-8708
# geometry :     {'location': {'lat': 40.42892000000001, 'lng': -80.007446}, 'viewport': {'northeast': {'lat': 40.43020483029151, 'lng': -80.00607401970849}, 'southwest': {'lat': 40.42750686970851, 'lng': -80.0087719802915}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     d11765069425cab2318cc80bdd14008fe035e6b2
# international_phone_number :     +1 412-488-8708
# name :     Kavsar Halal Restaurant
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '2200'}, 'open': {'day': 0, 'time': '1100'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1200'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1200'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1200'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1200'}}, {'close': {'day': 5, 'time': '2300'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 6, 'time': '2300'}, 'open': {'day': 6, 'time': '1100'}}], 'weekday_text': ['Monday: 12:00 – 10:00 PM', 'Tuesday: 12:00 – 10:00 PM', 'Wednesday: 12:00 – 10:00 PM', 'Thursday: 12:00 – 10:00 PM', 'Friday: 11:00 AM – 11:00 PM', 'Saturday: 11:00 AM – 11:00 PM', 'Sunday: 11:00 AM – 10:00 PM']}
# place_id :     ChIJsZMZQkvxNIgRTT3U6FiRBx4
# rating :     4.4
# reviews :     [{'author_name': 'Gary Kalyn', 'author_url': 'https://www.google.com/maps/contrib/105351723404498907925/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-2sEjjCheywI/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWCdN1ldaCMbJYJMzyGOYOxXaa_uuA/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'I love the layout of this place. And the food is extremely well portioned. What a helpful group of people making this restaurant no longer just some random place I pass by on my way home from work and school. Thank you so much for helping me expand my horizons and for the great tasting food. God bless yinz.', 'time': 1518850789}, {'author_name': 'Heather Covington', 'author_url': 'https://www.google.com/maps/contrib/105984322633648240681/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-s0FE6RorMws/AAAAAAAAAAI/AAAAAAAADWs/dwL-c0IJ-nM/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 5, 'relative_time_description': 'in the last week', 'text': "They treat you like family here and the portions are huge so be prepared to take home leftovers. I didn't get the Borscht but everyone else in my party did (with beans and without) and I'll be ordering my or bowl next time. Mushroom & potato samsa was delicious and the signature beef dish was outstanding.", 'time': 1521906941}, {'author_name': 'Anton Charniauski', 'author_url': 'https://www.google.com/maps/contrib/112172187836861004331/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/--pSmX3aBPM0/AAAAAAAAAAI/AAAAAAAAATI/8fK8jzzemZw/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'Delicious Eastern European food cooked to order. Great and friendly service. $15-20/ person is enough for lunch or dinner.', 'time': 1519596433}, {'author_name': 'Glenn B', 'author_url': 'https://www.google.com/maps/contrib/104024429035482267109/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-Ta29Q8kDgyM/AAAAAAAAAAI/AAAAAAAAALQ/-WqiZNX48C4/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '2 weeks ago', 'text': 'Excellent dining experience.  Casual.  Excellent food and service.  Try the Lagman - superb flavor.', 'time': 1520884879}, {'author_name': 'Hannah Goforth', 'author_url': 'https://www.google.com/maps/contrib/102165307098145886804/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-amuNFqTrGKM/AAAAAAAAAAI/AAAAAAAAAAA/Qa-f2k5pIRg/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '2 weeks ago', 'text': 'Beautiful place to share your birthday with friends! Delicious food, wonderful wait staff, and fantastic atmosphere!', 'time': 1520811441}]
# types :     ['restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=2163857957024185677
# utc_offset :     -240
# vicinity :     16 Southern Avenue, Pittsburgh
# website :     http://www.kavsar.net/
#
#
# Istanbul Sofra
# formatted_address :     3234, 7610 Forbes Ave, Pittsburgh, PA 15221, USA
# formatted_phone_number :     (412) 727-6693
# geometry :     {'location': {'lat': 40.439586, 'lng': -79.897183}, 'viewport': {'northeast': {'lat': 40.4409842802915, 'lng': -79.89583601970848}, 'southwest': {'lat': 40.4382863197085, 'lng': -79.8985339802915}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     4d4f86b6f9f378dbc7135068dbcf4206b5ef1031
# international_phone_number :     +1 412-727-6693
# name :     Istanbul Sofra
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '2200'}, 'open': {'day': 0, 'time': '1030'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1030'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1030'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1030'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1030'}}, {'close': {'day': 5, 'time': '2300'}, 'open': {'day': 5, 'time': '1030'}}, {'close': {'day': 6, 'time': '2300'}, 'open': {'day': 6, 'time': '1030'}}], 'weekday_text': ['Monday: 10:30 AM – 10:00 PM', 'Tuesday: 10:30 AM – 10:00 PM', 'Wednesday: 10:30 AM – 10:00 PM', 'Thursday: 10:30 AM – 10:00 PM', 'Friday: 10:30 AM – 11:00 PM', 'Saturday: 10:30 AM – 11:00 PM', 'Sunday: 10:30 AM – 10:00 PM']}
# place_id :     ChIJ5aEMpeDtNIgRIUSoYk06NVQ
# rating :     4.9
# reviews :     [{'author_name': 'Khalil Badalov', 'author_url': 'https://www.google.com/maps/contrib/106679182927780426341/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-gdeIr1j9TW0/AAAAAAAAAAI/AAAAAAAAAC0/TvBolX5kZBk/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '2 weeks ago', 'text': 'Lots of good and tasty food. All my family loves it!', 'time': 1520994200}, {'author_name': 'Lance Winston', 'author_url': 'https://www.google.com/maps/contrib/109030543190044422424/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-5TA3pQdpVSc/AAAAAAAAAAI/AAAAAAAABOQ/cHkSZtWYuho/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg', 'rating': 5, 'relative_time_description': '3 months ago', 'text': "Excellent food and service, and it's BYOB", 'time': 1514482518}, {'author_name': 'paula breuer', 'author_url': 'https://www.google.com/maps/contrib/114354313934769367527/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-M0CF5QvkDMg/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWA136Q2VRYJzYkKw0DZzgwHrj4Aow/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 5, 'relative_time_description': '4 months ago', 'text': 'Love this place, delicious food , attentive service, great ambience', 'time': 1511104572}, {'author_name': 'Linda Lavery', 'author_url': 'https://www.google.com/maps/contrib/110122581433747204256/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-dRvLa_lvUgc/AAAAAAAAAAI/AAAAAAAAAAw/YxhZPuEr95w/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '3 years ago', 'text': 'I love this store for my guinea pigs.  We buy the most wonderful Sweet Meadow Organic Herbs & Timothy hay there.  My piggies bury themselves in it.  It is so fluffy and smells so nice, it makes me want to join them.\nThe staff is so helpful.\nI appreciate their ethics and the honesty with which they purport their values.\n', 'time': 1406571425}, {'author_name': 'Bakhodir Tadjiev', 'author_url': 'https://www.google.com/maps/contrib/117206095706315247936/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-tiXD5fHRYVc/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWCaqXkx-duYSC9FU7u3s62pgZIFbA/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '2 months ago', 'text': 'Best food', 'time': 1516056780}]
# types :     ['meal_takeaway', 'restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=6067820176993698849
# utc_offset :     -240
# vicinity :     3234, 7610 Forbes Avenue, Pittsburgh
# website :     http://www.istanbulsofra.com/
#
#
# Dijlah Restaurant and Hookah Lounge
# formatted_address :     4130 Butler St, Pittsburgh, PA 15201, USA
# formatted_phone_number :     (412) 742-4998
# geometry :     {'location': {'lat': 40.4701807, 'lng': -79.9605352}, 'viewport': {'northeast': {'lat': 40.4715466302915, 'lng': -79.9592297197085}, 'southwest': {'lat': 40.46884866970851, 'lng': -79.96192768029151}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     b0f997342879db3739a8e078f75d5dab410b72ca
# international_phone_number :     +1 412-742-4998
# name :     Dijlah Restaurant and Hookah Lounge
# opening_hours :     {'open_now': True, 'periods': [{'close': {'day': 0, 'time': '2100'}, 'open': {'day': 0, 'time': '0900'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 6, 'time': '0100'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 0, 'time': '0100'}, 'open': {'day': 6, 'time': '0900'}}], 'weekday_text': ['Monday: Closed', 'Tuesday: 11:00 AM – 10:00 PM', 'Wednesday: 11:00 AM – 10:00 PM', 'Thursday: 11:00 AM – 10:00 PM', 'Friday: 11:00 AM – 1:00 AM', 'Saturday: 9:00 AM – 1:00 AM', 'Sunday: 9:00 AM – 9:00 PM']}
# place_id :     ChIJDxKskE3yNIgRZVoDJ9pI2OE
# rating :     4.3
# reviews :     [{'author_name': 'John Harvey', 'author_url': 'https://www.google.com/maps/contrib/102238991979429123831/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-muyRuSvnFjs/AAAAAAAAAAI/AAAAAAAAIG4/JsE7U0dhr7E/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 4, 'relative_time_description': 'a month ago', 'text': "A good place for lunch. The Dijlah menu is simple but has something for everyone. Good selection of halal foods. Both meat and vegetarian dishes are served. Don't forget to finish off your meal with a delicious baklava.", 'time': 1517521610}, {'author_name': 'John Harvey', 'author_url': 'https://www.google.com/maps/contrib/111274531718718287407/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-yOUTitASX38/AAAAAAAAAAI/AAAAAAABSK0/msZsAl0X278/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 4, 'relative_time_description': '2 months ago', 'text': 'Good selection of Mediterranean food. The food is well prepared, and was served quickly. I had the Dijlah kabobs which were delicious. The restaurant is quiet, and it does not appear that one needs a reservation. No alcohol.', 'time': 1516471510}, {'author_name': 'Adil Abd', 'author_url': 'https://www.google.com/maps/contrib/103062325106899065439/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-fEvy5JvD5AI/AAAAAAAAAAI/AAAAAAAAAUk/psKj0a_w3WU/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': 'a week ago', 'text': 'For first visit we loved this place as a family due to delicious and awesome food , remind me about all old days back in home , cool staff too, thanks for good time and services .', 'time': 1521773901}, {'author_name': 'Jihan Fanous', 'author_url': 'https://www.google.com/maps/contrib/109912495606380410095/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-9pA76P5RE-w/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWCXxKdTi-03oq6SrZizabCyLZ-ygg/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '3 months ago', 'text': 'Very nice quiet diner place and a separate room for Hookah with TV screen and projector and nice music and songs. Very affordable price for food and Hookah. Charcoal grilled meat and chicken kebab. Very healthy food and drink. Fresh squeezed juice.', 'time': 1512505421}, {'author_name': 'Bob Smathers', 'author_url': 'https://www.google.com/maps/contrib/115193877509176355703/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-tjFdCXziC28/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWA_UX8iqJM6XI85mbjHDrRAdhcmrA/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': 'in the last week', 'text': 'Iraqi kebab was delicious. Great service and good selection of teas as well.', 'time': 1521999883}]
# types :     ['restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=16273837355297888869
# utc_offset :     -240
# vicinity :     4130 Butler Street, Pittsburgh
# website :     http://www.dijlahrestaurant.com/
#
#
# Alihan's Mediterranean Cuisine
# formatted_address :     124 6th St, Pittsburgh, PA 15222, USA
# formatted_phone_number :     (412) 888-0630
# geometry :     {'location': {'lat': 40.4432428, 'lng': -80.0025696}, 'viewport': {'northeast': {'lat': 40.4446124302915, 'lng': -80.0011418697085}, 'southwest': {'lat': 40.4419144697085, 'lng': -80.00383983029151}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     30f60fac5fc16a885a4f982a1183fecb0382d4eb
# international_phone_number :     +1 412-888-0630
# name :     Alihan's Mediterranean Cuisine
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '2200'}, 'open': {'day': 0, 'time': '1100'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 5, 'time': '2300'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 6, 'time': '2300'}, 'open': {'day': 6, 'time': '1100'}}], 'weekday_text': ['Monday: 11:00 AM – 10:00 PM', 'Tuesday: 11:00 AM – 10:00 PM', 'Wednesday: 11:00 AM – 10:00 PM', 'Thursday: 11:00 AM – 10:00 PM', 'Friday: 11:00 AM – 11:00 PM', 'Saturday: 11:00 AM – 11:00 PM', 'Sunday: 11:00 AM – 10:00 PM']}
# place_id :     ChIJ4ws4DVbxNIgRfdiGwIuzWB4
# price_level :     2
# rating :     4.4
# reviews :     [{'author_name': 'Bonnie Hassan', 'author_url': 'https://www.google.com/maps/contrib/104288678726417736874/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-9Q6fBTzrj50/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWBHdgYTKbJV_mSBAt6HeIWPCB__3Q/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 4, 'relative_time_description': 'a month ago', 'text': 'Friendly service but the food was mostly just kebab. Food was fine. I would have liked more selection.  Atmosphere was 5 star.  Easy to get a reservation.  Disappointed to see alcohol in a halal restaurant. Dessert was very tasty.', 'time': 1517379285}, {'author_name': 'chris balouris', 'author_url': 'https://www.google.com/maps/contrib/103352627876718806445/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-MNVO8hbKz3U/AAAAAAAAAAI/AAAAAAAAEsY/hW24HQ_AIUk/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': 'in the last week', 'text': 'Authentic Turkish cuisine. Family owned and operated. Enjoyed nice red snapper dish. Desserts were great.', 'time': 1521905886}, {'author_name': 'Bill Cartiff', 'author_url': 'https://www.google.com/maps/contrib/111008426111783755197/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-kMGKebph_OY/AAAAAAAAAAI/AAAAAAAAADI/A8K42BnXQ3I/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 3, 'relative_time_description': 'a month ago', 'text': "I was not impressed with my food. My dining companions were and I understand there are many good reviews of this restaurant. Maybe I just had a bad dish or it just wasn't made right but I did not enjoy my meal. Service was great waiter was nice no complaints other than the taste of my particular dish", 'time': 1517288401}, {'author_name': 'Zachary Berger', 'author_url': 'https://www.google.com/maps/contrib/115737223942365750558/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-oNPjKvMBTo8/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWB1C8DEeAoBA5cjVQoQljdz1qsuZA/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '2 months ago', 'text': 'Great food and service. I have wanted to go to Alihan’s ever since I saw their commercial as it looked delicious. Although the space is a little small it is the perfect downtown restaurant for some delicious Mediterranean cuisine without spending a fortune. In addition, it is also BYOB!', 'time': 1515589813}, {'author_name': 'Barbie Jackson', 'author_url': 'https://www.google.com/maps/contrib/110309896946864601633/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-61XXHIwkbfk/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWAeDJCJxkdUzz-FVK-vtBnin6r8vg/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': "If you enjoy Mediterranean food, this place is for you.  It's the real deal!  My husband and I have season tickets to the symphony and travel two hours to get to Pittsburgh. So choosing a good restaurant is part of making the drive worth it for is.   And we noticed that we keep coming back to Alihan's!  Kabobs of every kind, wheat bulgar, salads, and desserts,  all amazing.  I tried the sea bass filet and was blown away.  It was wonderful!  Two musts:  order their cold appetizer sampler and order a side of pita bread!  You won't be disappointed.  Alihan's location is right beside a public parking garage and in the heart of Pittsburgh's culterual district.", 'time': 1519657512}]
# types :     ['meal_delivery', 'restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=2186695031900264573
# utc_offset :     -240
# vicinity :     124 6th Street, Pittsburgh
# website :     http://www.alihansrestaurantpittsburgh.com/
#
#
# Naya Cuisine
# formatted_address :     2018 Murray Ave, Pittsburgh, PA 15217, USA
# formatted_phone_number :     (412) 421-1920
# geometry :     {'location': {'lat': 40.4341966, 'lng': -79.9230678}, 'viewport': {'northeast': {'lat': 40.4355455802915, 'lng': -79.9217188197085}, 'southwest': {'lat': 40.4328476197085, 'lng': -79.92441678029151}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     1d2c8611f8a3bf75c3368e513c6f157a0480f437
# international_phone_number :     +1 412-421-1920
# name :     Naya Cuisine
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '2100'}, 'open': {'day': 0, 'time': '1600'}}, {'close': {'day': 1, 'time': '2130'}, 'open': {'day': 1, 'time': '1700'}}, {'close': {'day': 2, 'time': '2130'}, 'open': {'day': 2, 'time': '1700'}}, {'close': {'day': 3, 'time': '2130'}, 'open': {'day': 3, 'time': '1700'}}, {'close': {'day': 4, 'time': '2130'}, 'open': {'day': 4, 'time': '1700'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1700'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1700'}}], 'weekday_text': ['Monday: 5:00 – 9:30 PM', 'Tuesday: 5:00 – 9:30 PM', 'Wednesday: 5:00 – 9:30 PM', 'Thursday: 5:00 – 9:30 PM', 'Friday: 5:00 – 10:00 PM', 'Saturday: 5:00 – 10:00 PM', 'Sunday: 4:00 – 9:00 PM']}
# place_id :     ChIJtRyU7v7xNIgRzL3C33VCl3k
# rating :     4.7
# reviews :     [{'author_name': 'Prince Mohammed', 'author_url': 'https://www.google.com/maps/contrib/102488859780716794885/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-d8Ui7hk-8UM/AAAAAAAAAAI/AAAAAAAAAA0/hybJzIWYCtA/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'I recommend it. The food tastes great. I tried many mediterranean restaurants in Pittsburgh, this one is wonderful 🙏🏻 thank you guys, will absolutely come again!', 'time': 1517991665}, {'author_name': 'Lindsey Denny', 'author_url': 'https://www.google.com/maps/contrib/112179259749863186994/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-tOECV--GB3k/AAAAAAAAAAI/AAAAAAAAFMI/Xfq9jkMiRBY/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '4 months ago', 'text': "My husband and I love Naya! It is one of the gems of the Murray Avenue restaurant scene. The atmosphere is intimate and cozy. We regularly bring friends and out-of-town guests there. I highly suggest ordering the Mezza platter as an appetizer for the table because it has a little bit of everything. I often let the waitstaff order for me and I'm always delighted by what they bring. The family who operates the restaurant is absolutely lovely and we are happy to be loyal patrons.", 'time': 1509646730}, {'author_name': 'Pete Rubinas', 'author_url': 'https://www.google.com/maps/contrib/107152199993220363510/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-4E8OiBai7Is/AAAAAAAAAAI/AAAAAAABiRY/qTJqDNwLrHQ/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 5, 'relative_time_description': '2 months ago', 'text': 'The folks at Naya were very welcoming to our party of 16, which included 4 teenagers and 4 children. Adham and his colleague welcomed us warmly and were attentive to us throughout our visit. The food was all excellent. I highly recommend the dawood basha. I look forward to returning on our next visit to Pittsburgh.', 'time': 1514692162}, {'author_name': 'Casey Schall', 'author_url': 'https://www.google.com/maps/contrib/102429845196707859484/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-y3eUBq9fuaM/AAAAAAAAAAI/AAAAAAAAAFo/RxRFkMhJUJ0/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '3 months ago', 'text': "My wife and I ordered from Naya last night and are enjoying the left overs this morning. Not only were the portions generous, but all of the food tasted fresh and delicious. The baba ganoush might be the best I've ever had- silky, creamy, and bright in all the best ways (can't go wrong with the hummus either, though). The stuffed grape leaves we're a treat and were easier to bite through than most. As a main course the American style falafel burger reminded me of all my favorite parts of a hamburger, without the meat- crispy on he outside, substantial on the inside, and much easier on my stomach. After dressing it with some baba and tabouleh, I was in a state of sensory bliss. If you love Middle Eastern food, you'll love this restaurant!", 'time': 1514129118}, {'author_name': 'Gelme Vaitkuniene', 'author_url': 'https://www.google.com/maps/contrib/103781968131264056392/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-aVChtcbNS_Q/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWB8p0cwpTUM8Dx2epB3_a7deB5bsw/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '4 months ago', 'text': 'Excellent food, very helpful staff and owner. I had best surprise party for my husband.', 'time': 1511312679}]
# types :     ['restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=8761544674105277900
# utc_offset :     -240
# vicinity :     2018 Murray Ave, Pittsburgh
# website :     http://www.nayacuisine.com/
#
#
# Grandma B's
# formatted_address :     2537 Wylie Ave, Pittsburgh, PA 15219, USA
# formatted_phone_number :     (412) 681-4087
# geometry :     {'location': {'lat': 40.44869449999999, 'lng': -79.9705415}, 'viewport': {'northeast': {'lat': 40.4500028302915, 'lng': -79.96916286970848}, 'southwest': {'lat': 40.4473048697085, 'lng': -79.9718608302915}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     820908d6d55e4e426dba7fed455d49f0f7e8d08a
# international_phone_number :     +1 412-681-4087
# name :     Grandma B's
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '1400'}, 'open': {'day': 0, 'time': '1000'}}, {'close': {'day': 1, 'time': '1530'}, 'open': {'day': 1, 'time': '0800'}}, {'close': {'day': 2, 'time': '1530'}, 'open': {'day': 2, 'time': '0800'}}, {'close': {'day': 3, 'time': '1530'}, 'open': {'day': 3, 'time': '0800'}}, {'close': {'day': 4, 'time': '1530'}, 'open': {'day': 4, 'time': '0800'}}, {'close': {'day': 5, 'time': '1530'}, 'open': {'day': 5, 'time': '0800'}}, {'close': {'day': 6, 'time': '1530'}, 'open': {'day': 6, 'time': '0800'}}], 'weekday_text': ['Monday: 8:00 AM – 3:30 PM', 'Tuesday: 8:00 AM – 3:30 PM', 'Wednesday: 8:00 AM – 3:30 PM', 'Thursday: 8:00 AM – 3:30 PM', 'Friday: 8:00 AM – 3:30 PM', 'Saturday: 8:00 AM – 3:30 PM', 'Sunday: 10:00 AM – 2:00 PM']}
# place_id :     ChIJF93Zb9HzNIgRaXsPqpc12X4
# rating :     4.7
# reviews :     [{'author_name': 'Carey-Marie Watts', 'author_url': 'https://www.google.com/maps/contrib/118300397718226591076/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-JnJIuUuc6bY/AAAAAAAAAAI/AAAAAAAAAAA/NEX-kOchFRo/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': "What an amazing breakfast!! About 10 minutes from downtown and one of the best breakfast places I've experienced in a while. I had the catfish and my husband had the kielbasa and french toast. Everything was delicious. Also do not leave without taking some sweet tea to go. They make it fresh everyday and you can tell. Staff were very friendly and service was timely.", 'time': 1519851974}, {'author_name': 'Grant Seifred', 'author_url': 'https://www.google.com/maps/contrib/102593484590953895778/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-Uz47-LLGr98/AAAAAAAAAAI/AAAAAAAAXGE/zHbE11Y5BQA/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg', 'rating': 4, 'relative_time_description': '4 months ago', 'text': 'Very friendly staff and locals at this neighborhood eatery. The steak salad was excellent. My partner had the fish dish which was fresh and lightly battered. Make sure you try the home made iced tea... delicious but not too sweet.', 'time': 1509629726}, {'author_name': 'Justin Miller', 'author_url': 'https://www.google.com/maps/contrib/112270563599494252503/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-71LMl_ZFq1M/AAAAAAAAAAI/AAAAAAAEKyo/vNcOqHxVRbI/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 5, 'relative_time_description': '4 months ago', 'text': "Do yourself a favor and get the fish and grits--it's good stuff. Enjoy the banter between the staff and the neighborhood regulars--it's worth the price of admission to experience a real neighborhood joint that feels like you're hanging out in a family kitchen. Support local business and check this place out.", 'time': 1511482957}, {'author_name': 'Shana Wright', 'author_url': 'https://www.google.com/maps/contrib/108203542638938400520/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-bWuGrOr-8Rg/AAAAAAAAAAI/AAAAAAAAATU/_IjlYqobcTQ/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '2 months ago', 'text': 'My favorite breakfast spot. The food is BOMB, the cooks are so nice and sweet, and it’s just a great atmosphere. I recommend this place to EVERYONE!', 'time': 1516199714}, {'author_name': 'Sugar Plum', 'author_url': 'https://www.google.com/maps/contrib/106604595608313958572/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-qE6OfUifrco/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWDhgERe-rmAHkY85L_-7Opr7DS2hg/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '3 months ago', 'text': "Service here is always kind and thoughtful. Food preparation and taste is excellent!!\nParking spot for my bus is always available!!!\nThank you Grandma B's for being a great spot to eat!!!🤗🤗🤗", 'time': 1512148101}]
# types :     ['restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=9140395844234607465
# utc_offset :     -240
# vicinity :     2537 Wylie Avenue, Pittsburgh
#
#
# Prince of India Restaurant
# formatted_address :     3614 Fifth Ave, Pittsburgh, PA 15213, USA
# formatted_phone_number :     (412) 687-0888
# geometry :     {'location': {'lat': 40.4415109, 'lng': -79.9585431}, 'viewport': {'northeast': {'lat': 40.4429151302915, 'lng': -79.9572645197085}, 'southwest': {'lat': 40.4402171697085, 'lng': -79.95996248029151}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     a09e23a6d14ffc5b6e3d02ab49d77cfd2e8e000a
# international_phone_number :     +1 412-687-0888
# name :     Prince of India Restaurant
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '1500'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 0, 'time': '2200'}, 'open': {'day': 0, 'time': '1630'}}, {'close': {'day': 1, 'time': '1500'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1630'}}, {'close': {'day': 2, 'time': '1500'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1630'}}, {'close': {'day': 3, 'time': '1500'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1630'}}, {'close': {'day': 4, 'time': '1500'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1630'}}, {'close': {'day': 5, 'time': '1500'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1630'}}, {'close': {'day': 6, 'time': '1500'}, 'open': {'day': 6, 'time': '1200'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1630'}}], 'weekday_text': ['Monday: 11:00 AM – 3:00 PM, 4:30 – 10:00 PM', 'Tuesday: 11:00 AM – 3:00 PM, 4:30 – 10:00 PM', 'Wednesday: 11:00 AM – 3:00 PM, 4:30 – 10:00 PM', 'Thursday: 11:00 AM – 3:00 PM, 4:30 – 10:00 PM', 'Friday: 11:00 AM – 3:00 PM, 4:30 – 10:00 PM', 'Saturday: 12:00 – 3:00 PM, 4:30 – 10:00 PM', 'Sunday: 12:00 – 3:00 PM, 4:30 – 10:00 PM']}
# place_id :     ChIJLQyxHSryNIgRvsaMdRFuWsc
# rating :     4
# reviews :     [{'author_name': 'Uma Dixit', 'author_url': 'https://www.google.com/maps/contrib/112956423879690222374/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-ucRek2Vag8A/AAAAAAAAAAI/AAAAAAAAPms/dadnDfc1ncQ/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'What a great location for this Indian food joint! My friend and I were visiting Pittsburgh for the day, and we decided to try out Prince of India for the lunch buffet. The choices were limited but the taste and quality of the food was amazing (their saag was phenomenal). The interior was also very nice and cozy. I would recommend this place to anyone who likes or wants to try Indian food.', 'time': 1519307642}, {'author_name': 'Matt Cellucci', 'author_url': 'https://www.google.com/maps/contrib/118272489338234143748/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-cCN-wB9dsmo/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWAbuPJ5cdZSe8lEbgo5hImduODfHA/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 3, 'relative_time_description': '2 months ago', 'text': "We stopped here after touring Pitt's campus for lunch.  Seeing that it offered a lunch buffet, that's what we went for.  The food on the buffet was mediocre at best.  I cannot attest to the regular menu food but some of it looked more appealing.  If you are looking for a ton of food, the buffet it great.  If you are looking for good food, go elsewhere.", 'time': 1516571866}, {'author_name': 'Torrey Trahanovsky', 'author_url': 'https://www.google.com/maps/contrib/112468347296108473843/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-RE-rjkYcBTA/AAAAAAAAAAI/AAAAAAAB40E/pClJNiwkLrw/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 5, 'relative_time_description': '3 weeks ago', 'text': 'Incredible food and atmosphere. Really attentative staff and quick service. Also amazing buffet at $9 for lunch & $11 for dinner!', 'time': 1520634545}, {'author_name': 'Richard', 'author_url': 'https://www.google.com/maps/contrib/108606444412760162482/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-zPgpfa9O1E4/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWDt4ErERRE89uNGLqejRFHOvcgvDg/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg', 'rating': 1, 'relative_time_description': 'a week ago', 'text': "Worst food I have ever had in my life. Not even a single dish is good, expensive and worst service. I felt sorry for the Indian students sitting in front of me, I felt so bad I think they don't have any option to get Indian food. Chicken I tasted is almost 8 to 10 days old. Literally spoil your health.", 'time': 1521857181}, {'author_name': 'robert webb', 'author_url': 'https://www.google.com/maps/contrib/105309432282224151532/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-yklakakN96Y/AAAAAAAAAAI/AAAAAAAAABE/YBRjHAGrBYg/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 5, 'relative_time_description': '2 weeks ago', 'text': 'First time eating Indian food. Let me say indian food my new fave. Great experience for me hope its the same for you. Going back and the groupon deal is a nice bonus', 'time': 1521134834}]
# types :     ['restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=14364914982717277886
# utc_offset :     -240
# vicinity :     3614 Fifth Avenue, Pittsburgh
# website :     http://www.princeofindiapittsburgh.com/
#
#
# McCormick & Schmick's Seafood & Steaks
# formatted_address :     301 Fifth Ave, Pittsburgh, PA 15222, USA
# formatted_phone_number :     (412) 201-6992
# geometry :     {'location': {'lat': 40.44124, 'lng': -79.99974710000001}, 'viewport': {'northeast': {'lat': 40.4422908302915, 'lng': -79.9985923197085}, 'southwest': {'lat': 40.4395928697085, 'lng': -80.0012902802915}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     b1d447831e9b6ca42c8fe7f19b71e2ba4fce9d5f
# international_phone_number :     +1 412-201-6992
# name :     McCormick & Schmick's Seafood & Steaks
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '2000'}, 'open': {'day': 0, 'time': '1600'}}, {'close': {'day': 1, 'time': '2100'}, 'open': {'day': 1, 'time': '1100'}}, {'close': {'day': 2, 'time': '2100'}, 'open': {'day': 2, 'time': '1100'}}, {'close': {'day': 3, 'time': '2100'}, 'open': {'day': 3, 'time': '1100'}}, {'close': {'day': 4, 'time': '2100'}, 'open': {'day': 4, 'time': '1100'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1100'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1600'}}], 'weekday_text': ['Monday: 11:00 AM – 9:00 PM', 'Tuesday: 11:00 AM – 9:00 PM', 'Wednesday: 11:00 AM – 9:00 PM', 'Thursday: 11:00 AM – 9:00 PM', 'Friday: 11:00 AM – 10:00 PM', 'Saturday: 4:00 – 10:00 PM', 'Sunday: 4:00 – 8:00 PM']}
# place_id :     ChIJGfCWEFfxNIgRu-HMmjamUoU
# price_level :     2
# rating :     3.8
# reviews :     [{'author_name': 'george chavarria', 'author_url': 'https://www.google.com/maps/contrib/118234501639397738617/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-PTYgG-kNELs/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWCR1G7kBmUuWJLnlnuL8pda2x99xA/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 2, 'relative_time_description': '2 weeks ago', 'text': "Food not a great value.  On our particular visit, waiter dropping entrees off before salad was done.  Felt like I was at Chili's.", 'time': 1521164792}, {'author_name': 'Katee Coleman', 'author_url': 'https://www.google.com/maps/contrib/112964218297295263016/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-585XsFGfjXI/AAAAAAAAAAI/AAAAAAAAIKc/csQrpntJbO4/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 1, 'relative_time_description': 'a month ago', 'text': 'Made a reservation for 6:15, dinner before a show downtown. At 6:15 we arrived and our table “would be ready in a few minutes.” By 6:30 the table was still unavailable and we were “behind another group of people in line”, so we decided to eat in the bar area in order to stick to our timeline and make the show. By 7:00 our waitress still had not taken our dinner order. When we requested the bill for our drinks so we could leave, we also asked to speak to the manager. When he spoke to us, it was clear he couldn’t care less about the less than ideal situation. He didn’t offer anything for our troubles, even though that was not the point of our conversation, it would have been nice to see an ounce of care on his part. In fact I’m glad he didn’t offer us a gift card or something of the likes, because I’m never coming back. Poor customer service and poor coordination of their establishment. What’s the point of a reservation if I still have to wait in the line when I arrive at my reserved time?', 'time': 1518309181}, {'author_name': 'Mike Garner', 'author_url': 'https://www.google.com/maps/contrib/113892270374490397934/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-STVlDaAbG9c/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWCxyTQYFSK2oUFl8K70ARnjdDpcFg/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'Everything was great again. Our server Bjorn was very professional and knowledgeable of the whole menu. The oysters Rockefeller were amazing as was our fish entrees.', 'time': 1519347912}, {'author_name': 'Jennifer Kortekaas', 'author_url': 'https://www.google.com/maps/contrib/114276541046301502580/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-OZWYk0aNip0/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWBc_Ss4I6T_5l9aLOPNawpjDEffhA/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 1, 'relative_time_description': '3 months ago', 'text': 'We had our wedding reception in MN @ the M&S. It has always been our celebration spot. We made our Christmas reservations at the one in Pittsburgh. We ordered calamari for appetizer. I am extremely allergic to shellfish. My daughter found a shrimp in the calamari. Luckily I had not eaten any yet, because even if it touches my food I get sick. My meal was inedible. They said they would bring a different fish. I requested and it didn’t  had the skin. But when it came came out it was another piece with skin. I hope the M&S restaurants are all not going down this path. We will never eat here again!', 'time': 1514592117}, {'author_name': 'Barbara Jones', 'author_url': 'https://www.google.com/maps/contrib/101128862729850356155/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/--chY9qiAEb4/AAAAAAAAAAI/AAAAAAAAABM/PQ1mB2p-7Ds/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 1, 'relative_time_description': 'a month ago', 'text': "The food was cold and it wasn't season well actually it was just awful but our server was very nice we visit the one in Cincinnati and everything was delicious so I wanted to come again but never will  ...
# types :     ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=9606923708590252475
# utc_offset :     -240
# vicinity :     301 Fifth Avenue, Pittsburgh
# website :     http://www.mccormickandschmicks.com/Locations/pittsburgh-pennsylvania/pittsburgh-pennsylvania/FifthAve.aspx?utm_campaign=Yext&utm_source=Yext&utm_medium=Website&utm_content=MSPP
#
#
# Ali Baba Restaurant
# formatted_address :     404 S Craig St, Pittsburgh, PA 15213, USA
# formatted_phone_number :     (412) 682-2829
# geometry :     {'location': {'lat': 40.44508009999999, 'lng': -79.9488817}, 'viewport': {'northeast': {'lat': 40.4464335802915, 'lng': -79.9474717697085}, 'southwest': {'lat': 40.4437356197085, 'lng': -79.9501697302915}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     ce98cf3c6f602856a1512ec04568cb94d4bd0f28
# international_phone_number :     +1 412-682-2829
# name :     Ali Baba Restaurant
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '2100'}, 'open': {'day': 0, 'time': '1600'}}, {'close': {'day': 1, 'time': '1430'}, 'open': {'day': 1, 'time': '1130'}}, {'close': {'day': 1, 'time': '2100'}, 'open': {'day': 1, 'time': '1600'}}, {'close': {'day': 2, 'time': '1430'}, 'open': {'day': 2, 'time': '1130'}}, {'close': {'day': 2, 'time': '2100'}, 'open': {'day': 2, 'time': '1600'}}, {'close': {'day': 3, 'time': '1430'}, 'open': {'day': 3, 'time': '1130'}}, {'close': {'day': 3, 'time': '2100'}, 'open': {'day': 3, 'time': '1600'}}, {'close': {'day': 4, 'time': '1430'}, 'open': {'day': 4, 'time': '1130'}}, {'close': {'day': 4, 'time': '2100'}, 'open': {'day': 4, 'time': '1600'}}, {'close': {'day': 5, 'time': '1430'}, 'open': {'day': 5, 'time': '1130'}}, {'close': {'day': 5, 'time': '2130'}, 'open': {'day': 5, 'time': '1600'}}, {'close': {'day': 6, 'time': '2130'}, 'open': {'day': 6, 'time': '1600'}}], 'weekday_text': ['Monday: 11:30 AM – 2:30 PM, 4:00 – 9:00 PM', 'Tuesday: 11:30 AM – 2:30 PM, 4:00 – 9:00 PM', 'Wednesday: 11:30 AM – 2:30 PM, 4:00 – 9:00 PM', 'Thursday: 11:30 AM – 2:30 PM, 4:00 – 9:00 PM', 'Friday: 11:30 AM – 2:30 PM, 4:00 – 9:30 PM', 'Saturday: 4:00 – 9:30 PM', 'Sunday: 4:00 – 9:00 PM']}
# place_id :     ChIJbZevISTyNIgRmAk5MgJN5NY
# price_level :     2
# rating :     4
# reviews :     [{'author_name': 'Pamla Mixter', 'author_url': 'https://www.google.com/maps/contrib/116042509699985154119/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-_tWgGIihxGk/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWArBQpSvglWVOsYWIY_Tc-ixZoCOw/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg', 'rating': 5, 'relative_time_description': '4 months ago', 'text': 'Excellent food, friendly and efficient customer service. Cozy atmosphere and clean place. The deserts are to die for! Medium priced but well worth it and large portion sizes! Been going here to eat for a few years and have never been disappointed!  Highly recommend for authentic middle Eastern cuisine.', 'time': 1510667517}, {'author_name': 'Deborah Corsini', 'author_url': 'https://www.google.com/maps/contrib/107896750165495153640/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-re85sh-lPsg/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWCqXv5BrXRvEqiUjNzZwvEutBOYKQ/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': "Authentic Middle Eastern cuisine, comfort food in a comfortable setting. Wonderful tastes, aromas and a menu with something for everyone. Hummus lovers won't be sorry with this homemade recipe.", 'time': 1518210577}, {'author_name': 'Daniel Lehman', 'author_url': 'https://www.google.com/maps/contrib/101568021715527332352/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-8Gp3FXOj0no/AAAAAAAAAAI/AAAAAAAAJT0/yXst0aJ8Kkc/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg', 'rating': 5, 'relative_time_description': 'a week ago', 'text': 'Wide variety of filling flavorful Mediterranean eats, with fast service and big portions. Spinach Pie was spectacular!', 'time': 1521725004}, {'author_name': 'Ashleigh Kuhn', 'author_url': 'https://www.google.com/maps/contrib/106306376752738834420/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-PotSO9e6mQo/AAAAAAAAAAI/AAAAAAAALJk/-ypzdpaLJqQ/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'Always delicious and of the highest quality! Everything I have tried is great but the loobee, chicken shish kabob and house salad dressing are some of my favorites! Oh and the Hummus is the best I have ever had! Quiet, relaxed atmosphere that fosters great conversations is an added bonus!', 'time': 1517713005}, {'author_name': 'Shafi Hamidi', 'author_url': 'https://www.google.com/maps/contrib/110380619090154372126/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-4G2YZbXS1k4/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWCcs2_UOfppJ5vC8wTV7aOnazQJLg/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 4, 'relative_time_description': 'a month ago', 'text': 'The food was delicious the service was prompt and courteous the only little glitch, the parking', 'time': 1519171161}]
# types :     ['restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=15484586090634480024
# utc_offset :     -240
# vicinity :     404 South Craig Street, Pittsburgh
#
#
# All India Restaurant
# formatted_address :     315 N Craig St, Pittsburgh, PA 15213, USA
# formatted_phone_number :     (412) 681-6600
# geometry :     {'location': {'lat': 40.45220870000001, 'lng': -79.95263349999999}, 'viewport': {'northeast': {'lat': 40.4536186802915, 'lng': -79.9511173197085}, 'southwest': {'lat': 40.4509207197085, 'lng': -79.95381528029151}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     5623378a8074cd25342d805a3a0ae6e07b97aa94
# international_phone_number :     +1 412-681-6600
# name :     All India Restaurant
# opening_hours :     {'open_now': True, 'periods': [{'close': {'day': 1, 'time': '0100'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 2, 'time': '0100'}, 'open': {'day': 1, 'time': '1130'}}, {'close': {'day': 3, 'time': '0100'}, 'open': {'day': 2, 'time': '1130'}}, {'close': {'day': 4, 'time': '0100'}, 'open': {'day': 3, 'time': '1130'}}, {'close': {'day': 5, 'time': '0100'}, 'open': {'day': 4, 'time': '1130'}}, {'close': {'day': 6, 'time': '0100'}, 'open': {'day': 5, 'time': '1130'}}, {'close': {'day': 0, 'time': '0100'}, 'open': {'day': 6, 'time': '1200'}}], 'weekday_text': ['Monday: 11:30 AM – 1:00 AM', 'Tuesday: 11:30 AM – 1:00 AM', 'Wednesday: 11:30 AM – 1:00 AM', 'Thursday: 11:30 AM – 1:00 AM', 'Friday: 11:30 AM – 1:00 AM', 'Saturday: 12:00 PM – 1:00 AM', 'Sunday: 12:00 PM – 1:00 AM']}
# place_id :     ChIJ6UmZhDryNIgROqLyBEGPUGs
# rating :     4.2
# ...
# international_phone_number :     +1 412-391-4800
# name :     Ruth's Chris Steak House
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 0, 'time': '2100'}, 'open': {'day': 0, 'time': '1700'}}, {'close': {'day': 1, 'time': '1500'}, 'open': {'day': 1, 'time': '1130'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1700'}}, {'close': {'day': 2, 'time': '1500'}, 'open': {'day': 2, 'time': '1130'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1700'}}, {'close': {'day': 3, 'time': '1500'}, 'open': {'day': 3, 'time': '1130'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1700'}}, {'close': {'day': 4, 'time': '1500'}, 'open': {'day': 4, 'time': '1130'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1700'}}, {'close': {'day': 5, 'time': '1500'}, 'open': {'day': 5, 'time': '1130'}}, {'close': {'day': 5, 'time': '2300'}, 'open': {'day': 5, 'time': '1700'}}, {'close': {'day': 6, 'time': '2300'}, 'open': {'day': 6, 'time': '1700'}}], 'weekday_text': ['Monday: 11:30 AM – 3:00 PM, 5:00 – 10:00 PM', 'Tuesday: 11:30 AM – 3:00 PM, 5:00 – 10:00 PM', 'Wednesday: 11:30 AM – 3:00 PM, 5:00 – 10:00 PM', 'Thursday: 11:30 AM – 3:00 PM, 5:00 – 10:00 PM', 'Friday: 11:30 AM – 3:00 PM, 5:00 – 11:00 PM', 'Saturday: 5:00 – 11:00 PM', 'Sunday: 5:00 – 9:00 PM']}
# place_id :     ChIJO1CPWlHxNIgRyejwmfRjHB4
# price_level :     3
# rating :     4.3
# reviews :     [{'author_name': 'John Eaves', 'author_url': 'https://www.google.com/maps/contrib/108714924570443821270/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-p8JmUWpcVPk/AAAAAAAAAAI/AAAAAAAAA4E/XIzwcDnWdS0/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': "This has always been one of the best places in the city for steak. They recently underwent a multi million dollar renovation, and it's beautiful. It was never dingy or unclean, but it had been starting to show its age. It's now a bright, open, thoroughly modern design. The food is every bit as good as it had always been. Perfectly prepared steaks and sides with modern touches on classic preparations.  At lunch, the prices are very reasonable. Service is always quick, knowledgeable, and attentive. I'd recommend this place to anyone.", 'time': 1517990814}, {'author_name': 'Greg Stadtlander', 'author_url': 'https://www.google.com/maps/contrib/100719977974085537662/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-7ToGrWfa3R0/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWDZpqDzbz300SWh0-_kthbD0XMTCQ/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 3, 'relative_time_description': 'in the last week', 'text': 'New bar area is beautifully appointed. VERY NICE.But, my guest and I thought the steaks were not cooked properly and we both work in restaurants. Service was very good,  but, after all, we did go for the steaks!', 'time': 1522072677}, {'author_name': 'Erin Showman', 'author_url': 'https://www.google.com/maps/contrib/109090245491997014047/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-JLof1sn6fJ4/AAAAAAAAAAI/AAAAAAAAHVk/n-6XEhbkqTQ/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'Amazing service and delicious food! Spicy shrimp was a perfect appetizer, you will NOT be disappointed. Our server was perfectly observant and diligent without being a bother. A great dining experience.', 'time': 1519215443}, {'author_name': 'Delsa White', 'author_url': 'https://www.google.com/maps/contrib/107115156529485331083/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-RVTsCdd1Gq4/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWD2GZAc4atx4rkNqgpy-6dXt-YNkw/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg', 'rating': 4, 'relative_time_description': '2 weeks ago', 'text': 'This was a first for us. Parking included is great. Food was very good.  Service was also good.  Will go back sometime, but prices are on the high side.', 'time': 1520934815}, {'author_name': 'Dominic DiGregory', 'author_url': 'https://www.google.com/maps/contrib/107527259966268709161/reviews', 'language': 'en', 'profile_photo_url': 'https://lh4.googleusercontent.com/-gfJjQSO1IdI/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWA4HlRm7fHsXg9DAaFvaIYfImmhXw/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 1, 'relative_time_description': '3 months ago', 'text': 'I asked for kids menu 3 times. Never got it. Was charged $60 for 2 kids meals. Clearly said I wanted “KIDS” steak and “KIDS” Mac and cheese. \n\nI think waitress wouldn’t bring the kids menu so she could charge adult prices. No desserts, drinks or sides for kids like the kids menu shows on line.  They were charged adult meals. Celebrating a birthday- paid for the birthday dessert. $300 with tip for 4 of us. Could have given a free dessert.  However the seafood tower was excellent.', 'time': 1514025156}]
# types :     ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=2169719022691608777
# utc_offset :     -240
# vicinity :     6 PPG Place, Pittsburgh
# website :     https://www.ruthschris.com/restaurant-locations/pittsburgh/?utm_source=google&utm_medium=organic&utm_campaign=local-business-listing
#
#
# Wings Over Pittsburgh
# formatted_address :     2525 E Carson St, Pittsburgh, PA 15203, USA
# formatted_phone_number :     (412) 301-9464
# geometry :     {'location': {'lat': 40.427812, 'lng': -79.969116}, 'viewport': {'northeast': {'lat': 40.4290904302915, 'lng': -79.9677987697085}, 'southwest': {'lat': 40.4263924697085, 'lng': -79.9704967302915}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     d3d3209b355a4f149802806483b0a580c9171e45
# international_phone_number :     +1 412-301-9464
# name :     Wings Over Pittsburgh
# opening_hours :     {'open_now': True, 'periods': [{'close': {'day': 1, 'time': '0000'}, 'open': {'day': 0, 'time': '1200'}}, {'close': {'day': 2, 'time': '0100'}, 'open': {'day': 1, 'time': '1600'}}, {'close': {'day': 3, 'time': '0100'}, 'open': {'day': 2, 'time': '1600'}}, {'close': {'day': 4, 'time': '0100'}, 'open': {'day': 3, 'time': '1600'}}, {'close': {'day': 5, 'time': '0100'}, 'open': {'day': 4, 'time': '1600'}}, {'close': {'day': 6, 'time': '0300'}, 'open': {'day': 5, 'time': '1600'}}, {'close': {'day': 0, 'time': '0300'}, 'open': {'day': 6, 'time': '1100'}}], 'weekday_text': ['Monday: 4:00 PM – 1:00 AM', 'Tuesday: 4:00 PM – 1:00 AM', 'Wednesday: 4:00 PM – 1:00 AM', 'Thursday: 4:00 PM – 1:00 AM', 'Friday: 4:00 PM – 3:00 AM', 'Saturday: 11:00 AM – 3:00 AM', 'Sunday: 12:00 PM – 12:00 AM']}
# place_id :     ChIJveO2t3bxNIgRR0FnNBRehMo
# price_level :     1
# rating :     4
# reviews :     [{'author_name': 'Kayla Schenck', 'author_url': 'https://www.google.com/maps/contrib/115308952698198310731/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-CW0--65ZRro/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWDU-RZdZ45QPD6Czo6tCxb4bYDGBg/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 2, 'relative_time_description': '3 weeks ago', 'text': "I was staying at the Sheraton in Station Square, for my husband and my anniversary, and I tried to order through you guys over the phone. Considering you guys are pretty much on the same street and it's only about a 10 minute drive with traffic, I didn't see the issue.\n\n I was told that delivery stopped a block before my location and there was nothing that could be done. I even offered to pay the driver an extra tip for going a BLOCK. I was told tough luck, there was nothing they could do, and to order off of GrubHub if I wanted it that badly. \n\nI was very displeased with this as it was not professional. We ended up taking our business elsewhere.", 'time': 1520536241}, {'author_name': 'Artayan Rose', 'author_url': 'https://www.google.com/maps/contrib/102294062433863120430/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-a5AUNNklVIU/AAAAAAAAAAI/AAAAAAAAAEg/9gQzbYlMbyw/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 1, 'relative_time_description': '2 weeks ago', 'text': 'Terrible customer service. I’ve never even had the food and probably never will. I called to place an order and the girl who answered was rude, didn’t greet me, and seemed bored with her job. She was short with me and ask two word questions. So unprofessional and impolite.  She has terrible customer service. Hire better Employees.', 'time': 1520808138}, {'author_name': 'Josh Gates', 'author_url': 'https://www.google.com/maps/contrib/109784516415111897008/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-tc0jA1ExC7o/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWAXAxNPI0_VUSSfOuwbI_JJR3dOAA/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': 'Wings vary in size day to day, but their delivery has been consistently on time, and they are generous with sauces and dipping sauces. Wings Over was also very accommodating in providing nutrition information on their sauces.', 'time': 1518771243}, {'author_name': 'Chad Popa', 'author_url': 'https://www.google.com/maps/contrib/113379099938259215551/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-OMv0WsomCXU/AAAAAAAAAAI/AAAAAAAAAME/lbiA_hVQ0AA/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '3 months ago', 'text': "Wings Over is a great restaurant. I wish I lived a bit closer. They have great meals that will leave you filled up and tons of options on different wing flavors. Great option if you're close and want some great wings.", 'time': 1514129546}, {'author_name': 'King Media & Gaming Blogs', 'author_url': 'https://www.google.com/maps/contrib/107131402438522267037/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-ZQZfpSr8LUc/AAAAAAAAAAI/AAAAAAAAB70/vc2WygAjd0M/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg', 'rating': 4, 'relative_time_description': 'a week ago', 'text': 'Good wings, quick & fast delievery with Grubhub.', 'time': 1521516090}]
# types :     ['restaurant', 'meal_takeaway', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=14592892133458788679
# utc_offset :     -240
# vicinity :     2525 East Carson Street, Pittsburgh
# website :     http://wingsover.com/locations/detail?location=54
#
#
# People's Indian Restaurant
# formatted_address :     1, 5147, Penn Ave, Pittsburgh, PA 15224, USA
# formatted_phone_number :     (412) 661-3160
# geometry :     {'location': {'lat': 40.4649334, 'lng': -79.9412107}, 'viewport': {'northeast': {'lat': 40.46619863029149, 'lng': -79.93988016970849}, 'southwest': {'lat': 40.46350066970849, 'lng': -79.94257813029151}}}
# icon :     https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png
# id :     e031b6e4a5550b2ecc2af5c0caa9783b2328efbc
# international_phone_number :     +1 412-661-3160
# name :     People's Indian Restaurant
# opening_hours :     {'open_now': False, 'periods': [{'close': {'day': 1, 'time': '1430'}, 'open': {'day': 1, 'time': '1130'}}, {'close': {'day': 1, 'time': '2200'}, 'open': {'day': 1, 'time': '1700'}}, {'close': {'day': 2, 'time': '1430'}, 'open': {'day': 2, 'time': '1130'}}, {'close': {'day': 2, 'time': '2200'}, 'open': {'day': 2, 'time': '1700'}}, {'close': {'day': 3, 'time': '1430'}, 'open': {'day': 3, 'time': '1130'}}, {'close': {'day': 3, 'time': '2200'}, 'open': {'day': 3, 'time': '1700'}}, {'close': {'day': 4, 'time': '1430'}, 'open': {'day': 4, 'time': '1130'}}, {'close': {'day': 4, 'time': '2200'}, 'open': {'day': 4, 'time': '1700'}}, {'close': {'day': 5, 'time': '1430'}, 'open': {'day': 5, 'time': '1130'}}, {'close': {'day': 5, 'time': '2200'}, 'open': {'day': 5, 'time': '1700'}}, {'close': {'day': 6, 'time': '1430'}, 'open': {'day': 6, 'time': '1130'}}, {'close': {'day': 6, 'time': '2200'}, 'open': {'day': 6, 'time': '1700'}}], 'weekday_text': ['Monday: 11:30 AM – 2:30 PM, 5:00 – 10:00 PM', 'Tuesday: 11:30 AM – 2:30 PM, 5:00 – 10:00 PM', 'Wednesday: 11:30 AM – 2:30 PM, 5:00 – 10:00 PM', 'Thursday: 11:30 AM – 2:30 PM, 5:00 – 10:00 PM', 'Friday: 11:30 AM – 2:30 PM, 5:00 – 10:00 PM', 'Saturday: 11:30 AM – 2:30 PM, 5:00 – 10:00 PM', 'Sunday: Closed']}
# place_id :     ChIJtT84-2nyNIgRtZthPxJLhFc
# price_level :     2
# rating :     4.4
# reviews :     [{'author_name': 'Derek Willis', 'author_url': 'https://www.google.com/maps/contrib/112777434089024534672/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-HBruTx9NOuI/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWBWxc_0S7cqMYGov3fzsPlUpgG-XQ/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 4, 'relative_time_description': 'a week ago', 'text': 'Small, intimate atmosphere. The food and price were good. The rice is not as big a portion as you would like, but the ability to put as much spice ad you want to meet your taste buds is great.', 'time': 1521328108}, {'author_name': 'Alicia Filigrana', 'author_url': 'https://www.google.com/maps/contrib/100054834612977615632/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-p5GHb2j3x_g/AAAAAAAAAAI/AAAAAAAAAH4/lCIeO9nSNd4/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg', 'rating': 5, 'relative_time_description': 'a month ago', 'text': "Very good food at a very reasonable price! All my Indian friends enjoy it a lot and say it tastes like traditional homemade food from India. The chai tea is amazing so drink at least a cup. It's never empty but you'll always find a place to sit. Try going for brunch, before 2:30. It is totally worth it!", 'time': 1518237564}, {'author_name': 'Nikolai Gage', 'author_url': 'https://www.google.com/maps/contrib/110423711522837354099/reviews', 'language': 'en', 'profile_photo_url': 'https://lh6.googleusercontent.com/-Ay3siQ7MM1M/AAAAAAAAAAI/AAAAAAAAZHU/Z_tSki8KBU4/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg', 'rating': 4, 'relative_time_description': 'a month ago', 'text': "I haven't eaten at many Indian places for comparison, but I wasn't disappointed. The prices seemed really reasonable, there was a good variety of food, and everything was clean and prepared quickly. I had the tikka masala at level 5 and would highly recommend it. My only negative is that is was incredibly quiet, which made me feel odd trying to have a conversation. If only there was more music or people to make the atmosphere more comfortable.", 'time': 1519270567}, {'author_name': 'Myriam THEOPHILE', 'author_url': 'https://www.google.com/maps/contrib/101323632166849196375/reviews', 'language': 'en', 'profile_photo_url': 'https://lh5.googleusercontent.com/-H3P6F2xKeqc/AAAAAAAAAAI/AAAAAAAAADU/l_VU7gAMwrU/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '4 months ago', 'text': 'We had buffet to take out and dinner at this place. I will say that I preferred the dinner. I liked the atmosphere, it was calm and cozy. The waitress was nice. And of course the food was nice too! We had, I think, a combo with lamb curry, salad, dessert and tea, we were full after that. The lamb was very good! Very tasty food!', 'time': 1511893736}, {'author_name': 'Janice Nim', 'author_url': 'https://www.google.com/maps/contrib/106541184017537991942/reviews', 'language': 'en', 'profile_photo_url': 'https://lh3.googleusercontent.com/-n8ZkuuDZKW4/AAAAAAAAAAI/AAAAAAAAAAA/ACLGyWAsXK6YNztFHCVbCKEzFI8cXWOOlQ/s128-c0x00000000-cc-rp-mo/photo.jpg', 'rating': 5, 'relative_time_description': '2 months ago', 'text': 'This is the best lunch buffet ever! Four to six vegetarian dishes as well as meat dishes. Delicious samosas and Nan. Yummy tea and mango pudding. You can smell the spices a block away. Well worth the trip!', 'time': 1516150293}]
# types :     ['restaurant', 'food', 'point_of_interest', 'establishment']
# url :     https://maps.google.com/?cid=6306247919970393013
# utc_offset :     -240
# vicinity :     5147, 1, Penn Avenue, Pittsburgh
# website :     http://www.peoplesindian.com/

# %% [markdown]
# # Using the Elevation and TimeZone APIs
#
# As the name implies, these APIs can be used to return the elevation above the local average sea level in meters and timezone values for any point on the Earth respectively.
# These two features could also serve as useful additions to predictive models.
# - The format of the TimeZoneAPI request will be as follows : *gmaps.timezone((lat/long tuple)).*
#     The response is in the form of a dictionary that specifies the timeZoneId, timeZoneName, rawOffset(time difference from UTC in seconds) and dstOffset (time difference from UTC in seconds after accounting for daylight savings if present)
# - The Elevation API returns the elevation values for single points as well as a series of points on the Earth. In case of the latter the response is elevation data along a path. The format for the Elevation API request will be as follows:
#     - *gmaps.elevation((lat/long tuple))* OR
#     - *gmaps.elevation([list of lat/long tuples])*
# - The Elevation response is in the form of a dictionary containing the elevation values, the location coordinates and the resolution (in case the exact elevation at the given point is not available, it is interpolated from several nearby points and the resolution gives the maximum distance in meters between these points)

# %%
# using the timezone api 
timezone=gmaps.timezone((40.438072,-79.922972))
print(timezone)
# Out:
# {'dstOffset': 3600, 'rawOffset': -18000, 'status': 'OK', 'timeZoneId': 'America/New_York', 'timeZoneName': 'Eastern Daylight Time'}

# %%
# using the elevation api
elevation=gmaps.elevation((40.438072,-79.922972))
path_elevation=gmaps.elevation([(40.438072,-79.922972),(42.438072,-79.922972),(50.438072,-90.922972),(62.438072,-70.922972)])
print(elevation)
print(path_elevation)
# Out:
# [{'elevation': 335.3444519042969, 'location': {'lat': 40.43807, 'lng': -79.92297}, 'resolution': 2.385987997055054}]
# [{'elevation': 335.3444519042969, 'location': {'lat': 40.43807, 'lng': -79.92297}, 'resolution': 2.385987997055054}, {'elevation': 129.9013824462891, 'location': {'lat': 42.43807, 'lng': -79.92297}, 'resolution': 152.7032318115234}, {'elevation': 429.0538330078125, 'location': {'lat': 50.43807, 'lng': -90.92297}, 'resolution': 38.17580795288086}, {'elevation': -238.9944610595703, 'location': {'lat': 62.43807, 'lng': -70.92297}, 'resolution': 610.8129272460938}]

# %% [markdown]
# # The GoogleMaps APIs in action
#
#
# For the purpose of demonstrating the usefulness of the geocoding API, we will be working with a dataset obtained from https://www.kaggle.com/c/nyc-taxi-trip-duration.
#
# Since the googlemaps API has an upper limit of 2500 free requests per day, I have cropped the dataset to contain only the top 20 rows just for purposes of demonstration.
#
# This Kaggle competition, based on taxi data from two taxi companies in New York,  required the estimation of the total ride time given certain features. These features include the pickup and dropoff geo-coordinates for each ride. There are several ways in which the GoogleMaps API can be useful in feature engineering:
# - The Geocoder API can help us reverse geocode these coordinates into locations and street addresses.The pickup and dropoff locations can be used as separate features that could be used in the final estimation model. It is possible that the originating or ending neighbourhood can have some part in detemrining the ride duration.
# - The Distance Matrix API can calculate the total distance between the origin and destination. This distance will be positively related to the ride duration.
#
# The code snippet below shows both the aforementioned techniques.
#
# In a separate analysis of the same dataset, it would be good to see whether, given the heavy traffic conditions in NYC, it would be faster to drive, walk or cycle from one point to another. The answer could vary for different origin/destination combinations since the traffic on all routes is not equally bad. So a multiway classification model could be built based on the data, predicting which mode of transport would be faster given a certain route. This can be by transforming the training data using the distance matrix. The Distance Matrix will return the total distance to be covered and time taken using all three modes and calculating the average speed for each mode.This has also been demonstrated below.

# %%
import numpy as np
import pandas as pd

# %%
#loading the dataset into a pandas dataframe
with open('./dataset.csv',encoding = 'utf-8') as ufile:
        u = pd.read_csv(ufile)
print(u.head())
# Out:
#    id  vendor_id      pickup_date dropoff_datetime  passenger_count  \
# 0   1          2  3/14/2016 17:24  3/14/2016 17:32                1
# 1   2          1   6/12/2016 0:43   6/12/2016 0:54                1
# 2   3          2  1/19/2016 11:35  1/19/2016 12:10                1
# 3   4          2   4/6/2016 19:32   4/6/2016 19:39                1
# 4   5          2  3/26/2016 13:30  3/26/2016 13:38                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
# 3        -74.010040        40.719971         -74.012268         40.706718
# 4        -73.973053        40.793209         -73.972923         40.782520
#
#    trip_duration
# 0            455
# 1            663
# 2           2124
# 3            429
# 4            435

# %%
# converting columns to correct datatypes
u['pickup_date'] = pd.to_datetime(u['pickup_date'])
u['dropoff_datetime'] = pd.to_datetime(u['dropoff_datetime'])
u.loc[:,'pickup_latitude']=pd.to_numeric(u['pickup_latitude']).astype(float)
u.loc[:,'pickup_longitude']=pd.to_numeric(u['pickup_longitude']).astype(float)
u.loc[:,'dropoff_latitude']=pd.to_numeric(u['dropoff_latitude']).astype(float)
u.loc[:,'dropoff_longitude']=pd.to_numeric(u['dropoff_longitude']).astype(float)

print(u.dtypes)
# Out:
# id                            int64
# vendor_id                     int64
# pickup_date          datetime64[ns]
# dropoff_datetime     datetime64[ns]
# passenger_count               int64
# pickup_longitude            float64
# pickup_latitude             float64
# dropoff_longitude           float64
# dropoff_latitude            float64
# trip_duration                 int64
# dtype: object

# %%
import datetime
now = datetime.datetime.now()
# function for reverse geocoding a point with coordinates (a,b) 
def rc(a,b):
    time.sleep(0.001)
    a=gmaps.reverse_geocode((a,b))
    b=(a)[0]
    long_name=b['address_components'][1]['long_name']
    full_address=b['formatted_address']
    return long_name,full_address

# function for returning directions, distances and time durations between two points a and b 
def get_dir(a,b):
    distance_driving= gmaps.distance_matrix(a,b,mode='driving',departure_time=datetime.datetime.now())
    distance_walking= gmaps.distance_matrix(a,b,mode='walking',departure_time=datetime.datetime.now())
    distance_cycling= gmaps.distance_matrix(a,b,mode='bicycling',departure_time=datetime.datetime.now())
    arr=[]
    for i in directions_result[0]['legs'][0]['steps']:
        arr.append(i)
    car_dist=distance_driving['rows'][0]['elements'][0]['distance']['value']
    walk_dist=distance_walking['rows'][0]['elements'][0]['distance']['value']
    cyc_dist=distance_cycling['rows'][0]['elements'][0]['distance']['value']
    car_time=distance_driving['rows'][0]['elements'][0]['duration']['value']
    walk_time=distance_walking['rows'][0]['elements'][0]['duration']['value']
    cyc_time=distance_cycling['rows'][0]['elements'][0]['duration']['value']
    
    return arr,car_dist,walk_dist,cyc_dist,car_time,walk_time,cyc_time

# %%
# the functions generated for returning API responses cannot be applied directly to pandas dataframe columns.
# Hence the columns need to be converted to arrays first 
t=u['pickup_latitude'].values
f=u['pickup_longitude'].values
plat=u['dropoff_latitude'].values
plong=u['dropoff_longitude'].values

# empty arrays are generated for storing the API response values 
h=[]
kl=[]
alpha=[]
beta=[]
car_distance=[]
car_time=[]
walk_distance=[]
walk_time=[]
cycle_distance=[]
cycle_time=[]

# %%
# From the four arrays containing lat and long coordinated for the originand destinatin, 
#the values for each row are taken one by  one and passed to the reverse geocoding function. 
# the function response is then appended to the new empty arrays h,kl, alpa and beta.  
for i in range(len(t)):
    j=t[i]  # source latitude
    k=f[i]  # source longitude
    l=plat[i] # dest latitude
    m=plong[i] # dest longitude
    
    q=rc(j,k)
    r=rc(l,m)
    h.append(q[0])   #source neighbourhood 
    kl.append(q[1])  #source address 
    alpha.append(r[0]) #destination neighbourhood
    beta.append(r[1])  #destination address

# %%
#Every pair of values in kl and beta, the arrays having origin and destination addresses, the get_dir function is called
# and the results are appended to the six new empty arrays car_distance.....cycle_time
for i in range(len(kl)):
    direct=get_dir(kl[i],beta[i])
    car_distance.append(direct[1])
    car_time.append(direct[4])
    walk_distance.append(direct[2])
    walk_time.append(direct[5])
    cycle_distance.append(direct[3])
    cycle_time.append(direct[6])

# %%
# the resulting arrays are then appended as columns to the dataframe
u['Source_Long_Name']=h
u['Source_Address']=kl
u['Dest_Long_Name']=alpha
u['Dest_Address']=beta
u['car_distance_metres']=car_distance
u['car_time_seconds']=car_time
u['walk_distance_metres']=walk_distance
u['walk_time_seconds']=walk_time
u['cycle_distance_metres']=cycle_distance
u['cycle_time_seconds']=cycle_time



print(u.head())
# Out:
#    id  vendor_id         pickup_date    dropoff_datetime  passenger_count  \
# 0   1          2 2016-03-14 17:24:00 2016-03-14 17:32:00                1
# 1   2          1 2016-06-12 00:43:00 2016-06-12 00:54:00                1
# 2   3          2 2016-01-19 11:35:00 2016-01-19 12:10:00                1
# 3   4          2 2016-04-06 19:32:00 2016-04-06 19:39:00                1
# 4   5          2 2016-03-26 13:30:00 2016-03-26 13:38:00                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.982155        40.767937         -73.964630         40.765602
# 1        -73.980415        40.738564         -73.999481         40.731152
# 2        -73.979027        40.763939         -74.005333         40.710087
# 3        -74.010040        40.719971         -74.012268         40.706718
# 4        -73.973053        40.793209         -73.972923         40.782520
#
#    trip_duration  Source_Long_Name  \
# 0            455   Columbus Circle
# 1            663  East 24th Street
# 2           2124  West 56th Street
# 3            429  Greenwich Street
# 4            435          Broadway
#
#                                Source_Address    Dest_Long_Name  \
# 0     4 Columbus Cir, New York, NY 10019, USA  East 65th Street
# 1  301-305 E 24th St, New York, NY 10010, USA  Macdougal Street
# 2      120 W 56th St, New York, NY 10019, USA    Beekman Street
# 3   377 Greenwich St, New York, NY 10013, USA    Exchange Place
# 4      2517 Broadway, New York, NY 10025, USA  West 81st Street
#
#                                Dest_Address  car_distance_metres  \
# 0    146 E 65th St, New York, NY 10065, USA                 2061
# 1  37 Macdougal St, New York, NY 10011, USA                 2546
# 2    41 Beekman St, New York, NY 10038, USA                 9928
# 3   73 Exchange Pl, New York, NY 10005, USA                 1883
# 4  22-54 W 81st St, New York, NY 10024, USA                 1594
#
#    car_time_seconds  walk_distance_metres  walk_time_seconds  \
# 0               529                  1988               1522
# 1               805                  2428               1860
# 2              1510                  6880               5241
# 3               585                  1687               1279
# 4               406                  1609               1238
#
#    cycle_distance_metres  cycle_time_seconds
# 0                   1996                 577
# 1                   2542                 607
# 2                   8515                1936
# 3                   2661                 596
# 4                   1596                 400

# %% [markdown]
# # Citations
#
# I have referred to the following two sources for the API documentation details. They are also good sources for learning more on this topic
#
#     https://developers.google.com/maps/
#
#     https://github.com/googlemaps/google-maps-services-python/blob/master/googlemaps/places.py
