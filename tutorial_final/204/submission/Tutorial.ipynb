# %% [markdown]
# # Practical Data Science Tutorial
# This tutorial will introduce you how to use and apply pytorch library to a specific speech classification problem. I am gonna use a speech dataset available in Kaggle, the whole process includes data preprocessing and using pytorch to build a All-CNNs model as the classifier and classify the speech in phoneme level.

# %% [markdown]
# ## The data file
# In this tutorial I use the following 2 file for training sake:
#
#     train-features.npy - training features
#     train-labels.npy - training labels
# And the follow file for testing:
#
#     test-features.npy - test features
#
# train-features.npy/test-features.npy is of shape (number of utterance, 2), denoted as data. data[:,0] is feature arrays, data[:,1] bound arrays. Each row in data is related to a single utterance, each utterance is composed of multiple phonemes, and each phonemes could be variable length part of array in a single utterance.
#
# More specifically, data[i,0] is also an array of phonemes (i.e. each phoneme may have variable length of feature in the array. eg. data[0,j] is the fist phoneme, data[j,k] is the second phoneme and data[k:] is the third phoneme, where 0<j<k<len(data)) which related to a single utterance "i"; and data[i,1] is an array of ints denoting the starting index of each phonemes within the single utterance "i". So, the features of phoneme i in utterance j are data[j,0][data[j,1][i]:data[j,1][i+1]].
#
# train-labels.npy is of shape (number of total phonemes,), and the "number of total phonemes" is the sum of the number of phonemes in each utterance in [train/test]-features.npy

# %% [markdown]
# ## Pytorch library introduction
# PyTorch is an open source machine learning library for Python, based on Torch, used for applications such as natural language processing. It is primarily developed by Facebook's artificial-intelligence research group, and Uber's "Pyro" software for probabilistic programming is built on it. Referred from [1].

# %% [markdown]
# # Now begin data preprocessing part

# %% [markdown]
# ## First import all the require library we  gonna use

# %%
import numpy as np
import torch
from torch import autograd, nn
import torch.utils.data
import os
import csv
import sys

# %% [markdown]
# ## Load raw data
# Load() and load_raw() function is used for load "[train/test]-features.npy" and "train-label.npy"

# %%
class Load:
    def __init__(self):
        self.test_set = None
        self.train_set = None
    @property
    def test(self):
        if self.test_set is None:
            self.test_set = np.load('./test-features.npy')
        return self.test_set

    @property
    def train(self):
        if self.train_set is None:
            self.train_set = load_raw('./train')
        return self.train_set

def load_raw(name): # return a tuple
    return (
        np.load('{}-features.npy'.format(name)),
        np.load('{}-labels.npy'.format(name))
    )

# %% [markdown]
# ## Override torch.utils.data.Dataset
# torch.utils.data.Dataset is an abstract class representing a dataset. Our custom dataset should inherit Dataset and override the following methods:
# __len__ so that len(dataset) returns the size of the dataset.
# __getitem__ to support the indexing such that dataset[i] can be used to get ith sample
# (Referred from [2])
# Since torch define its own Dataset function which will also passed as a parameter to torch's DataLoader function, Dataset defines a bridge from the raw data to the Dataloader, we can change the data form in Dataset function to decide what shape or what kind of data we passed to the DataLoader. Dataloader will return an iterator of final versioned training data and labels of each mini-batch, shaped as (data, label).
#
# In line #8 and #9, I split the raw dataset and form them as what they belong to. And also I rewrite "__len__" and "__getitem__" function to feed what I want to my DataLoader.

# %%
class myDataset(torch.utils.data.Dataset):
    def __init__(self, dataset):  # ([samples, 2], [samples]): 
                                  # samples*(
                                  # feature: ([time, frequency], [phoneme count]),
                                  # label: [phoneme count]
                                  #)
        super(myDataset, self).__init__()
        self.dataset = dataset[0][:,0]
        self.seg_arr = dataset[0][:,1]
        self.label = dataset[1]
    

    def __len__(self):
        return self.dataset.shape[0]


    def __getitem__(self, idx):
        if self.label is not None:  # Noted that for test dataset, the label is "None"
            return self.dataset[idx], self.label[idx], self.seg_arr[idx]
        return self.dataset[idx], None, self.seg_arr[idx]

# %% [markdown]
# # Override collate_fn() function in torch.utils.data.DataLoader (Core of Data Preprocessing)
# collate_fn() is a function in torch.utils.data.DataLoader, DataLoader will call collate_fn() function like this: "batch = self.collate_fn([self.dataset[i] for i in batch_size])" in its __next__() function of __iter__() function, for every epoch, the __iter__() function will be called once and generate a interator including all batches in a single epoch; and the __next__() will be called by __iter__() for generate each batch within the epoch. Therefore, we overwrite the collate_fn() function whose job is to recieve torch.utils.data.DataSet class and generate a tuple of data for the training routine. By default, the default coallte_fn() function will return (a batch of data, a batch of label). By overriding this function, we can arbitrarily return the form of data whatever we like to see!
#
# Now Let's talk about data preprocessing details. The "data" in line #1 is a list of tuple generated by calling our version of __getitem__() function for "batch_size" times. Here's the trick of the preprocessing part: our aim is to train a model to classify the voice data in phoneme level not in utterance level (one utterance includes multiple phonemes), but our data is arrange in utterance level (i.e. feature[i] is a utterance consist of an array of phonemes). Also, there's another ploblem here: although feature[i] is an array of phonemes, but it has different length for all i. However, to pass the batch data to GPU for model training, We have to stack our data into a rectangle which means feature[i] needs to be padded out to the same length for all i in range(len(feature)). To overcome 2 problem stated above, we do the following things:
#     1. make feature of a rectangled new shape of (batch_size, frequency, maxlen_feature), where frequency is 40, the dimension for a phoneme feature, maxlen_feature is the max length of utterance of all utterance in feature;
#     2. make label of a rectangled new shape of (batch_size,  maxlen_feature);
#     3. create "mask" to denoted where the actually data in the new feature created in step 1, the mask shaped as (batch_size, maxlen_feature,  maxlen_feature), to use it, when done the forward pass throung the model, the prediction matrix will do some multiplication with this mask so that it will zero out the padded data in the corresponding dimension in the prediction matrix;
#     4. create "mask_loss" to denote the actually data in label (as opposed to the padded ones in newly created labels in step 2);
# Finally, return a tuple containing all these four newly created data as one single batch.

# %%
def collate_fn(data):
    '''
        Parameters: data - a list of tuple
            - feature batch_size, ([time, frequency])
            - label batch_size*([phoneme count])
            - seg_arr batch_size*([phoneme count])
        Return tupe of numpy array: 
            - feature    batch_size, frequency, maxlen_feature (frequency is 40, which is the dimension for a phoneme)
            - label    batch_size, maxlen_feature
            - mask    batch_size, maxlen_feature, maxlen_feature
            - mask_loss mask for masking loss array use batch_size * maxlen_feature
    '''
    feature, label, seg_arr = zip(*data) # all are tuple of numpy-ndarray
    batch_size = len(feature)
    frequency = feature[0].shape[1]
    maxlen_feature = 0

    for utterance in feature:
        if utterance.shape[0] > maxlen_feature:
            maxlen_feature = utterance.shape[0]

    label_new = None if label[0] is None else np.zeros((batch_size, maxlen_feature))
    feature_new = np.zeros((batch_size, frequency, maxlen_feature))
    mask = np.zeros((batch_size, maxlen_feature, maxlen_feature))
    mask_loss = np.zeros((batch_size, maxlen_feature))

    for i in range(batch_size):
        # first, update labels and mask
        cur_arr = seg_arr[i]
        cur_len = len(feature[i])
        for j in range(len(cur_arr)):
            if label_new is not None:
                label_new[i][cur_arr[j]:len(feature[i])] = label[i][j]
            over = cur_len if j == len(cur_arr)-1 else cur_arr[j+1] 
            mask[i][cur_arr[j]:over, cur_arr[j]:over]= 1
            mask_loss[i][cur_arr[j]] = 1 
        # second, update features
        feature_new[i][:,:cur_len] = feature[i].T  # use transpose to make it (frequency, maxlen_feature) 
    feature = feature_new
    label = label_new
    return feature, label, mask, mask_loss

# %% [markdown]
# # Now begin model building part
# I use ALL-CNN-c model described in paper$^{[3]}$. The whole architecture is as the following image shows:
# ![alt text](ALL_CNN_C.png "ALL-CNN-C Model")
# There are totally 21 layers defined in the model (i.e. only convolutional, ReLU and Dropout layer are counted as layers). I also add some batch normalization between convolutional layers whose job is to do the covariance shift to make output of each layer more uniform in some sense.
# Noted that I write a class CNNModel which inherent torch.nn.Module class. In this way, I overwirte the "$\textbf{forward}$" function which will functioned as actual calculation part in the forward pass.
# As to all parameters I used in layers, simply speaking, the model take input data of shape (batch_size, frequency, maxlen_feature), treate "frequency" as the "input channels" of CNN layer; with some ReLU, Dropout and Batch Normalization done, the model output the data with the shape of (batch_size, 46, maxlen_feature), where 46 is the final number of class we want to classify each phoneme into.

# %%
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.layers = nn.ModuleList([
            nn.Conv1d(in_channels=40, out_channels=192, padding=3, kernel_size=7),
            nn.Dropout(0.2, False),
            # nn.BatchNorm1d(192),
            nn.ReLU(False),
            nn.Conv1d(in_channels=192, out_channels=192, padding=3, kernel_size=7),
            nn.BatchNorm1d(192),
            nn.ReLU(False),
            nn.Conv1d(in_channels=192, out_channels=192, padding=3, kernel_size=7),
            nn.BatchNorm1d(192),
            nn.ReLU(False),


            nn.Conv1d(in_channels=192, out_channels=192, padding=3, kernel_size=7),
            nn.Dropout(0.3, False),
            # nn.BatchNorm1d(192),
            nn.ReLU(False),
            nn.Conv1d(in_channels=192, out_channels=192, padding=3, kernel_size=7),
            nn.BatchNorm1d(192),
            nn.ReLU(False),
            nn.Conv1d(in_channels=192, out_channels=192, padding=3, kernel_size=7),
            nn.BatchNorm1d(192),
            nn.ReLU(False),


            nn.Conv1d(in_channels=192, out_channels=192, padding=3, kernel_size=7),
            nn.Dropout(0.3, False),
            # nn.BatchNorm1d(192),
            nn.ReLU(False),
            nn.Conv1d(in_channels=192, out_channels=192, padding=3, kernel_size=7),
            nn.BatchNorm1d(192),
            nn.ReLU(False),
            nn.Conv1d(in_channels=192, out_channels=46, padding=3, kernel_size=7),
            nn.BatchNorm1d(46),
            nn.ReLU(False)

        ])
        self.firstrun = True

    def forward(self, input):
        h = input
        if self.firstrun:
            print("****************************************")
            print("input: {}".format(h.size()))
        for layer in self.layers:
            h = layer(h)
            if self.firstrun:
                print("{}: {}".format(layer, h.size()))
        if self.firstrun:
            print("****************************************")
        self.firstrun = False
        return h

# %% [markdown]
# # Training Routine

# %% [markdown]
# First, we initialize all parameters such as "learning rate" and "batch size";
#
# Second, in line #35, we create the model of ALL-CNN-C defined above and apply "weights_init" for all convolutional layers in the model;
#
# Then, define our loss function and optimizer as cross entropy loss and Adam optimizer respectively;
#
# Next, move all parameters of the module and variables to GPU (If available) in line #45;
#
# Next, load our DataLoader in line #51, using our overwirted version of Dataset and collate_fn() as parameters;
#
# Then, dive into 2 for-loop, the first one defines number of epochs to run, and the second iterate through all batches within an epoch;
#
# Then, seal all data in variable and move the data to the GPU (If available) in line #70~ #74. Noted that torch will need all data is "torch.autograd.Variable" to calculate is gradient when doing the backpropgation;
#
# Then, do the forward pass in line , and transpose the prediction matrix for later use;
#
# Next, use "mask" to zero out the padding in the prediction matrix in line #78 ~ #79. After masking, the output shape is (batch_size,  max_feature,  46);
#
# Next, mask the label data, and together with the prediction, it is passed to the loss function in line ; Here is one more thing to notice, that is, because we need to do the mask to the loss in order to discard the part of loss corresponding to the padded phonemes, we need to make "reduce=False" in line #37 when defining the loss function, which, will return loss matrix corresponding to each poneme instead of a scalar of averaged loss;
#
# Then, zero out the padding loss in line #85 and #86, we do the backpropagation in line #87 in which we will get the corresponding gradient to each variable;
#
# Finally, we update all the parameter in our model by calling "optimizer.step()" in line #89.

# %%
def to_Doubletensor(numpy_array):
    # Numpy array -> Tensor
    return torch.from_numpy(numpy_array).float()


def to_Longtensor(numpy_array):
    # Numpy array -> Tensor
    return torch.from_numpy(numpy_array).type(torch.LongTensor)


def to_variable(tensor):
    # Tensor -> Variable (on GPU if possible)
    if torch.cuda.is_available():
        # Tensor -> GPU Tensor
        tensor = tensor.cuda()
    return autograd.Variable(tensor)


def weights_init(m):
    if isinstance(m, nn.Conv2d):  # apply only to convolutional layer
        nn.init.xavier_normal(m.weight)


def training_routine():

    # Define parameters
    learning_rate = 0.01
    momentum_rate = 0.7
    minibatch_size = 1
    num_epochs = 30

    raw_data = Load()
    mydataset = myDataset(raw_data.train)
    my_net = CNNModel()  # Create the network,
    my_net.apply(weights_init)

    loss_fn = torch.nn.CrossEntropyLoss(reduce=False)  # and choose the loss function / optimizer
    optim = torch.optim.SGD(
        my_net.parameters(), lr=learning_rate, momentum=momentum_rate)
#     optim = torch.optim.Adam(
#         my_net.parameters(), lr=learning_rate)
    # optim = torch.optim.Adagrad(
    #     my_net.parameters(), lr=learning_rate, weight_decay=0)

    if torch.cuda.is_available():
        # Move the network and the optimizer to the GPU
        my_net = my_net.cuda()
        loss_fn = loss_fn.cuda()

    # Define dataset
    data_loader = torch.utils.data.DataLoader(
        mydataset, batch_size=minibatch_size,
        shuffle=True, pin_memory=True,
        collate_fn=collate_fn, drop_last=True)
    '''
        data formata:
            - feature    batch_size, frequency, maxlen_feature
            - label    batch_size, maxlen_feature
            - mask    batch_size, maxlen_feature, maxlen_feature
            - mask_loss batch_size, maxlen_feature
    '''
    ep_cnt = 0
    for epoch in range(num_epochs):
        losses = []

        i = 0
 
        for (input_val, label, mask, mask_loss) in data_loader:
            # Need to transform all numpy array to tensor then to variable to flow in network
            input_val = to_variable(to_Doubletensor(input_val))
            label = to_variable(to_Longtensor(label))
            mask = to_variable(to_Doubletensor(mask))
            mask_loss = to_variable(to_Doubletensor(mask_loss))
            optim.zero_grad()  # Reset the gradients
            prediction = torch.transpose(my_net(input_val), 1,2)  # (batch_size,  maxlen_feature,  46)
            # WARNING!!! We need to keep everything in Variable to retain gradient
            mask_sum = torch.sum(mask, 2).unsqueeze(2)
            prediction_avg = torch.matmul(mask, prediction) / (
                mask_sum + (mask_sum == 0).float())  # (batch_size,  max_feature,  46)

            # Resize prediction and label to fit to loss funciton
            label = label.resize(label.size()[0] * label.size()[1], )  # (batch_size * max_feature, )
            prediction_avg = prediction_avg.resize(prediction_avg.size()[0] *
                            prediction_avg.size()[1], prediction_avg.size()[2]) # (batch_size * max_feature, 46)
            loss = loss_fn(prediction_avg, label)  # Compute losses
            mask_loss = mask_loss.resize(mask_loss.size()[0] * mask_loss.size()[1],)
            loss = torch.sum(loss * mask_loss) / torch.sum(mask_loss)
            loss.backward()  # Backpropagate the gradients
            losses.append(loss.data.cpu().numpy())
            optim.step() # Update the network
            i += 1
            if i % 5 ==0:
                print("Epoch {} Round {} Loss: {:.4f}".format(epoch, i, np.asscalar(np.mean(losses))))
            if i >= 250: return  # This is just for show use for this tutorial
        print('Saving net for Epoch{}', ep_cnt)
        torch.save(my_net, './net_Epoch_' + str(ep_cnt) + '.pkl')
        ep_cnt += 1
    return my_net.cpu()

# %% [markdown]
# # Testing Routine

# %% [markdown]
# The logic of testing routine is almost the same with the training, except the testing part do not require computing the gradient since all parameters do not need to be updated during testing. So all to do is just perform a forward pass. I use the comment to some of the line to explain why do this way or the output shape of this line. Also, followings are the points need to be noticed.
# 1. set "my_net.eval()" to switch from the "training mode" to "evaluation" mode in which it will turn off some function that should not work in the testing phase such as "dropout", and also change the behaviour of some function like "Batch Normalization";
# 2. batch size is set to 1 to predict 1 sample in a batch;
# 3. turn off the "shuffle" selection in DataLoader to keep the input samples in their original order;
# 4. the prediction is also use "mask" and "mask_loss" to zero out the padding for generalization use (i.e. In this case we do need to do the mask actually because the size of batch size is 1).

# %%
def testing_routine(my_net):  # net in cpu model
    if torch.cuda.is_available():
        # Move the network and the optimizer to the GPU
        my_net = my_net.cuda()
    net = net.eval()  # switch to evaluation mode to disable drop out layer
    raw_test_data = Load()
    mydataset = myDataset(raw_test_data.test)
    data_loader = torch.utils.data.DataLoader(
        mydataset,
        batch_size=1, shuffle=False,
        collate_fn=collate_fn, pin_memory=True)  # Do not shuffle

    predictions = []
    for (input_val, _, mask, mask_loss) in data_loader:
            # Need to transform all numpy array to tensor then to variable to flow in network
            input_val = to_variable(to_Doubletensor(input_val))
            mask = to_variable(to_Doubletensor(mask))
            mask_loss = to_variable(to_Longtensor(mask_loss))

            prediction = torch.transpose(my_net(input_val), 1,2)  # (batch_size, maxlen_feature, 46)
            # pooling layer, no need to cal gradient
            mask_sum = torch.sum(mask, 2).unsqueeze(2)
            prediction_avg = torch.matmul(mask, prediction) /  (mask_sum + (mask_sum == 0).float())  # (batch_size, max_feature, 46)

            prediction_avg = prediction_avg.resize(prediction_avg.size()[0]
                            * prediction_avg.size()[1], prediction_avg.size()[2]).data.cpu().numpy()  # (batch_size * max_feature, 46)
            prediction_avg = [np.argmax(p) for p in prediction_avg]  # (batch_size * max_feature, )
            predictions += prediction_avg[np.where(mask_loss.data.cpu().numpy() !=0)].tolist()

    return predictions  # (number of phonemes in the test data set,)

# %% [markdown]
# ## Main logic
#
# In this module, I am gonna show the training intermida result and testing output.
#
# Limited to the length of content, I just show a part of training process which is enough for demonstrate the whole process.
#
# For testing part, I just jump directly to the ".csv" file that generated in advance using my trained model. Sorry for can not wait training phase to finish due to huge amout of time consuming :-)

# %%
def main(argv):
    # Training settings
    net = training_routine()
#     predictions, labels = testing_routine(net)
#     acc = len(np.where(prediction == labels)[0]) / len(predictions)
    with open('Prediction_Results_20.csv', newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            print('Sample #'+row['Id']+", Label:"+row['Label'])
if __name__ == '__main__':
    main(sys.argv[1:])
# Out:
# ****************************************
# input: torch.Size([1, 40, 499])
# Conv1d(40, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# Dropout(p=0.2): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# Dropout(p=0.3): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# Dropout(p=0.3): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 192, 499])
# BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True): torch.Size([1, 192, 499])
# ReLU(): torch.Size([1, 192, 499])
# Conv1d(192, 46, kernel_size=(7,), stride=(1,), padding=(3,)): torch.Size([1, 46, 499])
# BatchNorm1d(46, eps=1e-05, momentum=0.1, affine=True): torch.Size([1, 46, 499])
# ReLU(): torch.Size([1, 46, 499])
# ****************************************
# Epoch 0 Round 5 Loss: 3.8053
# Epoch 0 Round 10 Loss: 3.7326
# Epoch 0 Round 15 Loss: 3.7076
# Epoch 0 Round 20 Loss: 3.6631
# Epoch 0 Round 25 Loss: 3.6301
# Epoch 0 Round 30 Loss: 3.5961
# Epoch 0 Round 35 Loss: 3.5749
# Epoch 0 Round 40 Loss: 3.5455
# Epoch 0 Round 45 Loss: 3.5112
# Epoch 0 Round 50 Loss: 3.4957
# Epoch 0 Round 55 Loss: 3.4781
# Epoch 0 Round 60 Loss: 3.4604
# Epoch 0 Round 65 Loss: 3.4498
# Epoch 0 Round 70 Loss: 3.4307
# Epoch 0 Round 75 Loss: 3.4179
# Epoch 0 Round 80 Loss: 3.4043
# Epoch 0 Round 85 Loss: 3.3894
# Epoch 0 Round 90 Loss: 3.3780
# Epoch 0 Round 95 Loss: 3.3653
# Epoch 0 Round 100 Loss: 3.3629
# Epoch 0 Round 105 Loss: 3.3485
# Epoch 0 Round 110 Loss: 3.3498
# Epoch 0 Round 115 Loss: 3.3372
# Epoch 0 Round 120 Loss: 3.3265
# Epoch 0 Round 125 Loss: 3.3160
# Epoch 0 Round 130 Loss: 3.3063
# Epoch 0 Round 135 Loss: 3.2940
# Epoch 0 Round 140 Loss: 3.2836
# Epoch 0 Round 145 Loss: 3.2768
# Epoch 0 Round 150 Loss: 3.2733
# Epoch 0 Round 155 Loss: 3.2741
# Epoch 0 Round 160 Loss: 3.2686
# Epoch 0 Round 165 Loss: 3.2565
# Epoch 0 Round 170 Loss: 3.2475
# Epoch 0 Round 175 Loss: 3.2379
# Epoch 0 Round 180 Loss: 3.2270
# Epoch 0 Round 185 Loss: 3.2179
# Epoch 0 Round 190 Loss: 3.2072
# Epoch 0 Round 195 Loss: 3.1999
# Epoch 0 Round 200 Loss: 3.1959
# Epoch 0 Round 205 Loss: 3.1886
# Epoch 0 Round 210 Loss: 3.1842
# Epoch 0 Round 215 Loss: 3.1727
# Epoch 0 Round 220 Loss: 3.1628
# Epoch 0 Round 225 Loss: 3.1527
# Epoch 0 Round 230 Loss: 3.1435
# Epoch 0 Round 235 Loss: 3.1382
# Epoch 0 Round 240 Loss: 3.1306
# Epoch 0 Round 245 Loss: 3.1224
# Epoch 0 Round 250 Loss: 3.1155
# Sample #0, Label:36
# Sample #1, Label:14
# Sample #2, Label:33
# Sample #3, Label:18
# Sample #4, Label:41
# Sample #5, Label:30
# Sample #6, Label:42
# Sample #7, Label:16
# Sample #8, Label:34
# Sample #9, Label:37
# Sample #10, Label:27
# Sample #11, Label:8
# Sample #12, Label:29
# Sample #13, Label:38
# Sample #14, Label:17
# Sample #15, Label:20
# Sample #16, Label:33
# Sample #17, Label:23
# Sample #18, Label:14
# Sample #19, Label:22
# Sample #20, Label:28
# Sample #21, Label:32
# Sample #22, Label:33
# Sample #23, Label:22
# Sample #24, Label:28
# Sample #25, Label:34
# Sample #26, Label:8
# Sample #27, Label:32
# Sample #28, Label:8
# Sample #29, Label:26
# Sample #30, Label:37
# Sample #31, Label:8
# Sample #32, Label:34
# Sample #33, Label:16
# Sample #34, Label:26
# Sample #35, Label:17
# Sample #36, Label:37
# Sample #37, Label:34
# Sample #38, Label:22
# Sample #39, Label:28
# Sample #40, Label:26
# Sample #41, Label:8
# Sample #42, Label:28
# Sample #43, Label:14
# Sample #44, Label:42
# Sample #45, Label:9
# Sample #46, Label:37
# Sample #47, Label:17
# Sample #48, Label:37
# Sample #49, Label:33
# Sample #50, Label:7
# Sample #51, Label:28
# Sample #52, Label:34
# Sample #53, Label:32
# Sample #54, Label:17
# Sample #55, Label:37
# Sample #56, Label:40
# Sample #57, Label:35
# Sample #58, Label:8
# Sample #59, Label:28
# Sample #60, Label:34
# Sample #61, Label:37
# Sample #62, Label:23
# Sample #63, Label:41
# Sample #64, Label:22
# Sample #65, Label:14
# Sample #66, Label:9
# Sample #67, Label:33
# Sample #68, Label:22
# Sample #69, Label:29
# Sample #70, Label:8
# Sample #71, Label:28
# Sample #72, Label:14
# Sample #73, Label:32
# Sample #74, Label:11
# Sample #75, Label:37
# Sample #76, Label:19
# Sample #77, Label:16
# Sample #78, Label:12
# Sample #79, Label:17
# Sample #80, Label:8
# Sample #81, Label:25
# Sample #82, Label:18
# Sample #83, Label:35
# Sample #84, Label:8
# Sample #85, Label:28
# Sample #86, Label:12
# Sample #87, Label:40
# Sample #88, Label:44
# Sample #89, Label:28
# Sample #90, Label:8
# Sample #91, Label:34
# Sample #92, Label:40
# Sample #93, Label:44
# Sample #94, Label:19
# Sample #95, Label:17
# Sample #96, Label:8
# Sample #97, Label:28
# Sample #98, Label:6
# Sample #99, Label:8
# Sample #100, Label:28
# Sample #101, Label:15
# Sample #102, Label:8
# Sample #103, Label:34
# Sample #104, Label:25
# Sample #105, Label:42
# Sample #106, Label:30
# Sample #107, Label:40
# Sample #108, Label:37
# Sample #109, Label:34
# Sample #110, Label:8
# Sample #111, Label:27
# Sample #112, Label:27
# Sample #113, Label:36
# Sample #114, Label:8
# Sample #115, Label:15
# Sample #116, Label:8
# Sample #117, Label:25
# Sample #118, Label:8
# Sample #119, Label:27
# Sample #120, Label:12
# Sample #121, Label:11
# Sample #122, Label:28
# Sample #123, Label:14
# Sample #124, Label:12
# Sample #125, Label:22
# Sample #126, Label:44
# Sample #127, Label:28
# Sample #128, Label:8
# Sample #129, Label:34
# Sample #130, Label:22
# Sample #131, Label:44
# Sample #132, Label:8
# Sample #133, Label:25
# Sample #134, Label:10
# Sample #135, Label:28
# Sample #136, Label:22
# Sample #137, Label:14
# Sample #138, Label:19
# Sample #139, Label:17
# Sample #140, Label:13
# Sample #141, Label:40
# Sample #142, Label:21
# Sample #143, Label:8
# Sample #144, Label:28
# Sample #145, Label:14
# Sample #146, Label:17
# Sample #147, Label:14
# Sample #148, Label:14
# Sample #149, Label:38
# Sample #150, Label:17
# Sample #151, Label:14
# Sample #152, Label:23
# Sample #153, Label:19
# Sample #154, Label:9
# Sample #155, Label:14
# Sample #156, Label:27
# Sample #157, Label:22
# Sample #158, Label:26
# Sample #159, Label:43
# Sample #160, Label:8
# Sample #161, Label:28
# Sample #162, Label:14
# Sample #163, Label:6
# Sample #164, Label:26
# Sample #165, Label:17
# Sample #166, Label:44
# Sample #167, Label:8
# Sample #168, Label:41
# Sample #169, Label:24
# Sample #170, Label:33
# Sample #171, Label:18
# Sample #172, Label:41
# Sample #173, Label:30
# Sample #174, Label:44
# Sample #175, Label:2
# Sample #176, Label:18
# Sample #177, Label:37
# Sample #178, Label:5
# Sample #179, Label:8
# Sample #180, Label:28
# Sample #181, Label:20
# Sample #182, Label:17
# Sample #183, Label:14
# Sample #184, Label:28
# Sample #185, Label:11
# Sample #186, Label:8
# Sample #187, Label:37
# Sample #188, Label:23
# Sample #189, Label:38
# Sample #190, Label:33
# Sample #191, Label:23
# Sample #192, Label:27
# Sample #193, Label:22
# Sample #194, Label:26
# Sample #195, Label:43
# Sample #196, Label:8
# Sample #197, Label:28
# Sample #198, Label:14
# Sample #199, Label:6
# Sample #200, Label:26
# Sample #201, Label:17
# Sample #202, Label:44
# Sample #203, Label:22
# Sample #204, Label:28
# Sample #205, Label:28
# Sample #206, Label:11
# Sample #207, Label:28
# Sample #208, Label:37
# Sample #209, Label:23
# Sample #210, Label:28
# Sample #211, Label:18
# Sample #212, Label:37
# Sample #213, Label:23
# Sample #214, Label:19
# Sample #215, Label:11
# Sample #216, Label:32
# Sample #217, Label:33
# Sample #218, Label:16
# Sample #219, Label:32
# Sample #220, Label:8
# Sample #221, Label:28
# Sample #222, Label:43
# Sample #223, Label:40
# Sample #224, Label:40
# Sample #225, Label:36
# Sample #226, Label:36
# Sample #227, Label:22
# Sample #228, Label:28
# Sample #229, Label:34
# Sample #230, Label:16
# Sample #231, Label:32
# Sample #232, Label:37
# Sample #233, Label:16
# Sample #234, Label:27
# Sample #235, Label:12
# Sample #236, Label:17
# Sample #237, Label:36
# Sample #238, Label:15
# Sample #239, Label:8
# Sample #240, Label:25
# Sample #241, Label:8
# Sample #242, Label:27
# Sample #243, Label:32
# Sample #244, Label:8
# Sample #245, Label:28
# Sample #246, Label:23
# Sample #247, Label:33
# Sample #248, Label:22
# Sample #249, Label:35
# Sample #250, Label:23
# Sample #251, Label:41
# Sample #252, Label:14
# Sample #253, Label:28
# Sample #254, Label:11
# Sample #255, Label:28
# Sample #256, Label:37
# Sample #257, Label:23
# Sample #258, Label:35
# Sample #259, Label:22
# Sample #260, Label:25
# Sample #261, Label:34
# Sample #262, Label:32
# Sample #263, Label:9
# Sample #264, Label:28
# Sample #265, Label:37
# Sample #266, Label:18
# Sample #267, Label:37
# Sample #268, Label:36
# Sample #269, Label:27
# Sample #270, Label:40
# Sample #271, Label:40
# Sample #272, Label:43
# Sample #273, Label:8
# Sample #274, Label:28
# Sample #275, Label:14
# Sample #276, Label:6
# Sample #277, Label:26
# Sample #278, Label:17
# Sample #279, Label:44
# Sample #280, Label:16
# Sample #281, Label:44
# Sample #282, Label:8
# Sample #283, Label:37
# Sample #284, Label:34
# Sample #285, Label:35
# Sample #286, Label:33
# Sample #287, Label:8
# Sample #288, Label:41
# Sample #289, Label:41
# Sample #290, Label:20
# Sample #291, Label:7
# Sample #292, Label:27
# Sample #293, Label:8
# Sample #294, Label:13
# Sample #295, Label:40
# Sample #296, Label:35
# Sample #297, Label:19
# Sample #298, Label:17
# Sample #299, Label:27
# Sample #300, Label:8
# Sample #301, Label:12
# Sample #302, Label:33
# Sample #303, Label:23
# Sample #304, Label:13
# Sample #305, Label:8
# Sample #306, Label:41
# Sample #307, Label:25
# Sample #308, Label:6
# Sample #309, Label:28
# Sample #310, Label:37
# Sample #311, Label:33
# Sample #312, Label:7
# Sample #313, Label:25
# Sample #314, Label:37
# Sample #315, Label:8
# Sample #316, Label:42
# Sample #317, Label:9
# Sample #318, Label:33
# Sample #319, Label:14
# Sample #320, Label:3
# Sample #321, Label:33
# Sample #322, Label:14
# Sample #323, Label:26
# Sample #324, Label:18
# Sample #325, Label:37
# Sample #326, Label:22
# Sample #327, Label:14
# Sample #328, Label:37
# Sample #329, Label:40
# Sample #330, Label:8
# Sample #331, Label:25
# Sample #332, Label:30
# Sample #333, Label:26
# Sample #334, Label:32
# Sample #335, Label:9
# Sample #336, Label:33
# Sample #337, Label:37
# Sample #338, Label:37
# Sample #339, Label:17
# Sample #340, Label:35
# Sample #341, Label:22
# Sample #342, Label:32
# Sample #343, Label:0
# Sample #344, Label:36
# Sample #345, Label:36
# Sample #346, Label:16
# Sample #347, Label:44
# Sample #348, Label:27
# Sample #349, Label:40
# Sample #350, Label:44
# Sample #351, Label:25
# Sample #352, Label:8
# Sample #353, Label:28
# Sample #354, Label:20
# Sample #355, Label:8
# Sample #356, Label:26
# Sample #357, Label:8
# Sample #358, Label:29
# Sample #359, Label:29
# Sample #360, Label:27
# Sample #361, Label:22
# Sample #362, Label:34
# Sample #363, Label:37
# Sample #364, Label:17
# Sample #365, Label:30
# Sample #366, Label:20
# Sample #367, Label:34
# Sample #368, Label:23
# Sample #369, Label:22
# Sample #370, Label:25
# Sample #371, Label:36
# Sample #372, Label:34
# Sample #373, Label:10
# Sample #374, Label:38
# Sample #375, Label:16
# Sample #376, Label:19
# Sample #377, Label:17
# Sample #378, Label:17
# Sample #379, Label:25
# Sample #380, Label:8
# Sample #381, Label:44
# Sample #382, Label:34
# Sample #383, Label:16
# Sample #384, Label:27
# Sample #385, Label:13
# Sample #386, Label:33
# Sample #387, Label:8
# Sample #388, Label:26
# Sample #389, Label:20
# Sample #390, Label:8
# Sample #391, Label:12
# Sample #392, Label:17
# Sample #393, Label:27
# Sample #394, Label:8
# Sample #395, Label:28
# Sample #396, Label:37
# Sample #397, Label:36
# Sample #398, Label:22
# Sample #399, Label:34
# Sample #400, Label:42
# Sample #401, Label:11
# Sample #402, Label:25
# Sample #403, Label:8
# Sample #404, Label:12
# Sample #405, Label:22
# Sample #406, Label:14
# Sample #407, Label:3
# Sample #408, Label:42
# Sample #409, Label:8
# Sample #410, Label:27
# Sample #411, Label:12
# Sample #412, Label:17
# Sample #413, Label:22
# Sample #414, Label:29
# Sample #415, Label:3
# Sample #416, Label:37
# Sample #417, Label:7
# Sample #418, Label:29
# Sample #419, Label:25
# Sample #420, Label:3
# Sample #421, Label:36
# Sample #422, Label:36
# Sample #423, Label:21
# Sample #424, Label:42
# Sample #425, Label:28
# Sample #426, Label:37
# Sample #427, Label:36
# Sample #428, Label:32
# Sample #429, Label:22
# Sample #430, Label:22
# Sample #431, Label:33
# Sample #432, Label:33
# Sample #433, Label:25
# Sample #434, Label:33
# Sample #435, Label:16
# Sample #436, Label:37
# Sample #437, Label:34
# Sample #438, Label:17
# Sample #439, Label:22
# Sample #440, Label:29
# Sample #441, Label:15
# Sample #442, Label:8
# Sample #443, Label:14
# Sample #444, Label:33
# Sample #445, Label:11
# Sample #446, Label:12
# Sample #447, Label:17
# Sample #448, Label:44
# Sample #449, Label:34
# Sample #450, Label:40
# Sample #451, Label:32
# Sample #452, Label:3
# Sample #453, Label:8
# Sample #454, Label:28
# Sample #455, Label:14
# Sample #456, Label:12
# Sample #457, Label:26
# Sample #458, Label:6
# Sample #459, Label:25
# Sample #460, Label:34
# Sample #461, Label:33
# Sample #462, Label:11
# Sample #463, Label:14
# Sample #464, Label:26
# Sample #465, Label:23
# Sample #466, Label:19
# Sample #467, Label:43
# Sample #468, Label:33
# Sample #469, Label:42
# Sample #470, Label:8
# Sample #471, Label:37
# Sample #472, Label:15
# Sample #473, Label:8
# Sample #474, Label:37
# Sample #475, Label:7
# Sample #476, Label:29
# Sample #477, Label:25
# Sample #478, Label:34
# Sample #479, Label:42
# Sample #480, Label:16
# Sample #481, Label:32
# Sample #482, Label:8
# Sample #483, Label:28
# Sample #484, Label:44
# Sample #485, Label:25
# Sample #486, Label:8
# Sample #487, Label:28
# Sample #488, Label:14
# Sample #489, Label:40
# Sample #490, Label:37
# Sample #491, Label:40
# Sample #492, Label:25
# Sample #493, Label:17
# Sample #494, Label:27
# Sample #495, Label:36
# Sample #496, Label:36
# Sample #497, Label:27
# Sample #498, Label:16
# Sample #499, Label:28
# Sample #500, Label:23
# Sample #501, Label:42
# Sample #502, Label:9
# Sample #503, Label:28
# Sample #504, Label:36
# Sample #505, Label:37
# Sample #506, Label:8
# Sample #507, Label:34
# Sample #508, Label:37
# Sample #509, Label:9
# Sample #510, Label:27
# Sample #511, Label:27
# Sample #512, Label:15
# Sample #513, Label:8
# Sample #514, Label:37
# Sample #515, Label:7
# Sample #516, Label:29
# Sample #517, Label:25
# Sample #518, Label:8
# Sample #519, Label:28
# Sample #520, Label:14
# Sample #521, Label:37
# Sample #522, Label:18
# Sample #523, Label:25
# Sample #524, Label:8
# Sample #525, Label:37
# Sample #526, Label:30
# Sample #527, Label:41
# Sample #528, Label:17
# Sample #529, Label:1
# Sample #530, Label:36
# Sample #531, Label:36
# Sample #532, Label:12
# Sample #533, Label:8
# Sample #534, Label:37
# Sample #535, Label:22
# Sample #536, Label:19
# Sample #537, Label:15
# Sample #538, Label:8
# Sample #539, Label:21
# Sample #540, Label:22
# Sample #541, Label:34
# Sample #542, Label:37
# Sample #543, Label:17
# Sample #544, Label:23
# Sample #545, Label:30
# Sample #546, Label:41
# Sample #547, Label:8
# Sample #548, Label:15
# Sample #549, Label:17
# Sample #550, Label:7
# Sample #551, Label:19
# Sample #552, Label:17
# Sample #553, Label:17
# Sample #554, Label:25
# Sample #555, Label:8
# Sample #556, Label:28
# Sample #557, Label:28
# Sample #558, Label:18
# Sample #559, Label:35
# Sample #560, Label:8
# Sample #561, Label:28
# Sample #562, Label:44
# Sample #563, Label:40
# Sample #564, Label:44
# Sample #565, Label:16
# Sample #566, Label:28
# Sample #567, Label:22
# Sample #568, Label:20
# Sample #569, Label:11
# Sample #570, Label:14
# Sample #571, Label:0
# Sample #572, Label:42
# Sample #573, Label:11
# Sample #574, Label:37
# Sample #575, Label:34
# Sample #576, Label:36
# Sample #577, Label:22
# Sample #578, Label:28
# Sample #579, Label:14
# Sample #580, Label:23
# Sample #581, Label:8
# Sample #582, Label:28
# Sample #583, Label:44
# Sample #584, Label:8
# Sample #585, Label:28
# Sample #586, Label:14
# Sample #587, Label:34
# Sample #588, Label:27
# Sample #589, Label:9
# Sample #590, Label:26
# Sample #591, Label:12
# Sample #592, Label:26
# Sample #593, Label:6
# Sample #594, Label:25
# Sample #595, Label:36
# Sample #596, Label:37
# Sample #597, Label:33
# Sample #598, Label:11
# Sample #599, Label:12
# Sample #600, Label:14
# Sample #601, Label:35
# Sample #602, Label:40
# Sample #603, Label:14
# Sample #604, Label:19
# Sample #605, Label:22
# Sample #606, Label:33
# Sample #607, Label:20
# Sample #608, Label:5
# Sample #609, Label:37
# Sample #610, Label:3
# Sample #611, Label:36
# Sample #612, Label:36
# Sample #613, Label:3
# Sample #614, Label:20
# Sample #615, Label:33
# Sample #616, Label:18
# Sample #617, Label:28
# Sample #618, Label:44
# Sample #619, Label:8
# Sample #620, Label:28
# Sample #621, Label:37
# Sample #622, Label:34
# Sample #623, Label:9
# Sample #624, Label:12
# Sample #625, Label:23
# Sample #626, Label:28
# Sample #627, Label:44
# Sample #628, Label:36
# Sample #629, Label:27
# Sample #630, Label:30
# Sample #631, Label:34
# Sample #632, Label:37
# Sample #633, Label:25
# Sample #634, Label:9
# Sample #635, Label:33
# Sample #636, Label:28
# Sample #637, Label:8
# Sample #638, Label:28
# Sample #639, Label:37
# Sample #640, Label:42
# Sample #641, Label:23
# Sample #642, Label:37
# Sample #643, Label:36
# Sample #644, Label:19
# Sample #645, Label:43
# Sample #646, Label:40
# Sample #647, Label:13
# Sample #648, Label:40
# Sample #649, Label:35
# Sample #650, Label:32
# Sample #651, Label:33
# Sample #652, Label:11
# Sample #653, Label:34
# Sample #654, Label:40
# Sample #655, Label:44
# Sample #656, Label:42
# Sample #657, Label:17
# Sample #658, Label:34
# Sample #659, Label:37
# Sample #660, Label:33
# Sample #661, Label:9
# Sample #662, Label:29
# Sample #663, Label:20
# Sample #664, Label:17
# Sample #665, Label:0
# Sample #666, Label:36
# Sample #667, Label:36
# Sample #668, Label:42
# Sample #669, Label:42
# Sample #670, Label:23
# Sample #671, Label:25
# Sample #672, Label:19
# Sample #673, Label:43
# Sample #674, Label:40
# Sample #675, Label:13
# Sample #676, Label:17
# Sample #677, Label:44
# Sample #678, Label:42
# Sample #679, Label:17
# Sample #680, Label:35
# Sample #681, Label:8
# Sample #682, Label:32
# Sample #683, Label:9
# Sample #684, Label:33
# Sample #685, Label:37
# Sample #686, Label:8
# Sample #687, Label:14
# Sample #688, Label:12
# Sample #689, Label:8
# Sample #690, Label:25
# Sample #691, Label:8
# Sample #692, Label:28
# Sample #693, Label:34
# Sample #694, Label:17
# Sample #695, Label:28
# Sample #696, Label:15
# Sample #697, Label:8
# Sample #698, Label:37
# Sample #699, Label:42
# Sample #700, Label:23
# Sample #701, Label:37
# Sample #702, Label:27
# Sample #703, Label:18
# Sample #704, Label:12
# Sample #705, Label:23
# Sample #706, Label:41
# Sample #707, Label:8
# Sample #708, Label:30
# Sample #709, Label:28
# Sample #710, Label:17
# Sample #711, Label:8
# Sample #712, Label:12
# Sample #713, Label:8
# Sample #714, Label:26
# Sample #715, Label:36
# Sample #716, Label:22
# Sample #717, Label:19
# Sample #718, Label:25
# Sample #719, Label:30
# Sample #720, Label:26
# Sample #721, Label:14
# Sample #722, Label:34
# Sample #723, Label:28
# Sample #724, Label:7
# Sample #725, Label:32
# Sample #726, Label:35
# Sample #727, Label:41
# Sample #728, Label:6
# Sample #729, Label:26
# Sample #730, Label:8
# Sample #731, Label:15
# Sample #732, Label:22
# Sample #733, Label:34
# Sample #734, Label:32
# Sample #735, Label:7
# Sample #736, Label:34
# Sample #737, Label:37
# Sample #738, Label:42
# Sample #739, Label:23
# Sample #740, Label:25
# Sample #741, Label:8
# Sample #742, Label:28
# Sample #743, Label:37
# Sample #744, Label:34
# Sample #745, Label:42
# Sample #746, Label:9
# Sample #747, Label:8
# Sample #748, Label:28
# Sample #749, Label:38
# Sample #750, Label:36
# Sample #751, Label:7
# Sample #752, Label:28
# Sample #753, Label:8
# Sample #754, Label:26
# Sample #755, Label:8
# Sample #756, Label:34
# Sample #757, Label:34
# Sample #758, Label:16
# Sample #759, Label:14
# Sample #760, Label:36
# Sample #761, Label:36
# Sample #762, Label:15
# Sample #763, Label:8
# Sample #764, Label:42
# Sample #765, Label:9
# Sample #766, Label:33
# Sample #767, Label:27
# Sample #768, Label:22
# Sample #769, Label:29
# Sample #770, Label:37
# Sample #771, Label:33
# Sample #772, Label:16
# Sample #773, Label:28
# Sample #774, Label:14
# Sample #775, Label:27
# Sample #776, Label:18
# Sample #777, Label:21
# Sample #778, Label:7
# Sample #779, Label:41
# Sample #780, Label:27
# Sample #781, Label:16
# Sample #782, Label:26
# Sample #783, Label:37
# Sample #784, Label:8
# Sample #785, Label:14
# Sample #786, Label:15
# Sample #787, Label:8
# Sample #788, Label:34
# Sample #789, Label:28
# Sample #790, Label:30
# Sample #791, Label:25
# Sample #792, Label:30
# Sample #793, Label:41
# Sample #794, Label:17
# Sample #795, Label:30
# Sample #796, Label:28
# Sample #797, Label:35
# Sample #798, Label:8
# Sample #799, Label:27
# Sample #800, Label:25
# Sample #801, Label:33
# Sample #802, Label:6
# Sample #803, Label:32
# Sample #804, Label:13
# Sample #805, Label:3
# Sample #806, Label:36
# Sample #807, Label:36
# Sample #808, Label:25
# Sample #809, Label:9
# Sample #810, Label:33
# Sample #811, Label:28
# Sample #812, Label:19
# Sample #813, Label:43
# Sample #814, Label:40
# Sample #815, Label:13
# Sample #816, Label:17
# Sample #817, Label:13
# Sample #818, Label:33
# Sample #819, Label:23
# Sample #820, Label:34
# Sample #821, Label:23
# Sample #822, Label:41
# Sample #823, Label:14
# Sample #824, Label:34
# Sample #825, Label:8
# Sample #826, Label:27
# Sample #827, Label:34
# Sample #828, Label:37
# Sample #829, Label:33
# Sample #830, Label:22
# Sample #831, Label:29
# Sample #832, Label:25
# Sample #833, Label:38
# Sample #834, Label:36
# Sample #835, Label:9
# Sample #836, Label:28
# Sample #837, Label:22
# Sample #838, Label:25
# Sample #839, Label:34
# Sample #840, Label:32
# Sample #841, Label:16
# Sample #842, Label:25
# Sample #843, Label:37
# Sample #844, Label:18
# Sample #845, Label:35
# Sample #846, Label:8
# Sample #847, Label:28
# Sample #848, Label:15
# Sample #849, Label:8
# Sample #850, Label:38
# Sample #851, Label:15
# Sample #852, Label:23
# Sample #853, Label:6
# Sample #854, Label:20
# Sample #855, Label:33
# Sample #856, Label:8
# Sample #857, Label:25
# Sample #858, Label:8
# Sample #859, Label:26
# Sample #860, Label:13
# Sample #861, Label:17
# Sample #862, Label:14
# Sample #863, Label:22
# Sample #864, Label:32
# Sample #865, Label:9
# Sample #866, Label:33
# Sample #867, Label:37
# Sample #868, Label:27
# Sample #869, Label:8
# Sample #870, Label:28
# Sample #871, Label:37
# Sample #872, Label:42
# Sample #873, Label:17
# Sample #874, Label:14
# Sample #875, Label:33
# Sample #876, Label:43
# Sample #877, Label:44
# Sample #878, Label:34
# Sample #879, Label:30
# Sample #880, Label:41
# Sample #881, Label:23
# Sample #882, Label:8
# Sample #883, Label:37
# Sample #884, Label:22
# Sample #885, Label:27
# Sample #886, Label:32
# Sample #887, Label:9
# Sample #888, Label:33
# Sample #889, Label:37
# Sample #890, Label:19
# Sample #891, Label:9
# Sample #892, Label:33
# Sample #893, Label:25
# Sample #894, Label:16
# Sample #895, Label:34
# Sample #896, Label:0
# Sample #897, Label:7
# Sample #898, Label:28
# Sample #899, Label:8
# Sample #900, Label:26
# Sample #901, Label:8
# Sample #902, Label:34
# Sample #903, Label:34
# Sample #904, Label:22
# Sample #905, Label:27
# Sample #906, Label:3
# Sample #907, Label:36
# Sample #908, Label:36
# Sample #909, Label:7
# Sample #910, Label:19
# Sample #911, Label:37
# Sample #912, Label:17
# Sample #913, Label:15
# Sample #914, Label:8
# Sample #915, Label:25
# Sample #916, Label:42
# Sample #917, Label:30
# Sample #918, Label:44
# Sample #919, Label:8
# Sample #920, Label:41
# Sample #921, Label:37
# Sample #922, Label:33
# Sample #923, Label:18
# Sample #924, Label:14
# Sample #925, Label:22
# Sample #926, Label:29
# Sample #927, Label:3
# Sample #928, Label:15
# Sample #929, Label:8
# Sample #930, Label:19
# Sample #931, Label:9
# Sample #932, Label:33
# Sample #933, Label:25
# Sample #934, Label:16
# Sample #935, Label:34
# Sample #936, Label:42
# Sample #937, Label:17
# Sample #938, Label:22
# Sample #939, Label:28
# Sample #940, Label:25
# Sample #941, Label:33
# Sample #942, Label:40
# Sample #943, Label:34
# Sample #944, Label:37
# Sample #945, Label:3
# Sample #946, Label:36
# Sample #947, Label:36
# Sample #948, Label:34
# Sample #949, Label:9
# Sample #950, Label:12
# Sample #951, Label:23
# Sample #952, Label:29
# Sample #953, Label:19
# Sample #954, Label:43
# Sample #955, Label:40
# Sample #956, Label:13
# Sample #957, Label:17
# Sample #958, Label:24
# Sample #959, Label:32
# Sample #960, Label:33
# Sample #961, Label:11
# Sample #962, Label:34
# Sample #963, Label:40
# Sample #964, Label:44
# Sample #965, Label:42
# Sample #966, Label:17
# Sample #967, Label:27
# Sample #968, Label:22
# Sample #969, Label:25
# Sample #970, Label:34
# Sample #971, Label:37
# Sample #972, Label:36
# Sample #973, Label:42
# Sample #974, Label:17
# Sample #975, Label:14
# Sample #976, Label:12
# Sample #977, Label:23
# Sample #978, Label:28
# Sample #979, Label:44
# Sample #980, Label:6
# Sample #981, Label:28
# Sample #982, Label:8
# Sample #983, Label:9
# Sample #984, Label:26
# Sample #985, Label:19
# Sample #986, Label:8
# Sample #987, Label:28
# Sample #988, Label:22
# Sample #989, Label:35
# Sample #990, Label:8
# Sample #991, Label:28
# Sample #992, Label:21
# Sample #993, Label:11
# Sample #994, Label:17
# Sample #995, Label:0
# Sample #996, Label:36
# Sample #997, Label:36
# Sample #998, Label:34
# Sample #999, Label:37
# Sample #1000, Label:33
# Sample #1001, Label:9
# Sample #1002, Label:29
# Sample #1003, Label:20
# Sample #1004, Label:17
# Sample #1005, Label:32
# Sample #1006, Label:6
# Sample #1007, Label:27
# Sample #1008, Label:9
# Sample #1009, Label:26
# Sample #1010, Label:32
# Sample #1011, Label:33
# Sample #1012, Label:11
# Sample #1013, Label:35
# Sample #1014, Label:40
# Sample #1015, Label:35
# Sample #1016, Label:21
# Sample #1017, Label:16
# Sample #1018, Label:26
# Sample #1019, Label:32
# Sample #1020, Label:37
# Sample #1021, Label:9
# Sample #1022, Label:26
# Sample #1023, Label:32
# Sample #1024, Label:33
# Sample #1025, Label:30
# Sample #1026, Label:35
# Sample #1027, Label:40
# Sample #1028, Label:35
# Sample #1029, Label:19
# Sample #1030, Label:33
# Sample #1031, Label:27
# Sample #1032, Label:3
# Sample #1033, Label:7
# Sample #1034, Label:28
# Sample #1035, Label:8
# Sample #1036, Label:26
# Sample #1037, Label:8
# Sample #1038, Label:34
# Sample #1039, Label:34
# Sample #1040, Label:22
# Sample #1041, Label:14
# Sample #1042, Label:36
# Sample #1043, Label:36
# Sample #1044, Label:36
# Sample #1045, Label:3
# Sample #1046, Label:27
# Sample #1047, Label:22
# Sample #1048, Label:34
# Sample #1049, Label:37
# Sample #1050, Label:17
# Sample #1051, Label:25
# Sample #1052, Label:6
# Sample #1053, Label:26
# Sample #1054, Label:8
# Sample #1055, Label:29
# Sample #1056, Label:44
# Sample #1057, Label:26
# Sample #1058, Label:17
# Sample #1059, Label:28
# Sample #1060, Label:14
# Sample #1061, Label:15
# Sample #1062, Label:8
# Sample #1063, Label:37
# Sample #1064, Label:8
# Sample #1065, Label:28
# Sample #1066, Label:30
# Sample #1067, Label:8
# Sample #1068, Label:28
# Sample #1069, Label:44
# Sample #1070, Label:25
# Sample #1071, Label:9
# Sample #1072, Label:33
# Sample #1073, Label:28
# Sample #1074, Label:22
# Sample #1075, Label:29
# Sample #1076, Label:14
# Sample #1077, Label:22
# Sample #1078, Label:41
# Sample #1079, Label:40
# Sample #1080, Label:45
# Sample #1081, Label:8
# Sample #1082, Label:28
# Sample #1083, Label:42
# Sample #1084, Label:8
# Sample #1085, Label:44
# Sample #1086, Label:33
# Sample #1087, Label:23
# Sample #1088, Label:14
# Sample #1089, Label:40
# Sample #1090, Label:35
# Sample #1091, Label:22
# Sample #1092, Label:29
# Sample #1093, Label:22
# Sample #1094, Label:37
# Sample #1095, Label:34
# Sample #1096, Label:34
# Sample #1097, Label:37
# Sample #1098, Label:11
# Sample #1099, Label:19
# Sample #1100, Label:0
# Sample #1101, Label:8
# Sample #1102, Label:28
# Sample #1103, Label:14
# Sample #1104, Label:42
# Sample #1105, Label:42
# Sample #1106, Label:14
# Sample #1107, Label:28
# Sample #1108, Label:23
# Sample #1109, Label:14
# Sample #1110, Label:10
# Sample #1111, Label:37
# Sample #1112, Label:34
# Sample #1113, Label:11
# Sample #1114, Label:14
# Sample #1115, Label:21
# Sample #1116, Label:16
# Sample #1117, Label:26
# Sample #1118, Label:36
# Sample #1119, Label:14
# Sample #1120, Label:40
# Sample #1121, Label:32
# Sample #1122, Label:33
# Sample #1123, Label:8
# Sample #1124, Label:14
# Sample #1125, Label:40
# Sample #1126, Label:34
# Sample #1127, Label:8
# Sample #1128, Label:28
# Sample #1129, Label:40
# Sample #1130, Label:44
# Sample #1131, Label:26
# Sample #1132, Label:16
# Sample #1133, Label:37
# Sample #1134, Label:17
# Sample #1135, Label:0
# Sample #1136, Label:36
# Sample #1137, Label:36
# Sample #1138, Label:21
# Sample #1139, Label:23
# Sample #1140, Label:27
# Sample #1141, Label:18
# Sample #1142, Label:14
# Sample #1143, Label:17
# Sample #1144, Label:34
# Sample #1145, Label:18
# Sample #1146, Label:26
# Sample #1147, Label:44
# Sample #1148, Label:25
# Sample #1149, Label:30
# Sample #1150, Label:26
# Sample #1151, Label:21
# Sample #1152, Label:40
# Sample #1153, Label:35
# Sample #1154, Label:5
# Sample #1155, Label:38
# Sample #1156, Label:3
# Sample #1157, Label:36
# Sample #1158, Label:36
# Sample #1159, Label:22
# Sample #1160, Label:37
# Sample #1161, Label:42
# Sample #1162, Label:8
# Sample #1163, Label:44
# Sample #1164, Label:8
# Sample #1165, Label:28
# Sample #1166, Label:37
# Sample #1167, Label:8
# Sample #1168, Label:20
# Sample #1169, Label:22
# Sample #1170, Label:41
# Sample #1171, Label:8
# Sample #1172, Label:42
# Sample #1173, Label:33
# Sample #1174, Label:3
# Sample #1175, Label:36
# Sample #1176, Label:36
# Sample #1177, Label:11
# Sample #1178, Label:34
# Sample #1179, Label:16
# Sample #1180, Label:37
# Sample #1181, Label:36
# Sample #1182, Label:14
# Sample #1183, Label:10
# Sample #1184, Label:28
# Sample #1185, Label:8
# Sample #1186, Label:28
# Sample #1187, Label:37
# Sample #1188, Label:34
# Sample #1189, Label:8
# Sample #1190, Label:20
# Sample #1191, Label:43
# Sample #1192, Label:17
# Sample #1193, Label:14
# Sample #1194, Label:10
# Sample #1195, Label:37
# Sample #1196, Label:42
# Sample #1197, Label:8
# Sample #1198, Label:37
# Sample #1199, Label:15
# Sample #1200, Label:23
# Sample #1201, Label:28
# Sample #1202, Label:23
# Sample #1203, Label:37
# Sample #1204, Label:22
# Sample #1205, Label:14
# Sample #1206, Label:3
# Sample #1207, Label:8
# Sample #1208, Label:28
# Sample #1209, Label:14
# Sample #1210, Label:34
# Sample #1211, Label:30
# Sample #1212, Label:26
# Sample #1213, Label:14
# Sample #1214, Label:15
# Sample #1215, Label:8
# Sample #1216, Label:27
# Sample #1217, Label:9
# Sample #1218, Label:28
# Sample #1219, Label:22
# Sample #1220, Label:37
# Sample #1221, Label:0
# Sample #1222, Label:36
# Sample #1223, Label:36
# Sample #1224, Label:15
# Sample #1225, Label:8
# Sample #1226, Label:34
# Sample #1227, Label:16
# Sample #1228, Label:28
# Sample #1229, Label:34
# Sample #1230, Label:8
# Sample #1231, Label:41
# Sample #1232, Label:28
# Sample #1233, Label:28
# Sample #1234, Label:32
# Sample #1235, Label:16
# Sample #1236, Label:28
# Sample #1237, Label:14
# Sample #1238, Label:22
# Sample #1239, Label:29
# Sample #1240, Label:20
# Sample #1241, Label:40
# Sample #1242, Label:27
# Sample #1243, Label:21
# Sample #1244, Label:7
# Sample #1245, Label:44
# Sample #1246, Label:34
# Sample #1247, Label:37
# Sample #1248, Label:11
# Sample #1249, Label:27
# Sample #1250, Label:23
# Sample #1251, Label:37
# Sample #1252, Label:36
# Sample #1253, Label:37
# Sample #1254, Label:23
# Sample #1255, Label:27
# Sample #1256, Label:9
# Sample #1257, Label:33
# Sample #1258, Label:37
# Sample #1259, Label:36
# Sample #1260, Label:15
# Sample #1261, Label:22
# Sample #1262, Label:35
# Sample #1263, Label:17
# Sample #1264, Label:5
# Sample #1265, Label:36
# Sample #1266, Label:36
# Sample #1267, Label:37
# Sample #1268, Label:40
# Sample #1269, Label:14
# Sample #1270, Label:18
# Sample #1271, Label:21
# Sample #1272, Label:23
# Sample #1273, Label:34
# Sample #1274, Label:16
# Sample #1275, Label:44
# Sample #1276, Label:36
# Sample #1277, Label:15
# Sample #1278, Label:23
# Sample #1279, Label:7
# Sample #1280, Label:14
# Sample #1281, Label:22
# Sample #1282, Label:37
# Sample #1283, Label:40
# Sample #1284, Label:37
# Sample #1285, Label:40
# Sample #1286, Label:44
# Sample #1287, Label:2
# Sample #1288, Label:11
# Sample #1289, Label:41
# Sample #1290, Label:20
# Sample #1291, Label:6
# Sample #1292, Label:37
# Sample #1293, Label:27
# Sample #1294, Label:11
# Sample #1295, Label:13
# Sample #1296, Label:6
# Sample #1297, Label:12
# Sample #1298, Label:36
# Sample #1299, Label:8
# Sample #1300, Label:28
# Sample #1301, Label:40
# Sample #1302, Label:43
# Sample #1303, Label:40
# Sample #1304, Label:41
# Sample #1305, Label:20
# Sample #1306, Label:6
# Sample #1307, Label:37
# Sample #1308, Label:43
# Sample #1309, Label:9
# Sample #1310, Label:33
# Sample #1311, Label:24
# Sample #1312, Label:6
# Sample #1313, Label:3
# Sample #1314, Label:36
# Sample #1315, Label:36
# Sample #1316, Label:16
# Sample #1317, Label:14
# Sample #1318, Label:44
# Sample #1319, Label:24
# Sample #1320, Label:30
# Sample #1321, Label:27
# Sample #1322, Label:5
# Sample #1323, Label:8
# Sample #1324, Label:14
# Sample #1325, Label:22
# Sample #1326, Label:41
# Sample #1327, Label:40
# Sample #1328, Label:45
# Sample #1329, Label:8
# Sample #1330, Label:28
# Sample #1331, Label:27
# Sample #1332, Label:7
# Sample #1333, Label:22
# Sample #1334, Label:28
# Sample #1335, Label:24
# Sample #1336, Label:17
# Sample #1337, Label:19
# Sample #1338, Label:17
# Sample #1339, Label:33
# Sample #1340, Label:8
# Sample #1341, Label:33
# Sample #1342, Label:23
# Sample #1343, Label:37
# Sample #1344, Label:18
# Sample #1345, Label:26
# Sample #1346, Label:17
# Sample #1347, Label:0
# Sample #1348, Label:22
# Sample #1349, Label:37
# Sample #1350, Label:13
# Sample #1351, Label:17
# Sample #1352, Label:14
# Sample #1353, Label:9
# Sample #1354, Label:20
# Sample #1355, Label:23
# Sample #1356, Label:37
# Sample #1357, Label:20
# Sample #1358, Label:9
# Sample #1359, Label:26
# Sample #1360, Label:42
# Sample #1361, Label:33
# Sample #1362, Label:26
# Sample #1363, Label:14
# Sample #1364, Label:36
# Sample #1365, Label:36
# Sample #1366, Label:27
# Sample #1367, Label:22
# Sample #1368, Label:34
# Sample #1369, Label:37
# Sample #1370, Label:17
# Sample #1371, Label:21
# Sample #1372, Label:30
# Sample #1373, Label:27
# Sample #1374, Label:44
# Sample #1375, Label:8
# Sample #1376, Label:25
# Sample #1377, Label:9
# Sample #1378, Label:33
# Sample #1379, Label:37
# Sample #1380, Label:36
# Sample #1381, Label:34
# Sample #1382, Label:16
# Sample #1383, Label:14
# Sample #1384, Label:21
# Sample #1385, Label:23
# Sample #1386, Label:32
# Sample #1387, Label:26
# Sample #1388, Label:7
# Sample #1389, Label:28
# Sample #1390, Label:44
# Sample #1391, Label:37
# Sample #1392, Label:40
# Sample #1393, Label:33
# Sample #1394, Label:40
# Sample #1395, Label:41
# Sample #1396, Label:43
# Sample #1397, Label:40
# Sample #1398, Label:15
# Sample #1399, Label:8
# Sample #1400, Label:34
# Sample #1401, Label:37
# Sample #1402, Label:33
# Sample #1403, Label:8
# Sample #1404, Label:25
# Sample #1405, Label:13
# Sample #1406, Label:33
# Sample #1407, Label:8
# Sample #1408, Label:41
# Sample #1409, Label:0
# Sample #1410, Label:12
# Sample #1411, Label:16
# Sample #1412, Label:26
# Sample #1413, Label:36
# Sample #1414, Label:20
# Sample #1415, Label:33
# Sample #1416, Label:40
# Sample #1417, Label:32
# Sample #1418, Label:3
# Sample #1419, Label:36
# Sample #1420, Label:36
# Sample #1421, Label:22
# Sample #1422, Label:37
# Sample #1423, Label:27
# Sample #1424, Label:18
# Sample #1425, Label:12
# Sample #1426, Label:23
# Sample #1427, Label:15
# Sample #1428, Label:8
# Sample #1429, Label:37
# Sample #1430, Label:6
# Sample #1431, Label:33
# Sample #1432, Label:34
# Sample #1433, Label:37
# Sample #1434, Label:33
# Sample #1435, Label:8
# Sample #1436, Label:25
# Sample #1437, Label:13
# Sample #1438, Label:33
# Sample #1439, Label:8
# Sample #1440, Label:28
# Sample #1441, Label:14
# Sample #1442, Label:27
# Sample #1443, Label:8
# Sample #1444, Label:26
# Sample #1445, Label:37
# Sample #1446, Label:8
# Sample #1447, Label:32
# Sample #1448, Label:26
# Sample #1449, Label:8
# Sample #1450, Label:34
# Sample #1451, Label:8
# Sample #1452, Label:37
# Sample #1453, Label:23
# Sample #1454, Label:8
# Sample #1455, Label:41
# Sample #1456, Label:25
# Sample #1457, Label:9
# Sample #1458, Label:33
# Sample #1459, Label:32
# Sample #1460, Label:17
# Sample #1461, Label:18
# Sample #1462, Label:35
# Sample #1463, Label:8
# Sample #1464, Label:28
# Sample #1465, Label:19
# Sample #1466, Label:40
# Sample #1467, Label:44
# Sample #1468, Label:8
# Sample #1469, Label:28
# Sample #1470, Label:37
# Sample #1471, Label:8
# Sample #1472, Label:27
# Sample #1473, Label:30
# Sample #1474, Label:34
# Sample #1475, Label:37
# Sample #1476, Label:22
# Sample #1477, Label:19
# Sample #1478, Label:16
# Sample #1479, Label:25
# Sample #1480, Label:37
# Sample #1481, Label:22
# Sample #1482, Label:14
# Sample #1483, Label:19
# Sample #1484, Label:17
# Sample #1485, Label:15
# Sample #1486, Label:8
# Sample #1487, Label:19
# Sample #1488, Label:43
# Sample #1489, Label:40
# Sample #1490, Label:13
# Sample #1491, Label:17
# Sample #1492, Label:0
# Sample #1493, Label:36
# Sample #1494, Label:36
# Sample #1495, Label:28
# Sample #1496, Label:30
# Sample #1497, Label:19
# Sample #1498, Label:17
# Sample #1499, Label:27
# Sample #1500, Label:32
# Sample #1501, Label:26
# Sample #1502, Label:7
# Sample #1503, Label:27
# Sample #1504, Label:21
# Sample #1505, Label:7
# Sample #1506, Label:44
# Sample #1507, Label:32
# Sample #1508, Label:16
# Sample #1509, Label:28
# Sample #1510, Label:14
# Sample #1511, Label:22
# Sample #1512, Label:41
# Sample #1513, Label:9
# Sample #1514, Label:44
# Sample #1515, Label:14
# Sample #1516, Label:36
# Sample #1517, Label:12
# Sample #1518, Label:37
# Sample #1519, Label:37
# Sample #1520, Label:22
# Sample #1521, Label:37
# Sample #1522, Label:22
# Sample #1523, Label:44
# Sample #1524, Label:8
# Sample #1525, Label:28
# Sample #1526, Label:14
# Sample #1527, Label:17
# Sample #1528, Label:25
# Sample #1529, Label:8
# Sample #1530, Label:28
# Sample #1531, Label:34
# Sample #1532, Label:22
# Sample #1533, Label:14
# Sample #1534, Label:17
# Sample #1535, Label:18
# Sample #1536, Label:35
# Sample #1537, Label:8
# Sample #1538, Label:28
# Sample #1539, Label:37
# Sample #1540, Label:40
# Sample #1541, Label:33
# Sample #1542, Label:40
# Sample #1543, Label:41
# Sample #1544, Label:43
# Sample #1545, Label:40
# Sample #1546, Label:15
# Sample #1547, Label:8
# Sample #1548, Label:21
# Sample #1549, Label:30
# Sample #1550, Label:26
# Sample #1551, Label:35
# Sample #1552, Label:37
# Sample #1553, Label:33
# Sample #1554, Label:8
# Sample #1555, Label:25
# Sample #1556, Label:13
# Sample #1557, Label:17
# Sample #1558, Label:21
# Sample #1559, Label:40
# Sample #1560, Label:35
# Sample #1561, Label:22
# Sample #1562, Label:14
# Sample #1563, Label:3
# Sample #1564, Label:36
# Sample #1565, Label:36
# Sample #1566, Label:15
# Sample #1567, Label:8
# Sample #1568, Label:32
# Sample #1569, Label:23
# Sample #1570, Label:32
# Sample #1571, Label:8
# Sample #1572, Label:26
# Sample #1573, Label:34
# Sample #1574, Label:32
# Sample #1575, Label:6
# Sample #1576, Label:33
# Sample #1577, Label:37
# Sample #1578, Label:23
# Sample #1579, Label:25
# Sample #1580, Label:6
# Sample #1581, Label:24
# Sample #1582, Label:33
# Sample #1583, Label:22
# Sample #1584, Label:27
# Sample #1585, Label:40
# Sample #1586, Label:41
# Sample #1587, Label:14
# Sample #1588, Label:22
# Sample #1589, Label:28
# Sample #1590, Label:14
# Sample #1591, Label:8
# Sample #1592, Label:25
# Sample #1593, Label:23
# Sample #1594, Label:32
# Sample #1595, Label:8
# Sample #1596, Label:34
# Sample #1597, Label:22
# Sample #1598, Label:35
# Sample #1599, Label:8
# Sample #1600, Label:28
# Sample #1601, Label:34
# Sample #1602, Label:8
# Sample #1603, Label:28
# Sample #1604, Label:16
# Sample #1605, Label:33
# Sample #1606, Label:23
# Sample #1607, Label:8
# Sample #1608, Label:44
# Sample #1609, Label:8
# Sample #1610, Label:41
# Sample #1611, Label:32
# Sample #1612, Label:8
# Sample #1613, Label:12
# Sample #1614, Label:26
# Sample #1615, Label:22
# Sample #1616, Label:25
# Sample #1617, Label:8
# Sample #1618, Label:14
# Sample #1619, Label:27
# Sample #1620, Label:8
# Sample #1621, Label:28
# Sample #1622, Label:8
# Sample #1623, Label:35
# Sample #1624, Label:37
# Sample #1625, Label:33
# Sample #1626, Label:18
# Sample #1627, Label:35
# Sample #1628, Label:8
# Sample #1629, Label:28
# Sample #1630, Label:36
# Sample #1631, Label:22
# Sample #1632, Label:28
# Sample #1633, Label:25
# Sample #1634, Label:26
# Sample #1635, Label:40
# Sample #1636, Label:14
# Sample #1637, Label:22
# Sample #1638, Label:29
# Sample #1639, Label:21
# Sample #1640, Label:16
# Sample #1641, Label:26
# Sample #1642, Label:38
# Sample #1643, Label:1
# Sample #1644, Label:16
# Sample #1645, Label:24
# Sample #1646, Label:17
# Sample #1647, Label:25
# Sample #1648, Label:18
# Sample #1649, Label:35
# Sample #1650, Label:8
# Sample #1651, Label:28
# Sample #1652, Label:3
# Sample #1653, Label:26
# Sample #1654, Label:18
# Sample #1655, Label:12
# Sample #1656, Label:17
# Sample #1657, Label:0
# Sample #1658, Label:19
# Sample #1659, Label:9
# Sample #1660, Label:33
# Sample #1661, Label:8
# Sample #1662, Label:29
# Sample #1663, Label:33
# Sample #1664, Label:23
# Sample #1665, Label:26
# Sample #1666, Label:18
# Sample #1667, Label:35
# Sample #1668, Label:8
# Sample #1669, Label:28
# Sample #1670, Label:44
# Sample #1671, Label:8
# Sample #1672, Label:28
# Sample #1673, Label:14
# Sample #1674, Label:7
# Sample #1675, Label:20
# Sample #1676, Label:33
# Sample #1677, Label:8
# Sample #1678, Label:25
# Sample #1679, Label:8
# Sample #1680, Label:26
# Sample #1681, Label:13
# Sample #1682, Label:17
# Sample #1683, Label:0
# Sample #1684, Label:36
# Sample #1685, Label:36
# Sample #1686, Label:12
# Sample #1687, Label:15
# Sample #1688, Label:8
# Sample #1689, Label:34
# Sample #1690, Label:8
# Sample #1691, Label:26
# Sample #1692, Label:10
# Sample #1693, Label:37
# Sample #1694, Label:22
# Sample #1695, Label:37
# Sample #1696, Label:36
# Sample #1697, Label:37
# Sample #1698, Label:40
# Sample #1699, Label:32
# Sample #1700, Label:26
# Sample #1701, Label:18
# Sample #1702, Label:34
# Sample #1703, Label:27
# Sample #1704, Label:9
# Sample #1705, Label:33
# Sample #1706, Label:33
# Sample #1707, Label:41
# Sample #1708, Label:22
# Sample #1709, Label:37
# Sample #1710, Label:34
# Sample #1711, Label:25
# Sample #1712, Label:6
# Sample #1713, Label:14
# Sample #1714, Label:33
# Sample #1715, Label:23
# Sample #1716, Label:22
# Sample #1717, Label:28
# Sample #1718, Label:15
# Sample #1719, Label:8
# Sample #1720, Label:32
# Sample #1721, Label:7
# Sample #1722, Label:28
# Sample #1723, Label:8
# Sample #1724, Label:27
# Sample #1725, Label:18
# Sample #1726, Label:28
# Sample #1727, Label:23
# Sample #1728, Label:8
# Sample #1729, Label:28
# Sample #1730, Label:32
# Sample #1731, Label:43
# Sample #1732, Label:0
# Sample #1733, Label:33
# Sample #1734, Label:6
# Sample #1735, Label:25
# Sample #1736, Label:33
# Sample #1737, Label:8
# Sample #1738, Label:34
# Sample #1739, Label:23
# Sample #1740, Label:3
# Sample #1741, Label:36
# Sample #1742, Label:36
# Sample #1743, Label:28
# Sample #1744, Label:40
# Sample #1745, Label:27
# Sample #1746, Label:17
# Sample #1747, Label:8
# Sample #1748, Label:34
# Sample #1749, Label:25
# Sample #1750, Label:6
# Sample #1751, Label:27
# Sample #1752, Label:33
# Sample #1753, Label:16
# Sample #1754, Label:14
# Sample #1755, Label:44
# Sample #1756, Label:42
# Sample #1757, Label:33
# Sample #1758, Label:8
# Sample #1759, Label:32
# Sample #1760, Label:28
# Sample #1761, Label:28
# Sample #1762, Label:37
# Sample #1763, Label:22
# Sample #1764, Label:14
# Sample #1765, Label:36
# Sample #1766, Label:27
# Sample #1767, Label:30
# Sample #1768, Label:34
# Sample #1769, Label:37
# Sample #1770, Label:40
# Sample #1771, Label:41
# Sample #1772, Label:19
# Sample #1773, Label:40
# Sample #1774, Label:27
# Sample #1775, Label:20
# Sample #1776, Label:33
# Sample #1777, Label:16
# Sample #1778, Label:24
# Sample #1779, Label:8
# Sample #1780, Label:42
# Sample #1781, Label:33
# Sample #1782, Label:37
# Sample #1783, Label:22
# Sample #1784, Label:14
# Sample #1785, Label:19
# Sample #1786, Label:17
# Sample #1787, Label:27
# Sample #1788, Label:43
# Sample #1789, Label:40
# Sample #1790, Label:28
# Sample #1791, Label:8
# Sample #1792, Label:41
# Sample #1793, Label:17
# Sample #1794, Label:35
# Sample #1795, Label:40
# Sample #1796, Label:8
# Sample #1797, Label:23
# Sample #1798, Label:35
# Sample #1799, Label:8
# Sample #1800, Label:28
# Sample #1801, Label:25
# Sample #1802, Label:6
# Sample #1803, Label:27
# Sample #1804, Label:27
# Sample #1805, Label:22
# Sample #1806, Label:28
# Sample #1807, Label:8
# Sample #1808, Label:35
# Sample #1809, Label:37
# Sample #1810, Label:12
# Sample #1811, Label:26
# Sample #1812, Label:6
# Sample #1813, Label:25
# Sample #1814, Label:27
# Sample #1815, Label:18
# Sample #1816, Label:35
# Sample #1817, Label:8
# Sample #1818, Label:28
# Sample #1819, Label:44
# Sample #1820, Label:36
# Sample #1821, Label:36
# Sample #1822, Label:7
# Sample #1823, Label:44
# Sample #1824, Label:42
# Sample #1825, Label:22
# Sample #1826, Label:38
# Sample #1827, Label:15
# Sample #1828, Label:8
# Sample #1829, Label:33
# Sample #1830, Label:16
# Sample #1831, Label:34
# Sample #1832, Label:37
# Sample #1833, Label:8
# Sample #1834, Label:41
# Sample #1835, Label:15
# Sample #1836, Label:8
# Sample #1837, Label:33
# Sample #1838, Label:40
# Sample #1839, Label:35
# Sample #1840, Label:23
# Sample #1841, Label:27
# Sample #1842, Label:21
# Sample #1843, Label:10
# Sample #1844, Label:16
# Sample #1845, Label:41
# Sample #1846, Label:17
# Sample #1847, Label:36
# Sample #1848, Label:15
# Sample #1849, Label:16
# Sample #1850, Label:33
# Sample #1851, Label:11
# Sample #1852, Label:37
# Sample #1853, Label:23
# Sample #1854, Label:6
# Sample #1855, Label:26
# Sample #1856, Label:8
# Sample #1857, Label:24
# Sample #1858, Label:40
# Sample #1859, Label:12
# Sample #1860, Label:22
# Sample #1861, Label:25
# Sample #1862, Label:18
# Sample #1863, Label:27
# Sample #1864, Label:25
# Sample #1865, Label:8
# Sample #1866, Label:28
# Sample #1867, Label:37
# Sample #1868, Label:7
# Sample #1869, Label:27
# Sample #1870, Label:8
# Sample #1871, Label:28
# Sample #1872, Label:18
# Sample #1873, Label:37
# Sample #1874, Label:22
# Sample #1875, Label:14
# Sample #1876, Label:12
# Sample #1877, Label:11
# Sample #1878, Label:15
# Sample #1879, Label:8
# Sample #1880, Label:37
# Sample #1881, Label:17
# Sample #1882, Label:27
# Sample #1883, Label:8
# Sample #1884, Label:41
# Sample #1885, Label:25
# Sample #1886, Label:17
# Sample #1887, Label:8
# Sample #1888, Label:32
# Sample #1889, Label:35
# Sample #1890, Label:8
# Sample #1891, Label:28
# Sample #1892, Label:38
# Sample #1893, Label:36
# Sample #1894, Label:36
# Sample #1895, Label:22
# Sample #1896, Label:28
# Sample #1897, Label:28
# Sample #1898, Label:11
# Sample #1899, Label:28
# Sample #1900, Label:37
# Sample #1901, Label:23
# Sample #1902, Label:28
# Sample #1903, Label:18
# Sample #1904, Label:37
# Sample #1905, Label:23
# Sample #1906, Label:19
# Sample #1907, Label:11
# Sample #1908, Label:41
# Sample #1909, Label:0
# Sample #1910, Label:32
# Sample #1911, Label:16
# Sample #1912, Label:28
# Sample #1913, Label:44
# Sample #1914, Label:9
# Sample #1915, Label:26
# Sample #1916, Label:42
# Sample #1917, Label:8
# Sample #1918, Label:28
# Sample #1919, Label:28
# Sample #1920, Label:22
# Sample #1921, Label:33
# Sample #1922, Label:26
# Sample #1923, Label:23
# Sample #1924, Label:40
# Sample #1925, Label:40
# Sample #1926, Label:16
# Sample #1927, Label:41
# Sample #1928, Label:8
# Sample #1929, Label:28
# Sample #1930, Label:12
# Sample #1931, Label:40
# Sample #1932, Label:40
# Sample #1933, Label:43
# Sample #1934, Label:8
# Sample #1935, Label:28
# Sample #1936, Label:14
# Sample #1937, Label:6
# Sample #1938, Label:26
# Sample #1939, Label:17
# Sample #1940, Label:44
# Sample #1941, Label:8
# Sample #1942, Label:28
# Sample #1943, Label:14
# Sample #1944, Label:16
# Sample #1945, Label:27
# Sample #1946, Label:8
# Sample #1947, Label:24
# Sample #1948, Label:22
# Sample #1949, Label:34
# Sample #1950, Label:22
# Sample #1951, Label:37
# Sample #1952, Label:36
# Sample #1953, Label:37
# Sample #1954, Label:33
# Sample #1955, Label:11
# Sample #1956, Label:26
# Sample #1957, Label:0
# Sample #1958, Label:15
# Sample #1959, Label:8
# Sample #1960, Label:12
# Sample #1961, Label:22
# Sample #1962, Label:20
# Sample #1963, Label:8
# Sample #1964, Label:34
# Sample #1965, Label:37
# Sample #1966, Label:24
# Sample #1967, Label:8
# Sample #1968, Label:24
# Sample #1969, Label:27
# Sample #1970, Label:8
# Sample #1971, Label:28
# Sample #1972, Label:37
# Sample #1973, Label:16
# Sample #1974, Label:41
# Sample #1975, Label:17
# Sample #1976, Label:8
# Sample #1977, Label:42
# Sample #1978, Label:9
# Sample #1979, Label:33
# Sample #1980, Label:14
# Sample #1981, Label:8
# Sample #1982, Label:37
# Sample #1983, Label:8
# Sample #1984, Label:32
# Sample #1985, Label:26
# Sample #1986, Label:28
# Sample #1987, Label:28
# Sample #1988, Label:37
# Sample #1989, Label:22
# Sample #1990, Label:19
# Sample #1991, Label:3
# Sample #1992, Label:36
# Sample #1993, Label:36
# Sample #1994, Label:15
# Sample #1995, Label:8
# Sample #1996, Label:37
# Sample #1997, Label:40
# Sample #1998, Label:25
# Sample #1999, Label:8
# Sample #2000, Label:27
# Sample #2001, Label:32
# Sample #2002, Label:8
# ...
# Sample #19387, Label:9
# Sample #19388, Label:33
# Sample #19389, Label:34
# Sample #19390, Label:8
# Sample #19391, Label:28
# Sample #19392, Label:8
# Sample #19393, Label:26
# Sample #19394, Label:44
# Sample #19395, Label:37
# Sample #19396, Label:40
# Sample #19397, Label:32
# Sample #19398, Label:26
# Sample #19399, Label:40
# Sample #19400, Label:44
# Sample #19401, Label:28
# Sample #19402, Label:6
# Sample #19403, Label:37
# Sample #19404, Label:37
# Sample #19405, Label:40
# Sample #19406, Label:43
# Sample #19407, Label:40
# Sample #19408, Label:44
# Sample #19409, Label:28
# Sample #19410, Label:40
# Sample #19411, Label:25
# Sample #19412, Label:26
# Sample #19413, Label:22
# Sample #19414, Label:33
# Sample #19415, Label:42
# Sample #19416, Label:16
# Sample #19417, Label:37
# Sample #19418, Label:17
# Sample #19419, Label:28
# Sample #19420, Label:44
# Sample #19421, Label:2
# Sample #19422, Label:8
# Sample #19423, Label:20
# Sample #19424, Label:16
# Sample #19425, Label:27
# Sample #19426, Label:34
# Sample #19427, Label:22
# Sample #19428, Label:15
# Sample #19429, Label:8
# Sample #19430, Label:44
# Sample #19431, Label:5
# Sample #19432, Label:5
# Sample #19433, Label:5
# Sample #19434, Label:36
# Sample #19435, Label:36
# Sample #19436, Label:22
# Sample #19437, Label:28
# Sample #19438, Label:8
# Sample #19439, Label:14
# Sample #19440, Label:22
# Sample #19441, Label:35
# Sample #19442, Label:8
# Sample #19443, Label:28
# Sample #19444, Label:2
# Sample #19445, Label:28
# Sample #19446, Label:40
# Sample #19447, Label:25
# Sample #19448, Label:26
# Sample #19449, Label:22
# Sample #19450, Label:33
# Sample #19451, Label:19
# Sample #19452, Label:33
# Sample #19453, Label:40
# Sample #19454, Label:44
# Sample #19455, Label:30
# Sample #19456, Label:28
# Sample #19457, Label:44
# Sample #19458, Label:9
# Sample #19459, Label:19
# Sample #19460, Label:22
# Sample #19461, Label:28
# Sample #19462, Label:16
# Sample #19463, Label:28
# Sample #19464, Label:25
# Sample #19465, Label:26
# Sample #19466, Label:40
# Sample #19467, Label:14
# Sample #19468, Label:33
# Sample #19469, Label:18
# Sample #19470, Label:28
# Sample #19471, Label:24
# Sample #19472, Label:27
# Sample #19473, Label:8
# Sample #19474, Label:28
# Sample #19475, Label:37
# Sample #19476, Label:34
# Sample #19477, Label:15
# Sample #19478, Label:8
# Sample #19479, Label:37
# Sample #19480, Label:33
# Sample #19481, Label:22
# Sample #19482, Label:25
# Sample #19483, Label:42
# Sample #19484, Label:11
# Sample #19485, Label:17
# Sample #19486, Label:28
# Sample #19487, Label:8
# Sample #19488, Label:20
# Sample #19489, Label:26
# Sample #19490, Label:23
# Sample #19491, Label:33
# Sample #19492, Label:42
# Sample #19493, Label:16
# Sample #19494, Label:32
# Sample #19495, Label:17
# Sample #19496, Label:28
# Sample #19497, Label:44
# Sample #19498, Label:14
# Sample #19499, Label:40
# Sample #19500, Label:32
# Sample #19501, Label:26
# Sample #19502, Label:9
# Sample #19503, Label:14
# Sample #19504, Label:2
# Sample #19505, Label:8
# Sample #19506, Label:24
# Sample #19507, Label:18
# Sample #19508, Label:34
# Sample #19509, Label:8
# Sample #19510, Label:27
# Sample #19511, Label:37
# Sample #19512, Label:34
# Sample #19513, Label:40
# Sample #19514, Label:15
# Sample #19515, Label:8
# Sample #19516, Label:44
# Sample #19517, Label:30
# Sample #19518, Label:29
# Sample #19519, Label:0
# Sample #19520, Label:6
# Sample #19521, Label:12
# Sample #19522, Label:26
# Sample #19523, Label:7
# Sample #19524, Label:27
# Sample #19525, Label:14
# Sample #19526, Label:9
# Sample #19527, Label:33
# Sample #19528, Label:7
# Sample #19529, Label:37
# Sample #19530, Label:34
# Sample #19531, Label:40
# Sample #19532, Label:36
# Sample #19533, Label:32
# Sample #19534, Label:23
# Sample #19535, Label:32
# Sample #19536, Label:8
# Sample #19537, Label:30
# Sample #19538, Label:37
# Sample #19539, Label:12
# Sample #19540, Label:11
# Sample #19541, Label:25
# Sample #19542, Label:36
# Sample #19543, Label:36
# Sample #19544, Label:36
# Sample #19545, Label:43
# Sample #19546, Label:43
# Sample #19547, Label:26
# Sample #19548, Label:14
# Sample #19549, Label:27
# Sample #19550, Label:7
# Sample #19551, Label:28
# Sample #19552, Label:8
# Sample #19553, Label:24
# Sample #19554, Label:27
# Sample #19555, Label:40
# Sample #19556, Label:27
# Sample #19557, Label:3
# Sample #19558, Label:36
# Sample #19559, Label:22
# Sample #19560, Label:44
# Sample #19561, Label:8
# Sample #19562, Label:28
# Sample #19563, Label:9
# Sample #19564, Label:26
# Sample #19565, Label:12
# Sample #19566, Label:16
# Sample #19567, Label:28
# Sample #19568, Label:19
# Sample #19569, Label:17
# Sample #19570, Label:25
# Sample #19571, Label:8
# Sample #19572, Label:28
# Sample #19573, Label:34
# Sample #19574, Label:40
# Sample #19575, Label:27
# Sample #19576, Label:17
# Sample #19577, Label:44
# Sample #19578, Label:3
# Sample #19579, Label:36
# Sample #19580, Label:36
# Sample #19581, Label:21
# Sample #19582, Label:30
# Sample #19583, Label:13
# Sample #19584, Label:30
# Sample #19585, Label:26
# Sample #19586, Label:44
# Sample #19587, Label:25
# Sample #19588, Label:8
# Sample #19589, Label:28
# Sample #19590, Label:43
# Sample #19591, Label:40
# Sample #19592, Label:44
# Sample #19593, Label:14
# Sample #19594, Label:8
# Sample #19595, Label:37
# Sample #19596, Label:22
# Sample #19597, Label:25
# Sample #19598, Label:28
# Sample #19599, Label:6
# Sample #19600, Label:26
# Sample #19601, Label:8
# Sample #19602, Label:24
# Sample #19603, Label:40
# Sample #19604, Label:37
# Sample #19605, Label:8
# Sample #19606, Label:32
# Sample #19607, Label:33
# Sample #19608, Label:23
# Sample #19609, Label:14
# Sample #19610, Label:22
# Sample #19611, Label:25
# Sample #19612, Label:37
# Sample #19613, Label:36
# Sample #19614, Label:42
# Sample #19615, Label:8
# Sample #19616, Label:28
# Sample #19617, Label:12
# Sample #19618, Label:22
# Sample #19619, Label:44
# Sample #19620, Label:28
# Sample #19621, Label:8
# Sample #19622, Label:34
# Sample #19623, Label:42
# Sample #19624, Label:17
# Sample #19625, Label:26
# Sample #19626, Label:12
# Sample #19627, Label:23
# Sample #19628, Label:8
# Sample #19629, Label:28
# Sample #19630, Label:43
# Sample #19631, Label:40
# Sample #19632, Label:45
# Sample #19633, Label:40
# Sample #19634, Label:42
# Sample #19635, Label:8
# Sample #19636, Label:26
# Sample #19637, Label:23
# Sample #19638, Label:34
# Sample #19639, Label:26
# Sample #19640, Label:30
# Sample #19641, Label:5
# Sample #19642, Label:8
# Sample #19643, Label:27
# Sample #19644, Label:38
# Sample #19645, Label:30
# Sample #19646, Label:8
# Sample #19647, Label:8
# Sample #19648, Label:34
# Sample #19649, Label:42
# Sample #19650, Label:8
# Sample #19651, Label:28
# Sample #19652, Label:27
# Sample #19653, Label:9
# Sample #19654, Label:33
# Sample #19655, Label:14
# Sample #19656, Label:22
# Sample #19657, Label:34
# Sample #19658, Label:25
# Sample #19659, Label:10
# Sample #19660, Label:28
# Sample #19661, Label:22
# Sample #19662, Label:29
# Sample #19663, Label:22
# Sample #19664, Label:44
# Sample #19665, Label:28
# Sample #19666, Label:18
# Sample #19667, Label:37
# Sample #19668, Label:22
# Sample #19669, Label:14
# Sample #19670, Label:36
# Sample #19671, Label:36
# Sample #19672, Label:7
# Sample #19673, Label:28
# Sample #19674, Label:14
# Sample #19675, Label:34
# Sample #19676, Label:8
# Sample #19677, Label:27
# Sample #19678, Label:13
# Sample #19679, Label:18
# Sample #19680, Label:28
# Sample #19681, Label:44
# Sample #19682, Label:36
# Sample #19683, Label:34
# Sample #19684, Label:8
# Sample #19685, Label:13
# Sample #19686, Label:40
# Sample #19687, Label:44
# Sample #19688, Label:21
# Sample #19689, Label:6
# Sample #19690, Label:26
# Sample #19691, Label:8
# Sample #19692, Label:14
# Sample #19693, Label:18
# Sample #19694, Label:25
# Sample #19695, Label:9
# Sample #19696, Label:33
# Sample #19697, Label:32
# Sample #19698, Label:17
# Sample #19699, Label:40
# Sample #19700, Label:35
# Sample #19701, Label:8
# Sample #19702, Label:28
# Sample #19703, Label:36
# Sample #19704, Label:35
# Sample #19705, Label:16
# Sample #19706, Label:33
# Sample #19707, Label:8
# Sample #19708, Label:37
# Sample #19709, Label:22
# Sample #19710, Label:28
# Sample #19711, Label:25
# Sample #19712, Label:9
# Sample #19713, Label:33
# Sample #19714, Label:32
# Sample #19715, Label:17
# Sample #19716, Label:40
# Sample #19717, Label:35
# Sample #19718, Label:8
# Sample #19719, Label:28
# Sample #19720, Label:7
# Sample #19721, Label:28
# Sample #19722, Label:14
# Sample #19723, Label:21
# Sample #19724, Label:11
# Sample #19725, Label:7
# Sample #19726, Label:14
# Sample #19727, Label:21
# Sample #19728, Label:30
# Sample #19729, Label:37
# Sample #19730, Label:30
# Sample #19731, Label:30
# Sample #19732, Label:44
# Sample #19733, Label:25
# Sample #19734, Label:9
# Sample #19735, Label:33
# Sample #19736, Label:32
# Sample #19737, Label:17
# Sample #19738, Label:40
# Sample #19739, Label:35
# Sample #19740, Label:8
# Sample #19741, Label:28
# Sample #19742, Label:0
# Sample #19743, Label:22
# Sample #19744, Label:28
# Sample #19745, Label:34
# Sample #19746, Label:16
# Sample #19747, Label:34
# Sample #19748, Label:37
# Sample #19749, Label:0
# Sample #19750, Label:15
# Sample #19751, Label:18
# Sample #19752, Label:42
# Sample #19753, Label:8
# Sample #19754, Label:26
# Sample #19755, Label:27
# Sample #19756, Label:18
# Sample #19757, Label:25
# Sample #19758, Label:36
# Sample #19759, Label:32
# Sample #19760, Label:26
# Sample #19761, Label:16
# Sample #19762, Label:28
# Sample #19763, Label:23
# Sample #19764, Label:22
# Sample #19765, Label:41
# Sample #19766, Label:33
# Sample #19767, Label:40
# Sample #19768, Label:27
# Sample #19769, Label:44
# Sample #19770, Label:8
# Sample #19771, Label:41
# Sample #19772, Label:22
# Sample #19773, Label:26
# Sample #19774, Label:8
# Sample #19775, Label:12
# Sample #19776, Label:8
# Sample #19777, Label:26
# Sample #19778, Label:8
# Sample #19779, Label:14
# Sample #19780, Label:12
# Sample #19781, Label:6
# Sample #19782, Label:33
# Sample #19783, Label:20
# Sample #19784, Label:8
# Sample #19785, Label:28
# Sample #19786, Label:33
# Sample #19787, Label:8
# Sample #19788, Label:14
# Sample #19789, Label:44
# Sample #19790, Label:3
# Sample #19791, Label:36
# Sample #19792, Label:36
# Sample #19793, Label:36
# Sample #19794, Label:15
# Sample #19795, Label:8
# Sample #19796, Label:19
# Sample #19797, Label:43
# Sample #19798, Label:9
# Sample #19799, Label:29
# Sample #19800, Label:15
# Sample #19801, Label:8
# Sample #19802, Label:20
# Sample #19803, Label:33
# Sample #19804, Label:18
# Sample #19805, Label:28
# Sample #19806, Label:9
# Sample #19807, Label:33
# Sample #19808, Label:12
# Sample #19809, Label:18
# Sample #19810, Label:34
# Sample #19811, Label:40
# Sample #19812, Label:25
# Sample #19813, Label:3
# Sample #19814, Label:25
# Sample #19815, Label:6
# Sample #19816, Label:33
# Sample #19817, Label:28
# Sample #19818, Label:42
# Sample #19819, Label:26
# Sample #19820, Label:26
# Sample #19821, Label:24
# Sample #19822, Label:8
# Sample #19823, Label:27
# Sample #19824, Label:32
# Sample #19825, Label:37
# Sample #19826, Label:40
# Sample #19827, Label:35
# Sample #19828, Label:22
# Sample #19829, Label:19
# Sample #19830, Label:37
# Sample #19831, Label:23
# Sample #19832, Label:19
# Sample #19833, Label:11
# Sample #19834, Label:41
# Sample #19835, Label:14
# Sample #19836, Label:6
# Sample #19837, Label:26
# Sample #19838, Label:17
# Sample #19839, Label:44
# Sample #19840, Label:36
# Sample #19841, Label:36
# Sample #19842, Label:22
# Sample #19843, Label:14
# Sample #19844, Label:42
# Sample #19845, Label:8
# Sample #19846, Label:44
# Sample #19847, Label:26
# Sample #19848, Label:7
# Sample #19849, Label:34
# Sample #19850, Label:37
# Sample #19851, Label:33
# Sample #19852, Label:40
# Sample #19853, Label:44
# Sample #19854, Label:37
# Sample #19855, Label:22
# Sample #19856, Label:28
# Sample #19857, Label:24
# Sample #19858, Label:40
# Sample #19859, Label:40
# Sample #19860, Label:27
# Sample #19861, Label:28
# Sample #19862, Label:11
# Sample #19863, Label:28
# Sample #19864, Label:37
# Sample #19865, Label:23
# Sample #19866, Label:28
# Sample #19867, Label:23
# Sample #19868, Label:18
# Sample #19869, Label:23
# Sample #19870, Label:19
# Sample #19871, Label:11
# Sample #19872, Label:19
# Sample #19873, Label:1
# Sample #19874, Label:37
# Sample #19875, Label:40
# Sample #19876, Label:19
# Sample #19877, Label:9
# Sample #19878, Label:33
# Sample #19879, Label:37
# Sample #19880, Label:23
# Sample #19881, Label:19
# Sample #19882, Label:11
# Sample #19883, Label:14
# Sample #19884, Label:14
# Sample #19885, Label:6
# Sample #19886, Label:26
# Sample #19887, Label:17
# Sample #19888, Label:44
# Sample #19889, Label:19
# Sample #19890, Label:17
# Sample #19891, Label:8
# Sample #19892, Label:27
# Sample #19893, Label:38
# Sample #19894, Label:17
# Sample #19895, Label:14
# Sample #19896, Label:23
# Sample #19897, Label:19
# Sample #19898, Label:6
# Sample #19899, Label:41
# Sample #19900, Label:14
# Sample #19901, Label:6
# Sample #19902, Label:26
# Sample #19903, Label:17
# Sample #19904, Label:44
# Sample #19905, Label:36
# Sample #19906, Label:36
# Sample #19907, Label:15
# Sample #19908, Label:8
# Sample #19909, Label:20
# Sample #19910, Label:30
# Sample #19911, Label:26
# Sample #19912, Label:14
# Sample #19913, Label:25
# Sample #19914, Label:6
# Sample #19915, Label:33
# Sample #19916, Label:14
# Sample #19917, Label:36
# Sample #19918, Label:42
# Sample #19919, Label:22
# Sample #19920, Label:13
# Sample #19921, Label:22
# Sample #19922, Label:28
# Sample #19923, Label:25
# Sample #19924, Label:26
# Sample #19925, Label:40
# Sample #19926, Label:44
# Sample #19927, Label:44
# Sample #19928, Label:8
# Sample #19929, Label:19
# Sample #19930, Label:43
# Sample #19931, Label:40
# Sample #19932, Label:40
# Sample #19933, Label:14
# Sample #19934, Label:22
# Sample #19935, Label:35
# Sample #19936, Label:28
# Sample #19937, Label:8
# Sample #19938, Label:26
# Sample #19939, Label:35
# Sample #19940, Label:17
# Sample #19941, Label:41
# Sample #19942, Label:41
# Sample #19943, Label:34
# Sample #19944, Label:40
# Sample #19945, Label:44
# Sample #19946, Label:42
# Sample #19947, Label:8
# Sample #19948, Label:26
# Sample #19949, Label:28
# Sample #19950, Label:10
# Sample #19951, Label:25
# Sample #19952, Label:9
# Sample #19953, Label:34
# Sample #19954, Label:37
# Sample #19955, Label:34
# Sample #19956, Label:16
# Sample #19957, Label:41
# Sample #19958, Label:8
# Sample #19959, Label:28
# Sample #19960, Label:22
# Sample #19961, Label:19
# Sample #19962, Label:6
# Sample #19963, Label:41
# Sample #19964, Label:14
# Sample #19965, Label:6
# Sample #19966, Label:26
# Sample #19967, Label:17
# Sample #19968, Label:44
# Sample #19969, Label:8
# Sample #19970, Label:43
# Sample #19971, Label:40
# Sample #19972, Label:33
# Sample #19973, Label:5
# Sample #19974, Label:36
# Sample #19975, Label:36
# Sample #19976, Label:15
# Sample #19977, Label:8
# Sample #19978, Label:20
# Sample #19979, Label:30
# Sample #19980, Label:26
# Sample #19981, Label:14
# Sample #19982, Label:25
# Sample #19983, Label:9
# Sample #19984, Label:33
# Sample #19985, Label:14
# Sample #19986, Label:19
# Sample #19987, Label:40
# Sample #19988, Label:42
# Sample #19989, Label:8
# Sample #19990, Label:44
# Sample #19991, Label:26
# Sample #19992, Label:7
# Sample #19993, Label:34
# Sample #19994, Label:37
# Sample #19995, Label:8
# Sample #19996, Label:28
# Sample #19997, Label:25
# Sample #19998, Label:33
# Sample #19999, Label:40
# Sample #20000, Label:34
# Sample #20001, Label:37
# Sample #20002, Label:40
# Sample #20003, Label:28
# Sample #20004, Label:34
# Sample #20005, Label:30
# Sample #20006, Label:32
# Sample #20007, Label:37
# Sample #20008, Label:8
# Sample #20009, Label:27
# Sample #20010, Label:12
# Sample #20011, Label:17
# Sample #20012, Label:27
# Sample #20013, Label:11
# Sample #20014, Label:28
# Sample #20015, Label:37
# Sample #20016, Label:40
# Sample #20017, Label:28
# Sample #20018, Label:43
# Sample #20019, Label:37
# Sample #20020, Label:23
# Sample #20021, Label:19
# Sample #20022, Label:9
# Sample #20023, Label:33
# Sample #20024, Label:0
# Sample #20025, Label:37
# Sample #20026, Label:40
# Sample #20027, Label:34
# Sample #20028, Label:22
# Sample #20029, Label:25
# Sample #20030, Label:34
# Sample #20031, Label:37
# Sample #20032, Label:23
# Sample #20033, Label:19
# Sample #20034, Label:11
# Sample #20035, Label:14
# Sample #20036, Label:14
# Sample #20037, Label:6
# Sample #20038, Label:26
# Sample #20039, Label:17
# Sample #20040, Label:44
# Sample #20041, Label:3
# Sample #20042, Label:19
# Sample #20043, Label:17
# Sample #20044, Label:27
# Sample #20045, Label:27
# Sample #20046, Label:19
# Sample #20047, Label:22
# Sample #20048, Label:19
# Sample #20049, Label:37
# Sample #20050, Label:40
# Sample #20051, Label:14
# Sample #20052, Label:6
# Sample #20053, Label:26
# Sample #20054, Label:17
# Sample #20055, Label:44
# Sample #20056, Label:3
# Sample #20057, Label:36

# %% [markdown]
# # Reference
# [1] https://en.wikipedia.org/wiki/PyTorch
#
# [2] http://pytorch.org/tutorials/beginner/data_loading_tutorial.html?highlight=dataloader
#
# [3] Springenberg, Jost Tobias, et al. "Striving for simplicity: The all convolutional net." arXiv preprint arXiv:1412.6806 (2014).
