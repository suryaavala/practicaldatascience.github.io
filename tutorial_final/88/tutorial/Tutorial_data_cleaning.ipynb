# %% [markdown]
# # Data preprocessing for NLP
#
#
# Before training a machine learning model, one important step we do is to preprocess the data. This step is extremely important regardless of what task we are doing. This is becuase a noisy data or a wrong input will result in compelety different result. Although I'm focusing on preprocessing the data for NLP tasks, I believe this tutorial will also be
# helpful for other tasks.
#
# In the tutorial, I will talk about how to preprocess data from raw text to numpy matrix, or even,
# tensor for libraries like Pytorch or Tensorflow. The steps I will cover include:
#
# 1.Simple methods of data cleaning for raw text data
#
# 2.Tokenize data into python structures that help training the model.
#
# 3.Batchify data into inputs for model like recurrent neural network.
#
# To begin with, the NLP task I'll be assuming will be some tasks that is related to sentence classification.
# One example will be sentiment analysis where we take a sentence and determine whether it's a positive
# comment neutral or a negatvie comment. In this turtorial, however, we will prepare for another task which is
# simply determine the object given a triple (subject,verb,object). So for example, in the triple
# (dog,likes,bone), the model should have a better chance to predict the word "bone" than "iphone" when it sees
# dog and likes.

# %%
#Below are the libraries that will be used through out the tutorial
#It is fine to not have torch since it is only used in the last section
#to make a demonstration of transforming data into torch tensor
import pickle
import string
import torch
from torch.autograd import Variable
import numpy as np

# %% [markdown]
# Before we start, here is a link of a brief introduction to the dataset we'll be using.
#
# http://rtw.ml.cmu.edu/resources/svo/
#
# The SVO triples we'll be using are basically extracted from concepts learned by a computer.
# For the purpose of this tutorial. I've truncated the whole data into only 10000 rows and
# only preserve the subject,verb,object and frequency. But after this preprocessing, the data
# is still filling with noise.

# %%
#You can take a look at what's inside the text file, which are
#subject,verb,object and frequency seperated by an empty space.
with open('./tutorial_data.txt','r') as data:
    for line in data:
        print(line)
# Out:
# Foyle  cost  lot  1
#
# Foyle  is  wrecked  1
#
# MP  supports  called  1
#
# Fr  ate  state  1
#
# Fr  graces  occasional  1
#
# Antonio  is  pastor  1
#
# Cullen  joined  Society  2
#
# Edward  offer  Mass  1
#
# Luiz  was  celebrant  2
#
# Mathew  introduced  bishops  1
#
# Peter  hold  book  1
#
# Tony  allow  family  1
#
# ee  am  heater  1
#
# Dimension  give  students  1
#
# Geometry  contain  wealth  1
#
# arts  is  matter  1
#
# patterns  filled  screen  2
#
# Fractals  are  things  1
#
# navigate  examinee  positione  1
#
# Decimal  render  men  1
#
# crystallization  is  removal  8
#
# Decimals  are  typed  9
#
# 's  is  ability  1
#
# Debris  take  PO  1
#
# Version  Listen  previews  1
#
# weapons  have  chance  1
#
# Fragility  heighten  beauty  1
#
# Fragment  is  translationally  2
#
# programs  implementation  computationally  1
#
# Fragmentation  is  concerning  2
#
# Problem  is  phenomenon  1
#
# thinking  is  exceptionalism  1
#
# Fragonard  illustrate  works  1
#
# Fragos  scream  warning  1
#
# Fragrance  s  growth  1
#
# Crafts  find  somethingism  1
#
# room  allow  marye  1
#
# Fragrances  have  mysteryes  2
#
# Fragrant  greeted  nose  1
#
# Fragrant  is  bodye  1
#
# Hostas  tolerate  sun  1
#
# pork  features  sauerkraut  1
#
# vanilla  toast  nuts  4
#
# Fraktal  is  onee  1
#
# Frame  began  explanationes  1
#
# Frame  create  Set  1
#
# Frame  is  chance  1
#
# Frame  is  set  1
#
# Frame  struck  relationship  2
#
# 4  show  verificationism  1
#
# Construction  require  experiencee  1
#
# info  contain  collectiones  1
#
# objectives  is  convenience  1
#
# timeline  adds  motion  34
#
# 8  introduce  number  1
#
# Framed  are  hypothesised  3
#
# Framed  was  elegance  1
#
# Framer  is  mapping  1
#
# Framers  built  Constitution  1
#
# Framers  designate  Constitution  1
#
# Framers  link  protectionism  1
#
# Frames  are  custom  1
#
# Frames  are  metal  2
#
# Frames  are  part  2
#
# Frames  are  solution  1
#
# Frames  are  tools  1
#
# Frames  choose  options  1
#
# Frames  have  effect  1
#
# Frames  hold  objects  1
#
# Frames  include  image  1
#
# Frames  is  band  1
#
# Frames  is  future  1
#
# Frames  make  website  2
#
# Frames  offer  opportunity  1
#
# Direct  release  footage  2
#
# frame  is  structure  1
#
# CFC  provide  arrayer  1
#
# Framework  Base  Learning  1
#
# Framework  compile  application  1
#
# Framework  died  Microsoft  1
#
# Framework  emphasise  importance  1
#
# Framework  is  ADO.NET  2
#
# Framework  is  sizes  1
#
# Framework  promisee  world  1
#
# Framework  trace  destruction  1
#
# Framework  was  theme  1
#
# 1.0  's  kind  1
#
# 2.0  missed  attention  1
#
# 3.5  contain  number  18
#
# 3.5  take  advantage  3
#
# Class  deserial  instance  1
#
# Convention  is  alliance  1
#
# Microsoft  got  copy  2
#
# Scott  kicking  things  2
#
# Source  forced  brilliance  1
#
# usage  is  plus  1
#
# Frameworks  take  view  1
#
# Odd  Make  frames  1
#
# Tips  look  days  1
#
# Framingham  is  site  1
#
# Framingham  made  pitch  1
#
# State  give  professors  1
#
# Frampton  contribute  supports  1
#
# Fran  find  mother  1
#
# Fran  finishe  kitchen  1
#
# Fran  had  dreams  1
#
# Fran  manage  place  1
#
# Fran  rememberance  detail  1
#
# Fran  retiring  months  1
#
# Fran  show  pictures  1
#
# Drescher  has  waye  1
#
# Healy  took  moments  1
#
# Hill  need  vacationers  1
#
# Petersen  was  Scoutmaster  1
#
# Casey  got  life  2
#
# Francais  are  times  2
#
# France  DO  gained  1
#
# France  awards  tribes  2
#
# France  becamee  part  2
#
# France  beginning  seriese  1
#
# France  bring  talk  2
#
# France  broke  terms  1
#
# France  claim  victory  1
#
# France  commanded  divisional  1
#
# France  comprisees  Normandy  1
#
# France  condemnation  war  2
#
# France  consideration  commitment  1
#
# France  controlled  lands  1
#
# France  development  softwareed  2
#
# France  dominateed  cities  3
#
# France  employed  mixture  1
#
# France  ensure  creation  1
#
# France  exported  components  1
#
# France  find  England  5
#
# France  gave  concurrence  1
#
# France  gave  lands  1
#
# France  grabbing  spoils  1
#
# France  has  issue  1
#
# France  has  politics  1
#
# France  has  shortage  4
#
# France  has  worries  7
#
# France  had  Italy  1
#
# France  had  army  3
#
# France  had  backing  1
#
# France  had  opportunity  1
#
# France  had  threshold  1
#
# France  have  couple  1
#
# France  have  problems  1
#
# France  have  systems  1
#
# France  hears  tramped  3
#
# France  invents  periscope  2
#
# France  is  traders  1
#
# France  is  trustee  1
#
# France  left  system  1
#
# France  liberate  region  3
#
# France  made  attempt  1
#
# France  made  home  1
#
# France  make  decisional  1
#
# France  need  someone  3
#
# France  obtain  foothold  1
#
# France  oppose  deadline  1
#
# France  pardons  men  1
#
# France  prohibit  sale  2
#
# France  provide  aircraft  11
#
# France  purchased  village  1
#
# France  recall  ambassador  1
#
# France  reverse  colours  1
#
# France  running  penalty  2
#
# France  set  example  1
#
# France  spend  onee  2
#
# France  supply  force  1
#
# France  threatens  Spain  2
#
# France  useful  failure  6
#
# France  useful  nerve  1
#
# France  violate  agreement  1
#
# France  voice  supports  1
#
# France  was  presidente  2
#
# France  was  superpower  5
#
# France  won  battle  1
#
# France  won  prize  1
#
# 's  offer  hopeful  1
#
# 's  comes  Britain  5
#
# 's  reflected  perfectionism  1
#
# 's  serveed  purpose  1
#
# 's  is  disasterous  1
#
# The  received  reported  1
#
# Youth  offer  travelers  1
#
# organizer  useful  power  1
#
# winners  describe  battle  2
#
# Frances  answered  tailored  1
#
# Frances  felt  eyesed  1
#
# Frances  give  goods  1
#
# Frances  had  man  1
#
# Frances  had  son  1
#
# Frances  is  wife  1
#
# Frances  learn  code  2
#
# Frances  loved  cats  1
#
# Frances  lowered  hands  4
#
# Frances  lowered  heads  7
#
# Frances  milk  cows  1
#
# Frances  recollects  declaration  2
#
# Frances  saw  classes  1
#
# Frances  underwent  lobotomy  1
#
# Frances  was  effect  1
#
# Frances  was  sheriff  1
#
# Anderton  explore  messagees  1
#
# Brandon  married  Master  1
#
# Cirino  is  students  1
#
# Forde  is  Professor  1
#
# Griffiths  photograph  fairies  2
#
# Maxwell  has  gen  1
#
# Moore  handle  sets  1
#
# Payne  is  onee  2
#
# Payne  trace  heritage  1
#
# Perkins  be  secretary  1
#
# Rose  was  onee  1
#
# Siedliska  desiree  happiness  1
#
# Smith  read  namese  1
#
# Yates  found  number  1
#
# Francesca  had  doubt  1
#
# Francesca  kept  everybody  1
#
# Francesca  show  interesting  1
#
# 's  is  pastiche  1
#
# Spencer  resigned  positione  1
#
# Woodman  visiting  Rome  1
#
# Francesco  beginning  onee  2
#
# Francesco  is  saints  1
#
# Franchise  displays  Million  1
#
# Franchise  imdb  ship  1
#
# Franchise  is  Building  1
#
# Ideas  added  section  1
#
# New  is  home  1
#
# tax  beginning  date  2
#
# Franchisee  evaluatees  importance  1
#
# Franchising  is  methods  9
#
# Franchot  loved  women  1
#
# Franchot  notifying  MGM  1
#
# Francia  was  result  1
#
# Francica  explore  topics  1
#
# Francie  lost  count  1
#
# Francie  transformers  experiences  1
#
# Francine  is  graduate  1
#
# Frensky  is  monkey  1
#
# Tate  told  investigators  1
#
# Ward  got  messagees  1
#
# Francis  Admit  woman  1
#
# Francis  McDonald  managerment  3
#
# Francis  approaching  people  2
#
# Francis  attack  France  7
#
# Francis  attended  number  1
#
# Francis  becamee  vassal  7
#
# Francis  begat  Joan  1
#
# Francis  called  creation  5
#
# Francis  capture  imagination  2
#
# Francis  discoverers  stigmata  2
#
# Francis  distributed  Communion  1
#
# Francis  emphasize  spirit  1
#
# Francis  felt  cowards  1
#
# Francis  gave  scandal  2
#
# Francis  has  collectiones  1
#
# Francis  had  affinity  1
#
# Francis  had  fights  1
#
# Francis  is  rookiee  1
#
# Francis  is  waye  2
#
# Francis  knock  lights  1
#
# Francis  left  MNI  1
#
# Francis  loved  Ben  1
#
# Francis  married  daughter  1
#
# Francis  met  Sultan  2
#
# Francis  missed  friends  1
#
# Francis  own  GameCube  3
#
# Francis  performer  internship  3
#
# Francis  practically  waye  1
#
# Francis  seeking  sheltering  2
#
# Francis  take  pride  1
#
# '  enable  family  1
#
# Ayers  built  cabin  1
#
# Bacon  was  Rosicrucian  3
#
# Barker  led  troopses  1
#
# Bartow  left  room  1
#
# Borgia  was  duke  1
#
# Fukuyama  is  onee  1
#
# Gomez  embarked  survivors  1
#
# II  proclaimed  Emperor  1
#
# Irving  development  TortoiseCVS  2
#
# Johnson  disses  suckering  1
#
# Lickerish  joined  band  1
#
# Moore  is  authorization  1
#
# Payton  had  points  1
#
# Scott  was  witnesse  1
#
# Technology  is  onee  1
#
# Xavier  do  Minho  1
#
# de  put  pens  1
#
# junior  ran  recorded  1
#
# order  had  monastery  5
#
# Franciscans  enters  province  1
#
# Franciscans  prepare  materials  1
#
# Francisco  found  waye  2
#
# Francisco  give  moneyer  1
#
# Francisco  make  witnesses  1
#
# Francisco  set  hook  1
#
# Arcaute  declines  comment  2
#
# Garcia  led  Jazz  1
#
# Gonzalo  useful  flag  1
#
# Sightseeing  Include  Tours  1
#
# Yahoo!7  was  Spanish  1
#
# Francisella  causeed  tularemia  1
#
# Franck  circulate  petitioner  1
#
# Franck  is  cooke  1
#
# Franck  was  onee  1
#
# KH  BE  Effects  1
#
# Muller  is  watchmaker  1
#
# Franco  added  potbelly  1
#
# Franco  anticipate  need  2
#
# Franco  gained  reputation  29
#
# Franco  has  everything  1
#
# Franco  like  worked  1
#
# Franco  pay  attention  1
#
# Franco  received  shots  1
#
# Franco  sings  Camino  1
#
# Prati  announce  launching  1
#
# Roma  bring  touch  1
#
# Francois  has  hu  1
#
# Kevorkian  abandoned  study  1
#
# Martin  transformers  Pondicherry  1
#
# Pinon  is  onee  3
#
# two  may  fruit  2
#
# Francoise  is  stepmother  1
#
# Francona  give  pitchers  4
#
# Franchising  find  franchisee  1
#
# Frangipani  is  onee  3
#
# Franjo  selective  Kamelot  1
#
# Frank  accepted  positione  2
#
# Frank  address  comment  1
#
# Frank  ask  Natasha  1
#
# Frank  ask  Peter  1
#
# Frank  become  family  1
#
# Frank  bring  recorded  1
#
# Frank  buys  property  1
#
# Frank  called  agent  1
#
# Frank  called  number  3
#
# Frank  chide  Joe  1
#
# Frank  closed  catalog  1
#
# Frank  collecting  things  1
#
# Frank  continueed  picnic  1
#
# Frank  development  ability  1
#
# Frank  displays  lot  1
#
# Frank  earned  doctorate  3
#
# Frank  elevate  medium  1
#
# Frank  emphasize  significance  1
#
# Frank  escort  team  1
#
# Frank  exhibition  products  1
#
# Frank  explain  decisional  1
#
# Frank  fold  arms  1
#
# Frank  found  time  4
#
# Frank  found  worked  6
#
# Frank  gave  ticket  1
#
# Frank  get  home  1
#
# Frank  give  listed  1
#
# Frank  got  jobs  2
#
# Frank  has  boyfriend  2
#
# Frank  has  cancer  1
#
# Frank  has  degreees  1
#
# Frank  has  interesting  1
#
# Frank  had  fleets  1
#
# Frank  is  descendant  2
#
# Frank  is  economist  2
#
# Frank  is  healer  1
#
# Frank  is  king  1
#
# Frank  is  moron  1
#
# Frank  is  professor  5
#
# Frank  is  proofreader  1
#
# Frank  is  specialist  2
#
# Frank  is  sweetness  2
#
# Frank  joined  MCS  1
#
# Frank  know  post  1
#
# Frank  lose  interesting  1
#
# Frank  made  appearance  1
#
# Frank  made  sandcastle  1
#
# Frank  made  shake  1
#
# Frank  magnify  office  1
#
# Frank  met  Rosa  1
#
# Frank  mov  6.5  2
#
# Frank  own  lands  1
#
# Frank  own  property  1
#
# Frank  pursued  Pepper  2
#
# Frank  put  bladed  1
#
# Frank  release  worked  1
#
# Frank  rememberance  woman  1
#
# Frank  reminding  students  4
#
# Frank  representation  progress  2
#
# Frank  smoke  cigars  1
#
# Frank  take  family  2
#
# Frank  useful  combination  1
#
# Frank  use  metaphor  2
#
# Frank  visiting  Vicalvi  1
#
# Frank  was  Justice  1
#
# Frank  was  bunting  1
#
# Frank  was  darling  2
#
# Frank  was  founder  15
#
# Frank  was  leader  3
#
# Frank  was  students  1
#
# 's  been  dozens  1
#
# Alvarado  rode  winners  1
#
# Armington  studying  arts  1
#
# Barlow  blackmails  McNulty  1
#
# Barr  was  pilot  1
#
# Baumgartner  is  owners  1
#
# Belknap  drank  alcohol  2
#
# Black  contributions  tracks  1
#
# Black  has  song  1
#
# Carter  highlighting  need  1
#
# Caruso  is  member  4
#
# Chief  mine  engineer  1
#
# Churchill  was  villains  1
#
# Cohen  is  onee  1
#
# Crean  second  motion  1
#
# Daniel  had  jurisdictionally  1
#
# Donelson  acquires  property  1
#
# Doyle  provide  MythBusters  1
#
# Fenton  becamee  foreman  1
#
# Ford  is  onee  1
#
# Gibson  is  moron  2
#
# Gilbane  present  assessment  1
#
# Groom  was  managerment  1
#
# H  took  bodye  1
#
# Hanson  was  member  1
#
# Henry  had  onee  1
#
# Herbert  point  dilemma  1
#
# Jones  was  someone  1
#
# King  is  onee  1
#
# Knight  emphasize  instability  1
#
# Knight  was  host  1
#
# Knudsen  investigate  relationship  1
#
# Leslie  tossed  nuggeting  1
#
# Lloyd  attended  Kindergarten  1
#
# Lloyd  inspiration  architecture  1
#
# Lloyd  visiting  site  1
#
# Lovejoy  portrayed  man  2
#
# Luke  lost  life  1
#
# Manley  was  designer  1
#
# Martin  can  coached  1
#
# Martin  create  works  3
#
# McCourt  painted  picturees  7
#
# McDonald  net  fishing  1
#
# Mead  joined  firm  1
#
# Miller  make  appearance  1
#
# Miller  writing  seriese  1
#
# Miller  given  breath  1
#
# Mixter  was  pharmacist  1
#
# Morison  publishes  Stone  2
#
# Neal  has  cancer  1
#
# Nugent  spent  life  1
#
# O  Write  Blurb  1
#
# O'Bannon  present  Hoosiers  1
#
# Oz  played  Shopkeeper  1
#
# Paul  plats  town  2
#
# Picarazzi  pleased  crowd  1
#
# Reese  hold  onee  1
#
# Rich  attack  Conservatism  17
#
# Riesling  was  favorite  2
#
# Robinson  put  namese  1
#
# Schwartz  closed  5  1
#
# Simon  praise  dedication  1
#
# Stella  offer  saviors  1
#
# Stronach  is  owners  1
#
# Tate  like  Lawson  1
#
# Thomas  has  total  1
#
# Trovato  ask  council  1
#
# Warner  closed  concerts  2
#
# Wilson  is  founder  1
#
# Work  made  determination  2
#
# Young  expressed  gratitude  1
#
# Zappa  facing  bat  1
#
# de  wrote  bookworm  1
#
# Potente  made  film  1
#
# Franke  find  supports  1
#
# Franke  left  Eurex  1
#
# 's  was  subjection  2
#
# Frankel  handle  numbers  1
#
# Franken  promotee  GOP  1
#
# Franken  raised  hands  2
#
# Franken  seeking  November  1
#
# Frankenberg  beginning  book  1
#
# Frankenstein  'm  rising  1
#
# Frankenstein  is  result  2
#
# Frankenstein  view  tales  3
#
# 's  was  force  1
#
# 's  wanted  nothingness  1
#
# Steven  kicking  Turn  1
#
# Frankfort  found  cartouche  1
#
# Frankfurt  do  dropped  1
#
# Frankfurt  was  heart  1
#
# International  experienced  onee  1
#
# Subversion  is  technique  1
#
# Frankfurter  got  jobs  1
#
# Frankfurter  has  intentionally  1
#
# Franki  have  loved  1
#
# Frankie  capture  zeitgeist  1
#
# Frankie  has  heat  1
#
# Frankie  maintained  contact  1
#
# Frankie  missed  jobs  1
#
# Frankie  was  everything  1
#
# Frankie  was  priest  1
#
# Vazquez  resonate  heart  1
#
# Frankincense  was  antidote  1
#
# Story  has  onee  1
#
# Frankland  hands  advantage  1
#
# Franklin  accepted  offer  1
#
# Franklin  appointed  Johnson  1
#
# Franklin  beat  Loreauville  1
#
# Franklin  believe  supply  1
#
# Franklin  bestowed  attention  1
#
# Franklin  bought  newspaper  1
#
# Franklin  compare  creation  2
#
# Franklin  continueed  involvement  1
#
# Franklin  demand  cessationism  2
#
# Franklin  denied  wrongdoing  1
#
# Franklin  did  worked  1
#
# Franklin  filed  Motion  1
#
# Franklin  hold  B.A.  1
#
# Franklin  including  instructions  1
#
# Franklin  is  grandfather  1
#
# Franklin  led  waye  2
#
# Franklin  like  ideas  1
#
# Franklin  made  experimental  1
#
# Franklin  made  treaty  1
#
# Franklin  offer  kind  2
#
# Franklin  organize  militia  2
#
# Franklin  performer  autopsy  1
#
# Franklin  prepare  foundationalism  1
#
# Franklin  produced  wealth  1
#
# Franklin  provide  namese  1
#
# Franklin  received  called  1
#
# Franklin  recorded  attributes  2
#
# Franklin  shucks  corn  1
#
# Franklin  started  life  1
#
# Franklin  understood  virtue  1
#
# Franklin  was  lobbyist  1
#
# Franklin  wearing  bifocals  1
#
# 's  was  keyes  1
#
# 's  urged  ratification  2
#
# 's  was  lacks  2
#
# Betty  is  member  2
#
# Center  carrying  missions  2
#
# Chang-Diaz  is  astronaut  2
#
# Conservation  welcome  comments  2
#
# County  Find  answers  1
#
# Delano  FDR  Memorial  1
#
# Delano  announced  decisional  1
#
# Delano  energize  national  1
#
# Delano  is  onee  2
#
# Institute  present  options  1
#
# Institute  present  Heart  2
#
# Junior  camryn  tapioca  1
#
# McDonald  summarize  discussions  1
#
# Morales  following  Francis  1
#
# Owens  was  principales  1
#
# Pierce  was  onee  1
#
# Research  is  programs  1
#
# Scholarship  was  push  1
#
# School  enjoy  supports  1
#
# Society  is  listed  2
#
# Street  meeting  Columbia  1
#
# Templeton  make  informationally  1
#
# apatite  contain  chlorine  1
#
# case  is  point  3
#
# indictment  point  waye  1
#
# kids  are  Justin  4
#
# Frankly  's  loaded  2
#
# Frankly  abandoned  mom  1
#
# Frankly  are  plenty  2
#
# Frankly  deserve  attention  2
#
# Frankly  enjoy  book  3
#
# Frankly  get  chance  1
#
# Frankly  got  attention  1
#
# Frankly  is  fishing  1
#
# Frankly  is  gobbledygook  1
#
# Frankly  lament  Cleland  1
#
# Frankly  look  fun  4
#
# Frankly  make  kind  1
#
# Frankly  missed  times  1
#
# Frankly  preferred  sake  1
#
# Frankly  save  time  2
#
# Frankly  thinks  IBM  1
#
# Frankly  thought  carnage  1
#
# Frankly  was  drawing  1
#
# Frankly  was  shit  2
#
# Frankly  wanted  leaders  1
#
# Frankly  were  people  1
#
# speaking  is  reason  4
#
# speaking  made  lot  1
#
# speaking  satsfi  air  1
#
# Franks  crossed  Rhine  4
#
# Franks  defeate  Saxons  2
#
# Franks  direct  invasione  2
#
# Franks  divide  Peloponnese  1
#
# Franks  recall  race  1
#
# Franks  spent  bulk  1
#
# Franks  stop  Moors  2
#
# Franks  take  time  1
#
# mayor  built  castle  4
#
# Frankweiler  made  dealing  1
#
# Franky  douglas  guitar  1
#
# Franky  show  use  1
#
# Frannie  feel  sanity  1
#
# Frannie  is  firm  1
#
# Frannie  like  waye  1
#
# Frannie  resemble  characterization  1
#
# Franny  's  time  1
#
# Lambi  is  onee  1
#
# Nauta  emphasise  need  3
#
# 's  has  malfunction  1
#
# Franti  made  called  1
#
# Frantic  called  sister  25
#
# Frantic  is  forte  1
#
# Frantisek  make  mistake  1
#
# Frantz  was  onee  3
#
# Franz  knew  Hebrew  1
#
# Franz  loved  motorbike  1
#
# Franz  played  guitar  1
#
# Franz  took  watch  1
#
# Ackermann  is  onee  1
#
# Ferdinand  married  Sophie  18
#
# Ferdinand  went  mainstream  1
#
# II  dissolves  Empire  1
#
# Joseph  had  responsibility  2
#
# Lisp  was  Lisp  1
#
# Mertens  declines  chair  10
#
# Walter  do  shots  1
#
# Franzen  dropped  onee  1
#
# Fraport  manage  airports  1
#
# AG  meeting  responsibility  1
#
# Fraps  are  waye  1
#
# Romantica  provideed  news  1
#
# Fraser  abandoned  project  2
#
# Fraser  becamee  center  3
#
# Fraser  cover  topics  1
#
# Fraser  has  cash  1
#
# Fraser  received  nomination  3
#
# Fraser  trace  developmental  1
#
# Fraser  treate  children  1
#
# Hansen  drill  couple  1
#
# Island  is  island  1
#
# Island  is  nature  2
#
# Valley  time  visiting  1
#
# Zoo  is  daye  1
#
# twins  are  result  4
#
# Fraternity  include  Coed  1
#
# Fraternity  was  objectives  1
#
# Phi  has  poles  1
#
# members  host  97  1
#
# Fraternization  is  issue  1
#
# Fratricide  beginning  weekend  1
#
# Frau  is  twenty  2
#
# Fraud  assistant  paye  1
#
# Fraud  is  exchange  4
#
# Fraud  pay  online  1
#
# Eliminator  mentioned  daye  1
#
# Protection  are  victim  1
#
# Review  put  need  1
#
# Sciences  won  fans  2
#
# detection  has  touch  1
#
# liquidation  running  tractor  1
#
# prevention  offer  tips  1
#
# Consultants  find  consultantion  1
#
# informationally  Given  system  1
#
# Frauke  is  chairman  1
#
# Frauke  is  geniuses  1
#
# Anna  took  interesting  1
#
# Ursula  has  ability  2
#
# family  sold  business  1
#
# SR  is  skin  1
#
# The  Help  answers  1
#
# 's  was  beginning  1
#
# Frazer  raised  family  1
#
# Frazier  attributed  resignation  1
#
# Frazier  had  brothers  1
#
# Frazier  is  insider  1
#
# Out  is  programme  1
#
# Freakin  take  responsibility  1
#
# Freaking  buys  onee  1
#
# Frec  was  video  2
#
# Freckles  dot  nose  3
#
# Fred  ask  members  1
#
# Fred  bemoaned  fact  1
#
# Fred  bet  savings  1
#
# Fred  climbing  peak  1
#
# Fred  commend  Eric  1
#
# Fred  delayed  release  1
#
# Fred  dining  daye  1
#
# Fred  doubt  loved  1
#
# Fred  employed  staff  1
#
# Fred  enforced  pace  1
#
# Fred  enters  ring  1
#
# Fred  experienced  attachment  1
#
# Fred  expressed  interesting  1
#
# Fred  following  lap  1
#
# Fred  gave  Christopher  1
#
# Fred  give  CD  1
#
# Fred  has  based  1
#
# Fred  had  nose  1
#
# Fred  have  shops  1
#
# Fred  hung  heads  1
#
# Fred  invited  Ray  1
#
# Fred  is  Algonquin  1
#
# Fred  is  animale  1
#
# Fred  is  answered  1
#
# Fred  is  example  1
#
# Fred  is  sweetie  1
#
# Fred  killed  two  1
#
# Fred  left  Michaelhouse  1
#
# Fred  like  Jack  1
#
# Fred  made  part  1
#
# Fred  make  sort  1
#
# Fred  measurements  block  1
#
# Fred  met  cheers  2
#
# Fred  played  guitar  1
#
# Fred  positione  chair  1
#
# Fred  rose  hands  1
#
# Fred  scanning  area  1
#
# Fred  shared  examples  1
#
# Fred  shut  mind  1
#
# Fred  started  adventure  1
#
# Fred  stretche  wings  1
#
# Fred  take  Renee  1
#
# Fred  take  drinks  1
#
# Fred  taught  methods  1
#
# Fred  told  Cordelia  1
#
# Fred  turn  pressure  1
#
# Fred  was  driver  1
#
# Fred  was  substance  1
#
# Fred  was  two  1
#
# Fred  went  river  1
#
# 's  got  onee  1
#
# 's  has  onee  1
#
# 's  increase  Articles  1
#
# Abrahams  wrote  reported  1
#
# Alan  is  physicist  2
#
# Barnes  had  column  1
#
# Bear  help  developmental  1
#
# Brooks  coins  notion  1
#
# Brown  knock  pair  6
#
# Clark  information  board  1
#
# Couples  designate  course  1
#
# Couples  did  somethingism  1
#
# Couples  had  issues  2
#
# Delany  muffled  chuckle  1
#
# Evers  is  Professor  1
#
# Gray  took  oath  1
#
# Hall  filled  form  1
#
# Hammond  signed  group  1
#
# Haney  called  time  1
#
# Ho  has  messagees  1
#
# Hutchinson  has  onee  1
#
# II  is  picturees  2
#
# Jetson  was  relic  1
#
# Kogan  teache  arts  1
#
# Krueger  hit  air  1
#
# Lemieux  was  uncle  1
#
# Luskin  distill  process  1
#
# McAllister  thought  ideas  1
#
# Myer  pick  juice  1
#
# Pentland  was  coached  1
#
# Phelps  protest  funeral  1
#
# Reed  was  onee  1
#
# Rio  does  everything  1
#
# Rogers  complete  programs  1
#
# Singer  had  linkse  1
#
# Small  is  ministereal  1
#
# Stecker  accepted  positione  2
#
# Thompson  endorse  McCain  3
#
# Thompson  has  resume  1
#
# Thompson  is  drop-out  3
#
# Thompson  is  member  6
#
# Thompson  joined  firm  1
#
# Thompson  is  congressman  1
#
# Thompson  promotee  fairness  3
#
# Thompson  has  marbles  1
#
# Thornburg  are  members  2
#
# Weiss  made  observationally  1
#
# fans  saw  magic  1
#
# Freda  blink  tearse  2
#
# Freda  had  doubt  1
#
# Band  played  mixed  2
#
# Freddie  encounter  Bentley  1
#
# Freddie  held  positione  1
#
# Freddie  is  daughter  1
#
# Freddie  misrepresentations  Dev  1
#
# Freddie  shook  heads  3
#
# Freddie  wracked  brain  1
#
# Frog  has  problems  2
#
# Mac  use  variety  5
#
# Mac  is  departure  2
#
# Frogs  have  variety  20
#
# Freddy  drove  van  1
#
# Freddy  has  patches  1
#
# Freddy  hid  belly  1
#
# Freddy  hold  hands  1
#
# Freddy  is  king  1
#
# Freddy  stop  van  1
#
# Freddy  turn  TV  1
#
# Freddy  was  eight  1
#
# Freddy  wearing  chains  1
#
# Freddy  wrote  lyrics  2
#
# Mercury  sang  song  1
#
# Napster  announced  debut  1
#
# Sanchez  had  onee  14
#
# Frederic  felt  called  1
#
# Frederic  hold  Master  1
#
# Frederic  received  sympathy  1
#
# Frederic  see  bevy  1
#
# Frederic  spend  time  1
#
# Frederick  crossed  border  22
#
# Frederick  fire  shots  1
#
# Frederick  found  ally  1
#
# Frederick  had  children  2
#
# Frederick  had  place  1
#
# Frederick  loaded  lunch  1
#
# Frederick  made  changes  1
#
# Frederick  press  worked  1
#
# Frederick  received  MFA  1
#
# Frederick  recognize  Louis  7
#
# Frederick  spent  morninge  2
#
# Boucher  drafted  bill  1
#
# Clotilda  is  net  2
#
# Cook  is  onee  1
#
# County  has  priority  1
#
# Delany  wanted  nothingness  1
#
# Douglass  find  needs  1
#
# Douglass  made  home  1
#
# Douglass  requirements  introductiones  1
#
# Funston  dealt  resistance  1
#
# Henry  prove  politician  2
#
# II  ascended  throne  1
#
# Luis  is  professor  1
#
# McKinley  invents  waye  1
#
# Neumann  was  man  1
#
# Parrot  reaching  peak  1
#
# Weaver  was  man  1
#
# Wentworth  is  onee  3
#
# William  central  administratione  1
#
# Wiseman  took  awards  1
#
# comfortable  facing  jacket  1
#
# police  are  onee  1
#
# Fredericks  include  chapter  1
#
# Fredericksburg  has  proliferation  1
#
# Fredericksburg  is  city  4
#
# Castle  funds  rebuilding  2
#
# Elementary  received  recognition  1
#
# Fredi  began  career  1
#
# Fredrick  provide  strains  1
#
# 's  lie  implementation  1
#
# Malm  is  authorization  2
#
# Fredrikstad  was  fortress  1
#
# Fredy  accepted  forgiveness  1
#
# Free  Be  bee  1
#
# Free  Check  box  1
#
# Free  Come  Home  1
#
# Free  Include  Nonfiction  1
#
# Free  Take  Initiative  1
#
# Free  accelerate  Space  1
#
# Free  acne  diet  1
#
# Free  animate  signature  2
#
# Free  are  materiale  1
#
# Free  become  mania  2
#
# Free  california  home  1
#
# Free  collecting  news  7
#
# Free  competency  funding  1
#
# Free  designate  greye  1
#
# Free  download  music  8
#
# Free  expanding  result  1
#
# Free  explore  town  1
#
# Free  find  Free  1
#
# Free  get  strategy  1
#
# Free  give  donatione  3
#
# Free  giveaways  daye  1
#
# Free  have  problems  1
#
# Free  hit  counter  28
#
# Free  hunting  hayfield  1
#
# Free  include  quality  1
#
# Free  information  consent  1
#
# Free  is  Ryzom  2
#
# Free  is  chain  2
#
# Free  is  future  4
#
# Free  is  solution  1
#
# Free  is  system  3
#
# Free  licence  use  2
#
# Free  madness  events  1
#
# Free  make  pressure  1
#
# Free  move  world  1
#
# Free  offer  number  1
#
# Free  photoblogs  drives  1
#
# Free  pick  monster  1
#
# Free  post  named  1
#
# Free  reaching  goals  3
#
# Free  read  ephedra  1
#
# Free  receive  frames  1
#
# Free  recommendations  march  1
#
# Free  rememberance  ely  1
#
# Free  reward  materials  1
#
# Free  s  slots  1
#
# Free  ship  pharmacy  1
#
# Free  sold  worked  1
#
# Free  stands  kids  1
#
# Free  submit  requesting  484
#
# Free  take  flight  1
#
# Free  turn  ideas  1
#
# Free  was  chairman  1
#
# Free  was  impetuses  1
#
# Free  worked  need  2
#
# Free  yarn  time  3
#
# 300  relateed  downloads  1
#
# 52075  create  humane  1
#
# 7  splitting  potted  1
#
# 70  is  compact  1
#
# Access  meaning  access  1
#
# Admission  was  responsibility  1
#
# Affidavit  leave  trails  1
#
# Air  are  satellite  1
#
# Amphetamine  relateed  downloads  1
#
# Animated  gave  answers  1
#
# Animated  lowered  eyesed  1
#
# Annual  may  2008  1
#
# Antivirus  expend  port  1
#
# Apple  crossed  mind  1
#
# Application  provideed  step  1
#
# Arabic  was  agee  1
#
# Article  Submit  articles  2
#
# Articles  provideed  tonsing  1
#
# Asian  cries  Wilder  1
#
# Atkins  allow  listed  3
#
# Auctions  are  property  5
#
# AutoCAD  Get  area  1
#
# Award  is  hopeful  1
#
# Azithromycin  relateed  downloads  1
#
# BPEL  is  cornerstone  2
#
# Baby  keep  deck  1
#
# Baldness  relateed  downloads  2
#
# Banners  reserve  right  3
#
# Banquet  attended  end  1
#
# Bartending  are  fun  1
#
# Best  redesigned  Avalon  1
#
# Birth  was  letter  1
#
# Blackjack  introduce  games  4
#
# Boobs  save  time  1
#
# Book  Submit  form  1
#
# Books  result  Scoliosis  1
#
# Bridal  cries  Frances  1
#
# Building  interrupt  Rose  1
#
# Calendar  download  acquaintance  1
#
# Calendars  ask  Rose  1
#
# Cash  Make  moneyer  9
#
# Casino  rewrite  number  1
#
# Cd  crossed  path  1
#
# Christian  Blog  Subscribe  1
#
# Christian  is  optional  1
#
# Christmas  is  article  1
#
# Christmas  forgot  bailiff  1
#
# Christmas  light  results  1
#
# Classified  forgets  friends  1
#
# Clinic  is  waye  1
#
# Competitive  featureed  highlights  1
#
# Computer  Download  Thousands  1
#
# Congress  stresses  need  1
#
# Content  Give  visitors  1
#
# Copy  please  click  1
#
# Countries  carrying  threat  1
#
# Cover  Help  Access  1
#
# Credit  's  gifts  1
#
# Criminal  exclaim  colonel  1
#
# Daily  Extend  Horoscope  8
#
# Dash  relateed  downloads  1
#
# Demo  Give  IntelliCAD  1
#
# Depression  echo  practitioner  1
#
# Derry  met  countryside  1
#
# Dictionary  has  lots  1
#
# Diet  exclaim  Gershom  1
#
# Dissertations  is  onee  1
#
# Dive  Tee  Time  1
#
# Download  Enjoi  variety  1
#
# Download  filled  gaps  1
#
# Download  based  Life  1
#
# Download  learn  Urdu  1
#
# Downloads  is  tool  1
#
# Dvd  stretching  arms  1
#
# E-mail  is  need  1
#
# Editions  have  limitation  1
#
# Ela  has  chance  1
#
# Email  read  threads  2
#
# Embroidery  furnished  materiale  1
#
# Emulator  answered  Mr  1
#
# Encyclopedia  is  formationism  1
#
# Enterprise  is  liberatore  2
#
# Entry  based  casino  1
#
# Family  is  picturees  1
#
# Fast  relateed  downloads  1
#
# File  studying  privacy  1
#
# Flu  show  interesting  1
#
# Food  grasp  arms  1
#
# Ford  named  Jaguar  1
#
# French  were  fore  1
#
# French  occupy  Syria  1
#
# Fundraising  Get  everything  3
#
# Funny  converted  innocence  1
#
# Funny  was  reason  1
#
# Game  s  PhysOrg.com  4
#
# Gift  ask  questionable  1
#
# Gig  Select  site  1
#
# Glitter  demand  Spike  1
#
# Groups  loved  FREE  1
#
# Hair  relateed  downloads  1
#
# Hand  Quilt  Patterns  1
#
# Herbal  online  Website  1
#
# Hgh  relateed  downloads  2
#
# Hip  hop  lessons  1
#
# History  is  distribution  1
#
# Hit  hit  counter  1
#
# Hot  did  fire  1
#
# ISP  is  waye  1
#
# Information  are  click  1
#
# Insert  appended  texts  1
#
# Internet  cries  father  1
#
# Internet  set  engineeering  1
#
# Internet  offer  access  3
#
# Jeep  tires  part  1
#
# Kids  is  place  1
#
# Lake  christmas  cards  1
#
# Legal  please  contact  1
#
# Legal  answered  Cap  1
#
# Library  Check  site  1
#
# Life  offer  listings  1
#
# Linda  Find  Apartment  1
#
# Live  is  site  2
#
# Local  repeate  Lawton  1
#
# Lotrel  relateed  downloads  1
#
# Lunch  inhabitants  Gore  1
#
# Lupus  relateed  downloads  1
#
# MSN  is  tool  1
#
# Masons  have  duty  1
#
# Medication  Add  Spirituality  1
#
# Melissa  demand  Esther  1
#
# Member  require  log-in  1
#
# Microsoft  gave  pittance  1
#
# Microsoft  got  computerized  1
#
# Mobility  is  project  1
#
# Mom  stir  multitude  1
#
# Money  continueed  discussione  2
#
# Mortgage  took  moneyer  1
#
# Mortgage  Can  Mortgages  1
#
# NJ  create  presentation  1
#
# Network  is  project  1
#
# Newsletter  offer  today  2
#
# Nutrition  offer  wealth  1
#
# Online  had  beauty  1
#
# Online  Pass  hands  1
#
# Online  offer  lining  1
#
# Online  are  tracks  2
#
# Online  spell  checked  2
#
# Online  is  Bridge  1
#
# PDF  eBook  Home  1
#
# Pain  relateed  downloads  1
#
# Palace  disbanding  capitol  1
#
# Parent  Get  obligation  1
#
# PayPal  nest  Protection  1
#
# Personal  was  commodore  1
#
# Personal  is  connectionism  1
#
# Photo  mount  charger  1
#
# Pictures  mutters  Jack  1
#
# Play  is  book  1
#
# Polyphonic  get  number  12
#
# Popular  relateed  downloads  1
#
# Pregnancy  online  source  1
#
# Premium  Lead  Click  1
#
# Premium  buys  e-book  1
#
# Press  exposed  Comcast  1
#
# Printed  Please  note  1
#
# Pritikin  online  source  1
#
# Programme  form  airports  1
#
# Psp  shook  heads  1
#
# Quote  has  years  1
#
# Radical  is  atoms  7
#
# Radio  is  group  1
#
# Reads  Please  note  1
#
# Real  Help  fear  1
#
# Records  was  rage  1
#
# Registration  take  seconds  2
#
# Republic  has  significance  1
#
# Residential  is  forerunner  1
#
# Resume  exclaim  Eve  1
#
# Reverse  Look  Ups  1
#
# Ringtones  mcgraw  ringtones  1
#
# Ringtones  find  center  1
#
# Ringtones  experienced  anguish  1
#
# Ringtones  wasn  t  1
#
# Roaming  offer  chance  1
#
# SIP  make  entry  1
#
# Sample  were  children  1
#
# Sample  essays  mistake  1
#
# Samples  was  consorts  1
#
# Service  has  nose  1
#
# Setup  Get  informationally  1
#
# Sheet  download  lessons  3
#
# Smileys  Get  Smileys  1
#
# Sms  said  elder  1
#
# Sms  uploaded  pic  1
#
# Software  take  controlled  2
#
# Software  has  interpretatione  1
#
# Software  is  part  1
#
# Software  need  help  26
#
# Software  is  matter  10
#
# Software  is  utility  1
#
# Solitaire  expressed  service  1
#
# Song  wav  proceedings  1
#
# Sony  ntelos  ringtones  1
#
# Sony  filled  link  2
#
# Speech  was  Christian  1
#
# Sprint  give  commanded  1
#
# Stampin  see  charts  1
#
# State  achievements  autonomy  6
#
# State  took  part  1
#
# Stock  Is  onee  1
#
# Surveys  Allow  users  1
#
# T-shirt  Have  Blast  1
#
# Term  Find  insurance  1
#
# Testosterone  relateed  downloads  2
#
# Texas  dispute  point  1
#
# Tibet  Take  Action  1
#
# Tibet  told  Standard  1
#
# Tobradex  relateed  downloads  1
#
# Trade  is  blueprints  1
#
# Trade  is  sham  1
#
# Trade  promotee  rules  2
#
# Trappers  scours  mountains  1
#
# Trial  incorporate  number  1
#
# Trials  online  adventures  1
#
# Trials  rate  service  2
#
# Tuition  target  students  1
#
# UK  is  site  1
#
# UPS  ground  shipping  1
#
# Unclaimed  abandoned  funds  1
#
# Underground  exclaim  Paul  1
#
# Valentine  is  time  1
#
# Video  offer  firewood  1
#
# Vioxx  relateed  downloads  1
#
# Virtual  round  point  1
#
# Visual  Check  set  2
#
# Weather  WA  Clear  1
#
# Web  is  collectiones  2
#
# Web  is  collectiones  1
#
# Website  use  frames  1
#
# Wedding  word  ideas  1
#
# White  depending  center  1
#
# White  lose  weight  1
#
# Zantac  relateed  downloads  1
#
# Zip  cries  Roderick  1
#
# Zithromax  relateed  downloads  2
#
# Zone  have  pretexts  1
#
# ads  Visit  shops  1
#
# agency  is  functions  5
#
# arrowhead  joined  Bond  1
#
# articles  make  moneyer  2
#
# artwork  make  place  1
#
# astrology  chatting  room  2
#
# autographs  was  internet  1
#
# banking  include  restrictions  2
#
# bare  have  parts  1
#
# beautifull  brides  ads  1
#
# board  are  part  1
#
# booze  is  tempting  1
#
# broadband  relateed  downloads  1
#
# buye  download  instructions  1
#
# called  saw  bingo  1
#
# car  quote  auto  3
#
# car  selective  onee  1
#
# carse  middot  properties  1
#
# casino  are  waye  1
#
# cell  sprint  http  1
#
# clips  Find  licensees  1
#
# collections  s  flashlight  1
#
# communicationes  is  default  1
#
# conversione  make  difference  1
#
# coupons  online  games  1
#
# credit  reported  sites  1
#
# data  acquire  data  1
#
# diet  relateed  downloads  1
#
# diving  is  exercise  1
#
# download  is  Diva  1
#
# download  is  Diva  1
#
# download  is  Diva  1
#
# e  are  exceptionalism  2
#
# email  is  Adobe  1
#
# enterprise  is  basises  1
#
# exercise  meaning  freedom  1
#
# forum  relateed  downloads  1
#
# fruits  relateed  downloads  1
#
# funds  had  application  1
#
# funnye  put  picturees  2
#
# gaming  deserve  reputation  2
#
# girls  relateed  downloads  1
#
# hair  relateed  downloads  1
#
# including  s  party  1
#
# info  Find  shops  3
#
# instant  reported  Calculators  2
#
# jasmine  hopeful  boost  2
#
# jazz  representation  freedom  2
#
# keywords  appears  They  2
#
# life  Optimize  system  1
#
# listed  serveed  membership  1
#
# meditationes  download  Worl  1
#
# membership  promotee  research  1
#
# migration  is  positione  1
#
# music  have  onee  1
#
# named  net  biz  1
#
# offers  info  Colleges  1
#
# online  is  women  1
#
# online  gine  system  1
#
# online  ensure  authors  1
#
# online  ged  diploma  2
#
# online  Add  items  1
#
# online  provideed  informationally  1
#
# online  need  seat  1
#
# online  know  home  1
#
# online  is  onee  1
#
# online  launche  makers  1
#
# patients  apply  eleven  1
#
# poker  include  informationally  1
#
# poker  variant  casino  1
#
# poker  win  prize  1
#
# poker  accepted  bonuses  1
#
# poker  is  raise  1
#
# press  get  beating  2
#
# price  cause  rhetoric  1
#
# prize  drawing  terms  2
#
# publicity  help  everyone  1
#
# puppy  had  kicking  1
#
# quotations  collecting  informationally  1
#
# quotes  relateed  downloads  1
#
# race  illustrate  midwayer  1
#
# racketeering  have  site  1
#
# rangee  is  backwardness  1
#
# rangee  are  onee  1
#
# real  lead  Unique  6
#
# reported  explore  costs  1
#
# ringtones  chatting  contact  1
#
# ringtones  is  summary  1
#
# salsa  enhance  eveninger  4
#
# schools  accreditation  schools  1
#
# secrets  relateed  downloads  1
#
# seriese  reported  Click  1
#
# shield  relateed  downloads  1
#
# shipping  are  part  4
#
# shipping  is  keyes  2
#
# shipping  punch  tin  1
#
# signed  win  moneyer  1
#
# slots  spin  slots  1
#
# softwareed  Attend  onee  1
#
# softwareed  need  vision  1
#
# softwareed  offer  freedom  2
#
# softwareed  supports  competition  1
#
# softwareed  contribute  time  2
#
# speech  include  dance  1
#
# speech  is  methods  2
#
# spillway  outweighs  Toshiba  1
#
# spironolactone  relateed  downloads  1
#
# storyes  depict  time  1
#
# study  sefer  offers  1
#
# stuff  project  Use  1
#
# talented  classify  ads  1
#
# testosterone  is  measuremental  1
#
# testosterone  relateed  downloads  1
#
# texas  apply  school  1
#
# trade  accelerate  rate  1
#
# trade  ease  passage  1
#
# traffic  has  cost  3
#
# training  is  trademarked  2
#
# transition  is  onee  1
#
# transportation  exposee  products  1
#
# treatments  Find  Information  1
#
# trial  Find  Information  3
#
# true  pc  ringtones  1
#
# typicall  are  theism  1
#
# typing  Are  light  1
#
# versions  allow  maximum  2
#
# vibe  is  organizationally  1
#
# webmaster  find  rangee  2
#
# website  create  website  1
#
# weight  Find  Price  1
#
# will  is  culprit  1
#
# will  was  denial  4
#
# worked  was  ride  1
#
# xxx  value  business  1
#
# oxidation  causeed  depletion  1
#
# children  was  rules  1
#
# horses  eating  lot  2
#
# Arabs  refute  premises  1
#
# FreeAdvice  find  lawyer  1
#
# FreeCreditReport.com  is  materiale  1
#
# MX  turn  artwork  1
#
# FreeMarker  has  access  2
#
# FreeNAS  recognize  drives  3
#
# Blog  visiting  blog  1
#
# XP  free  memory  2
#
# FreeSurfer  supports  conversione  1
#
# site  is  place  1
#
# Freebee  has  manners  1
#
# Freebie  are  companies  1
#
# Stop  is  pride  1
#
# Freed  can  crowd  1
#
# Freed  demonstrate  prowess  1
#
# Freed  is  nose  1
#
# Freedman  saw  need  1
#
# Center  is  partnership  1
#
# Freedmen  is  part  1
#
# Freedom  are  minority  1
#
# Freedom  are  nature  1
#
# Freedom  are  tools  1
#
# Freedom  broadcast  alerted  1
#
# Freedom  choose  loaned  1
#
# Freedom  enriche  humanity  1
#
# Freedom  exercise  choice  1
#
# Freedom  gave  substance  2
#
# Freedom  get  copy  2
#
# Freedom  got  minutes  1
#
# Freedom  have  bishops  2
#
# Freedom  have  fun  6
#
# Freedom  imply  freedom  5
#
# Freedom  is  conversationally  1
#
# Freedom  is  copy  1
#
# Freedom  is  corollary  3
#
# Freedom  is  creation  2
#
# Freedom  is  enterprise  1
#
# Freedom  is  fragrance  1
#
# Freedom  is  future  1
#
# Freedom  is  implication  1
#
# Freedom  is  incentive  1
#
# Freedom  is  nonsense  2
#
# Freedom  is  proclamation  1
#
# Freedom  is  progenitor  1
#
# Freedom  is  renunciation  1
#
# Freedom  is  salvationism  1
#
# Freedom  lick  blood  2
#
# Freedom  made  presentation  1
#
# Freedom  meaning  loved  3
#
# Freedom  meaning  restraints  1
#
# Freedom  meaning  right  22
#
# Freedom  permitted  ubiquity  1
#
# Freedom  present  results  2
#
# Freedom  provideed  anonymity  2
#
# Freedom  provideed  groups  1
#
# Freedom  require  knowledge  1
#
# Freedom  send  requesting  2
#
# Freedom  serveed  Gal  1
#
# Freedom  supersede  rules  1
#
# Freedom  took  root  1
#
# Freedom  utilize  semantics  1
#
# Freedom  was  heritage  1
#
# Freedom  was  issue  1
#
# Freedom  was  leader  1
#
# Freedom  was  materiale  1
#
# Freedom  was  result  1
#
# Freedom  yielding  peace  1
#
# 100  beginning  stretching  1
#
# Pharmacy  is  onee  20
#
# Pledge  take  words  2
#
# Press  played  host  1
#
# Riders  left  Montgomery  1
#
# Shrine  is  collectiones  2
#
# cannon  lead  stores  1
#
# fighters  capture  heart  1
#
# winners  is  listed  1
#
# Freeganism  is  lifestyle  1
#
# Raceway  reconstructed  racetrack  1
#
# Township  is  onee  1
#
# women  reduceed  risk  1
#
# stalker  ambushe  fixation  1
#
# Freel  get  chances  1
#
# Scottish  saw  scoops  1
#
# illustrator  forced  retirement  1
#
# writer  teache  yoga  1
#
# registeration  get  projects  1
#
# Freelancing  save  moneyer  1
#
# Freeland  questionable  Boyd  1
#
# Freelon  transformers  museum  1
#
# Freely  shared  stories  1
#
# Freeman  becamee  publisher  1
#
# Freeman  blending  sense  1
#
# Freeman  give  hopeful  1
#
# Freeman  has  answered  2
#
# Freeman  have  saye  1
#
# Freeman  is  guye  1
#
# Freeman  like  Williams  1
#
# Freeman  need  break  1
#
# Freeman  quoted  Turner  2
#
# Freeman  recognize  difference  1
#
# Freeman  revealed  origins  2
#
# Freeman  trace  historyes  2
#
# Freeman  uploaded  tracks  1
#
# Freeman  was  pastor  1
#
# Freeman  wearing  jerseyes  1
#
# 's  marks  book  1
#
# Hancock  was  son  1
#
# WJ  give  models  1
#
# programs  provideed  scholarships  1
#
# Freemans  lost  daughter  1
#
# Freemason  cutting  Deacons  1
#
# Freemasonry  teache  astrology  1
#
# Freemasonry  teache  men  1
#
# Proven  is  worshipped  1
#
# Freemasons  carrying  911  1
#
# Freemasons  gave  venting  1
#
# Freemasons  have  somethingism  1
#
# Freep  told  DFT  1
#
# Freeport  is  beehive  1
#
# Freeport  is  two  1
#
# Freeport  reviews  policy  1
#
# GT  provideed  musicians  1
#
# Frees  parsee  output  2
#
# 's  provideed  data  1
#
# Video  is  tool  2
#
# Freespire  need  level  1
#
# Skiff  has  amounts  1
#
# Freestore  has  waye  1
#
# Freestyle  exemplified  willingness  2
#
# Freestyle  penalize  wrestler  1
#
# Freethinker  is  onee  1
#
# Freethought  is  characteristic  1
#
# Freetown  celebrate  tricentennial  1
#
# project  is  approaching  1
#
# Freeview  is  operatore  1
#
# Freeware  Leave  comment  1
#
# Freeware  download  Misc  2
#
# Freeware  require  registration  1
#
# Our  is  Yadis  1
#
# Program  is  FREE  1
#
# games  require  DirectX  1
#
# Madness  is  frustration  1
#
# Manifesto  was  signed  1
#
# site  use  layout  1
#
# Freewill  Divid  Baptist  1
#
# Baptist  pervades  College  1
#
# bundle  include  VoIP  1
#
# Freeza  kept  Vegeta  2
#
# Freeze  is  sort  1
#
# frames  have  resolutioners  1
#
# Drawers  drawer  events  1
#
# biography  ran  hunting  1
#
# Freezing  is  optional  4
#
# Cells  See  notes  1
#
# damage  is  form  1
#
# Frege  motivate  logicism  1
#
# formulation  was  system  6
#
# fifth  is  layers  1
#
# Freiberg  analyze  data  2
#
# Freiberg  s  effort  1
#
# Freida  learn  ventriloquism  1
#
# Policy  are  responsibility  4
#
# costs  include  shipment  1
#
# trains  hold  horn  1
#
# zu  die  Freiheit  1
#
# Freire  cutting  tapes  2
#
# Freire  enters  University  1
#
# Freising  is  districts  2
#
# Freitas  authorization  Nanomedicine  4
#
# Fremantle  was  port  1
#
# Fremder  is  onee  1
#
# Fremont  attack  Sylvia  1
#
# Fremont  demand  resignation  1
#
# Fremont  enjoy  stayes  2
#
# Fremont  forfeited  season  1
#
# Fremont  has  number  1
#
# Fremont  held  court  1
#
# Fremont  won  level  2
#
# County  offer  variety  1
#
# Pass  had  lunch  1
#
# Swim  enters  address  12
#
# French  Check  availability  1
#
# French  adds  letter  1
#
# French  alter  named  1
#
# French  approves  arms  1
#
# French  are  gifts  1
#
# French  arriving  people  1
#
# French  assert  superiority  1
#
# French  assume  protectorate  1
#
# French  ate  foods  2
#
# French  bring  reinforcement  2
#
# French  brought  slaves  5
#
# French  came  home  1
#
# French  celebrate  Christmas  3
#
# French  changed  flag  1
#
# French  changed  spelling  1
#
# French  change  pronunciation  1
#
# French  claim  credit  1
#
# French  claim  successful  1
#
# French  complete  canal  1
#
# French  consideration  Scotland  1
#
# French  controll  interiors  1
#
# French  defeate  Mameluke  1
#
# French  deposed  emperor  1
#
# French  designate  architecture  1
#
# French  destroyed  Rastatt  1
#
# French  destroyed  dockyard  1
#
# French  destroyed  temple  1
#
# French  disarmed  warships  1
#
# French  discoverers  secrets  1
#
# French  do  Easter  3
#
# French  drew  pictures  1
#
# French  eating  horseed  2
#
# French  elections  idiots  1
#
# French  encouraging  hostility  1
#
# French  exclaim  Aileen  1
#
# French  found  City  1
#
# French  found  use  2
#
# French  give  candidates  1
#
# French  had  Napoleon  1
#
# French  had  convoyer  2
#
# French  have  Cari  1
#
# French  have  conventionally  3
#
# French  have  funding  1
#
# French  increase  meanse  1
#
# French  is  named  1
#
# French  is  native  1
#
# French  keep  health  3
#
# French  know  Lindell  1
#
# French  launching  counterattack  1
#
# French  left  Vietnam  11
#
# French  lost  concentration  1
#
# French  loved  Paris  13
#
# French  made  counterattack  2
#
# French  organisations  territory  1
#
# French  ousted  Spanish  2
#
# French  painted  North  1
#
# French  passed  PhD  1
#
# French  portrayed  poet  1
#
# French  protective  language  1
#
# French  provideed  input  1
#
# French  publishes  reported  1
#
# French  sack  Rome  1
#
# French  seize  Saigon  2
#
# French  show  respects  2
#
# French  subsidize  system  1
#
# French  supports  Maronites  1
#
# French  supports  Mobutu  1
#
# French  surrender  fort  1
#
# French  swears  words  12
#
# French  take  documents  4
#
# French  took  claim  1
#
# French  took  ideas  1
#
# French  treate  patients  1
#
# French  turn  Winchester  1
#
# French  useful  Wolof  1
#
# French  was  Catholic  1
#
# French  was  ministereal  1
#
# French  were  bunch  1
#
# French  wrote  addresses  1
#
# 75  use  reds  1
#
# Acadians  settled  area  1
#
# Army  reorganize  role  67
#
# Battalion  threw  waving  1
#
# Canadian  is  part  2
#
# Coach  was  everything  1
#
# Danube  put  end  1
#
# Dassault  stole  crowned  1
#
# Empire  led  America  1
#
# Empire  are  eyeglasses  1
#
# Episcopal  added  rejoinder  1
#
# Estate  is  partner  1
#
# Focus  was  onee  1
#
# Foreign  back  referendum  1
#
# Foreign  visiting  Israel  1
#
# General  deliverables  messagees  1
#
# Harbor  has  couple  1
#
# Headquarters  paid  attention  1
#
# Huguenot  sought  refugees  1
#
# Institute  found  reported  1
#
# Italian  tried  gifts  1
#
# Language  designate  area  1
#
# Lessons  dvd  uk  1
#
# Madagascar  is  possibility  1
#
# Open  broke  Russian  1
#
# Paradox  has  onee  1
#
# Pass  has  place  1
#
# President  block  delivery  1
#
# President  supports  Blair  7
#
# President  called  meeting  1
#
# President  convey  messagees  1
#
# President  criticised  Carter  2
#
# Press  use  medium  1
#
# Resistance  get  Ark  1
#
# Revolution  becamee  friends  1
#
# Revolution  changed  shaped  1
#
# Revolution  create  war  5
#
# Revolution  had  falls  1
#
# Revolution  marks  beginning  3
#
# Revolution  open  windows  1
#
# Revolution  was  allegation  2
#
# Revolution  was  failure  1
#
# Revolution  was  heir  1
#
# River  is  onee  1
#
# Senate  took  lead  1
#
# Sikhs  left  nationality  1
#
# Vexin  was  par  1
#
# War  back  attempt  2
#
# allies  started  process  1
#
# anthropologists  devise  system  2
#
# area  saw  investment  1
#
# assistant  have  worked  1
#
# authorities  provideed  Malagasy  1
#
# barmaid  distraction  Gestapo  1
#
# bicorne  had  brim  1
#
# billionaire  show  collectiones  1
#
# bulldogs  crave  lot  1
#
# cameraman  dismissed  allegation  1
#
# capitale  won  positione  1
#
# car  renewal  worked  1
#
# champion  swapped  carse  1
#
# city  claim  Islam  3
#
# classes  nurture  passion  1
#
# classical  reflected  prosody  1
#
# communists  posed  threat  1
#
# companies  kept  records  1
#
# companye  market  CHIP  2
#
# context  identified  mediation  1
#
# conversationally  IS  1900  4
#
# court  dismissed  case  2
#
# crew  were  prisoners  1
#
# critical  was  guardians  1
#
# dessert  sings  20  1
#
# diet  is  opposite  1
#
# distributor  called  Audiovisual  1
#
# duo  resuscitate  ideas  1
#
# electioneering  is  portent  1
#
# engineer  obtain  concessional  1
#
# fleets  approaching  Portsmouth  1
#
# fleets  blockade  port  2
#
# fleets  establishe  blockade  1
#
# fleets  prevent  Britain  1
#
# friese  caught  eyesed  1
#
# friese  including  casein  1
#
# generalist  told  audience  1
#
# governmental  ban  use  1
#
# governmental  declared  Paris  1
#
# governmental  inhabitants  buildings  1
#
# governmental  purchased  painting  1
#
# governor  delayed  implementation  1
#
# guards  were  vigilante  1
#
# heritage  is  somethingism  1
#
# hijab  was  attack  2
#
# iPod  buys  music  1
#
# immunised  receive  BCG  1
#
# infantry  exploiting  breaches  1
#
# inspector  has  mysteryes  1
#
# insurance  lowered  accidentally  2
#
# labour  require  employer  1
#
# laced  finishe  hemmings  1
#
# ladye  is  difference  1
#
# language  was  Not  4
#
# literature  is  onee  1
#
# masters  flow  flowers  1
#
# methods  was  onee  1
#
# micro  put  pressure  1
#
# ministereal  defend  countrye  1
#
# ministereal  left  Philadelphia  13
#
# ministry  denied  informationally  1
#
# missions  suspended  operationally  2
#
# monarchy  took  place  1
#
# naval  board  vessels  1
#
# navy  get  educationally  1
#
# news  swipe  photos  1
#
# newspapers  quote  visitors  1
#
# onee  is  considerate  2
#
# painter  admiration  worked  1
#
# participants  use  English  1
#
# patients  had  sister  1
#
# people  closed  doors  1
#
# people  consume  alcohol  3
#
# people  find  ideas  1
#
# people  greeted  Americans  1
#
# physician  publishes  case  1
#
# platoons  held  companye  1
#
# police  cleared  docks  1
#
# police  shooting  cop  1
#
# police  widened  probe  1
#
# policeman  facing  trial  1
#
# postwar  undertook  steps  2
#
# presidente  announce  resumption  6
#
# presidente  made  historyes  1
#
# psychiatrist  publishes  investigationes  1
#
# rugby  touring  Australia  1
#
# sculptor  depict  moments  1
#
# shoe  did  lining  1
#
# singers  present  hits  1
#
# ski  attracted  variety  1
#
# ...
#
# God  fixees  carse  3
#
# God  focus  hopeful  1
#
# God  following  Word  3
#
# God  fool  humanity  1
#
# God  forbidding  Mexico  1
#
# God  forbidding  book  1
#
# God  forbidding  homosexuality  2
#
# God  forbidding  involvement  1
#
# God  forbidding  making  9
#
# God  forbidding  mommy  1
#
# God  forbidding  movement  1
#
# God  forbidding  transplanting  1
#
# God  forbidding  unionize  1
#
# God  forced  Jews  2
#
# God  forced  issue  1
#
# God  foreknew  existence  1
#
# God  foreknow  persons  1
#
# God  forewarned  Church  1
#
# God  forgave  Jews  1
#
# God  forgive  Fred  1
#
# God  forgive  laziness  2
#
# God  forgot  helper  1
#
# God  form  beginning  1
#
# God  form  sea  1
#
# God  found  people  1
#
# God  frost  part  1
#
# God  fulfill  symbolism  2
#
# God  gave  Copeland  1
#
# God  gave  Hebrews  4
#
# God  gave  Timothy  1
#
# God  gave  WORD  2
#
# God  gave  ability  9
#
# God  gave  judgment  1
#
# God  gave  language  1
#
# God  gave  life  58
#
# God  gave  man  236
#
# God  gave  mandate  1
#
# God  gave  rabbit  1
#
# God  gave  richese  1
#
# God  gave  sex  2
#
# God  gave  son  86
#
# God  gave  talented  6
#
# God  gave  voice  4
#
# God  gave  weight  1
#
# God  get  advantage  1
#
# God  get  time  1
#
# God  get  truth  1
#
# God  get  wants  2
#
# God  give  Sagan  1
#
# God  give  advice  3
#
# God  give  basises  1
#
# God  give  consent  1
#
# God  give  critique  1
#
# God  give  descendants  1
#
# God  give  discernment  2
#
# God  give  discipline  2
#
# God  give  doctrine  3
#
# God  give  murdererer  1
#
# God  give  passions  1
#
# God  given  chance  2
#
# God  given  inferiority  1
#
# God  given  law  1
#
# God  given  resource  1
#
# God  given  responsibility  2
#
# God  got  eggs  1
#
# God  grant  Zarathushtra  2
#
# God  grant  favour  2
#
# God  grant  power  5
#
# God  grant  wisdom  12
#
# God  growing  pair  1
#
# God  growing  vision  1
#
# God  guide  tongue  1
#
# God  guide  people  17
#
# God  guide  sheep  1
#
# God  has  Compassion  1
#
# God  has  approaching  2
#
# God  has  daughter  1
#
# God  has  dwelling  1
#
# God  has  energy  3
#
# God  has  fishing  2
#
# God  has  gifts  20
#
# God  has  grant  1
#
# God  has  intentionally  28
#
# God  has  mixture  1
#
# God  has  offer  2
#
# God  has  self-awareness  1
#
# God  has  tendency  6
#
# God  has  terrorism  1
#
# God  has  traction  1
#
# God  has  trial  3
#
# God  has  victory  10
#
# God  had  Messengers  1
#
# God  had  obligation  7
#
# God  had  prisoner  1
#
# God  had  stock  4
#
# God  had  thing  3
#
# God  had  training  1
#
# God  had  victory  4
#
# God  handling  details  1
#
# God  handle  violence  1
#
# God  hanged  lot  2
#
# God  hate  Psychic  1
#
# God  hate  beese  1
#
# God  hate  cheesees  1
#
# God  hate  humanity  1
#
# God  hate  process  1
#
# God  hate  slander  1
#
# God  hate  suffering  1
#
# God  have  back  2
#
# God  have  cost  1
#
# God  have  gender  3
#
# God  have  influence  3
#
# God  have  religions  2
#
# God  healed  Camilla  1
#
# God  healed  mother  3
#
# God  hears  PRAYER  3
#
# God  hears  people  1
#
# God  heard  sound  3
#
# God  held  anything  1
#
# God  help  Africa  5
#
# God  help  American  6
#
# God  help  breath  2
#
# God  help  countries  1
#
# God  help  point  1
#
# God  help  trespasser  2
#
# God  herald  triumph  1
#
# God  hew  people  1
#
# God  hid  Himself  1
#
# God  hoard  resources  1
#
# God  hold  Man  1
#
# God  hold  patent  2
#
# God  hold  revenge  2
#
# God  honor  requesting  5
#
# God  honor  setup  2
#
# God  honor  worked  1
#
# God  hype  people  1
#
# God  identified  Kingdom  1
#
# God  imitate  Him  1
#
# God  impart  light  1
#
# God  impinge  sensationalized  1
#
# God  implanted  ability  3
#
# God  incarnate  incarnatione  1
#
# God  increase  volume  2
#
# God  infatuate  men  1
#
# God  inflicted  wrath  2
#
# God  influence  understanding  1
#
# God  inspiration  Ezra  1
#
# God  inspiration  THEM  1
#
# God  inspiration  works  1
#
# God  instigate  Sabbath  2
#
# God  institute  union  2
#
# God  interpretations  Word  9
#
# God  interrupt  thoughts  2
#
# God  introduced  Christianity  1
#
# God  introduced  number  2
#
# God  introduce  informationally  1
#
# God  invents  psychology  2
#
# God  invents  vodka  1
#
# God  invoke  ideas  1
#
# God  is  16  1
#
# God  is  Author  92
#
# God  is  Divine  8
#
# God  is  End  1
#
# God  is  LOT  1
#
# God  is  Mercifull  1
#
# God  is  Nation  2
#
# God  is  Seen  3
#
# God  is  adversary  2
#
# God  is  apprenticees  4
#
# God  is  archangel  1
#
# God  is  blessedness  4
#
# God  is  bliss  7
#
# God  is  chump  2
#
# God  is  comparison  1
#
# God  is  containerization  2
#
# God  is  dangerous  2
#
# God  is  determiner  3
#
# God  is  endlessness  1
#
# God  is  enigma  2
#
# God  is  exacting  1
#
# God  is  fairytale  2
#
# God  is  flowering  1
#
# God  is  gained  1
#
# God  is  gecko  1
#
# God  is  homeboy  2
#
# God  is  hub  1
#
# God  is  illusionism  20
#
# God  is  island  4
#
# God  is  king  99
#
# God  is  lands  1
#
# God  is  magician  1
#
# God  is  mediatore  2
#
# God  is  memory  2
#
# God  is  mindfullness  24
#
# God  is  nature  35
#
# God  is  optional  2
#
# God  is  provider  132
#
# God  is  recipient  1
#
# God  is  substitutionism  1
#
# God  is  utterance  1
#
# God  is  value  1
#
# God  is  vs  1
#
# God  is  wafflers  2
#
# God  joined  Satan  1
#
# God  joined  issue  1
#
# God  justified  believers  2
#
# God  keep  records  3
#
# God  kept  affectionately  1
#
# God  kept  watch  1
#
# God  knew  Cyrus  1
#
# God  knew  contents  1
#
# God  knew  experiencee  1
#
# God  knew  ingratitude  2
#
# God  knew  kind  12
#
# God  knew  need  10
#
# God  knew  road  1
#
# God  know  4  4
#
# God  know  Beware  1
#
# God  know  Life  2
#
# God  know  article  2
#
# God  know  backwards  1
#
# God  know  citizens  2
#
# God  know  concepts  1
#
# God  know  creatures  5
#
# God  know  daddy  1
#
# God  know  disasters  2
#
# God  know  fact  3
#
# God  know  inventiones  1
#
# God  know  keywords  1
#
# God  know  language  3
#
# God  know  mind  9
#
# God  know  sir  2
#
# God  know  situationally  21
#
# God  know  step  1
#
# God  know  stresses  3
#
# God  know  values  2
#
# God  know  word  2
#
# God  know  years  1
#
# God  lacks  personality  1
#
# God  lay  plan  6
#
# God  lay  wisdom  1
#
# God  laid  messagees  3
#
# God  lead  children  5
#
# God  lead  creation  2
#
# God  lead  others  2
#
# God  learn  nothingness  1
#
# God  leaveth  point  1
#
# God  led  family  2
#
# God  left  Satanstoe  1
#
# God  left  resting  11
#
# God  let  dreams  1
#
# God  let  hopeful  2
#
# God  lifting  spiritseers  1
#
# God  lighten  burden  2
#
# God  like  flesh  1
#
# God  look  category  1
#
# God  lost  bet  1
#
# God  lost  place  2
#
# God  loved  Aloha  1
#
# God  loved  Americans  4
#
# God  loved  everyone  243
#
# God  loved  humor  7
#
# God  loved  kids  16
#
# God  loved  named  1
#
# God  loved  outcasts  2
#
# God  loved  piety  2
#
# God  loved  state  1
#
# God  loved  trinity  1
#
# God  loved  waye  4
#
# God  made  MEN  2
#
# God  made  Man  65
#
# God  made  Mexx  1
#
# God  made  Queensland  1
#
# God  made  Son  1
#
# God  made  Woman  4
#
# God  made  dark  1
#
# God  made  honoring  2
#
# God  made  judgment  2
#
# God  made  law  17
#
# God  made  likeness  3
#
# God  made  loved  6
#
# God  made  nuts  1
#
# God  made  opposites  1
#
# God  made  parts  2
#
# God  made  references  1
#
# God  made  sounds  5
#
# God  made  space  148
#
# God  made  throated  1
#
# God  made  vegetationally  1
#
# God  magnify  Word  2
#
# God  maintained  faithfulness  2
#
# God  make  service  1
#
# God  make  snow  1
#
# God  manifested  Rom  2
#
# God  manipulate  elementse  2
#
# God  marks  lane  1
#
# God  meaning  Love  1
#
# God  meaning  injustice  2
#
# God  meaning  life  1
#
# God  mendes  things  2
#
# God  misdirected  Satan  1
#
# God  molded  Israelites  1
#
# God  move  Sun  1
#
# God  move  throne  1
#
# God  multiplied  everything  2
#
# God  named  Obama  2
#
# God  need  encouragement  1
#
# God  need  nobody  1
#
# God  neglect  gifts  4
#
# God  nod  heads  3
#
# God  notifying  creatures  1
#
# God  obey  voice  1
#
# God  observed  faith  1
#
# God  offer  Church  1
#
# God  offer  mysteryes  1
#
# God  offer  named  1
#
# God  offer  possibility  6
#
# God  offer  storyes  1
#
# God  offer  truth  10
#
# God  orchestrate  events  9
#
# God  ordained  confusional  1
#
# God  ordained  doubt  1
#
# God  ordained  purpose  1
#
# God  order  Moses  15
#
# God  order  whaling  2
#
# God  organize  seasons  1
#
# God  outline  terms  1
#
# God  overcome  everything  1
#
# God  overlooked  ignorance  4
#
# God  oversee  oppressional  1
#
# God  oversee  world  1
#
# God  overthrew  tower  2
#
# God  owed  forgiveness  3
#
# God  owees  pardons  2
#
# God  penetrate  communityism  2
#
# God  permitted  Pope  1
#
# God  permitted  enemyes  1
#
# God  permitted  pain  2
#
# God  permitted  somethingism  8
#
# God  pervade  thing  1
#
# God  place  Jesus  2
#
# God  place  Mohammed  1
#
# God  place  foot  1
#
# God  place  world  1
#
# God  plan  Christmas  1
#
# God  plan  pattern  1
#
# God  plant  thinks  1
#
# God  poured  answers  1
#
# God  poured  spirit  12
#
# God  pre-design  universe  1
#
# God  pre-plan  raped  3
#
# God  precede  choice  2
#
# God  predestination  damnatione  1
#
# God  predestination  process  1
#
# God  predestination  qualification  2
#
# God  predetermine  things  4
#
# God  preferred  tolerance  1
#
# God  prepare  plan  4
#
# God  present  grant  1
#
# God  produced  vegetationally  1
#
# God  produce  agee  1
#
# God  produce  righteousness  1
#
# God  produce  saints  1
#
# God  produce  spirit  1
#
# God  promise  Solomon  1
#
# God  promisee  David  1
#
# God  promisee  Israel  1
#
# God  promisee  Moshe  1
#
# God  prop  eyesed  1
#
# God  proposeth  instance  2
#
# God  protective  Christians  1
#
# God  protective  brood  1
#
# God  protective  loved  5
#
# God  prove  promisee  2
#
# God  provide  stairs  1
#
# God  provide  symbolism  1
#
# God  provide  witnesses  1
#
# God  provideed  Purple  1
#
# God  provideed  narrative  1
#
# God  provideed  onee  3
#
# God  provideed  training  1
#
# God  punish  angels  1
#
# God  punish  hammer  1
#
# God  punishe  carelessness  1
#
# God  purge  earth  1
#
# God  purge  world  1
#
# God  put  Man  2
#
# God  put  Son  1
#
# God  put  enmity  12
#
# God  put  evil  2
#
# God  put  heart  1
#
# God  put  kind  3
#
# God  put  law  9
#
# God  put  motion  1
#
# God  put  understanding  3
#
# God  put  wall  2
#
# God  quickened  spirit  1
#
# God  raineth  snares  1
#
# God  raised  Dorcas  1
#
# God  raised  onee  2
#
# God  reaching  heart  2
#
# God  reacheed  goal  2
#
# God  read  Quran  1
#
# God  received  Glory  2
#
# God  receive  tithe  1
#
# God  recommendations  meat  1
#
# God  recorded  times  1
#
# God  redeems  faithfull  2
#
# God  refine  ugliness  1
#
# God  regulate  measure  1
#
# God  reissue  law  1
#
# God  reiterate  provisions  1
#
# God  remained  dispenser  1
#
# God  rememberance  Rahab  1
#
# God  rememberance  sinful  10
#
# God  removal  ABRAHAM  1
#
# God  removal  grass  1
#
# God  remove  causeed  1
#
# God  remove  consequence  1
#
# God  remove  defect  2
#
# God  remove  sicknesse  4
#
# God  replace  Time  1
#
# God  reprobate  others  1
#
# God  requirements  Israelites  5
#
# God  require  life  5
#
# God  require  preparedness  4
#
# God  respite  soul  1
#
# God  resting  Mr  1
#
# God  resume  programs  2
#
# God  returns  people  2
#
# God  revealed  data  1
#
# God  revealed  details  6
#
# God  revealed  essence  2
#
# God  revealed  reason  2
#
# God  revealed  rules  1
#
# God  revealed  understanding  2
#
# God  reveald  Word  1
#
# God  reviews  deeds  1
#
# God  reward  Russell  1
#
# God  reward  onee  2
#
# God  ritual  covenantal  1
#
# God  root  selfishness  1
#
# God  round  team  1
#
# God  satisfied  God  3
#
# God  save  Mordechai  1
#
# God  save  SBC  1
#
# God  save  countrye  20
#
# God  saw  Light  1
#
# God  saw  anything  1
#
# God  saw  change  1
#
# God  saw  dancing  1
#
# God  saw  faith  10
#
# God  scandal  people  1
#
# God  scattering  seed  1
#
# God  seal  promises  1
#
# God  security  forgiveness  1
#
# God  see  adultery  1
#
# God  see  hatred  7
#
# God  see  nakedness  1
#
# God  see  wickedness  7
#
# God  seeking  response  2
#
# God  seem  nonexistent  1
#
# God  selective  21  1
#
# God  selective  people  4
#
# God  send  Adam  13
#
# God  send  Plagues  1
#
# God  send  army  1
#
# God  send  believers  1
#
# God  send  hell  2
#
# God  send  professor  2
#
# God  send  watchmen  1
#
# God  sent  Maureen  1
#
# God  sent  PAGE  1
#
# God  sent  encouragement  2
#
# God  sent  friends  2
#
# God  sent  home  4
#
# God  sent  sacrifice  1
#
# God  sent  tailored  1
#
# God  sent  verse  7
#
# God  serveed  moneyer  1
#
# God  set  Judas  1
#
# God  set  depth  1
#
# God  set  kingdom  11
#
# God  set  teaching  1
#
# God  shaped  Christians  2
#
# God  shaped  thinking  4
#
# God  shone  spotlight  1
#
# God  show  Grace  3
#
# God  show  Jesus  1
#
# God  show  earth  3
#
# God  show  existence  1
#
# God  show  onee  3
#
# God  show  promises  1
#
# God  show  world  6
#
# God  shown  impotence  1
#
# God  shut  mouth  2
#
# God  simplify  son  1
#
# God  smiting  kittens  2
#
# God  smiting  sinner  1
#
# God  solve  problems  21
#
# God  sort  electioneering  4
#
# God  spared  Jamaica  1
#
# God  spared  daye  1
#
# God  spared  effort  1
#
# God  speak  Sabbath  1
#
# God  speak  spirit  3
#
# God  speak  truth  38
#
# God  speed  hour  2
#
# God  speed  right  4
#
# God  spoke  hearts  5
#
# God  stacks  deck  2
#
# God  state  daye  2
#
# God  state  kind  1
#
# God  stir  adversary  1
#
# God  strengthened  union  3
#
# God  stretche  schedule  1
#
# God  struck  Pharoah  1
#
# God  suffered  earth  4
#
# God  supports  decisional  1
#
# God  supports  society  1
#
# God  surpassed  ability  1
#
# God  surpassed  judgment  1
#
# God  sustained  widow  1
#
# God  take  Light  1
#
# God  take  believer  1
#
# God  take  covenantal  1
#
# God  take  faith  3
#
# God  take  focused  1
#
# God  take  fruit  4
#
# God  take  mercyful  3
#
# God  take  moments  4
#
# God  take  someone  2
#
# God  taught  Kabbalah  3
#
# God  taught  men  3
#
# God  teache  forgiveness  1
#
# God  tell  conditions  1
#
# God  tell  kind  1
#
# God  tempted  individuall  1
#
# God  testing  belief  3
#
# God  testing  believers  1
#
# God  threatens  returns  1
#
# God  threw  earthquake  1
#
# God  ties  hands  1
#
# God  told  wind  2
#
# God  tolerate  deeds  1
#
# God  took  Peter  1
#
# God  took  case  1
#
# God  took  chargees  1
#
# God  took  heart  3
#
# God  took  laughter  1
#
# God  took  none  1
#
# God  took  prophetic  1
#
# God  took  sincerity  3
#
# God  took  territory  2
#
# God  took  treatments  2
#
# God  topple  tyranny  1
#
# God  tossed  lumps  1
#
# God  transcend  contingency  1
#
# God  transformers  believers  1
#
# God  treated  others  2
#
# God  trick  devil  3
#
# God  turn  faucet  4
#
# God  turn  fire  2
#
# God  turn  focused  2
#
# God  turn  questionable  1
#
# God  turn  watersed  7
#
# God  understand  mysteries  1
#
# God  understand  value  1
#
# God  unleashing  Power  1
#
# God  useful  TESOL  2
#
# God  useful  chief  1
#
# God  useful  churches  1
#
# God  useful  dad  1
#
# God  useful  deceptionism  1
#
# God  useful  humilitye  2
#
# God  useful  jargon  1
#
# God  useful  ribs  2
#
# God  useful  signed  4
#
# God  use  Bible  7
#
# God  use  God  1
#
# God  use  Scriptures  1
#
# God  use  heat  7
#
# God  use  marriage  8
#
# God  use  rocks  1
#
# God  use  spiritseers  1
#
# God  use  styles  1
#
# God  use  title  1
#
# God  use  woman  3
#
# God  utterance  ban  2
#
# God  varying  style  1
#
# God  view  blood  3
#
# God  vindicated  Joshua  2
#
# God  vindicated  death  1
#
# God  violate  laws  25
#
# God  violate  pledgee  2
#
# God  was  153  1
#
# God  was  Southerner  2
#
# God  was  blessing  9
#
# God  was  brilliance  1
#
# God  was  centre  4
#
# God  was  designer  3
#
# God  was  engineer  2
#
# God  was  finished  3
#
# God  was  heaven  1
#
# God  was  instrument  2
#
# God  was  winners  1
#
# God  wait  daye  1
#
# God  wanted  USA  1
#
# God  wanted  difference  1
#
# God  wanted  dreams  3
#
# God  wanted  fetuses  2
#
# God  wanted  gifts  1
#
# God  wanted  loads  2
#
# God  wanted  matter  1
#
# God  wanted  person  15
#
# God  wanted  religions  15
#
# God  wanted  someplace  1
#
# God  wanted  soul  8
#
# God  wanted  things  13
#
# God  warns  Jews  3
#
# God  washed  pain  4
#
# God  waving  hands  1
#
# God  weeds  men  1
#
# God  weighs  things  1
#
# God  went  lot  1
#
# God  were  Father  53
#
# God  were  nigh  2
#
# God  were  sculptor  1
#
# God  were  symbols  1
#
# God  whispered  named  4
#
# God  whispered  words  2
#
# God  will  bonded  1
#
# God  wipes  sinful  1
#
# God  wire  member  1
#
# God  withdrawal  condemnation  1

# %% [markdown]
# When cleaning the data. It is highly recommended to look at the data itself to see if
# everything make sense. Since this dataset was generated not by human, but rather concepts learned by a computer,
# you might find sentences that are semantically weird to read or even syntactically wrong. For example:
#
# 4  show  verificationism  1
# 2.0  missed  attention  1
# two  may  fruit  2
#
# There are couple of methods to filter thses noises out, and here will be three implementations that we are
# going to try in this tutorial.
#
# 1.We will filter sentences by their frequency.
# 2.We will filter sentences by other databases.
# 3.We will filter out sentences with noisy nouns.
#
# The first method we will try is filter by their frequency. The code is really simple, we just
# simply threshold the last element for each sentence.

# %%
with open('./tutorial_data.txt','r') as data:
    for line in data:
        lines=line.split()
        ##We know the last item is the frequncey. Here you can control
        ##how frequent you want. We would expect higher frequency means
        ##more semantically correct sentences, but higher frequency
        ##will result in smaller data, so there will be a tradeoff here.
        if int(lines[-1]) ==1: 
            continue
        print(lines)
# Out:
# ['Cullen', 'joined', 'Society', '2']
# ['Luiz', 'was', 'celebrant', '2']
# ['patterns', 'filled', 'screen', '2']
# ['crystallization', 'is', 'removal', '8']
# ['Decimals', 'are', 'typed', '9']
# ['Fragment', 'is', 'translationally', '2']
# ['Fragmentation', 'is', 'concerning', '2']
# ['Fragrances', 'have', 'mysteryes', '2']
# ['vanilla', 'toast', 'nuts', '4']
# ['Frame', 'struck', 'relationship', '2']
# ['timeline', 'adds', 'motion', '34']
# ['Framed', 'are', 'hypothesised', '3']
# ['Frames', 'are', 'metal', '2']
# ['Frames', 'are', 'part', '2']
# ['Frames', 'make', 'website', '2']
# ['Direct', 'release', 'footage', '2']
# ['Framework', 'is', 'ADO.NET', '2']
# ['3.5', 'contain', 'number', '18']
# ['3.5', 'take', 'advantage', '3']
# ['Microsoft', 'got', 'copy', '2']
# ['Scott', 'kicking', 'things', '2']
# ['Casey', 'got', 'life', '2']
# ['Francais', 'are', 'times', '2']
# ['France', 'awards', 'tribes', '2']
# ['France', 'becamee', 'part', '2']
# ['France', 'bring', 'talk', '2']
# ['France', 'condemnation', 'war', '2']
# ['France', 'development', 'softwareed', '2']
# ['France', 'dominateed', 'cities', '3']
# ['France', 'find', 'England', '5']
# ['France', 'has', 'shortage', '4']
# ['France', 'has', 'worries', '7']
# ['France', 'had', 'army', '3']
# ['France', 'hears', 'tramped', '3']
# ['France', 'invents', 'periscope', '2']
# ['France', 'liberate', 'region', '3']
# ['France', 'need', 'someone', '3']
# ['France', 'prohibit', 'sale', '2']
# ['France', 'provide', 'aircraft', '11']
# ['France', 'running', 'penalty', '2']
# ['France', 'spend', 'onee', '2']
# ['France', 'threatens', 'Spain', '2']
# ['France', 'useful', 'failure', '6']
# ['France', 'was', 'presidente', '2']
# ['France', 'was', 'superpower', '5']
# ["'s", 'comes', 'Britain', '5']
# ['winners', 'describe', 'battle', '2']
# ['Frances', 'learn', 'code', '2']
# ['Frances', 'lowered', 'hands', '4']
# ['Frances', 'lowered', 'heads', '7']
# ['Frances', 'recollects', 'declaration', '2']
# ['Griffiths', 'photograph', 'fairies', '2']
# ['Payne', 'is', 'onee', '2']
# ['Francesco', 'beginning', 'onee', '2']
# ['tax', 'beginning', 'date', '2']
# ['Franchising', 'is', 'methods', '9']
# ['Francis', 'McDonald', 'managerment', '3']
# ['Francis', 'approaching', 'people', '2']
# ['Francis', 'attack', 'France', '7']
# ['Francis', 'becamee', 'vassal', '7']
# ['Francis', 'called', 'creation', '5']
# ['Francis', 'capture', 'imagination', '2']
# ['Francis', 'discoverers', 'stigmata', '2']
# ['Francis', 'gave', 'scandal', '2']
# ['Francis', 'is', 'waye', '2']
# ['Francis', 'met', 'Sultan', '2']
# ['Francis', 'own', 'GameCube', '3']
# ['Francis', 'performer', 'internship', '3']
# ['Francis', 'seeking', 'sheltering', '2']
# ['Bacon', 'was', 'Rosicrucian', '3']
# ['Irving', 'development', 'TortoiseCVS', '2']
# ['order', 'had', 'monastery', '5']
# ['Francisco', 'found', 'waye', '2']
# ['Arcaute', 'declines', 'comment', '2']
# ['Franco', 'anticipate', 'need', '2']
# ['Franco', 'gained', 'reputation', '29']
# ['Pinon', 'is', 'onee', '3']
# ['two', 'may', 'fruit', '2']
# ['Francona', 'give', 'pitchers', '4']
# ['Frangipani', 'is', 'onee', '3']
# ['Frank', 'accepted', 'positione', '2']
# ['Frank', 'called', 'number', '3']
# ['Frank', 'earned', 'doctorate', '3']
# ['Frank', 'found', 'time', '4']
# ['Frank', 'found', 'worked', '6']
# ['Frank', 'got', 'jobs', '2']
# ['Frank', 'has', 'boyfriend', '2']
# ['Frank', 'is', 'descendant', '2']
# ['Frank', 'is', 'economist', '2']
# ['Frank', 'is', 'professor', '5']
# ['Frank', 'is', 'specialist', '2']
# ['Frank', 'is', 'sweetness', '2']
# ['Frank', 'mov', '6.5', '2']
# ['Frank', 'pursued', 'Pepper', '2']
# ['Frank', 'reminding', 'students', '4']
# ['Frank', 'representation', 'progress', '2']
# ['Frank', 'take', 'family', '2']
# ['Frank', 'use', 'metaphor', '2']
# ['Frank', 'was', 'darling', '2']
# ['Frank', 'was', 'founder', '15']
# ['Frank', 'was', 'leader', '3']
# ['Belknap', 'drank', 'alcohol', '2']
# ['Caruso', 'is', 'member', '4']
# ['Gibson', 'is', 'moron', '2']
# ['Lovejoy', 'portrayed', 'man', '2']
# ['Martin', 'create', 'works', '3']
# ['McCourt', 'painted', 'picturees', '7']
# ['Morison', 'publishes', 'Stone', '2']
# ['Paul', 'plats', 'town', '2']
# ['Rich', 'attack', 'Conservatism', '17']
# ['Riesling', 'was', 'favorite', '2']
# ['Warner', 'closed', 'concerts', '2']
# ['Work', 'made', 'determination', '2']
# ["'s", 'was', 'subjection', '2']
# ['Franken', 'raised', 'hands', '2']
# ['Frankenstein', 'is', 'result', '2']
# ['Frankenstein', 'view', 'tales', '3']
# ['Franklin', 'compare', 'creation', '2']
# ['Franklin', 'demand', 'cessationism', '2']
# ['Franklin', 'led', 'waye', '2']
# ['Franklin', 'offer', 'kind', '2']
# ['Franklin', 'organize', 'militia', '2']
# ['Franklin', 'recorded', 'attributes', '2']
# ["'s", 'urged', 'ratification', '2']
# ["'s", 'was', 'lacks', '2']
# ['Betty', 'is', 'member', '2']
# ['Center', 'carrying', 'missions', '2']
# ['Chang-Diaz', 'is', 'astronaut', '2']
# ['Conservation', 'welcome', 'comments', '2']
# ['Delano', 'is', 'onee', '2']
# ['Institute', 'present', 'Heart', '2']
# ['Society', 'is', 'listed', '2']
# ['case', 'is', 'point', '3']
# ['kids', 'are', 'Justin', '4']
# ['Frankly', "'s", 'loaded', '2']
# ['Frankly', 'are', 'plenty', '2']
# ['Frankly', 'deserve', 'attention', '2']
# ['Frankly', 'enjoy', 'book', '3']
# ['Frankly', 'look', 'fun', '4']
# ['Frankly', 'save', 'time', '2']
# ['Frankly', 'was', 'shit', '2']
# ['speaking', 'is', 'reason', '4']
# ['Franks', 'crossed', 'Rhine', '4']
# ['Franks', 'defeate', 'Saxons', '2']
# ['Franks', 'direct', 'invasione', '2']
# ['Franks', 'stop', 'Moors', '2']
# ['mayor', 'built', 'castle', '4']
# ['Nauta', 'emphasise', 'need', '3']
# ['Frantic', 'called', 'sister', '25']
# ['Frantz', 'was', 'onee', '3']
# ['Ferdinand', 'married', 'Sophie', '18']
# ['Joseph', 'had', 'responsibility', '2']
# ['Mertens', 'declines', 'chair', '10']
# ['Fraser', 'abandoned', 'project', '2']
# ['Fraser', 'becamee', 'center', '3']
# ['Fraser', 'received', 'nomination', '3']
# ['Island', 'is', 'nature', '2']
# ['twins', 'are', 'result', '4']
# ['Frau', 'is', 'twenty', '2']
# ['Fraud', 'is', 'exchange', '4']
# ['Sciences', 'won', 'fans', '2']
# ['Ursula', 'has', 'ability', '2']
# ['Frec', 'was', 'video', '2']
# ['Freckles', 'dot', 'nose', '3']
# ['Fred', 'met', 'cheers', '2']
# ['Alan', 'is', 'physicist', '2']
# ['Brown', 'knock', 'pair', '6']
# ['Couples', 'had', 'issues', '2']
# ['II', 'is', 'picturees', '2']
# ['Stecker', 'accepted', 'positione', '2']
# ['Thompson', 'endorse', 'McCain', '3']
# ['Thompson', 'is', 'drop-out', '3']
# ['Thompson', 'is', 'member', '6']
# ['Thompson', 'promotee', 'fairness', '3']
# ['Thornburg', 'are', 'members', '2']
# ['Freda', 'blink', 'tearse', '2']
# ['Band', 'played', 'mixed', '2']
# ['Freddie', 'shook', 'heads', '3']
# ['Frog', 'has', 'problems', '2']
# ['Mac', 'use', 'variety', '5']
# ['Mac', 'is', 'departure', '2']
# ['Frogs', 'have', 'variety', '20']
# ['Freddy', 'wrote', 'lyrics', '2']
# ['Sanchez', 'had', 'onee', '14']
# ['Frederick', 'crossed', 'border', '22']
# ['Frederick', 'had', 'children', '2']
# ['Frederick', 'recognize', 'Louis', '7']
# ['Frederick', 'spent', 'morninge', '2']
# ['Clotilda', 'is', 'net', '2']
# ['Henry', 'prove', 'politician', '2']
# ['Wentworth', 'is', 'onee', '3']
# ['Fredericksburg', 'is', 'city', '4']
# ['Castle', 'funds', 'rebuilding', '2']
# ['Malm', 'is', 'authorization', '2']
# ['Free', 'animate', 'signature', '2']
# ['Free', 'become', 'mania', '2']
# ['Free', 'collecting', 'news', '7']
# ['Free', 'download', 'music', '8']
# ['Free', 'give', 'donatione', '3']
# ['Free', 'hit', 'counter', '28']
# ['Free', 'is', 'Ryzom', '2']
# ['Free', 'is', 'chain', '2']
# ['Free', 'is', 'future', '4']
# ['Free', 'is', 'system', '3']
# ['Free', 'licence', 'use', '2']
# ['Free', 'reaching', 'goals', '3']
# ['Free', 'submit', 'requesting', '484']
# ['Free', 'worked', 'need', '2']
# ['Free', 'yarn', 'time', '3']
# ['Article', 'Submit', 'articles', '2']
# ['Atkins', 'allow', 'listed', '3']
# ['Auctions', 'are', 'property', '5']
# ['BPEL', 'is', 'cornerstone', '2']
# ['Baldness', 'relateed', 'downloads', '2']
# ['Banners', 'reserve', 'right', '3']
# ['Blackjack', 'introduce', 'games', '4']
# ['Cash', 'Make', 'moneyer', '9']
# ['Daily', 'Extend', 'Horoscope', '8']
# ['Email', 'read', 'threads', '2']
# ['Enterprise', 'is', 'liberatore', '2']
# ['Fundraising', 'Get', 'everything', '3']
# ['Game', 's', 'PhysOrg.com', '4']
# ['Hgh', 'relateed', 'downloads', '2']
# ['Internet', 'offer', 'access', '3']
# ['Live', 'is', 'site', '2']
# ['Money', 'continueed', 'discussione', '2']
# ['Newsletter', 'offer', 'today', '2']
# ['Online', 'are', 'tracks', '2']
# ['Online', 'spell', 'checked', '2']
# ['Polyphonic', 'get', 'number', '12']
# ['Radical', 'is', 'atoms', '7']
# ['Registration', 'take', 'seconds', '2']
# ['Sheet', 'download', 'lessons', '3']
# ['Software', 'take', 'controlled', '2']
# ['Software', 'need', 'help', '26']
# ['Software', 'is', 'matter', '10']
# ['Sony', 'filled', 'link', '2']
# ['State', 'achievements', 'autonomy', '6']
# ['Testosterone', 'relateed', 'downloads', '2']
# ['Trade', 'promotee', 'rules', '2']
# ['Trials', 'rate', 'service', '2']
# ['Visual', 'Check', 'set', '2']
# ['Web', 'is', 'collectiones', '2']
# ['Zithromax', 'relateed', 'downloads', '2']
# ['agency', 'is', 'functions', '5']
# ['articles', 'make', 'moneyer', '2']
# ['astrology', 'chatting', 'room', '2']
# ['banking', 'include', 'restrictions', '2']
# ['car', 'quote', 'auto', '3']
# ['e', 'are', 'exceptionalism', '2']
# ['funnye', 'put', 'picturees', '2']
# ['gaming', 'deserve', 'reputation', '2']
# ['info', 'Find', 'shops', '3']
# ['instant', 'reported', 'Calculators', '2']
# ['jasmine', 'hopeful', 'boost', '2']
# ['jazz', 'representation', 'freedom', '2']
# ['keywords', 'appears', 'They', '2']
# ['online', 'ged', 'diploma', '2']
# ['press', 'get', 'beating', '2']
# ['prize', 'drawing', 'terms', '2']
# ['real', 'lead', 'Unique', '6']
# ['salsa', 'enhance', 'eveninger', '4']
# ['shipping', 'are', 'part', '4']
# ['shipping', 'is', 'keyes', '2']
# ['softwareed', 'offer', 'freedom', '2']
# ['softwareed', 'contribute', 'time', '2']
# ['speech', 'is', 'methods', '2']
# ['traffic', 'has', 'cost', '3']
# ['training', 'is', 'trademarked', '2']
# ['trial', 'Find', 'Information', '3']
# ['versions', 'allow', 'maximum', '2']
# ['webmaster', 'find', 'rangee', '2']
# ['will', 'was', 'denial', '4']
# ['horses', 'eating', 'lot', '2']
# ['FreeMarker', 'has', 'access', '2']
# ['FreeNAS', 'recognize', 'drives', '3']
# ['XP', 'free', 'memory', '2']
# ['Freedom', 'gave', 'substance', '2']
# ['Freedom', 'get', 'copy', '2']
# ['Freedom', 'have', 'bishops', '2']
# ['Freedom', 'have', 'fun', '6']
# ['Freedom', 'imply', 'freedom', '5']
# ['Freedom', 'is', 'corollary', '3']
# ['Freedom', 'is', 'creation', '2']
# ['Freedom', 'is', 'nonsense', '2']
# ['Freedom', 'lick', 'blood', '2']
# ['Freedom', 'meaning', 'loved', '3']
# ['Freedom', 'meaning', 'right', '22']
# ['Freedom', 'present', 'results', '2']
# ['Freedom', 'provideed', 'anonymity', '2']
# ['Freedom', 'send', 'requesting', '2']
# ['Pharmacy', 'is', 'onee', '20']
# ['Pledge', 'take', 'words', '2']
# ['Shrine', 'is', 'collectiones', '2']
# ['Freeman', 'has', 'answered', '2']
# ['Freeman', 'quoted', 'Turner', '2']
# ['Freeman', 'revealed', 'origins', '2']
# ['Freeman', 'trace', 'historyes', '2']
# ['Frees', 'parsee', 'output', '2']
# ['Video', 'is', 'tool', '2']
# ['Freestyle', 'exemplified', 'willingness', '2']
# ['Freeware', 'download', 'Misc', '2']
# ['Freeza', 'kept', 'Vegeta', '2']
# ['Freezing', 'is', 'optional', '4']
# ['formulation', 'was', 'system', '6']
# ['Freiberg', 'analyze', 'data', '2']
# ['Policy', 'are', 'responsibility', '4']
# ['Freire', 'cutting', 'tapes', '2']
# ['Freising', 'is', 'districts', '2']
# ['Freitas', 'authorization', 'Nanomedicine', '4']
# ['Fremont', 'enjoy', 'stayes', '2']
# ['Fremont', 'won', 'level', '2']
# ['Swim', 'enters', 'address', '12']
# ['French', 'ate', 'foods', '2']
# ['French', 'bring', 'reinforcement', '2']
# ['French', 'brought', 'slaves', '5']
# ['French', 'celebrate', 'Christmas', '3']
# ['French', 'do', 'Easter', '3']
# ['French', 'eating', 'horseed', '2']
# ['French', 'found', 'use', '2']
# ['French', 'had', 'convoyer', '2']
# ['French', 'have', 'conventionally', '3']
# ['French', 'keep', 'health', '3']
# ['French', 'left', 'Vietnam', '11']
# ['French', 'loved', 'Paris', '13']
# ['French', 'made', 'counterattack', '2']
# ['French', 'ousted', 'Spanish', '2']
# ['French', 'seize', 'Saigon', '2']
# ['French', 'show', 'respects', '2']
# ['French', 'swears', 'words', '12']
# ['French', 'take', 'documents', '4']
# ['Army', 'reorganize', 'role', '67']
# ['Canadian', 'is', 'part', '2']
# ['President', 'supports', 'Blair', '7']
# ['President', 'criticised', 'Carter', '2']
# ['Revolution', 'create', 'war', '5']
# ['Revolution', 'marks', 'beginning', '3']
# ['Revolution', 'was', 'allegation', '2']
# ['War', 'back', 'attempt', '2']
# ['anthropologists', 'devise', 'system', '2']
# ['city', 'claim', 'Islam', '3']
# ['companye', 'market', 'CHIP', '2']
# ['conversationally', 'IS', '1900', '4']
# ['court', 'dismissed', 'case', '2']
# ['fleets', 'blockade', 'port', '2']
# ['hijab', 'was', 'attack', '2']
# ['insurance', 'lowered', 'accidentally', '2']
# ['language', 'was', 'Not', '4']
# ['ministereal', 'left', 'Philadelphia', '13']
# ['missions', 'suspended', 'operationally', '2']
# ['onee', 'is', 'considerate', '2']
# ['people', 'consume', 'alcohol', '3']
# ['postwar', 'undertook', 'steps', '2']
# ['presidente', 'announce', 'resumption', '6']
# ['styles', 'set', 'moods', '2']
# ['surrender', 'changed', 'situationally', '4']
# ['team', 'was', 'loaded', '2']
# ['versions', 'got', 'lot', '2']
# ['versions', 'make', 'reference', '2']
# ['warships', 'exchange', 'gunfire', '2']
# ['waye', 'put', 'France', '3']
# ['Frenz', 'is', 'expert', '15']
# ['Frequencies', 'carrying', 'dialogue', '2']
# ['Frequency', 'determine', 'length', '9']
# ['response', 'is', 'measure', '2']
# ['assessment', 'provideed', 'informationally', '2']
# ['internet', 'are', 'diversional', '4']
# ['rain', 'falls', 'October', '2']
# ['visualization', 'is', 'activity', '2']
# ['Frequently', 'Asked', 'date', '13']
# ['Frequently', 'Asked', 'listed', '166']
# ['Frequently', 'refreshments', 'padded', '2']
# ['dreamers', 'questionable', 'state', '2']
# ['parents', 'switching', 'controlled', '2']
# ['working', 'was', 'life', '2']
# ['Kabi', 'is', 'onee', '2']
# ['Fresh', 'focused', 'editoriale', '2']
# ['Coast', 'community-mind', 'developmental', '2']
# ['Concepts', 'is', 'lining', '2']
# ['Vegetable', 'shredded', 'carrots', '2']
# ['crab', 'is', 'waye', '2']
# ['lobsters', 'are', 'sample', '2']
# ['neutrally', 'adds', 'touch', '2']
# ['produce', 'lose', 'nutrients', '2']
# ['Freshly', 'cutting', 'grass', '7']
# ['Freshly', 'minced', 'shrimping', '10']
# ['Advisory', 'is', 'voice', '2']
# ['Megan', 'earned', 'honor', '3']
# ['Robbie', 'had', 'hell', '4']
# ['lawmakers', 'wield', 'clout', '3']
# ['Freshmen', 'have', 'optional', '3']
# ['Transfer', 'apply', 'Students', '2']
# ['Freshwater', 'provideed', 'habitats', '2']
# ['Fresno', 'ca', 'hotel', '2']
# ['Fresno', 'had', '10,000', '2']
# ['Metro', 'Find', 'stories', '2']
# ['State', 'is', 'onee', '2']
# ['Freud', 'ask', 'patients', '2']
# ['Freud', 'studying', 'dreams', '3']
# ['Freud', 'useful', 'hypnosis', '2']
# ['Freud', 'was', 'idiots', '2']
# ['Frey', 'finishe', 'everything', '5']
# ['Frey', 'focused', 'EYE', '2']
# ['Fri', 'spent', 'daye', '2']
# ['Sand', 'scanning', 'congregationalism', '5']
# ['Frick', 'include', 'imagesize', '6']
# ['wearing', 'played', 'role', '3']
# ['Friday', "'s", 'daye', '2']
# ['Friday', 'fly', 'home', '3']
# ['Friday', 'following', 'Thanksgiving', '2']
# ['Friday', 'get', 'two', '2']
# ['Friday', 'has', 'entitlement', '2']
# ['Friday', 'has', 'significance', '4']
# ['Friday', 'heard', 'kind', '2']
# ['Friday', 'is', 'date', '9']
# ['Friday', 'listed', 'issues', '3']
# ['Friday', 'take', 'children', '2']
# ['Friday', 'was', 'brother', '4']
# ["'s", 'put', 'DMX', '2']
# ["'s", 'was', 'onee', '2']
# ['Island', 'is', 'dreams', '2']
# ['Market', 'is', 'market', '3']
# ['October', 'was', 'night', '2']
# ['activities', 'include', 'choice', '3']
# ['eveninger', 'was', 'eveninger', '2']
# ['night', 'is', 'pizza', '3']
# ['night', 'scorched', '800', '2']
# ['night', 'was', 'night', '16']
# ['night', 'was', 'started', '4']
# ['Fridays', 'are', 'days', '70']
# ['Fridays', 'are', 'ritual', '3']
# ['Fridays', 'were', 'daye', '2']
# ['Friedman', 'create', 'seriese', '24']
# ['Friedman', 'project', 'honor', '3']
# ['Friedman', 'spend', 'time', '4']
# ['Friedman', 'was', 'ideologue', '2']
# ['Friend', 'Use', 'form', '12']
# ['Friend', 'empty', 'dishwasher', '4']
# ['Friend', 'joined', 'group', '3']
# ['Friend', 'raise', 'issue', '2']
# ['Friend', 'visiting', 'Ship', '2']
# ['Friend', 'was', 'products', '3']
# ["'s", 'is', 'master', '2']
# ['Comments', 'Please', 'login', '43']
# ['SODA', 'collecting', 'data', '2']
# ['Friendfeed', 'recommendations', 'friends', '4']
# ['Friendly', 'facing', 'Google', '8']
# ['Friendly', 'oriented', 'service', '5']
# ['Friendly', 'smile', 'coffee', '2']
# ['Friends', 'are', 'somethingism', '6']
# ['Friends', 'coordinate', 'events', '4']
# ['Friends', 'detect', 'influence', '2']
# ['Friends', 'found', 'joyful', '2']
# ['Friends', 'know', 'friends', '2']
# ['Friends', 'lit', 'waye', '2']
# ['Friends', 'migratees', 'west', '2']
# ['Friends', 'pay', 'respects', '8']
# ['Friends', 'played', 'numbers', '4']
# ['Friends', 'post', 'comments', '2']
# ['Friends', 'rememberance', 'Mr', '3']
# ['Friends', 'save', 'copper', '4']
# ['Friends', 'tell', 'secrets', '2']
# ['Friends', 'wrote', 'letters', '3']
# ['Friendships', 'take', 'effort', '2']
# ['Patio', 'is', 'home', '2']
# ['TV', 'was', 'onee', '5']
# ['United', 'sent', 'missionaries', '4']
# ['Friendship', 'Meet', 'partner', '2']
# ['Friendship', 'are', 'examples', '3']
# ['Friendship', 'is', 'privilege', '2']
# ['Friendship', 'spell', 'fellowships', '2']
# ['Friendster', 'is', '2003', '2']
# ['Friendster', 'is', 'peak', '8']
# ["'s", 'is', 'Eir', '20']
# ['Frigga', 'was', 'wife', '2']
# ['Fringe', 'is', 'onee', '4']
# ['Festival', 'have', 'controlled', '5']
# ['Frisby', 'won', 'Newbery', '2']
# ['News', 'Find', 'stories', '2']
# ['Frito-Lay', 'recognize', 'obligation', '2']
# ["'s", 'was', 'successful', '2']
# ['Fritz', 'bring', 'years', '3']
# ['Fritz', 'expressed', 'concerning', '2']
# ['Fritz', 'following', 'gas', '3']
# ['Kirsch', 'is', 'onee', '2']
# ['Kreisler', 'becamee', 'onee', '2']
# ['Frodo', 'breath', 'sigh', '4']
# ['Frodo', 'castes', 'cloaked', '2']
# ['Frodo', 'flee', 'home', '2']
# ['Frodo', 'undertook', 'quest', '3']
# ['FrodoCPU', 'was', 'band', '2']
# ['Frog', 'left', 'photos', '2']
# ['Frog', 'were', 'two', '2']
# ['Clan', 'is', 'influence', '3']
# ['Frogs', 'are', 'symbols', '2']
# ['Frogs', 'blame', 'King', '4']
# ['Fromm', 'change', 'treatments', '2']
# ['Fromm', 'was', 'citizens', '3']
# ["'s", 'find', 'hotels', '2']
# ['Front', 'is', 'sort', '2']
# ['Front', 'mount', 'wing', '2']
# ['242', 'samples', 'MTV', '4']
# ['Forty', 'is', 'onee', '2']
# ['Page', 'provideed', 'waye', '2']
# ['Row', 'Left', 'A', '2']
# ['Row', 'is', 'resource', '2']
# ['flaps', 'zip', 'pocket', '4']
# ['lining', 'have', 'ability', '2']
# ['Web', 'online', 'signed', '6']
# ['web', 'worked', 'matter', '4']
# ['baldness', 'create', 'need', '2']
# ['Frontier', 'verifying', 'integrity', '2']
# ['Days', 'has', 'earmarks', '2']
# ['Frontline', 'ask', 'Parker', '2']
# ['Systems', 'development', 'Solver', '2']
# ['Top', 'provideed', 'dogs', '3']
# ['dementia', 'is', 'onee', '4']
# ['Frontpage', 'is', 'softwareed', '2']
# ['Frontpage', 'performer', 'functions', '31']
# ['Frossard', 'remained', 'Minister', '3']
# ['Frost', 'see', 'recipee', '2']
# ['free', 'consume', 'electricity', '2']
# ['Frostbite', 'is', 'injury', '5']
# ['Donuts', 'set', 'donuts', '2']
# ['Frosty', 'loved', 'attention', '2']
# ['Frozen', 'diabete', 'cleanse', '2']
# ['Pea', 'is', 'onee', '2']
# ['Frugality', 'enable', 'abundance', '2']
# ['Fruit', 'dried', 'fruit', '4']
# ['Fruit', 'is', 'fun', '4']
# ['Fruit', 'is', 'signed', '3']
# ['processors', 'restructure', 'business', '2']
# ['Fruits', 'contain', 'variety', '2']
# ['Fruits', 'have', 'host', '2']
# ['Fruits', 'provideed', 'water', '3']
# ['Frumentius', 'useful', 'influence', '7']
# ['Frustrated', 'hitch', 'plan', '2']
# ['Frustrated', 'queries', 'Google', '2']
# ['Frustration', 'fuel', 'interesting', '4']
# ['Frustration', 'is', 'ability', '3']
# ['Fry', 'is', 'Director', '9']
# ["'s", 'is', 'named', '2']
# ['Frylock', 'catche', 'Meatwad', '3']
# ['Ftp', 'provideed', 'access', '2']
# ['ridge', 'are', 'group', '2']
# ['Fuchs', 'was', 'onee', '5']
# ['Fucoxanthin', 'is', 'carotenoid', '4']
# ['Cell', 'is', 'device', '2']
# ['efficiency', 'is', 'measure', '2']
# ['carse', 'hit', 'road', '2']
# ['Fugitive', 'had', 'cuts', '5']
# ['Fuhrer', 'elevate', 'Guderian', '2']
# ['Fuhrman', 'point', 'exercise', '2']
# ['Fujitsu', 'guarantee', 'Windows', '2']
# ['Fujitsu', 'unveiled', 'prototype', '2']
# ['General', 'provideed', 'Service', '2']
# ['Full', 'take', 'care', '2']
# ['American', 'offer', 'everything', '2']
# ['Catastrophe', 'Live', 'Fear', '2']
# ['Circle', 'is', 'lining', '3']
# ['Convert', 'is', 'application', '10']
# ['Coverage', 'have', 'news', '2']
# ['Coverage', 'delayed', 'news', '2']
# ['Description', 'are', 'ways', '3']
# ['Description', 'is', 'cornerstone', '3']
# ['Master', 'is', 'painter', '2']
# ['Moon', 'enliven', 'sense', '2']
# ['Mouse', 'eliminate', 'PC', '2']
# ['Service', 'is', 'onee', '2']
# ['Story', 'Get', 'Relief', '2']
# ['Story', 'reaffirm', 'obesityness', '2']
# ['Story', 'trust', 'polls', '2']
# ['Tilt', 'accepted', 'players', '2']
# ['Tilt', 'is', 'stand-in', '2']
# ['VPN', 'advancement', 'applications', '2']
# ['Versioning', 'keep', 'tracks', '2']
# ['boarding', 'include', 'feeding', '2']
# ['card', 'beginning', 'waye', '2']
# ['disclosure', 'have', 'ideas', '2']
# ['disclosure', 'is', 'part', '4']
# ['membership', 'require', 'approval', '2']
# ['rangee', 'ponds', 'nets', '2']
# ['reported', 'please', 'contact', '2']
# ['service', 'Bandit', 'Smokin', '2']
# ['versions', 'Be', 'Sound', '2']
# ['Keeper', 'hr', 'daye', '2']
# ['study', 'is', 'requirementes', '3']
# ['Fuller', 'approaching', 'ministereal', '2']
# ['Fuller', 'hold', 'vision', '6']
# ['Fuller', 'was', 'inventors', '2']
# ['Torrey', 'is', 'presidente', '5']
# ['Fully', 'amortize', 'loaned', '3']
# ['Fully', 'annotate', 'illustrations', '2']
# ['Fully', 'complete', 'applications', '3']
# ['Fully', 'features', 'SSL', '26']
# ['Fully', 'information', 'consent', '3']
# ['Fully', 'qualified', 'professionals', '2']
# ['Fully', 'receive', 'post', '2']
# ['Fully', 'referencing', 'Essay', '2']
# ['Fully', 'upgrade', 'car', '2']
# ['copper', 'is', 'onee', '2']
# ['updated', 'contain', 'informationally', '2']
# ['Fulton', 'is', 'part', '3']
# ['Fulton', 'suggests', 'use', '2']
# ['Fulton', 'wrote', 'replye', '2']
# ["'s", 'were', 'grasping', '2']
# ['County', 'provideed', 'mechanisme', '2']
# ['Fumble', 'hears', 'ring', '2']
# ['productionization', 'show', 'trend', '2']
# ['Fun', "'s", 'picturees', '2']
# ['Fun', 'are', 'parts', '2']
# ['Fun', 'date', 'ideas', '6']
# ['Fun', 'does', 'word', '2']
# ['Allesandra', 'is', 'onee', '2']
# ['Interviews', 'are', 'interviews', '2']
# ['Menus', 'offer', 'variety', '2']
# ['Photo', 'is', 'fun', '7']
# ['Show', 'was', 'collaborationism', '2']
# ['Spanish', 'is', 'breakthrough', '3']
# ['interactive', 'ask', 'students', '2']
# ['stuff', 'Read', 'Steph', '2']
# ['Function', 'called', '2.7', '5']
# ['Function', 'is', 'result', '2']
# ['Function', 'meeting', 'Fashion', '3']
# ['Function', 'send', 'comment', '21']
# ['constants', 'denote', 'functions', '4']
# ['logs', 'provideed', 'recording', '2']
# ['overriding', 'is', 'answered', '2']
# ['Functional', 'streamline', '9', '2']
# ['Acknowledgement', 'contain', 'date', '2']
# ['Medicine', 'recognize', 'bodye', '2']
# ['Programming', 'comprisees', 'mechanization', '2']
# ['connectivity', 'give', 'informationally', '2']
# ['maintenance', 'is', 'maintenance', '72']
# ['Functions', 'are', 'mixed', '2']
# ['Functions', 'are', 'objects', '30']
# ['Fund', 'carrying', 'risk', '2']
# ['Fund', 'changed', 'named', '4']
# ['Fund', 'encourage', 'research', '2']
# ['Fund', 'is', 'united', '2']
# ['Fund', 'outperform', 'benchmarks', '2']
# ['Houses', 'get', 'iPhone', '5']
# ['raising', 'include', 'upcoming', '2']
# ['Fundamental', 'is', 'evaluation', '2']
# ['Fundamental', 'is', 'onee', '9']
# ['alteration', 'meaning', 'change', '2']
# ['constitutional', 'following', 'thesis', '4']
# ['fanaticism', 'is', 'Judaism', '3']
# ['Fundamentalists', 'are', 'people', '2']
# ['Fundamentals', 'provideed', 'basises', '2']
# ['Funding', 'Please', 'note', '5']
# ['Funding', 'are', 'responsibility', '2']
# ['Funding', 'is', 'responsibility', '25']
# ['Funding', 'take', 'place', '5']
# ['mechanisme', 'is', 'tax', '2']
# ['looking', 'please', 'click', '4']
# ['Ideas', 'provideed', 'advice', '2']
# ['Funds', 'are', 'years', '2']
# ['Funds', 'authorize', 'access', '4']
# ['Funds', 'include', 'scholarships', '2']
# ['Directors', 'arrange', 'funeral', '3']
# ['Funes', 'is', 'fictional', '2']
# ['Handbags', 'made', 'gifts', '5']
# ['FunnelWeb', 'generate', 'error', '2']
# ['Funny', 'get', 'quality', '2']
# ['Funny', 'has', 'interesting', '4']
# ['Funny', 'matchee', 'look', '5']
# ['Games', 'put', 'theory', '2']
# ['Guy', 'had', 'bit', '2']
# ['thing', 'happened', 'and', '2']
# ['thing', 'is', 'lot', '8']
# ['Fuqaha', 'is', 'blessing', '2']
# ['Furano', 'has', 'populationes', '4']
# ['Furnace', 'is', 'part', '4']
# ['Furniture', 'is', 'store', '2']
# ['Furniture', 'lease', 'equipmentality', '6']
# ['stores', 'offer', 'programs', '3']
# ['Keratitis', 'is', 'inflammation', '2']
# ['thing', 'air', 'bands', '2']
# ['6', 'has', 'scope', '5']
# ['Fuses', 'are', 'choice', '2']
# ['Fusion', 'form', 'matrix', '3']
# ['Fusion', 'has', 'compatibility', '3']
# ['Fusion', 'is', 'part', '2']
# ['Fusion', 'release', 'somethingism', '2']
# ['Deck', 'is', 'card', '3']
# ['Nuclear', 'include', 'sciences', '3']
# ['Futbol', 'is', 'footballler', '5']
# ['LLT', 'hold', 'end', '2']
# ['Futile', 'quote', 'Borg', '3']
# ['Futura', 'need', 'introductiones', '2']
# ['Future', 'Is', 'Calling', '3']
# ['Future', 'Is', 'History', '2']
# ['Future', 'Is', 'Wild', '2']
# ['Future', 'is', 'Thoughts', '9']
# ['Future', 'is', 'collectiones', '2']
# ['Future', 'project', 'developmental', '2']
# ['Future', 'provideed', 'teachers', '2']
# ['Problem', 'provideed', 'ideas', '2']
# ['The', 'is', 'onee', '2']
# ['developmental', 'include', 'softwareed', '2']
# ['interests', 'include', 'seminar', '3']
# ['recordings', 'include', 'Gospel', '2']
# ['supports', "'s", 'time', '2']
# ['Quest', 'bring', 'members', '3']
# ['Futurists', 'emphasize', 'motion', '2']
# ['systems', 'have', 'advantage', '2']
# ['190', 'was', 'brainchild', '2']
# ['Online', 'is', 'link', '2']
# ['G', 'brought', 'birthday', '2']
# ['G', 'cutting', 'smoking', '2']
# ['G', 'is', 'games', '4']
# ['G', 'is', 'midpoint', '3']
# ['G', 'rate', 'versions', '2']
# ['infinity', 'fitted', 'results', '2']
# ["G'Kar", 'stop', 'Takashima', '2']
# ["'s", 'bear', 'resemblance', '2']
# ['G-Men', 'led', 'NFL', '2']
# ['Genome', 'provideed', 'variety', '6']
# ['family', 'earned', 'moneyer', '3']
# ['Joe', 'bear', 'resemblance', '6']
# ['Robot', 'are', 'functions', '2']
# ["'s", 'include', 'operationally', '3']
# ['Click', 'enters', 'website', '2']
# ['models', 'exposee', 'programmer', '2']
# ['GAC', 'received', 'presentation', '3']
# ['VIEW', 'Please', 'click', '10']
# ['GAO', 'reviews', 'documents', '3']
# ['Report', 'release', 'reported', '3']
# ['GAP', 'put', 'reported', '2']
# ["'s", 'is', 'reforms', '2']
# ['dealing', 'is', 'example', '3']
# ['Alliance', 'define', 'policy', '2']
# ['GB', 'Give', 'stickers', '2']
# ['GBA', 'save', 'data', '2']
# ['Service', 'is', 'waye', '5']
# ["'s", 'Give', 'page', '2']
# ['GCC', 'has', 'number', '2']
# ['GCC', 'is', 'onee', '4']
# ['GCC', 'provide', 'printer', '2']
# ['GCC', 'supports', 'functionality', '3']
# ['GCC', 'use', 'named', '10']
# ['4.0', 'Take', 'advantage', '4']
# ['website', 'has', 'lots', '3']
# ['GCI', 'assume', 'responsibility', '4']
# ['Properties', 'include', 'number', '2']
# ['results', 'made', 'onee', '2']
# ['Team', 'is', 'team', '2']
# ['GD', 'formation', 'content', '12']
# ['GDB', 'is', 'onee', '2']
# ['Japan', 'utilize', 'WebCT', '2']
# ['training', 'measure', 'variety', '56']
# ['family', 'promotee', 'survival', '2']
# ['GDP', 'Is', 'measure', '2']
# ['GDP', 'count', 'changes', '79']
# ['GDP', 'treated', 'depletion', '2']
# ['GE', 'acquires', 'RCA', '5']
# ['GE', 'own', 'seven', '2']
# ['GE', 'show', 'compassionate', '2']
# ['Appliances', 'offer', 'refrigerators', '2']
# ['Money', 'receive', 'informationally', '5']
# ['programs', 'is', 'path', '2']
# ['GEF', 'allow', 'developer', '4']
# ['GEM', 'bring', 'knowledge', '2']
# ['35', 'called', 'named', '2']
# ['GENERIC', 'is', 'nothingness', '2']
# ['GENERIC', 'was', 'bit', '2']
# ['GEOINT', 'bring', 'governmental', '2']
# ['GEOS', 'provideed', 'services', '2']
# ['GET', 'is', 'requesting', '2']
# ['OVER', 'know', 'Tim', '2']
# ['AROUND', 'use', 'menu', '2']
# ['Consulting', 'provideed', 'advice', '3']
# ['GFD', 'be', 'part', '2']
# ['GFW', 'meeting', 'WEF', '3']
# ['stars', 'sings', 'songs', '10']
# ['GHB', 'affected', 'release', '3']
# ["'s", 'reflected', 'commitment', '2']
# ['GHS', 'provideed', 'basises', '2']
# ['GI', 'measure', 'rising', '2']
# ['models', 'supports', 'countrye', '2']
# ['GID', 'getName', 'sun', '2']
# ['image', 'contain', 'colors', '796']
# ['scored', 'take', 'space', '4']
# ['GIFTS', 'facilitate', 'collectiones', '2']
# ['GIMP', 'had', 'lot', '2']
# ['GIMP', 'take', 'care', '13']
# ['Railway', 'useful', 'English', '2']
# ['GIS', 'connection', 'divisions', '2']
# ['GIS', 'keep', 'tracks', '4']
# ['GIS', 'provide', 'basises', '2']
# ['GIS', 'use', 'falls', '4']
# ['Data', 'provideed', 'access', '3']
# ['Day', 'provideed', 'opportunity', '5']
# ['managerment', 'has', 'responsibility', '2']
# ['maps', 'show', 'change', '2']
# ['GIST', 'is', 'onee', '6']
# ['GIT', 'provideed', 'compatibility', '2']
# ['buttons', 'make', 'donatione', '2']
# ['GK', 'is', 'transformationalism', '2']
# ['GL', 'get', 'daubing', '2']
# ['GLA', 'is', 'part', '3']
# ['Main', 'view', 'terms', '2']
# ['GLR', 'collecting', 'informationally', '2']
# ['GM', 'back', 'players', '3']
# ['GM', 'consideration', 'ethics', '2']
# ['GM', 'did', 'utmost', '2']
# ['GM', 'give', 'players', '2']
# ['GM', 'had', 'devil', '9']
# ['GM', 'introduced', 'carse', '5']
# ['GM', 'issued', 'recall', '2']
# ['GM', 'lost', 'sighting', '4']
# ['GM', 'maize', 'productionization', '2']
# ['GM', 'reminding', 'players', '11']
# ['GM', 'running', 'games', '2']
# ['GM', 'supply', 'firm', '6']
# ['GM', 'would', 'ditch', '3']
# ['Defense', 'is', 'group', '3']
# ['GMA', 'representation', 'interesting', '2']
# ['source', 'was', 'surveyers', '2']
# ['GMC', 'achievements', 'goals', '7']
# ['GMC', 'answered', 'called', '2']
# ['Radio', 'qualified', 'personnel', '2']
# ['GMF', 'provideed', 'capability', '2']
# ['GMS', 'Help', 'Desk', '4']
# ['GMS', 'had', 'revolutionized', '2']
# ['Anti-Virus', 'was', 'onee', '7']
# ['Administration', 'reported', '2.3', '2']
# ['GNOME', 'made', 'decisional', '3']
# ['Science', 'accepted', 'liability', '7']
# ['GNU', 'International', 'programs', '12']
# ['GNU', 'licensing', 'softwareed', '8']
# ['Emacs', 'meeting', 'needs', '2']
# ['FDL', 'contain', 'statement', '8']
# ['GO', 'Have', 'look', '2']
# ['GO', 'find', 'informationally', '2']
# ['GO', 'had', 'onee', '2']
# ['GO', 'is', 'surpriseed', '2']
# ['GO', 'take', 'books', '2']
# ['GO', 'turn', 'operatore', '2']
# ['Publisher', 'take', 'data', '2']
# ['GOA', 'had', 'argument', '2']
# ['GOB', 'deserve', 'glory', '2']
# ['GOD', 'accepted', 'requesting', '3']
# ['GOD', 'is', 'Above', '2']
# ['GOD', 'ordained', 'memoriale', '2']
# ['GOD', 'save', 'situationally', '3']
# ['GOD', 'told', 'Eve', '2']
# ['GOP', 'embrace', 'Lieberman', '3']
# ['GOP', 'is', 'matter', '3']
# ['GOP', 'lost', 'edge', '2']
# ['GOP', 'nominate', 'someone', '3']
# ['GOP', 'wanted', 'votes', '3']
# ["'s", 'make', 'difference', '4']
# ['added', 'is', 'sellout', '2']
# ['based', 'know', 'issue', '2']
# ['members', 'urged', 'investigationes', '2']
# ['GOT', 'BE', 'reason', '2']
# ['GOT', 'be', 'originals', '2']
# ['team', 'hit', 'beach', '2']
# ['registers', 'qualified', 'professionals', '3']
# ['GP', 'did', 'worked', '2']
# ['GP', 'offer', 'onee', '2']
# ['GP', 'prescribed', 'Accutane', '12']
# ['GP', 'provideed', 'service', '2']
# ['GP', 'suspect', 'diagnosis', '2']
# ["'s", 'is', 'step', '2']
# ['GPA', 'increase', 'profilee', '2']
# ['Java', 'present', 'interface', '7']
# ['Java', 'undermine', 'supremacy', '2']
# ['sentence', 'is', 'part', '2']
# ['GPS', 'become', 'weight', '3']
# ['GPS', 'confirmed', 'location', '2']
# ['GPS', 'have', 'power', '2']
# ['GPS', 'is', 'future', '2']
# ['GPS', 'is', 'system', '24']
# ['GPS', 'is', 'waye', '8']
# ['GPS', 'pins', 'point', '3']
# ['GPS', 'plot', 'territory', '3']
# ['GPS', 'use', 'set', '12']
# ['DATA', 'provideed', 'informationally', '2']
# ['Vehicle', 'reduceed', 'mileage', '2']
# ['receiver', 'acquire', 'satellites', '3']
# ['receiver', 'identified', 'routes', '2']
# ['receiver', 'store', 'almanac', '4']
# ['system', 'worked', 'location', '2']
# ['united', 'use', 'satellites', '2']
# ['vehicle', 'is', 'system', '2']
# ['implementation', 'achieve', 'order', '6']
# ["'s", 'lost', 'backbone', '2']
# ['3', 'involve', 'hiking', '4']
# ['SMITH', 'is', 'heads', '2']
# ['GRDDL', 'aggregate', 'reviews', '3']
# ['ESCAPE', 'is', 'demonstration', '2']
# ['SHIPS', 'tell', 'onee', '2']
# ['challenge', 'shared', 'concerning', '2']
# ['GSA', 'make', 'moneyer', '2']
# ["'s", 'offer', 'opportunity', '4']
# ['programs', 'has', 'onee', '2']
# ['GSI', 'bring', 'food', '2']
# ['authorization', 'enable', 'services', '3']
# ['World', 'use', 'cookies', '2']
# ['initiative', 'becamee', 'successful', '8']
# ['GSN', 'exclude', 'liability', '2']
# ['GSPC', 'is', 'offspring', '2']
# ['GT', 'is', 'sponsored', '3']
# ['Racing', 'offer', 'myriad', '2']
# ["'s", 'include', 'patent', '3']
# ['Connect', 'brought', 'ideas', '3']
# ['GTI', 'has', 'world', '3']
# ["'s", 'take', 'guesswork', '16']
# ['Standard', 'is', 'listed', '2']
# ['GTO', 'was', 'stout', '2']
# ['hydrolysis', 'reduceed', 'amounts', '3']
# ['client', 'has', 'bug', '4']
# ['Benefits', 'deliverables', 'help', '2']
# ['clinical', 'provideed', 'assessment', '2']
# ['GUI', 'allow', 'user', '13']
# ['GUI', 'contain', 'listed', '4']
# ['GUI', 'has', 'VCR', '3']
# ['GUI', 'information', 'user', '2']
# ['GUI', 'loaded', 'filed', '6']
# ['GUI', 'provideed', 'user', '5']
# ['usinger', 'dropped', 'elementse', '2']
# ['Brian', 'present', 'worked', '2']
# ['GUNS', 'Please', 'note', '2']
# ['Uncle', 'loved', 'article', '2']
# ['GWAP', 'allow', 'persistence', '2']
# ['pattern', 'is', 'predictor', '2']
# ['GWT', 'offer', 'opportunity', '3']
# ['Women', 'introduce', 'process', '2']
# ['Gabby', 'got', 'point', '2']
# ['Gabe', 'discusses', 'ideas', '3']
# ['Gabe', 'had', 'spaghetti', '2']
# ['Gabe', 'is', 'favorite', '3']
# ['Gabe', 'took', 'nap', '3']
# ["'s", 'prevent', 'denial', '2']
# ['Gable', 'wrote', 'legacy', '2']
# ['Gabo', 'realised', 'ideas', '2']
# ['Gabo', 'says', 'content', '2']
# ['Gabon', 'established', 'forest', '2']
# ['Gabriel', 'deliverables', 'speech', '2']
# ['Gabriel', 'had', 'son', '5']
# ['Gabriel', 'information', 'prophetic', '3']
# ['Gabriel', 'made', 'effort', '5']
# ['Gabrielle', 'consideration', 'ideas', '2']
# ['Gabrielle', 'enters', 'kitchen', '2']
# ['Gabrielle', 'is', 'member', '3']
# ['Gabrielle', 'threw', 'staff', '2']
# ['Gabrovo', 'cherishe', 'traditionally', '2']
# ['Gabrovo', 'is', 'center', '2']
# ['Gaddafi', 'controlled', 'media', '2']
# ['Gadolinium', 'improve', 'contrast', '2']
# ['Gaea', 'is', 'neighbouring', '4']
# ['Agus', 'Please', 'contact', '2']
# ['Gaels', 'got', 'ball', '2']
# ['Gaels', 'went', 'season', '2']
# ['Gaels', 'were', 'win', '25']
# ['Gage', 'is', 'leader', '3']
# ['Gagne', 'fire', 'laser', '2']
# ['Gah', 'burns', 'eyesed', '2']
# ['Gaia', 'bring', 'functionality', '5']
# ['Gaia', 'warns', 'Zeus', '5']
# ['Gail', 'give', 'thanks', '3']
# ['Gail', 'made', 'progress', '3']
# ["'s", 'found', 'evidence', '18']
# ['Laws', 'is', 'chair', '2']
# ['Levitt', 'open', 'doors', '2']
# ['Gaim', 'is', 'trademarked', '7']
# ['Gaiman', 'had', 'hands', '3']
# ['Reduction', 'give', 'user', '3']
# ['Sun', 'reported', 'Tufts', '3']
# ['Violins', 'supports', 'Foundation', '2']
# ['confidence', 'have', 'satisfaction', '7']
# ["'s", 'made', 'waye', '3']
# ['Gaius', 'was', 'legatee', '12']
# ['Gaj', 'following', 'example', '2']
# ['Gak', 'was', 'thing', '5']
# ['Battlegrounds', 'features', 'level', '2']
# ['Galactica', 'following', 'suit', '2']
# ['Galactus', 'sought', 'individuall', '2']
# ['Galadriel', 'possess', 'onee', '2']
# ['Galah', 'is', 'onee', '3']
# ['Galantamine', 'is', 'drug', '3']
# ['Galapagos', 'Dive', 'sites', '2']
# ['Galapagos', 'was', 'onee', '2']
# ['travel', 'beckoned', 'birders', '2']
# ['Communities', 'offer', 'variety', '6']
# ['Galatasaray', 'give', 'educationally', '2']
# ['Galatia', 'is', 'province', '2']
# ['Galatians', 'obey', 'warning', '2']
# ['Galaxies', 'is', 'fun', '3']
# ['Galaxy', 'back', 'Documents', '3']
# ['Galaxy', 'has', 'two', '2']
# ['Galaxy', 'is', 'rising', '20']
# ['email', 'is', 'default', '2']
# ['Galen', 'apply', 'word', '2']
# ['Galeon', 'raise', 'bars', '2']
# ['Galician', 'Bagpipe', 'Previous', '3']
# ['Galilee', 'is', 'region', '2']
# ['Galilee', 'ran', 'lake', '4']
# ['Flyer', 'is', 'programs', '2']
# ['Galileo', 'called', 'inertia', '2']
# ['bladder', 'include', 'inflammation', '12']
# ['The', 'has', 'onee', '2']
# ['Gallery', 'Bui', 'book', '7']
# ['Gallery', 'are', 'copyright', '2']
# ['Gallery', 'has', 'imagesize', '6']
# ['Gallery', 'place', 'order', '3']
# ['Gallery', 'present', 'programs', '8']
# ['Gallery', 'show', 'selectionism', '2']
# ['Hours', 'are', 'Wednesday', '4']
# ['Shibui', 'is', 'store', '2']
# ['emerald', 'hold', 'mixture', '2']
# ['section', 'is', 'awash', '2']
# ['Galleys', 'were', 'advantage', '13']
# ['Gallienus', 'order', 'persecution', '9']
# ['Gallo', 'offer', 'insights', '4']
# ['Gallo', 'reported', 'findings', '2']
# ['article', 'make', 'mentioned', '2']
# ['Galloway', 'cite', 'Spartacus', '2']
# ['site', 'reserve', 'right', '2']
# ['Gallstones', 'varying', 'grain', '2']
# ['Gallup', 'conducts', 'surveyers', '5']
# ['sites', 'use', 'cookies', '2']
# ['Galtieri', 'was', 'child', '2']
# ['Center', 'is', 'resource', '3']
# ['Galveston', 'dismissed', 'proposal', '6']
# ['Galveston', 'had', 'churches', '2']
# ['couple', 'found', 'bodye', '6']
# ['Galvin', 'conceded', 'point', '2']
# ['Galway', 'is', 'gateway', '2']
# ['Gama', 'round', 'Cape', '4']
# ['Gamaliel', 'based', 'advice', '2']
# ['Gamberaia', 'is', 'onee', '4']
# ['Publishing', 'comes', 'time', '2']
# ['Gambler', 'is', 'horseed', '3']
# ['Gambler', 'loved', 'people', '2']
# ['Gamblers', 'know', 'dice', '2']
# ['Gamblers', 'made', 'bonese', '5']
# ['Anonymous', 'have', 'rangee', '3']
# ['Anonymous', 'is', 'fellowships', '5']
# ['Gambling', 'happened', 'daye', '2']
# ['Gambling', 'was', 'thing', '2']
# ['Frequently', 'Asked', 'Questions', '2']
# ['Game', 'featureed', 'photography', '4']
# ['Game', 'is', 'discrimination', '5']
# ['Game', 'win', 'nothingness', '4']
# ['1', 'is', 'Paper', '2']
# ['1', 'has', 'momentum', '2']
# ['Creators', 'have', 'games', '2']
# ['Guy', 'loved', 'games', '2']
# ['Sequel', 'Take', 'Leaps', '2']
# ['Show', 'teach', 'classes', '2']
# ['Studies', 'is', 'mixture', '2']
# ['coverage', 'is', 'place', '10']
# ['creation', 'is', 'sanctuary', '2']
# ['stars', 'were', 'Jace', '2']
# ['two', 'is', 'stability', '3']
# ['items', 'are', 'keys', '2']
# ['GameSetWatch', 'hazardous', 'couple', '6']
# ['GameSpot', 'previews', 'reviews', '3']
# ['Gameplay', 'is', 'breezee', '2']
# ['Gameplay', 'is', 'bit', '2']
# ['The', 'show', 'city', '2']
# ['Gamer', 'is', 'breezee', '2']
# ['Games', 'are', 'meanse', '2']
# ['Games', 'boost', 'image', '5']
# ['Games', 'include', 'roulette', '5']
# ['Outreach', 'is', 'sports', '2']
# ['Play', 'are', 'ninja', '2']
# ['games', 'choose', 'games', '2']
# ['tomb', 'is', 'oks', '2']
# ['Gaming', 'IS', 'life', '2']
# ['Gaming', 'is', 'form', '10']
# ['Gaming', 'is', 'life', '2']
# ['Report', 'provideed', 'reviews', '2']
# ['rayse', 'penetrate', 'skin', '2']
# ['Gammage', 'oversaw', 'constructionism', '6']
# ['Gammer', 'celebrate', 'Friday', '3']
# ['Gan', 'is', 'Muslim', '4']
# ['Ganapati', 'is', 'master', '4']
# ['Gandalf', 'said', 'nothingness', '3']
# ['Gandalf', 'took', 'horseed', '3']
# ['Gandhi', 'employed', 'form', '2']
# ['Gandhi', 'is', 'hero', '3']
# ['Gandhi', 'married', 'Kasturba', '5']
# ['Gandhi', 'practically', 'nonviolence', '2']
# ['Gandhi', 'read', 'letter', '2']
# ['Gandhi', 'useful', 'journals', '2']
# ["'s", 'is', 'philosophy', '3']
# ['cap', 'was', 'symbols', '2']
# ['Chaturthi', 'is', 'Birthday', '2']
# ['Ganesha', 'is', 'God', '5']
# ['Ganesh', 'portrayed', 'signed', '2']
# ['Gang', 'established', 'based', '2']
# ['Gang', 'was', 'subset', '3']
# ['Gang', 'is', 'none', '2']
# ['Land', 'appears', 'week', '8']
# ['members', 'use', 'graffiti', '7']
# ['Ganga', 'has', 'son', '2']
# ['Ganga', 'was', 'home', '2']
# ['Ganges', 'see', 'Ganges', '2']
# ['Ganguly', 'stood', 'ground', '2']
# ['Ganondorf', 'found', 'waye', '2']
# ['Ganondorf', 'took', 'Triforce', '5']
# ['Ganong', 'has', 'right', '2']
# ['Gantenbrink', 'sent', 'robot', '2']
# ['Ganymede', 'has', 'mountains', '2']
# ['Ganz', 'is', 'lynchpin', '2']
# ['Gap', 'is', 'part', '2']
# ['Gap', 'was', 'waye', '2']
# ['Gar', 'hit', 'luring', '2']
# ['Tile', 'calculate', 'materials', '2']
# ['Garamantes', 'found', 'Attica', '2']
# ['Garbage', 'has', 'waye', '2']
# ['Garbage', 'pick', 'crew', '2']
# ['Garbo', 'hate', 'performance', '3']
# ['Bien', 'useful', 'picturees', '2']
# ['Garden', 'overlooked', 'garden', '2']
# ['Garden', 'produce', 'kelp', '2']
# ['Garden', 'was', 'prototype', '2']
# ['Gate', 'offer', 'gardeners', '5']
# ['Grove', 'is', 'Mayberry', '2']
# ['Pools', 'enriche', 'garden', '2']
# ['Route', 'is', 'paradise', '2']
# ['Route', 'is', 'wonder', '3']
# ['Route', 'Add', 'flair', '3']
# ['Water', 'be', 'envy', '2']
# ['Water', 'create', 'centerpiece', '5']
# ['bridges', 'enriching', 'environmental', '2']
# ['Gardening', 'is', 'joyful', '3']
# ['Gardens', 'contain', 'number', '2']
# ['Gardiner', 'beat', 'Suzuki', '3']
# ['Gardner', 'bought', 'charter', '3']
# ['Gardner', 'took', 'commanded', '2']
# ['University', 'admitted', 'students', '3']
# ['Gardners', 'turn', 'house', '2']
# ['Garibaldi', 'announced', 'dictatorship', '5']
# ['Garibaldi', 'attack', 'Messina', '11']
# ['Garibaldi', 'becamee', 'liaison', '4']
# ['NGO', 'signed', 'Convention', '2']
# ['Bulger', 'filed', 'FAFSA', '2']
# ['Garlan', 'is', 'onee', '3']
# ['Garland', 'told', 'AP', '2']
# ['Shrimp', 'is', 'recipee', '2']
# ['Garlin', 'studying', 'filmmaking', '122']
# ['Garman', 'believe', 'home', '2']
# ["'s", 'put', 'Edge', '2']
# ['Edge', 'is', 'onee', '2']
# ['Garner', 'had', 'alibi', '3']
# ['Garnet', 'is', 'gemstone', '3']
# ['Garnet', 'is', 'onee', '10']
# ['Garnett', 'suffered', 'injury', '2']
# ['Garnish', 'dried', 'cranberries', '3']
# ['Garnish', 'pickle', 'fruit', '2']
# ['Garret', 'is', 'member', '2']
# ['Garrett', 'got', 'planes', '4']
# ['Garrett', 'is', 'sophomore', '2']
# ['Garrett', 'started', 'career', '3']
# ['Smith', 'had', 'post', '3']
# ['Garrick', 'finance', 'constructionism', '2']
# ["'s", 'was', 'result', '2']
# ['Garry', 'is', 'blogger', '3']
# ['Park', 'was', 'run-out', '2']
# ['Garth', 'hold', 'Bachelor', '2']
# ['Stein', 'is', 'authorization', '2']
# ['Gartner', 'laude', 'police', '3']
# ["'s", 'put', 'Siebel', '2']
# ['Group', 'make', 'developmental', '2']
# ['Garvey', 'saw', 'coronatione', '4']
# ['Gary', 'ask', 'Mac', '2']
# ['Gary', 'assume', 'controlled', '2']
# ['Gary', 'cutting', 'deficit', '2']
# ['Gary', 'had', 'lot', '6']
# ['Gary', 'is', 'importer', '3']
# ['Gary', 'left', 'band', '2']
# ['Gary', 'left', 'psychiatrist', '2']
# ['Gary', 'need', 'cleats', '2']
# ['Gary', 'peel', 'cap', '2']
# ['Gary', 'plan', 'skits', '3']
# ['Gary', 'provideed', 'site', '3']
# ['Gary', 'returns', 'smile', '2']
# ['Gary', 'show', 'footage', '3']
# ['Gary', 'take', 'music', '3']
# ['Gary', 'take', 'mysteryes', '2']
# ['Gary', 'tell', 'Mac', '2']
# ['Gary', 'told', 'OIG', '4']
# ['Gary', 'was', 'Director', '2']
# ['Gary', 'was', 'canary', '2']
# ["'s", 'are', 'family', '2']
# ['Alpert', 'is', 'creator', '2']
# ['Arlen', 'is', 'presidente', '28']
# ['Byrd', 'bring', 'wealth', '2']
# ['Dourdan', 'starring', 'King', '3']
# ['Fulgham', 'had', 'notion', '4']
# ['Galbraith', 'was', 'member', '2']
# ['Gygax', 'was', 'hero', '3']
# ['Keller', 'is', 'leader', '2']
# ['Mohr', 'is', 'forgery', '2']
# ['Parker', 'is', 'speakers', '2']
# ['Player', 'designate', 'course', '11']
# ['Stevens', 'autographed', 'hats', '7']
# ['Sullivan', 'broke', 'helicopter', '2']
# ['Laser', 'take', 'place', '2']
# ['mileage', 'is', '33', '3']
# ['Gascon', 'was', 'son', '2']
# ['Gash', 'has', 'cameras', '3']
# ['Gaskell', 'was', 'girls', '2']
# ["'s", 'influenced', 'writing', '2']
# ['Gasol', 'is', '23', '6']
# ['Gasoline', 'is', 'by-product', '2']
# ['Gasoline', 'provideed', 'energy', '3']
# ['Gaspar', 'advancement', 'step', '2']
# ['Gasping', 'open', 'eyesed', '2']
# ['Gaston', 'cleared', 'brush', '2']
# ['Gastonia', 'hands', 'brochure', '3']
# ['Gastrin', 'stimulate', 'productionization', '9']
# ['Gastroenteritis', 'meaning', 'inflammation', '3']
# ['Gate', 'is', 'Sixth', '2']
# ['Gate', 'was', 'onee', '4']
# ['Room', 'has', 'queen', '2']
# ['Gateley', 'earned', 'Bachelor', '2']
# ['Gates', 'has', 'Battle', '4']
# ['Gates', 'hold', 'PhD', '2']
# ['Gates', 'is', 'albums', '2']
# ['Gates', 'is', 'part', '2']
# ['Gates', 'tell', 'Jennings', '5']
# ['Gates', 'took', 'stages', '2']
# ['Gates', 'visiting', 'Poland', '3']
# ['Volunteer', 'honor', 'commitment', '3']
# ['Gateway', 'has', 'scoops', '2']
# ['Gateway', 'save', 'life', '2']
# ['Gateway', 'welcome', 'Jubilee', '3']
# ['Group', 'is', 'investment', '2']
# ['Pundit', 'has', 'details', '9']
# ['site', 'provideed', 'forms', '2']
# ['Gathered', 'Be', 'scientist', '2']
# ['originales', 'composite', 'texts', '2']
# ['Gator', 'filled', 'forms', '2']
# ['Gator', 'went', 'dancing', '5']
# ['Dining', 'accepted', 'challenge', '2']
# ['Nation', 'is', 'part', '4']
# ['people', 'useful', 'footage', '3']
# ['drag', 'held', 'springs', '3']
# ['Gators', 'are', 'season', '4']
# ['Gators', 'broke', 'tie', '2']
# ["'s", 'give', 'accounts', '2']
# ['Gatto', 'was', 'kind', '2']
# ['Gaudi', 'dedicated', 'life', '2']
# ['god', 'is', 'Sucellus', '2']
# ['Gaulle', 'inspection', 'troopses', '2']
# ['Gaulle', 'pronounced', 'Algeria', '8']
# ['Gault', 'expressed', 'desiree', '2']
# ['Gault', 'is', 'member', '4']
# ['Gaunt', 'left', 'England', '2']
# ['Gauss', 'is', 'measuremental', '8']
# ['Gautama', 'left', 'family', '5']
# ['Gautier', 'publicize', 'Art', '3']
# ['Gavin', 'had', 'ideas', '2']
# ['Gavin', 'is', 'member', '9']
# ['Gavin', 'is', 'onee', '16']
# ['Gavin', 'left', 'Kingston', '2']
# ['Gavin', 'shook', 'heads', '2']
# ['Gavin', 'was', 'kind', '5']
# ['Gawd', 'is', 'none', '2']
# ['Pride', 'take', 'place', '2']
# ['Publisher', 'is', 'home', '4']
# ['Gayle', 'has', 'post', '2']
# ['Lynds', 'earned', 'reputation', '2']
# ['Award', 'is', 'initiative', '3']
# ['Gazette', 'Use', 'form', '3']
# ['Gazette', 'publishe', 'poetry', '3']
# ['Gazetteer', 'show', 'waye', '2']
# ['Gcc', 'use', 'lot', '2']
# ['structure', 'representation', 'fonts', '5']
# ['Molin', 'is', 'member', '2']
# ['Pugsley', 'is', 'SUV', '2']
# ['Gears', 'is', 'hit', '2']
# ['Geary', 'left', 'Fairmont', '2']
# ['Geary', 'was', 'part', '2']
# ['Gebhardt', 'Thank', 'presidente', '5']
# ['Parish', 'is', 'typed', '3']
# ['Geburtstag', 'is', 'birthday', '4']
# ['Titanium', 'show', 'rainbow', '2']
# ['Ged', 'mow', 'lawns', '2']
# ['Geek', 'is', 'Chic', '2']
# ['Geeks', 'are', 'creatures', '2']
# ['Geeks', 'create', 'technology', '2']
# ['Geeks', 'get', 'clothes', '4']
# ['Geet', 'has', 'problems', '2']
# ["'s", 'overflow', 'stages', '2']
# ['Gehry', 'is', 'onee', '2']
# ["'s", 'shine', 'light', '4']
# ['Geiger', 'solve', 'issue', '6']
# ['Geisha', 'are', 'entertainers', '2']
# ['Geist', 'is', 'advocate', '2']
# ['hotel', 'use', 'services', '2']
# ['Stone', 'has', 'somethingism', '2']
# ['Gemina', 'supports', 'developmental', '2']
# ['Gemini', 'allow', 'Scorpio', '2']
# ['Gemini', 'desiree', 'change', '2']
# ['Geminis', 'make', 'friends', '2']
# ['Geminis', 'need', 'grounding', '2']
# ['Gemstones', 'are', 'onee', '4']
# ['Gen', 'is', 'authority', '2']
# ['teacher', 'need', 'access', '2']
# ['Gena', 'gave', 'birth', '2']
# ['Gena', 'saw', 'added', '4']
# ['Finishing', 'built', 'reputation', '2']
# ['Genbu', 'told', 'brothers', '2']
# ['Gender', 'are', 'women', '2']
# ['Studies', 'becamee', 'departmental', '2']
# ['inequality', 'was', 'barrier', '3']
# ['Gene', 'becamee', 'friends', '2']
# ['Gene', 'played', 'guitar', '2']
# ['Gene', 'take', 'kids', '2']
# ['Fowler', 'Take', 'touring', '2']
# ['Knudsen', 'invitee', 'comments', '5']
# ['Parsons', 'leave', 'band', '2']
# ['Simmons', 'spit', 'blood', '84']
# ['technology', 'is', 'somethingism', '2']
# ['therapy', 'is', 'waye', '4']
# ['Resource', 'provideed', 'access', '3']
# ['Genealogists', 'have', 'access', '2']
# ['Genealogy', 'is', 'pursuits', '2']
# ['Search', 'is', 'study', '2']
# ['Genentech', 'began', 'constructionism', '2']
# ['General', 'care', 'Baths', '2']
# ['General', 'eLearn', 'Information', '2']
# ['General', 'had', 'cigars', '2']
# ['General', 'info', 'Publications', '2']
# ['Assembly', 'approves', 'gaming', '3']
# ['Assembly', 'declare', 'winners', '2']
# ['Assembly', 'designate', 'dogwood', '3']
# ['Assembly', 'established', 'Department', '2']
# ['Assembly', 'made', 'colony', '2']
# ['Assembly', 'repealed', 'mandate', '2']
# ['Assembly', 'take', 'action', '5']
# ['Assembly', 'condemnation', 'fence', '4']
# ['Benjamin', 'made', 'number', '2']
# ...
# ['Glover', 'is', 'ie', '2']
# ['Glover', 'visiting', 'Ethiopia', '3']
# ['Glow', 'cover', 'lot', '2']
# ['Glow', 'give', 'waye', '2']
# ['Glucosamine', 'played', 'role', '4']
# ['Glucose', 'are', 'examples', '3']
# ['Glucose', 'causeed', 'dilation', '4']
# ['Glucose', 'is', 'nutrient', '2']
# ['Glue', 'posed', 'problems', '2']
# ['guns', 'are', 'part', '2']
# ['Glutathione', 'protective', 'tissues', '2']
# ['Glutathione', 'require', 'selenium', '8']
# ['Gluten', 'is', 'form', '2']
# ['enteropathy', 'is', 'inability', '2']
# ['Glycation', 'impairments', 'bindingness', '2']
# ['Load', 'give', 'people', '2']
# ['Glycerin', 'is', 'onee', '6']
# ['Glycerin', 'is', 'sweetener', '2']
# ['acid', 'Diminishe', 'cohesion', '2']
# ['Maxwell', 'see', 'role', '2']
# ['Glyphs', 'is', 'symbols', '2']
# ['Gmail', 'Attachment', 'prevention', '2']
# ['Gmail', 'is', 'invitation', '3']
# ['Gmail', 'offer', 'lot', '2']
# ['Gmail', 'representation', 'service', '2']
# ['Gmail', 'useful', 'TLS', '3']
# ['Gmail', 'use', 'language', '5']
# ['Gmane', 'approve', 'application', '5']
# ['Movies', 'travel', 'world', '2']
# ['Gnostics', 'were', 'Christians', '3']
# ['Go', 'Know', 'Score', '2']
# ['Go', 'See', 'Us', '2']
# ['Go', 'be', 'family', '2']
# ['Go', 'is', 'city', '2']
# ['To', 'following', 'instructions', '2']
# ['Goa', 'is', 'loadstar', '2']
# ['Goal', 'Remember', 'goal', '3']
# ['Goal', 'is', 'Love', '3']
# ['4', 'Increase', 'amounts', '2']
# ['5', 'Stimulate', 'acquisition', '7']
# ['Seek', 'find', 'price', '2']
# ['Students', 'solve', 'stimulating', '2']
# ['Goals', 'Help', 'students', '3']
# ['Goals', 'Incorporate', 'use', '2']
# ['Goals', 'are', 'part', '5']
# ['Goals', 'give', 'students', '2']
# ['Goals', 'include', 'developmental', '16']
# ['Goals', 'make', 'listsings', '2']
# ['Goals', 'prepare', 'students', '5']
# ['Goals', 'put', 'Cherokee', '2']
# ['Goannas', 'are', 'typed', '2']
# ['Island', 'is', 'part', '3']
# ['Goats', 'eating', 'everything', '2']
# ['Goats', 'make', 'milk', '3']
# ['Gober', 'led', 'Rams', '6']
# ['Queen', 'writing', 'poems', '2']
# ['printing', 'is', 'waye', '2']
# ['God', "'s", 'waye', '2']
# ['God', "'s", 'wonder', '2']
# ['God', 'Bless', 'onee', '27']
# ['God', 'Bless', 'warrior', '2']
# ['God', 'Call', 'People', '3']
# ['God', 'Create', 'Universe', '2']
# ['God', 'Is', 'Good', '15']
# ['God', 'Know', 'desiree', '2']
# ['God', 'Rest', 'soul', '8']
# ['God', 'Sai', 'Jump', '2']
# ['God', 'Save', 'Queen', '9']
# ['God', 'accepted', 'appeal', '2']
# ['God', 'accomplished', 'somethingism', '2']
# ['God', 'accomplishe', 'redemptioner', '3']
# ['God', 'adoree', 'Him', '2']
# ['God', 'aid', 'husband', '2']
# ['God', 'allow', 'Noah', '4']
# ['God', 'allow', 'pestilence', '2']
# ['God', 'appointed', 'calendar', '2']
# ['God', 'are', 'everything', '2']
# ['God', 'ask', 'onee', '3']
# ['God', 'assume', 'blame', '2']
# ['God', 'awakened', 'fear', '2']
# ['God', 'back', 'Word', '2']
# ['God', 'based', 'length', '2']
# ['God', 'be', 'focused', '6']
# ['God', 'be', 'ruler', '2']
# ['God', 'beat', 'Cain', '4']
# ['God', 'becamee', 'man', '534']
# ['God', 'becamee', 'terrorism', '2']
# ['God', 'become', 'duality', '2']
# ['God', 'become', 'enemyes', '5']
# ['God', 'begetting', 'Christians', '2']
# ['God', 'blending', 'colors', '2']
# ['God', 'blessed', 'Africa', '41']
# ['God', 'blessed', 'Australia', '9']
# ['God', 'blessed', 'Decider', '2']
# ['God', 'blessed', 'Earth', '3']
# ['God', 'blessed', 'Esau', '2']
# ['God', 'blessed', 'Father', '4']
# ['God', 'blessed', 'Flag', '5']
# ['God', 'blessed', 'Rachelle', '2']
# ['God', 'blessed', 'Randy', '2']
# ['God', 'blessed', 'Smirnoff', '2']
# ['God', 'blessed', 'Staff', '2']
# ['God', 'blessed', 'Taiwan', '4']
# ['God', 'blessed', 'decisional', '8']
# ['God', 'blessed', 'editors', '6']
# ['God', 'blessed', 'firefighters', '2']
# ['God', 'blessed', 'generationer', '2']
# ['God', 'blessed', 'peace', '3']
# ['God', 'blessed', 'reformationism', '2']
# ['God', 'blessed', 'sinners', '2']
# ['God', 'bring', 'Ezekiel', '4']
# ['God', 'bring', 'children', '8']
# ['God', 'bring', 'creation', '3']
# ['God', 'bring', 'release', '3']
# ['God', 'bring', 'remnant', '3']
# ['God', 'bring', 'salvationism', '13']
# ['God', 'bring', 'storm', '2']
# ['God', 'brought', 'Son', '4']
# ['God', 'brought', 'destruction', '2']
# ['God', 'brought', 'healing', '5']
# ['God', 'brought', 'law', '5']
# ['God', 'building', 'hedge', '2']
# ['God', 'built', 'hill', '2']
# ['God', 'called', 'Ex', '2']
# ['God', 'called', 'Jews', '3']
# ['God', 'called', 'Servant', '3']
# ['God', 'called', 'person', '29']
# ['God', 'called', 'spade', '2']
# ['God', 'called', 'things', '24']
# ['God', 'cannot', 'sinful', '10']
# ['God', 'catch', 'men', '2']
# ['God', 'causeed', 'conversione', '2']
# ['God', 'changed', 'attitude', '10']
# ['God', 'changed', 'perspective', '3']
# ['God', 'chastened', 'people', '2']
# ['God', 'cherishe', 'partner', '3']
# ['God', 'choose', 'leaders', '2']
# ['God', 'cleared', 'confusional', '2']
# ['God', 'comes', 'rent', '2']
# ['God', 'comes', 'rescuees', '2']
# ['God', 'commanded', 'light', '13']
# ['God', 'commanded', 'mankind', '4']
# ['God', 'commanded', 'somethingism', '23']
# ['God', 'commanded', 'watersed', '5']
# ['God', 'conducts', 'people', '2']
# ['God', 'consideration', 'sinners', '2']
# ['God', 'consideration', 'son', '2']
# ['God', 'contain', 'causeed', '2']
# ['God', 'controlled', 'circumstances', '7']
# ['God', 'controlled', 'world', '51']
# ['God', 'create', 'Bohr', '8']
# ['God', 'create', 'blessing', '2']
# ['God', 'create', 'comforts', '2']
# ['God', 'create', 'disciplines', '3']
# ['God', 'create', 'fellowships', '3']
# ['God', 'create', 'home', '10']
# ['God', 'create', 'morality', '3']
# ['God', 'create', 'problems', '5']
# ['God', 'curse', 'national', '2']
# ['God', 'cutting', 'horn', '2']
# ['God', 'damn', 'Pulse', '2']
# ['God', 'damn', 'milk', '8']
# ['God', 'deck', 'Jesus', '2']
# ['God', 'delayed', 'answered', '2']
# ['God', 'deliverables', 'Israel', '52']
# ['God', 'deliverables', 'enemies', '2']
# ['God', 'deliverables', 'onee', '2']
# ['God', 'deliverables', 'substance', '2']
# ['God', 'demonstrate', 'sovereignty', '4']
# ['God', 'designate', 'formation', '2']
# ['God', 'desiree', 'glory', '2']
# ['God', 'desiree', 'kingdom', '2']
# ['God', 'destroyed', 'everything', '3']
# ['God', 'destroyed', 'soul', '2']
# ['God', 'devisee', 'plan', '2']
# ['God', 'did', 'healed', '2']
# ['God', 'divide', 'populationes', '2']
# ['God', 'does', 'making', '8']
# ['God', 'drew', 'people', '2']
# ['God', 'drowning', 'everything', '2']
# ['God', 'elevate', 'Moses', '2']
# ['God', 'endorse', 'divorcee', '3']
# ['God', 'established', 'law', '7']
# ['God', 'exalted', 'Redeemer', '3']
# ['God', 'exalted', 'horn', '2']
# ['God', 'exalteth', 'meeks', '6']
# ['God', 'exercise', 'providence', '2']
# ['God', 'exists', 'approaches', '2']
# ['God', 'expell', 'Adam', '21']
# ['God', 'experiencee', 'time', '5']
# ['God', 'explore', 'historyes', '2']
# ['God', 'fed', 'heart', '2']
# ['God', 'feeding', 'people', '6']
# ['God', 'finishe', 'Work', '2']
# ['God', 'fixees', 'carse', '3']
# ['God', 'following', 'Word', '3']
# ['God', 'forbidding', 'homosexuality', '2']
# ['God', 'forbidding', 'making', '9']
# ['God', 'forced', 'Jews', '2']
# ['God', 'forgive', 'laziness', '2']
# ['God', 'fulfill', 'symbolism', '2']
# ['God', 'gave', 'Hebrews', '4']
# ['God', 'gave', 'WORD', '2']
# ['God', 'gave', 'ability', '9']
# ['God', 'gave', 'life', '58']
# ['God', 'gave', 'man', '236']
# ['God', 'gave', 'sex', '2']
# ['God', 'gave', 'son', '86']
# ['God', 'gave', 'talented', '6']
# ['God', 'gave', 'voice', '4']
# ['God', 'get', 'wants', '2']
# ['God', 'give', 'advice', '3']
# ['God', 'give', 'discernment', '2']
# ['God', 'give', 'discipline', '2']
# ['God', 'give', 'doctrine', '3']
# ['God', 'given', 'chance', '2']
# ['God', 'given', 'responsibility', '2']
# ['God', 'grant', 'Zarathushtra', '2']
# ['God', 'grant', 'favour', '2']
# ['God', 'grant', 'power', '5']
# ['God', 'grant', 'wisdom', '12']
# ['God', 'guide', 'people', '17']
# ['God', 'has', 'approaching', '2']
# ['God', 'has', 'energy', '3']
# ['God', 'has', 'fishing', '2']
# ['God', 'has', 'gifts', '20']
# ['God', 'has', 'intentionally', '28']
# ['God', 'has', 'offer', '2']
# ['God', 'has', 'tendency', '6']
# ['God', 'has', 'trial', '3']
# ['God', 'has', 'victory', '10']
# ['God', 'had', 'obligation', '7']
# ['God', 'had', 'stock', '4']
# ['God', 'had', 'thing', '3']
# ['God', 'had', 'victory', '4']
# ['God', 'hanged', 'lot', '2']
# ['God', 'have', 'back', '2']
# ['God', 'have', 'gender', '3']
# ['God', 'have', 'influence', '3']
# ['God', 'have', 'religions', '2']
# ['God', 'healed', 'mother', '3']
# ['God', 'hears', 'PRAYER', '3']
# ['God', 'heard', 'sound', '3']
# ['God', 'help', 'Africa', '5']
# ['God', 'help', 'American', '6']
# ['God', 'help', 'breath', '2']
# ['God', 'help', 'trespasser', '2']
# ['God', 'hold', 'patent', '2']
# ['God', 'hold', 'revenge', '2']
# ['God', 'honor', 'requesting', '5']
# ['God', 'honor', 'setup', '2']
# ['God', 'implanted', 'ability', '3']
# ['God', 'increase', 'volume', '2']
# ['God', 'inflicted', 'wrath', '2']
# ['God', 'instigate', 'Sabbath', '2']
# ['God', 'institute', 'union', '2']
# ['God', 'interpretations', 'Word', '9']
# ['God', 'interrupt', 'thoughts', '2']
# ['God', 'introduced', 'number', '2']
# ['God', 'invents', 'psychology', '2']
# ['God', 'is', 'Author', '92']
# ['God', 'is', 'Divine', '8']
# ['God', 'is', 'Nation', '2']
# ['God', 'is', 'Seen', '3']
# ['God', 'is', 'adversary', '2']
# ['God', 'is', 'apprenticees', '4']
# ['God', 'is', 'blessedness', '4']
# ['God', 'is', 'bliss', '7']
# ['God', 'is', 'chump', '2']
# ['God', 'is', 'containerization', '2']
# ['God', 'is', 'dangerous', '2']
# ['God', 'is', 'determiner', '3']
# ['God', 'is', 'enigma', '2']
# ['God', 'is', 'fairytale', '2']
# ['God', 'is', 'homeboy', '2']
# ['God', 'is', 'illusionism', '20']
# ['God', 'is', 'island', '4']
# ['God', 'is', 'king', '99']
# ['God', 'is', 'mediatore', '2']
# ['God', 'is', 'memory', '2']
# ['God', 'is', 'mindfullness', '24']
# ['God', 'is', 'nature', '35']
# ['God', 'is', 'optional', '2']
# ['God', 'is', 'provider', '132']
# ['God', 'is', 'wafflers', '2']
# ['God', 'justified', 'believers', '2']
# ['God', 'keep', 'records', '3']
# ['God', 'knew', 'ingratitude', '2']
# ['God', 'knew', 'kind', '12']
# ['God', 'knew', 'need', '10']
# ['God', 'know', '4', '4']
# ['God', 'know', 'Life', '2']
# ['God', 'know', 'article', '2']
# ['God', 'know', 'citizens', '2']
# ['God', 'know', 'creatures', '5']
# ['God', 'know', 'disasters', '2']
# ['God', 'know', 'fact', '3']
# ['God', 'know', 'language', '3']
# ['God', 'know', 'mind', '9']
# ['God', 'know', 'sir', '2']
# ['God', 'know', 'situationally', '21']
# ['God', 'know', 'stresses', '3']
# ['God', 'know', 'values', '2']
# ['God', 'know', 'word', '2']
# ['God', 'lay', 'plan', '6']
# ['God', 'laid', 'messagees', '3']
# ['God', 'lead', 'children', '5']
# ['God', 'lead', 'creation', '2']
# ['God', 'lead', 'others', '2']
# ['God', 'led', 'family', '2']
# ['God', 'left', 'resting', '11']
# ['God', 'let', 'hopeful', '2']
# ['God', 'lighten', 'burden', '2']
# ['God', 'lost', 'place', '2']
# ['God', 'loved', 'Americans', '4']
# ['God', 'loved', 'everyone', '243']
# ['God', 'loved', 'humor', '7']
# ['God', 'loved', 'kids', '16']
# ['God', 'loved', 'outcasts', '2']
# ['God', 'loved', 'piety', '2']
# ['God', 'loved', 'waye', '4']
# ['God', 'made', 'MEN', '2']
# ['God', 'made', 'Man', '65']
# ['God', 'made', 'Woman', '4']
# ['God', 'made', 'honoring', '2']
# ['God', 'made', 'judgment', '2']
# ['God', 'made', 'law', '17']
# ['God', 'made', 'likeness', '3']
# ['God', 'made', 'loved', '6']
# ['God', 'made', 'parts', '2']
# ['God', 'made', 'sounds', '5']
# ['God', 'made', 'space', '148']
# ['God', 'magnify', 'Word', '2']
# ['God', 'maintained', 'faithfulness', '2']
# ['God', 'manifested', 'Rom', '2']
# ['God', 'manipulate', 'elementse', '2']
# ['God', 'meaning', 'injustice', '2']
# ['God', 'mendes', 'things', '2']
# ['God', 'multiplied', 'everything', '2']
# ['God', 'named', 'Obama', '2']
# ['God', 'neglect', 'gifts', '4']
# ['God', 'nod', 'heads', '3']
# ['God', 'offer', 'possibility', '6']
# ['God', 'offer', 'truth', '10']
# ['God', 'orchestrate', 'events', '9']
# ['God', 'order', 'Moses', '15']
# ['God', 'order', 'whaling', '2']
# ['God', 'overlooked', 'ignorance', '4']
# ['God', 'overthrew', 'tower', '2']
# ['God', 'owed', 'forgiveness', '3']
# ['God', 'owees', 'pardons', '2']
# ['God', 'penetrate', 'communityism', '2']
# ['God', 'permitted', 'pain', '2']
# ['God', 'permitted', 'somethingism', '8']
# ['God', 'place', 'Jesus', '2']
# ['God', 'poured', 'spirit', '12']
# ['God', 'pre-plan', 'raped', '3']
# ['God', 'precede', 'choice', '2']
# ['God', 'predestination', 'qualification', '2']
# ['God', 'predetermine', 'things', '4']
# ['God', 'prepare', 'plan', '4']
# ['God', 'proposeth', 'instance', '2']
# ['God', 'protective', 'loved', '5']
# ['God', 'prove', 'promisee', '2']
# ['God', 'provideed', 'onee', '3']
# ['God', 'put', 'Man', '2']
# ['God', 'put', 'enmity', '12']
# ['God', 'put', 'evil', '2']
# ['God', 'put', 'kind', '3']
# ['God', 'put', 'law', '9']
# ['God', 'put', 'understanding', '3']
# ['God', 'put', 'wall', '2']
# ['God', 'raised', 'onee', '2']
# ['God', 'reaching', 'heart', '2']
# ['God', 'reacheed', 'goal', '2']
# ['God', 'received', 'Glory', '2']
# ['God', 'redeems', 'faithfull', '2']
# ['God', 'rememberance', 'sinful', '10']
# ['God', 'remove', 'defect', '2']
# ['God', 'remove', 'sicknesse', '4']
# ['God', 'requirements', 'Israelites', '5']
# ['God', 'require', 'life', '5']
# ['God', 'require', 'preparedness', '4']
# ['God', 'resume', 'programs', '2']
# ['God', 'returns', 'people', '2']
# ['God', 'revealed', 'details', '6']
# ['God', 'revealed', 'essence', '2']
# ['God', 'revealed', 'reason', '2']
# ['God', 'revealed', 'understanding', '2']
# ['God', 'reward', 'onee', '2']
# ['God', 'satisfied', 'God', '3']
# ['God', 'save', 'countrye', '20']
# ['God', 'saw', 'faith', '10']
# ['God', 'see', 'hatred', '7']
# ['God', 'see', 'wickedness', '7']
# ['God', 'seeking', 'response', '2']
# ['God', 'selective', 'people', '4']
# ['God', 'send', 'Adam', '13']
# ['God', 'send', 'hell', '2']
# ['God', 'send', 'professor', '2']
# ['God', 'sent', 'encouragement', '2']
# ['God', 'sent', 'friends', '2']
# ['God', 'sent', 'home', '4']
# ['God', 'sent', 'verse', '7']
# ['God', 'set', 'kingdom', '11']
# ['God', 'shaped', 'Christians', '2']
# ['God', 'shaped', 'thinking', '4']
# ['God', 'show', 'Grace', '3']
# ['God', 'show', 'earth', '3']
# ['God', 'show', 'onee', '3']
# ['God', 'show', 'world', '6']
# ['God', 'shut', 'mouth', '2']
# ['God', 'smiting', 'kittens', '2']
# ['God', 'solve', 'problems', '21']
# ['God', 'sort', 'electioneering', '4']
# ['God', 'speak', 'spirit', '3']
# ['God', 'speak', 'truth', '38']
# ['God', 'speed', 'hour', '2']
# ['God', 'speed', 'right', '4']
# ['God', 'spoke', 'hearts', '5']
# ['God', 'stacks', 'deck', '2']
# ['God', 'state', 'daye', '2']
# ['God', 'strengthened', 'union', '3']
# ['God', 'suffered', 'earth', '4']
# ['God', 'take', 'faith', '3']
# ['God', 'take', 'fruit', '4']
# ['God', 'take', 'mercyful', '3']
# ['God', 'take', 'moments', '4']
# ['God', 'take', 'someone', '2']
# ['God', 'taught', 'Kabbalah', '3']
# ['God', 'taught', 'men', '3']
# ['God', 'testing', 'belief', '3']
# ['God', 'told', 'wind', '2']
# ['God', 'took', 'heart', '3']
# ['God', 'took', 'sincerity', '3']
# ['God', 'took', 'territory', '2']
# ['God', 'took', 'treatments', '2']
# ['God', 'treated', 'others', '2']
# ['God', 'trick', 'devil', '3']
# ['God', 'turn', 'faucet', '4']
# ['God', 'turn', 'fire', '2']
# ['God', 'turn', 'focused', '2']
# ['God', 'turn', 'watersed', '7']
# ['God', 'useful', 'TESOL', '2']
# ['God', 'useful', 'humilitye', '2']
# ['God', 'useful', 'ribs', '2']
# ['God', 'useful', 'signed', '4']
# ['God', 'use', 'Bible', '7']
# ['God', 'use', 'heat', '7']
# ['God', 'use', 'marriage', '8']
# ['God', 'use', 'woman', '3']
# ['God', 'utterance', 'ban', '2']
# ['God', 'view', 'blood', '3']
# ['God', 'vindicated', 'Joshua', '2']
# ['God', 'violate', 'laws', '25']
# ['God', 'violate', 'pledgee', '2']
# ['God', 'was', 'Southerner', '2']
# ['God', 'was', 'blessing', '9']
# ['God', 'was', 'centre', '4']
# ['God', 'was', 'designer', '3']
# ['God', 'was', 'engineer', '2']
# ['God', 'was', 'finished', '3']
# ['God', 'was', 'instrument', '2']
# ['God', 'wanted', 'dreams', '3']
# ['God', 'wanted', 'fetuses', '2']
# ['God', 'wanted', 'loads', '2']
# ['God', 'wanted', 'person', '15']
# ['God', 'wanted', 'religions', '15']
# ['God', 'wanted', 'soul', '8']
# ['God', 'wanted', 'things', '13']
# ['God', 'warns', 'Jews', '3']
# ['God', 'washed', 'pain', '4']
# ['God', 'were', 'Father', '53']
# ['God', 'were', 'nigh', '2']
# ['God', 'whispered', 'named', '4']
# ['God', 'whispered', 'words', '2']

# %% [markdown]
# Another trick we can do is to look for other database and do a cross filtering. So for example,
# you can use freebase dataset as a filter. Here is a small database provided by Professor Tom Mitchell.
# This database contains the most frequent verbs he found during data collecting. If we use this as a filter,
# then we'll get the following result.

# %%
database=set()
with open('verbs484.txt','r') as txt:
    for line in txt:
        lines=line.split()
        database.add(lines[0])
        if len(lines)>1:
            #In the verbs484.txt, some rows only have one column.
            database.add(lines[1])  

with open('tutorial_data.txt','r') as txt:
    for line in txt:
        lines=line.split()
        if lines[1] not in database:
            #If the verb does not appear in the dataset.
            continue
        print(lines)
# Out:
# ['Foyle', 'cost', 'lot', '1']
# ['Fr', 'ate', 'state', '1']
# ['Peter', 'hold', 'book', '1']
# ['Tony', 'allow', 'family', '1']
# ['Geometry', 'contain', 'wealth', '1']
# ['patterns', 'filled', 'screen', '2']
# ['Fragos', 'scream', 'warning', '1']
# ['room', 'allow', 'marye', '1']
# ['Fragrant', 'greeted', 'nose', '1']
# ['info', 'contain', 'collectiones', '1']
# ['Framers', 'built', 'Constitution', '1']
# ['Frames', 'hold', 'objects', '1']
# ['Framework', 'trace', 'destruction', '1']
# ['3.5', 'contain', 'number', '18']
# ['Source', 'forced', 'brilliance', '1']
# ['Tips', 'look', 'days', '1']
# ['Fran', 'manage', 'place', '1']
# ['France', 'broke', 'terms', '1']
# ['France', 'claim', 'victory', '1']
# ['France', 'commanded', 'divisional', '1']
# ['France', 'employed', 'mixture', '1']
# ['France', 'spend', 'onee', '2']
# ['France', 'won', 'battle', '1']
# ['France', 'won', 'prize', '1']
# ["'s", 'reflected', 'perfectionism', '1']
# ['Frances', 'answered', 'tailored', '1']
# ['Frances', 'felt', 'eyesed', '1']
# ['Frances', 'learn', 'code', '2']
# ['Frances', 'loved', 'cats', '1']
# ['Frances', 'milk', 'cows', '1']
# ['Brandon', 'married', 'Master', '1']
# ['Payne', 'trace', 'heritage', '1']
# ['Franchot', 'loved', 'women', '1']
# ['Francie', 'lost', 'count', '1']
# ['Tate', 'told', 'investigators', '1']
# ['Francis', 'attack', 'France', '7']
# ['Francis', 'attended', 'number', '1']
# ['Francis', 'felt', 'cowards', '1']
# ['Francis', 'knock', 'lights', '1']
# ['Francis', 'loved', 'Ben', '1']
# ['Francis', 'married', 'daughter', '1']
# ['Francis', 'met', 'Sultan', '2']
# ['Ayers', 'built', 'cabin', '1']
# ['Barker', 'led', 'troopses', '1']
# ['junior', 'ran', 'recorded', '1']
# ['Franciscans', 'prepare', 'materials', '1']
# ['Garcia', 'led', 'Jazz', '1']
# ['Franco', 'pay', 'attention', '1']
# ['Prati', 'announce', 'launching', '1']
# ['Frank', 'closed', 'catalog', '1']
# ['Frank', 'earned', 'doctorate', '3']
# ['Frank', 'fold', 'arms', '1']
# ['Frank', 'get', 'home', '1']
# ['Frank', 'lose', 'interesting', '1']
# ['Frank', 'met', 'Rosa', '1']
# ['Frank', 'smoke', 'cigars', '1']
# ['Alvarado', 'rode', 'winners', '1']
# ['Belknap', 'drank', 'alcohol', '2']
# ['Lloyd', 'attended', 'Kindergarten', '1']
# ['Luke', 'lost', 'life', '1']
# ['Nugent', 'spent', 'life', '1']
# ['Oz', 'played', 'Shopkeeper', '1']
# ['Reese', 'hold', 'onee', '1']
# ['Rich', 'attack', 'Conservatism', '17']
# ['Schwartz', 'closed', '5', '1']
# ['Warner', 'closed', 'concerts', '2']
# ['de', 'wrote', 'bookworm', '1']
# ['Franken', 'raised', 'hands', '2']
# ['Franklin', 'hold', 'B.A.', '1']
# ['Franklin', 'led', 'waye', '2']
# ['Franklin', 'prepare', 'foundationalism', '1']
# ['Delano', 'announced', 'decisional', '1']
# ['apatite', 'contain', 'chlorine', '1']
# ['Frankly', 'deserve', 'attention', '2']
# ['Frankly', 'get', 'chance', '1']
# ['Frankly', 'look', 'fun', '4']
# ['Frankly', 'thought', 'carnage', '1']
# ['Franks', 'spent', 'bulk', '1']
# ['Franks', 'stop', 'Moors', '2']
# ['mayor', 'built', 'castle', '4']
# ['Frannie', 'feel', 'sanity', '1']
# ['Franz', 'loved', 'motorbike', '1']
# ['Franz', 'played', 'guitar', '1']
# ['Ferdinand', 'married', 'Sophie', '18']
# ['Franzen', 'dropped', 'onee', '1']
# ['Fraport', 'manage', 'airports', '1']
# ['Fraser', 'trace', 'developmental', '1']
# ['Fraud', 'pay', 'online', '1']
# ['Sciences', 'won', 'fans', '2']
# ['family', 'sold', 'business', '1']
# ['Frazer', 'raised', 'family', '1']
# ['Fred', 'bet', 'savings', '1']
# ['Fred', 'employed', 'staff', '1']
# ['Fred', 'hung', 'heads', '1']
# ['Fred', 'invited', 'Ray', '1']
# ['Fred', 'killed', 'two', '1']
# ['Fred', 'met', 'cheers', '2']
# ['Fred', 'played', 'guitar', '1']
# ['Fred', 'rose', 'hands', '1']
# ['Fred', 'shared', 'examples', '1']
# ['Fred', 'shut', 'mind', '1']
# ['Fred', 'taught', 'methods', '1']
# ['Fred', 'told', 'Cordelia', '1']
# ['Fred', 'turn', 'pressure', '1']
# ['Abrahams', 'wrote', 'reported', '1']
# ['Brown', 'knock', 'pair', '6']
# ['Hall', 'filled', 'form', '1']
# ['Krueger', 'hit', 'air', '1']
# ['McAllister', 'thought', 'ideas', '1']
# ['Myer', 'pick', 'juice', '1']
# ['Freda', 'blink', 'tearse', '2']
# ['Band', 'played', 'mixed', '2']
# ['Freddie', 'held', 'positione', '1']
# ['Freddy', 'drove', 'van', '1']
# ['Freddy', 'hid', 'belly', '1']
# ['Freddy', 'hold', 'hands', '1']
# ['Freddy', 'stop', 'van', '1']
# ['Freddy', 'turn', 'TV', '1']
# ['Freddy', 'wrote', 'lyrics', '2']
# ['Mercury', 'sang', 'song', '1']
# ['Napster', 'announced', 'debut', '1']
# ['Frederic', 'felt', 'called', '1']
# ['Frederic', 'hold', 'Master', '1']
# ['Frederic', 'see', 'bevy', '1']
# ['Frederic', 'spend', 'time', '1']
# ['Frederick', 'loaded', 'lunch', '1']
# ['Frederick', 'press', 'worked', '1']
# ['Frederick', 'spent', 'morninge', '2']
# ["'s", 'lie', 'implementation', '1']
# ['Free', 'get', 'strategy', '1']
# ['Free', 'hit', 'counter', '28']
# ['Free', 'move', 'world', '1']
# ['Free', 'pick', 'monster', '1']
# ['Free', 'sold', 'worked', '1']
# ['Free', 'turn', 'ideas', '1']
# ['Free', 'worked', 'need', '2']
# ['Atkins', 'allow', 'listed', '3']
# ['Banquet', 'attended', 'end', '1']
# ['Derry', 'met', 'countryside', '1']
# ['Download', 'filled', 'gaps', '1']
# ['Download', 'learn', 'Urdu', '1']
# ['Emulator', 'answered', 'Mr', '1']
# ['Groups', 'loved', 'FREE', '1']
# ['Hip', 'hop', 'lessons', '1']
# ['Hit', 'hit', 'counter', '1']
# ['Legal', 'answered', 'Cap', '1']
# ['Mom', 'stir', 'multitude', '1']
# ['PayPal', 'nest', 'Protection', '1']
# ['Polyphonic', 'get', 'number', '12']
# ['Sms', 'said', 'elder', '1']
# ['Sony', 'filled', 'link', '2']
# ['Stampin', 'see', 'charts', '1']
# ['Tibet', 'told', 'Standard', '1']
# ['White', 'lose', 'weight', '1']
# ['gaming', 'deserve', 'reputation', '2']
# ['poker', 'win', 'prize', '1']
# ['press', 'get', 'beating', '2']
# ['real', 'lead', 'Unique', '6']
# ['shipping', 'punch', 'tin', '1']
# ['signed', 'win', 'moneyer', '1']
# ['versions', 'allow', 'maximum', '2']
# ['MX', 'turn', 'artwork', '1']
# ['Freedom', 'broadcast', 'alerted', '1']
# ['Freedom', 'exercise', 'choice', '1']
# ['Freedom', 'get', 'copy', '2']
# ['Freedom', 'lick', 'blood', '2']
# ['Freedom', 'permitted', 'ubiquity', '1']
# ['Press', 'played', 'host', '1']
# ['cannon', 'lead', 'stores', '1']
# ['Freel', 'get', 'chances', '1']
# ['illustrator', 'forced', 'retirement', '1']
# ['registeration', 'get', 'projects', '1']
# ['Freely', 'shared', 'stories', '1']
# ['Freeman', 'trace', 'historyes', '2']
# ['Freemans', 'lost', 'daughter', '1']
# ['Freep', 'told', 'DFT', '1']
# ['biography', 'ran', 'hunting', '1']
# ['Freida', 'learn', 'ventriloquism', '1']
# ['trains', 'hold', 'horn', '1']
# ['Fremont', 'attack', 'Sylvia', '1']
# ['Fremont', 'held', 'court', '1']
# ['Fremont', 'won', 'level', '2']
# ['French', 'ate', 'foods', '2']
# ['French', 'claim', 'credit', '1']
# ['French', 'claim', 'successful', '1']
# ['French', 'destroyed', 'Rastatt', '1']
# ['French', 'destroyed', 'dockyard', '1']
# ['French', 'destroyed', 'temple', '1']
# ['French', 'disarmed', 'warships', '1']
# ['French', 'drew', 'pictures', '1']
# ['French', 'lost', 'concentration', '1']
# ['French', 'loved', 'Paris', '13']
# ['French', 'turn', 'Winchester', '1']
# ['French', 'wrote', 'addresses', '1']
# ['Acadians', 'settled', 'area', '1']
# ['Battalion', 'threw', 'waving', '1']
# ['Empire', 'led', 'America', '1']
# ['Headquarters', 'paid', 'attention', '1']
# ['Open', 'broke', 'Russian', '1']
# ['Resistance', 'get', 'Ark', '1']
# ['Revolution', 'open', 'windows', '1']
# ['capitale', 'won', 'positione', '1']
# ['city', 'claim', 'Islam', '3']
# ['classical', 'reflected', 'prosody', '1']
# ['fleets', 'prevent', 'Britain', '1']
# ['friese', 'caught', 'eyesed', '1']
# ['generalist', 'told', 'audience', '1']
# ['governmental', 'ban', 'use', '1']
# ['masters', 'flow', 'flowers', '1']
# ['navy', 'get', 'educationally', '1']
# ['people', 'closed', 'doors', '1']
# ['people', 'greeted', 'Americans', '1']
# ['platoons', 'held', 'companye', '1']
# ['police', 'cleared', 'docks', '1']
# ['presidente', 'announce', 'resumption', '6']
# ['ski', 'attracted', 'variety', '1']
# ['soldiers', 'dance', 'groups', '1']
# ['sports', 'announced', 'establishment', '1']
# ['wanted', 'get', 'unemployment', '1']
# ['Frenchman', 'bit', 'lipse', '1']
# ['Frenchman', 'lose', 'battle', '1']
# ['cleaning', 'extended', 'life', '1']
# ['feedback', 'allow', 'students', '1']
# ['travelers', 'earned', 'credit', '1']
# ['audience', 'shared', 'stages', '1']
# ['van', 'travel', 'waye', '1']
# ['Fresh', 'pick', 'papayas', '1']
# ['Fresh', 'twist', 'two', '1']
# ['Bee', 'contain', 'protein', '1']
# ['blood', 'stain', 'wraps', '1']
# ['flowers', 'attracted', 'spiritseers', '1']
# ['ingredients', 'squeeze', 'juice', '1']
# ['produce', 'lose', 'nutrients', '2']
# ['sites', 'get', 'traffic', '1']
# ['Freshly', 'killed', 'baiting', '1']
# ['Freshly', 'washed', 'apples', '1']
# ['Bonnie', 'led', 'Clippers', '1']
# ['Mandy', 'attended', 'meeting', '1']
# ['Megan', 'earned', 'honor', '3']
# ['Rachel', 'drive', 'lane', '1']
# ['Stephanie', 'led', 'waye', '1']
# ['Tom', 'led', 'team', '1']
# ['point', 'lead', 'team', '1']
# ['Volleyball', 'hit', 'ball', '1']
# ['Fretting', 'peel', 'coversation', '1']
# ['Freud', 'employed', 'lot', '1']
# ['Freud', 'extended', 'models', '1']
# ['Freud', 'met', 'resistance', '1']
# ['Freud', 'see', 'connectionism', '1']
# ['Freud', 'turn', 'metaphor', '1']
# ['Freund', 'phone', 'Mr', '1']
# ['Freya', 'get', 'change', '1']
# ['Freya', 'open', 'eyesed', '1']
# ['Fri', 'spent', 'daye', '2']
# ['Friars', 'raised', 'recorded', '1']
# ['wearing', 'played', 'role', '3']
# ['Friday', 'allow', 'time', '1']
# ['Friday', 'closed', 'stores', '1']
# ['Friday', 'dance', 'music', '1']
# ['Friday', 'get', 'ideas', '1']
# ['Friday', 'get', 'two', '2']
# ['Friday', 'heard', 'kind', '2']
# ['Friday', 'hold', 'keyes', '1']
# ['Friday', 'open', 'bag', '1']
# ['Friday', 'see', 'release', '1']
# ["'s", 'announced', 'additionally', '1']
# ['eveninger', 'met', 'Jag', '1']
# ['morninge', 'dropped', 'car', '1']
# ['night', 'scorched', '800', '2']
# ['night', 'stop', 'car', '1']
# ['Fridays', 'won', 'competition', '1']
# ['Friedberg', 'spend', 'time', '1']
# ['Friedman', 'challenge', 'view', '1']
# ['Friedman', 'spend', 'time', '4']
# ['Hoelderlin', 'wrote', 'onee', '1']
# ['Nietzche', 'sold', 'birthright', '1']
# ['Friend', 'get', 'certificate', '1']
# ['Friend', 'led', 'classes', '1']
# ['Friend', 'raise', 'issue', '2']
# ['Description', 'boast', 'curves', '1']
# ['Friendly', 'smile', 'coffee', '2']
# ['Friends', 'allow', 'period', '1']
# ['Friends', 'arranged', 'release', '1']
# ['Friends', 'extended', 'family', '1']
# ['Friends', 'hold', 'vigil', '1']
# ['Friends', 'manage', 'Friends', '1']
# ['Friends', 'pay', 'respects', '8']
# ['Friends', 'played', 'numbers', '4']
# ['Friends', 'repair', 'lights', '1']
# ['Friends', 'tell', 'secrets', '2']
# ['Friends', 'wrote', 'letters', '3']
# ['heads', 'sit', 'medicine', '1']
# ['movies', 'packed', 'gearing', '1']
# ['Friendster', 'stop', 'developmental', '1']
# ['Frightened', 'refuse', 'requesting', '1']
# ['Frisby', 'get', 'ride', '1']
# ['Frisby', 'won', 'Newbery', '2']
# ['Jackson', 'dropped', 'ball', '1']
# ['Fritz', 'tore', 'car', '1']
# ['Frodo', 'felt', 'step', '1']
# ['Frodo', 'rub', 'cheeks', '1']
# ['Front', 'hold', 'place', '1']
# ['Front', 'knit', 'details', '1']
# ['Desk', 'answered', 'telephone', '1']
# ['flaps', 'zip', 'pocket', '4']
# ['page', 'contain', 'linkse', '1']
# ['Explorer', 'manage', 'organizationally', '1']
# ['Explorer', 'open', 'web', '1']
# ['web', 'worked', 'matter', '4']
# ['justice', 'replaced', 'rules', '1']
# ['Chris', 'reflected', 'somberness', '1']
# ['Frost', 'dropped', 'spot', '1']
# ['Frost', 'pay', 'tributee', '1']
# ['Frost', 'see', 'recipee', '2']
# ['Frosting', 'chopped', 'water', '1']
# ['Frosty', 'get', 'shots', '1']
# ['Frosty', 'loved', 'attention', '2']
# ["'s", 'live', 'resting', '1']
# ['Dean', 'thought', 'moments', '1']
# ['Frozen', 'move', 'heads', '1']
# ['Sections', 'avoid', 'need', '1']
# ['Fruit', 'dried', 'fruit', '4']
# ['Fruitcake', 'dropped', 'arms', '1']
# ['business', 'lose', 'moneyer', '1']
# ['Fruits', 'contain', 'variety', '2']
# ['Fruits', 'feel', 'pain', '1']
# ['Frustrated', 'closed', 'negotiation', '1']
# ['Frustrated', 'forced', 'resignation', '1']
# ['Frustrated', 'poured', 'hearts', '1']
# ['Discount', 'allow', 'site', '1']
# ['Fuchs', 'sang', 'Klingsor', '1']
# ['carse', 'hit', 'road', '2']
# ['Fugi', 'threw', 'salt', '1']
# ['Fuhrman', 'sell', 'products', '1']
# ['Fujimori', 'lost', 'hearing', '1']
# ['Fujitsu', 'see', 'need', '1']
# ['Fujitsu', 'sold', 'controlled', '1']
# ['Fukuda', 'met', 'requirementes', '1']
# ['Scholar', 'hold', 'B.A.', '1']
# ['Full', 'get', 'dancing', '1']
# ['Full', 'reflected', 'mysteries', '1']
# ['Coverage', 'twist', 'knife', '1']
# ['Description', 'loved', 'flexibility', '1']
# ['Pc', 'said', 'side', '1']
# ['Service', 'sell', 'rate', '1']
# ['Speed', 'live', 'hobbit', '1']
# ['Story', 'trust', 'polls', '2']
# ['Story', 'announce', 'engagement', '1']
# ['leather', 'raised', 'bands', '1']
# ['listed', 'contain', 'categories', '1']
# ['storyes', 'open', 'Saturday', '1']
# ['faculty', 'teach', 'minority', '1']
# ['Fuller', 'held', 'patent', '1']
# ['Fuller', 'hold', 'vision', '6']
# ['Fuller', 'led', 'turnaround', '1']
# ['Fullmer', 'chase', 'Benvenuti', '1']
# ['Fully', 'applauded', 'decisional', '1']
# ['adjustable', 'extended', 'driver', '1']
# ['updated', 'contain', 'informationally', '2']
# ['Fulton', 'wrote', 'replye', '2']
# ['Fun', 'allow', 'kids', '1']
# ['Fun', 'get', 'Post-It', '1']
# ['Fun', 'greeted', '05', '1']
# ['Fun', 'look', 'readers', '1']
# ['Funambol', 'balance', 'needs', '1']
# ['content', 'told', 'Shacknews', '1']
# ['Functional', 'plan', 'obsolescence', '1']
# ['Acknowledgement', 'contain', 'date', '2']
# ['tests', 'filled', 'confidence', '1']
# ['Fund', 'encourage', 'research', '2']
# ['Fund', 'pull', 'menu', '1']
# ['Houses', 'get', 'iPhone', '5']
# ['Muslims', 'fear', 'Other', '1']
# ['Fundamentalists', 'break', 'law', '1']
# ['Fundamentals', 'lay', 'process', '1']
# ['Fundamentals', 'wish', 'claim', '1']
# ['programs', 'see', 'Work', '1']
# ['Funding', 'prevent', 'Faculty', '1']
# ['Funding', 'reflected', 'emergence', '1']
# ['sourcese', 'drive', 'separatione', '1']
# ['Funds', 'hold', 'personnel', '1']
# ['Directors', 'arrange', 'funeral', '3']
# ['Home', 'laid', 'crossways', '1']
# ['Fung', 'told', 'audience', '1']
# ['Funk', 'wrestled', 'likes', '1']
# ['Funny', 'claim', 'liability', '1']
# ['Funny', 'get', 'quality', '2']
# ['Funny', 'thought', 'justificatione', '1']
# ['Funny', 'wrote', 'histories', '1']
# ['Furious', 'blow', 'steam', '1']
# ['Furnish', 'lay', 'hearth', '1']
# ['Enhance', 'remove', 'matching', '1']
# ['The', 'deserve', 'place', '1']
# ['Fury', 'lost', 'eyee', '1']
# ['Fury', 'pull', 'cigars', '1']
# ['4', 'move', 'framework', '1']
# ['LLT', 'hold', 'end', '2']
# ['Futhermore', 'contain', 'lyrics', '1']
# ['Future', 'built', 'bookstore', '1']
# ['Future', 'held', 'meeting', '1']
# ['Future', 'plan', 'goal', '1']
# ['G', 'loved', 'skateboarding', '1']
# ['G', 'see', 'IV', '1']
# ['G', 'worked', 'waye', '1']
# ['G', 'wrote', 'book', '1']
# ['Index', 'encourage', 'developmental', '1']
# ['delivery', 'get', 'playful', '1']
# ["G'Kar", 'stop', 'Takashima', '2']
# ['Form', 'get', 'copy', '1']
# ['G-Men', 'led', 'NFL', '2']
# ['family', 'earned', 'moneyer', '3']
# ['GAM', 'claim', 'responsibility', '1']
# ['GAMES', 'deserve', 'kudos', '1']
# ['GAO', 'lost', 'case', '1']
# ['GAO', 'raised', 'number', '1']
# ['GB', 'felt', 'Bourdon', '1']
# ['GC', 'packed', 'stuff', '1']
# ['workshop', 'encourage', 'submission', '1']
# ['GDP', 'treated', 'depletion', '2']
# ['GE', 'allow', 'audience', '1']
# ['GE', 'manage', 'variety', '1']
# ['GE', 'open', 'number', '1']
# ['credentialling', 'open', 'doors', '1']
# ['GEDCOM', 'filled', 'forms', '1']
# ['GEF', 'allow', 'developer', '4']
# ['GEO', 'observe', 'distribution', '1']
# ['GF', 'destroyed', 'career', '1']
# ['GF', 'loved', 'cartoon', '1']
# ["'s", 'reflected', 'commitment', '2']
# ['Far', 'won', 'prize', '1']
# ['image', 'contain', 'colors', '796']
# ['Chesterton', 'told', 'storyes', '1']
# ['GL', 'get', 'daubing', '2']
# ['special', 'paid', 'attention', '1']
# ['GLS', 'decorate', 'house', '1']
# ['GLS', 'order', 'lobsters', '1']
# ['GM', 'led', 'Rangers', '1']
# ['GM', 'lost', 'sighting', '4']
# ['GM', 'replace', 'Musial', '1']
# ['GM', 'sell', 'Spark', '1']
# ['Norwood', 'hit', 'jackpot', '1']
# ['GMC', 'answered', 'called', '2']
# ["'s", 'get', 'lot', '1']
# ['GNIS', 'allow', 'use', '1']
# ['FDL', 'contain', 'statement', '8']
# ['GO', 'turn', 'operatore', '2']
# ['GOB', 'deserve', 'glory', '2']
# ['GOD', 'employed', 'shepherd', '1']
# ['GOD', 'get', 'glory', '1']
# ['GOD', 'told', 'Eve', '2']
# ['WILL', 'lay', 'hands', '1']
# ['GOLD', 'contain', 'news', '1']
# ['DAY', 'cleared', 'waye', '1']
# ['MAN', 'loved', 'surface', '1']
# ['Factual', 'rub', 'maps', '1']
# ['GOP', 'hate', 'Clinton', '1']
# ['GOP', 'led', 'Democrats', '1']
# ['GOP', 'lost', 'edge', '2']
# ['GOP', 'lost', 'positione', '1']
# ['GOP', 'manipulate', 'process', '1']
# ['GOSSIP', 'calculate', 'P-value', '1']
# ['team', 'hit', 'beach', '2']
# ["'s", 'reflected', 'ability', '1']
# ['GPAC', 'met', 'months', '1']
# ['Table', 'contain', 'informationally', '1']
# ['GPL', 'preserve', 'traditionally', '1']
# ['GPM', 'allow', 'borrower', '1']
# ['PowerPoint', 'see', 'pictures', '1']
# ['system', 'worked', 'location', '2']
# ["'s", 'lost', 'backbone', '2']
# ['PLAN', 'hold', 'party', '1']
# ['SHIPS', 'tell', 'onee', '2']
# ['challenge', 'shared', 'concerning', '2']
# ['protocol', 'contain', 'stages', '1']
# ['GSH', 'cleared', 'brain', '1']
# ['GTD', 'treated', 'tasks', '1']
# ['GTE', 'sold', 'majority', '1']
# ['GUI', 'allow', 'user', '13']
# ['GUI', 'contain', 'listed', '4']
# ['GUI', 'loaded', 'filed', '6']
# ['usinger', 'dropped', 'elementse', '2']
# ['GV', 'get', 'editors', '1']
# ['Uncle', 'loved', 'article', '2']
# ['GWAP', 'allow', 'persistence', '2']
# ['GWB', 'open', 'mouth', '1']
# ['Horn', 'see', 'page', '1']
# ['Trombone', 'see', 'page', '1']
# ['Gaara', 'killed', 'computerized', '1']
# ['Gabe', 'heard', 'tone', '1']
# ['Gabe', 'open', 'eyesed', '1']
# ['Gabe', 'pull', 'cameras', '1']
# ["'s", 'prevent', 'denial', '2']
# ['Gabi', 'wrote', 'articles', '1']
# ['Gable', 'played', 'convict', '1']
# ['Gable', 'wrote', 'legacy', '2']
# ['Gabor', 'waste', 'time', '1']
# ['Gabriel', 'announced', 'Mary', '1']
# ['Gabriel', 'hold', 'S.M.', '1']
# ['Gabriel', 'spot', 'demon', '1']
# ['Gabriella', 'clean', 'area', '1']
# ['Gabriella', 'forced', 'wings', '1']
# ['Gabrielle', 'broke', 'seal', '1']
# ['Gabrielle', 'held', 'Spirit', '1']
# ['Gabrielle', 'speak', 'English', '1']
# ['Gabrielle', 'threw', 'staff', '2']
# ['tribes', 'lead', 'goat', '1']
# ['Gaels', 'speak', 'Highlanders', '1']
# ['Gage', 'felt', 'somethingism', '1']
# ['Gage', 'loved', 'Grinch', '1']
# ['Gail', 'ate', 'lunch', '1']
# ['Gail', 'earned', 'MS', '1']
# ['Gail', 'met', 'stranger', '1']
# ['Levitt', 'open', 'doors', '2']
# ['strength', 'lose', 'weight', '1']
# ['Gainer', 'lose', 'weight', '1']
# ['credibility', 'challenge', 'assessment', '1']
# ['Gaius', 'raised', 'eyebrows', '1']
# ['Gal', 'lead', 'band', '1']
# ['Gala', 'closed', 'eyesed', '1']
# ['Home', 'live', 'life', '1']
# ['Galadriel', 'possess', 'onee', '2']
# ['Galadriel', 'turn', 'hands', '1']
# ['Galatians', 'obey', 'warning', '2']
# ['Galbraith', 'dance', 'Histoire', '1']
# ['Galbraith', 'trace', 'descent', '1']
# ['Galen', 'felt', 'use', '1']
# ['Fox', 'paid', 'price', '1']
# ['Galeon', 'raise', 'bars', '2']
# ['Galilee', 'ran', 'lake', '4']
# ['Galileo', 'heard', 'device', '1']
# ['man', 'served', 'time', '1']
# ['Galland', 'drew', 'Thousand', '1']
# ['History', 'travel', 'globe', '1']
# ['Gallery', 'closed', 'Thursdays', '1']
# ['Gallery', 'see', 'versions', '1']
# ['emerald', 'hold', 'mixture', '2']
# ['Galli', 'smile', 'thing', '1']
# ['Galliano', 'turn', 'back', '1']
# ['Gallienus', 'order', 'persecution', '9']
# ['Galton', 'attended', 'Cambridge', '1']
# ['Galton', 'extended', 'logic', '1']
# ['County', 'attended', 'fundraiser', '1']
# ['Fire', 'see', 'linkse', '1']
# ['New', 'loved', 'Aileen', '1']
# ['Tries', 'get', 'Comeuppance', '1']
# ['Gamble', 'raise', 'stakes', '1']
# ['Gambler', 'loved', 'people', '2']
# ['Gambler', 'won', 'everything', '1']
# ['Gambling', 'led', 'group', '1']
# ['interests', 'tap', 'fever', '1']
# ['Game', 'encourage', 'players', '1']
# ['Game', 'get', 'practice', '1']
# ['Game', 'played', 'graphics', '1']
# ['Game', 'stood', 'chance', '1']
# ['Game', 'win', 'nothingness', '4']
# ['Guy', 'loved', 'games', '2']
# ['Photos', 'worked', 'Jan', '1']
# ['Show', 'teach', 'classes', '2']
# ['The', 'allow', 'players', '1']
# ['birds', 'preserve', '34', '1']
# ['onee', 'played', 'Smithville', '1']
# ['onee', 'look', 'onee', '1']
# ['GameStop', 'lost', 'opportunity', '1']
# ['Enchanted', 'tell', 'storyes', '1']
# ['centers', 'gather', 'trade', '1']
# ['Games', 'served', 'variety', '1']
# ['News', 'bet', 'tips', '1']
# ['windows', 'allow', 'adjustment', '1']
# ['Gandalf', 'met', 'eyesed', '1']
# ['Gandalf', 'said', 'nothingness', '3']
# ['Gandhi', 'employed', 'form', '2']
# ['Gandhi', 'led', 'group', '1']
# ['Gandhi', 'married', 'Kasturba', '5']
# ['Green', 'threw', 'tons', '1']
# ['Ganges', 'see', 'Ganges', '2']
# ['Ganguly', 'led', 'waye', '1']
# ['Ganguly', 'stood', 'ground', '2']
# ['Ganymede', 'served', 'godse', '1']
# ['Ganz', 'led', 'students', '1']
# ['Gar', 'hit', 'luring', '2']
# ['Opener', 'said', 'guide', '1']
# ['Tile', 'calculate', 'materials', '2']
# ['Garbage', 'pick', 'crew', '2']
# ['Garbage', 'tumble', 'surface', '1']
# ['5', 'move', 'heads', '1']
# ['Garbo', 'hate', 'performance', '3']
# ['Garcia', 'closed', 'round', '1']
# ['Garcia', 'drive', 'three', '1']
# ['Garcia', 'hold', 'arms', '1']
# ['Garcia', 'pull', 'handguns', '1']
# ['Gard', 'wrote', 'memoirs', '1']
# ['Nizoral', 'hold', 'Pilgrimage', '1']
# ['Party', 'see', 'picturees', '1']
# ['The', 'contain', 'library', '1']
# ['Gardens', 'contain', 'number', '2']
# ['Gardens', 'drew', 'number', '1']
# ['Gardiner', 'break', 'handicapped', '1']
# ['Gardiner', 'wrote', 'reported', '1']
# ['Howland', 'won', 'awards', '1']
# ['Gardner', 'exploded', 'myth', '1']
# ['Gardner', 'loved', 'painting', '1']
# ['Gardner', 'tell', 'storyes', '1']
# ['Gardners', 'turn', 'house', '2']
# ['Baker', 'led', 'Lakers', '1']
# ['Garfield', 'attack', 'Confederates', '1']
# ['Garfield', 'fell', 'victim', '1']
# ['Garg', 'plan', 'words', '1']
# ['Gargoyles', 'played', 'Zelda', '1']
# ['Garibaldi', 'announced', 'dictatorship', '5']
# ['Garibaldi', 'attack', 'Messina', '11']
# ['Garland', 'told', 'AP', '2']
# ['Valley', 'contain', 'fat', '1']
# ['mixing', 'whip', 'oil', '1']
# ['Garlon', 'raised', 'eyebrows', '1']
# ['Garnets', 'broke', 'onee', '1']
# ['Garnett', 'learn', 'eveninger', '1']
# ['Garnett', 'suffered', 'injury', '2']
# ['Garnish', 'chopped', 'salamis', '1']
# ['Garnish', 'dried', 'cranberries', '3']
# ['Garrett', 'break', 'allegiance', '1']
# ['Garrett', 'told', 'Judge', '1']
# ['Garson', 'laid', 'blame', '1']
# ['Garth', 'hold', 'Bachelor', '2']
# ['Brooks', 'sell', 'soul', '1']
# ['Woodside', 'spend', 'bit', '1']
# ["'s", 'grew', 'tense', '1']
# ['Archive', 'contain', 'papers', '1']
# ['Gary', 'announce', 'break', '1']
# ['Gary', 'bow', 'heads', '1']
# ['Gary', 'dropped', 'facing', '1']
# ['Gary', 'felt', 'bit', '1']
# ['Gary', 'froze', 'mind', '1']
# ['Gary', 'heard', 'cracking', '1']
# ['Gary', 'lent', 'hands', '1']
# ['Gary', 'lost', 'balance', '1']
# ['Gary', 'loved', 'son', '1']
# ['Gary', 'peel', 'cap', '2']
# ['Gary', 'plan', 'skits', '3']
# ['Gary', 'race', 'bike', '1']
# ['Gary', 'raised', 'topics', '1']
# ['Gary', 'shared', 'storyes', '1']
# ['Gary', 'tell', 'Mac', '2']
# ['Gary', 'told', 'OIG', '4']
# ['Gary', 'wrote', 'rules', '1']
# ["'s", 'open', 'doors', '1']
# ['Cooper', 'played', 'lead', '1']
# ['Crossman', 'attended', 'conference', '1']
# ['Fabian', 'ran', 'boat', '1']
# ['Fortune', 'shared', 'experiencee', '1']
# ['Graham', 'built', 'life', '1']
# ['Gray', 'get', 'lot', '1']
# ['Gray', 'pick', 'winners', '1']
# ['Hart', 'wrote', 'article', '1']
# ['May', 'open', 'meeting', '1']
# ['Moore', 'told', 'group', '1']
# ['Robinson', 'attended', 'teleconference', '1']
# ['Sheffield', 'waste', 'time', '1']
# ['Sullivan', 'broke', 'helicopter', '2']
# ['Gas', 'shut', 'friends', '1']
# ['plasma', 'allow', 'creation', '1']
# ['Gasping', 'open', 'eyesed', '2']
# ['Gasping', 'tore', 'tie', '1']
# ['Gaston', 'cleared', 'brush', '2']
# ['Technologies', 'sell', 'breakthrough', '1']
# ['Gatekeeper', 'killed', 'anything', '1']
# ['Gateley', 'earned', 'Bachelor', '2']
# ['Gates', 'announced', 'number', '1']
# ['Gates', 'earned', 'Masters', '1']
# ['Gates', 'hold', 'PhD', '2']
# ['Gates', 'loved', 'stories', '1']
# ['Gates', 'observed', 'movements', '1']
# ['Gates', 'raised', 'bow', '1']
# ['Gates', 'tell', 'Jennings', '5']
# ['classes', 'hold', 'recorded', '1']
# ['Gator', 'filled', 'forms', '2']
# ['Spyware', 'filled', 'forms', '1']
# ['drag', 'held', 'springs', '3']
# ['Gators', 'broke', 'tie', '2']
# ['Gaunt', 'tip', 'scales', '1']
# ['kernel', 'allow', 'onee', '1']
# ['Gauthier', 'told', 'Joseph', '1']
# ['Gave', 'spent', 'daye', '1']
# ['Gave', 'turn', 'back', '1']
# ['Gavin', 'choke', 'cry', '1']
# ['Gawan', 'get', 'horseed', '1']
# ['college', 'told', 'CNN', '1']
# ['Lynds', 'earned', 'reputation', '2']
# ['Gaynor', 'said', 'buffet', '1']
# ['Gaz', 'drove', 'waye', '1']
# ['Gaza', 'attack', 'Israel', '1']
# ['rocket', 'told', 'world', '1']
# ['reporting', 'open', 'implication', '1']
# ['Gazprom', 'won', 'today', '1']
# ['Gbenga', 'deserve', 'sympathy', '1']
# ['GearHead', 'shared', 'experiences', '1']
# ['Geared', 'held', 'attention', '1']
# ['Geb', 'contain', 'ideas', '1']
# ['called', 'pay', 'use', '1']
# ['Geeks', 'get', 'clothes', '4']
# ['Geese', 'challenge', 'master', '1']
# ['Geeta', 'lost', 'parents', '1']
# ["'s", 'overflow', 'stages', '2']
# ['Geita', 'won', 'tossed', '1']
# ['Jewelry', 'caught', 'hands', '1']
# ['Gell', 'travel', 'state', '1']
# ['Gelsomina', 'smile', 'ropes', '1']
# ['Gemini', 'allow', 'Scorpio', '2']
# ['Gemini', 'break', 'rules', '1']
# ['Pass', 'see', 'photos', '1']
# ["'s", 'lost', 'controlled', '1']
# ['Warrior', 'won', 'awards', '1']
# ['Gen', 'extended', 'invitation', '1']
# ['Finishing', 'built', 'reputation', '2']
# ['Genbu', 'told', 'brothers', '2']
# ['Watch', 'contain', 'articles', '1']
# ['Gene', 'get', 'thing', '1']
# ['Gene', 'hold', 'conferences', '1']
# ['Gene', 'played', 'guitar', '2']
# ['Gene', 'spend', 'night', '1']
# ['Hunt', 'dropped', 'Eat', '1']
# ['Simmons', 'look', 'waye', '1']
# ['Learning', 'learn', 'basics', '1']
# ['General', 'commanded', 'Brigade', '1']
# ['General', 'order', 'troopses', '1']
# ['General', 'suffered', 'bulk', '1']
# ['General', 'tell', 'Colonel', '1']
# ['General', 'won', 'hearts', '1']
# ["'s", 'drew', 'blood', '1']
# ['Assembly', 'order', 'halted', '1']
# ['Attacks', 'contain', 'descriptiones', '1']
# ['Bible', 'smoke', 'resting', '1']
# ['Bradley', 'order', 'Middleton', '1']
# ['Bush', 'order', 'massacre', '6']
# ['Cota', 'order', 'battalion', '1']
# ['Dayan', 'order', 'attack', '2']
# ['Dean', 'closed', 'messagees', '1']
# ['Dental', 'see', 'listed', '1']
# ['Douglas', 'remove', 'value', '1']
# ['Early', 'tip', 'hats', '1']
# ['Eisenhower', 'met', 'men', '1']
# ['Electric', 'ban', 'use', '10']
# ['Electric', 'sold', 'contract', '1']
# ['Electric', 'challenge', 'ROD', '1']
# ['George', 'raise', 'level', '1']
# ['George', 'sailed', 'yachting', '1']
# ['George', 'move', 'headquarters', '1']
# ['Greene', 'drove', 'British', '1']
# ['Hammond', 'stop', 'Jack', '1']
# ['Hospital', 'spoke', 'briefly', '1']
# ['Hunter', 'married', 'daughter', '1']
# ['Information', 'speak', 'German', '1']
# ['Introduction', 'wrote', 'introductiones', '1']
# ['John', 'commanded', 'constructionism', '1']
# ['Lord', 'led', 'column', '1']
# ['Mar', 'pick', 'steam', '1']
# ['Meetings', 'see', 'Calendar', '1']
# ['Patton', 'get', 'credit', '1']
# ['Pervez', 'led', 'army', '1']
# ['Privacy', 'contain', 'linkse', '4']
# ['Project', 'contain', 'linkse', '1']
# ['Purpose', 'cleared', 'everything', '1']
# ['Reference', 'hit', 'web', '1']
# ['Science', 'contain', 'citations', '3']
# ['Science', 'worked', 'ways', '2']
# ['Sessions', 'order', 'Jones', '5']
# ['Shuler', 'earned', 'MS', '1']
# ['Stephen', 'commanded', 'troopses', '1']
# ['Subcommittee', 'hold', 'saddle', '1']
# ['Sykes', 'hold', 'positione', '1']
# ['Thomas', 'earned', 'promotionally', '1']
# ['Wallis', 'suffered', 'checked', '3']
# ['William', 'drive', 'rebels', '1']
# ['comments', 'see', 'comments', '3']
# ['managerment', 'announced', 'move', '2']
# ['managerment', 'greeted', 'guests', '1']
# ['predators', 'destroyed', 'eggs', '1']
# ['rules', 'tell', 'storyes', '3']
# ['Generals', 'won', 'Battle', '2']
# ['Generation', 'pull', 'data', '1']
# ['X', 'raised', 'kids', '1']
# ['Generations', 'attended', 'celebratione', '1']
# ['Views', 'see', 'chapter', '1']
# ['Genes', 'tell', 'tales', '1']
# ['Genesis', 'hold', 'Christians', '1']
# ['Genesis', 'shut', 'lab', '1']
# ['Defects', 'played', 'role', '1']
# ['Geneva', 'shared', 'experiencee', '1']
# ['Khan', 'led', 'Mongols', '5']
# ['Khan', 'led', 'divisional', '2']
# ['Khan', 'look', 'Great', '1']
# ['Genii', 'told', 'Philip', '2']
# ['Genius', 'stop', 'plague', '4']
# ['Gennadios', 'move', 'patriarchate', '1']
# ['Gattuso', 'pull', 'Gerrard', '1']
# ["'s", 'hit', 'Mario', '1']
# ['Lounge', 'played', 'part', '1']
# ['Gentili', 'wrote', 'article', '1']
# ['Gentry', 'ran', 'place', '1']
# ['hobbies', 'played', 'zither', '1']
# ['Geoff', 'played', 'guitar', '4']
# ['Geoff', 'told', 'Don', '1']
# ["'s", 'open', 'picturees', '2']
# ['Geoffrey', 'lock', 'drawer', '1']
# ['Sauer', 'wrote', 'site', '1']
# ['Challenges', 'worked', 'site', '1']
# ['departmental', 'encourage', 'students', '1']
# ['Geometric', 'tie', 'Jump', '1']
# ['Analysis', 'invited', 'lecture', '1']
# ['Geordie', 'pull', 'bars', '1']
# ['Georg', 'wrote', 'FAQ', '2']
# ['George', 'appreciate', 'thoughts', '1']
# ['George', 'arrive', 'argument', '1']
# ['George', 'broke', 'packed', '1']
# ['George', 'chase', 'family', '1']
# ['George', 'dance', 'ballet', '1']
# ['George', 'gather', 'things', '1']
# ['George', 'grew', 'Moses', '1']
# ['George', 'harass', 'son', '1']
# ['George', 'hold', 'positione', '2']
# ['George', 'killed', 'snake', '1']
# ['George', 'open', 'doors', '16']
# ['George', 'open', 'hoods', '13']
# ['George', 'played', 'hero', '1']
# ['George', 'played', 'onee', '2']
# ['George', 'played', 'victim', '1']
# ['George', 'ran', 'afoul', '1']
# ['George', 'shared', 'bit', '1']
# ['George', 'sold', 'nursery', '1']
# ['George', 'spend', 'years', '2']
# ['George', 'spent', 'boyhood', '1']
# ['George', 'spent', 'night', '1']
# ['George', 'teach', 'children', '1']
# ['George', 'told', 'authorities', '1']
# ['George', 'turn', 'page', '1']
# ['George', 'waste', 'time', '1']
# ['George', 'won', 'hands', '1']
# ["'s", 'broke', 'arms', '1']
# ['Bailey', 'get', 'revenge', '1']
# ['Bailey', 'spend', 'life', '3']
# ['Best', 'deserve', 'mentioned', '1']
# ['Bush', 'announced', 'couple', '1']
# ['Bush', 'won', '2004', '1']
# ['Bush', 'won', 'thing', '2']
# ['Clooney', 'played', 'part', '1']
# ['Clooney', 'won', 'actor', '1']
# ['Demetri', 'led', 'research', '5']
# ['Dubya', 'hold', 'title', '1']
# ['Eliot', 'spent', 'time', '1']
# ['Mason', 'raised', 'issue', '2']
# ['Orwell', 'wrote', 'novel', '2']
# ['Simpson', 'order', 'establishment', '1']
# ['Snyder', 'lost', 'rights', '1']
# ['Town', 'attended', 'school', '2']
# ['V', 'attended', 'games', '1']
# ['W', 'won', 'state', '2']
# ['Wallace', 'attended', 'service', '2']
# ['Warrington', 'tell', 'friends', '1']
# ['Washington', 'pull', 'troopses', '1']
# ['Washington', 'turn', 'nose', '11']
# ['Washington', 'contain', 'informationally', '2']
# ['everything', 'get', 'seat', '1']
# ['Georges', 'met', 'Powell', '1']
# ['windows', 'hit', 'eyee', '1']
# ['Georgetown', 'get', 'lead', '1']
# ['Georgetown', 'played', 'couple', '1']
# ["'s", 'shared', 'sense', '1']
# ['Georgia', 'earned', 'trips', '1']
# ['Georgia', 'led', 'America', '1']
# ['Georgia', 'played', 'receptionist', '1']
# ['Georgia', 'shared', 'border', '1']
# ['Georgia', 'shared', 'interesting', '2']
# ['Georgia', 'won', 'candelabra', '1']
# ['Tech', 'get', 'boost', '1']
# ['delegation', 'lost', 'seats', '1']
# ['man', 'felt', 'wrath', '1']
# ['Georgiana', 'said', 'Yay', '1']
# ['Georgians', 'see', 'Russia', '1']
# ['Georgians', 'wish', 'nothingness', '1']
# ['Georgina', 'rode', 'bike', '1']
# ['Department', 'filled', 'form', '1']
# ['Gerald', 'loved', 'Commissioned', '2']
# ['Gerald', 'spot', 'deer', '2']
# ['Ford', 'smoke', 'pipe', '1']
# ['Gerard', 'lead', 'chargees', '1']
# ['Gerard', 'replied', 'Addison', '1']
# ['Gerard', 'spent', 'couple', '2']
# ["'s", 'awoke', 'baby', '1']
# ['Germain', 'threw', 'runner', '1']
# ['German', 'attack', 'leader', '1']
# ['German', 'replaced', 'Dutch', '1']
# ['German', 'speak', 'Samnaun', '1']
# ['German', 'told', 'Reuters', '1']
# ['Chancellor', 'ban', 'practice', '1']
# ['Chemicals', 'move', 'headquarters', '10']
# ['Nazis', 'killed', 'humans', '1']
# ['Oktoberfest', 'turn', 'town', '1']
# ['Proverb', 'attended', 'workshop', '2']
# ['Shepherd', 'ate', 'heads', '2']
# ['Shepherd', 'pick', 'pace', '1']
# ['Shepherd', 'loved', 'tastee', '1']
# ['air', 'concentrate', 'attack', '1']
# ['companye', 'built', 'railroad', '3']
# ['counterattack', 'threw', 'companye', '1']
# ['desiree', 'get', 'Jews', '2']
# ['invasione', 'led', 'Britain', '1']
# ['occupationally', 'order', 'Jews', '1']
# ['scientists', 'see', 'output', '2']
# ['team', 'won', 'Gold', '3']
# ['volunteers', 'cost', 'Soviets', '1']
# ['carriers', 'claim', 'successful', '1']
# ['Germanium', 'flooded', 'repertory', '1']
# ['Germano', 'threw', 'anything', '1']
# ['Germans', 'attack', 'outpost', '1']
# ['Germans', 'bomb', 'Belgrade', '3']
# ['Germans', 'dance', 'Allemande', '1']
# ['Germans', 'destroyed', 'synagogue', '1']
# ['Germans', 'killed', 'bunch', '1']
# ['Germans', 'lose', 'destroyer', '3']
# ['Germans', 'loved', 'arts', '1']
# ['Germans', 'pay', 'studio', '6']
# ['Germans', 'slept', 'night', '1']
# ['Germanus', 'held', 'office', '1']
# ['Germany', 'approve', 'requesting', '1']
# ['Germany', 'attack', 'America', '1']
# ['Germany', 'attack', 'Poland', '26']
# ['Germany', 'attack', 'onee', '1']
# ['Germany', 'avoid', 'persecution', '1']
# ['Germany', 'bore', 'fraction', '2']
# ['Germany', 'challenge', 'U.S.', '2']
# ['Germany', 'extended', 'knowledge', '1']
# ['Germany', 'hate', 'speech', '1']
# ['Germany', 'learn', 'trade', '1']
# ['Germany', 'move', 'Frankfurt', '5']
# ['Germany', 'move', 'west', '5']
# ['Germany', 'pick', 'team', '1']
# ['Germany', 'prevent', 'war', '1']
# ['Germany', 'shared', 'bill', '1']
# ['Germany', 'threw', 'gears', '1']
# ['Germany', 'won', 'war', '28']
# ['Gerontocracy', 'closed', 'opportunity', '1']
# ['Gerrard', 'pick', 'Carragher', '1']
# ['Gerry', 'lead', 'reviews', '1']
# ['Gerry', 'worked', 'WGNY', '3']
# ['Gerson', 'hold', 'MBA', '1']
# ["'s", 'turn', 'heads', '1']
# ['Gertie', 'drink', 'water', '1']
# ['Gertrude', 'possess', 'advantage', '2']
# ['Gertrude', 'sat', 'digress', '1']
# ['Gertrude', 'tell', 'Claudius', '4']
# ['Gertrude', 'tell', 'two', '1']
# ['Stein', 'contain', 'storyes', '1']
# ['Pro', 'announce', 'release', '2']
# ['Tables', 'manage', 'softwareed', '1']
# ['Car', 'hit', 'stages', '1']
# ['people', 'charge', 'chances', '1']
# ['Getty', 'hold', 'individuall', '1']
# ['Information', 'closed', 'Face', '1']
# ['Ghada', 'chewed', 'fat', '2']
# ['Ghana', 'ban', 'sale', '1']
# ['Ghana', 'look', 'oasis', '1']
# ["'s", 'stir', 'stadium', '1']
# ['Ghiberti', 'won', 'competition', '6']
# ['Sickness', 'heard', 'voices', '1']
# ['Stories', 'contain', 'articles', '2']
# ['Giada', 'drink', 'look', '1']
# ['cinemas', 'force', 'scrutiny', '1']
# ['drives', 'thought', 'leadership', '4']
# ['Giant', 'turn', 'Rodman', '1']
# ['Grim', 'order', 'pilgrims', '1']
# ['Wow', 'lend', 'tastee', '1']
# ['shockers', 'get', 'waye', '2']
# ['verticales', 'poured', 'water', '2']
# ['Giants', 'ate', 'people', '1']
# ['Giants', 'lost', '9-1', '1']
# ['Giants', 'lost', 'ball', '1']
# ['Giants', 'trade', 'Alvarez', '1']
# ['Giants', 'win', 'tomorrow', '1']
# ['receivers', 'lead', 'league', '2']
# ['Giba', 'prepare', 'engineeering', '1']
# ['Gibbs', 'chase', 'thief', '1']
# ['Gibbs', 'plan', 'appeal', '1']
# ['Gibbs', 'tell', 'readers', '2']
# ['Gibeonites', 'hanged', 'men', '2']
# ['1932', 'broke', 'cover', '1']
# ['Gibson', 'get', 'nothingness', '1']
# ['Gibson', 'order', 'Rachel', '1']
# ["'s", 'move', 'family', '2']
# ['website', 'get', 'visitors', '1']
# ['Gien', 'felt', 'waving', '1']
# ['Gift', 'open', 'path', '2']
# ['Gift', 'treated', 'green', '2']
# ['Baskets', 'loved', 'sites', '1']
# ['Certificate', 'allow', 'purchase', '1']
# ['cards', 'extended', 'holidaye', '1']
# ['Development', 'appreciate', 'level', '1']
# ['Gifts', 'strengthened', 'collectiones', '1']
# ['Food', 'played', 'concerts', '3']
# ['Limited', 'announced', 'appointment', '5']
# ['Gigantoraptor', 'bore', 'feathers', '1']
# ['Gijs', 'drove', 'car', '1']
# ['Gil', 'thought', 'riddle', '1']
# ['Grissom', 'met', 'Sara', '2']
# ['Gilbert', 'drew', 'planes', '4']
# ['Gilbert', 'extended', 'analysiser', '1']
# ['Gilbert', 'open', 'onee', '1']
# ['Gilbert', 'treated', 'search', '1']
# ['Brown', 'played', 'confidence', '1']
# ['Gilchrist', 'broke', 'silence', '8']
# ['Gilchrist', 'played', 'games', '2']
# ['Gilchrist', 'told', 'WND', '2']
# ['Gilchrist', 'waste', 'time', '1']
# ['Giles', 'clean', 'glasses', '2']
# ['Giles', 'cough', 'bit', '2']
# ['Giles', 'hate', 'hospitals', '1']
# ['Giles', 'held', 'grins', '1']
# ['Giles', 'hold', 'doors', '1']
# ['Giles', 'hold', 'title', '1']
# ['Giles', 'led', 'Buffy', '1']
# ['Giles', 'pick', 'ring', '1']
# ['Giles', 'pull', 'handkerchief', '5']
# ['Gill', 'get', 'nod', '1']
# ['Gill', 'lost', 'electioneering', '1']
# ['Gilla', 'get', 'can', '1']
# ['Gillespie', 'loved', 'limelight', '1']
# ['Gilliam', 'tell', 'Tideland', '2']
# ["'s", 'look', 'Grimm', '1']
# ['Gilligan', 'announced', 'candidacy', '1']
# ['yesterdaye', 'broke', 'silence', '1']
# ['Gilly', 'ran', 'waye', '3']
# ['Gilmore', 'closed', 'business', '1']
# ['Gilmour', 'won', 'right', '1']
# ['Gilroy', 'wrote', 'screenplayer', '1']
# ['Gilson', 'told', 'mayor', '1']
# ['title', 'faded', 'end', '1']
# ["'s", 'invited', 'Grandma', '1']
# ["'s", 'open', 'store', '1']
# ['Gimli', 'push', 'Legolas', '2']
# ['Gimli', 'raised', 'heads', '1']
# ['Big', 'get', 'resting', '1']
# ['Gimp', 'worked', 'waye', '1']
# ['Gina', 'felt', 'urge', '1']
# ['Gingerly', 'pick', 'path', '2']
# ['Gingerly', 'raised', 'cameras', '1']
# ['Gingrich', 'get', 'nomination', '1']
# ['Gini', 'pick', 'Jack', '1']
# ['Ginny', 'push', 'shift', '1']
# ['Ginny', 'replace', 'Harry', '5']
# ['Gino', 'bent', 'lot', '1']
# ['Gino', 'touch', 'deck', '1']
# ['Ginrai', 'see', 'vehicle', '1']
# ['Ginseng', 'prevent', 'disease', '2']
# ['Giorgio', 'threw', 'cloud', '1']
# ['Giorgis', 'led', 'Marist', '2']
# ['Giovanni', 'speak', 'English', '1']
# ['Girardi', 'manage', 'bullpen', '2']
# ['Girl', 'get', 'guye', '3']
# ['Girl', 'get', 'superpowers', '5']
# ['Scouts', 'encourage', 'girls', '2']
# ['Scouts', 'reflected', 'diversity', '1']
# ['children', 'shared', 'worked', '1']
# ['LEAD', 'prepare', 'girls', '1']
# ['White', 'led', 'girls', '1']
# ['assigned', 'prepare', 'flags', '1']
# ['Gisele', 'live', 'apartment', '1']
# ['Giuliani', 'pull', 'onee', '3']
# ['Giuliani', 'slip', 'popularity', '3']
# ['Giuliani', 'whip', 'fireseal', '1']
# ["'s", 'stir', 'angered', '1']
# ['campaign', 'lead', 'website', '1']
# ['technology', 'worked', 'waye', '3']
# ['airfare', 'tell', 'hour', '1']
# ['Richards', 'hold', 'Bachelor', '1']
# ['Gizmodo', 'turn', 'freelance', '1']
# ['Glad', 'see', 'Jessica', '2']
# ['Glad', 'see', 'Missourian', '1']
# ['Glad', 'see', 'Slipstream', '1']
# ['Glad', 'see', 'friends', '1']
# ['Glad', 'see', 'post', '17']
# ['Glad', 'see', 'potters', '1']
# ['Glad', 'see', 'yesterdaye', '1']
# ['Gladstone', 'told', 'CNN', '1']
# ['Gladys', 'loved', 'music', '3']
# ['Glasgow', 'boast', 'shopping', '1']
# ['Glasgow', 'contain', 'populationes', '1']
# ['Glasgow', 'pinch', 'result', '1']
# ['Glasgow', 'won', 'reputation', '1']
# ['Glasscock', 'built', 'hall', '1']
# ['Trail', 'turn', 'course', '1']
# ['Gleason', 'said', 'sizes', '1']
# ['Gleim', 'permitted', 'returns', '1']
# ["'s", 'allow', 'freedom', '1']
# ['Ochre', 'wrote', 'chapter', '1']
# ['composite', 'lighten', 'loaded', '1']
# ['Glenavon', 'held', 'lead', '1']
# ['Glenda', 'taught', 'arts', '1']
# ['Glenn', 'hold', 'MBA', '3']
# ['Glenn', 'hold', 'MS', '2']
# ['Chandler', 'wore', 'diapers', '1']
# ['Dorsey', 'played', 'season', '1']
# ['E', 'wrote', 'editoriale', '1']
# ['Inwood', 'told', 'media', '1']
# ['Miller', 'told', 'CNN', '1']
# ['Sharpe', 'worked', 'waye', '1']
# ['Glenside', 'contain', 'onee', '1']
# ['Glinda', 'held', 'reception', '1']
# ['Glob', 'tell', 'world', '1']
# ['News', 'tell', 'historyes', '1']
# ['Payments', 'caught', 'eyee', '1']
# ['Poverty', 'reflected', 'desiree', '2']
# ['Training', 'open', 'facility', '1']
# ['Warming', 'get', 'facts', '1']
# ['Wealth', 'tap', 'strength', '7']
# ['competition', 'forced', 'closure', '1']
# ['processesed', 'tie', 'national', '3']
# ['televisione', 'attended', 'classes', '1']
# ['Globalism', 'concentrate', 'power', '1']
# ['Globe', 'applauded', 'plan', '1']
# ['obituary', 'contain', 'archives', '1']
# ['Voice', 'get', 'attention', '2']
# ['Glottal', 'stop', 'length', '1']
# ['Cathedral', 'built', 'crypts', '1']
# ['County', 'attracted', 'visitors', '1']
# ['Glover', 'lead', 'NFL', '1']
# ['Glucosamine', 'played', 'role', '4']
# ['Glue', 'felt', 'hats', '1']
# ['Free', 'win', 'seller', '1']
# ['immune', 'lose', 'efficiency', '1']
# ['Maxwell', 'see', 'role', '2']
# ['Glynn', 'told', 'architects', '1']
# ['Gmane', 'approve', 'application', '5']
# ['administratores', 'get', 'copy', '1']
# ['Movies', 'travel', 'world', '2']
# ['Goal', 'smell', 'fishy', '1']
# ['Goals', 'prepare', 'students', '5']
# ['Gober', 'led', 'Rams', '6']
# ['Gobles', 'told', 'investigators', '1']
# ['Cock', 'get', 'mentioned', '1']
# ['God', 'allow', 'Noah', '4']
# ['God', 'allow', 'Osteen', '1']
# ['God', 'allow', 'Peter', '1']
# ['God', 'allow', 'enemyes', '1']
# ['God', 'allow', 'pestilence', '2']
# ['God', 'announced', 'falls', '1']
# ['God', 'answered', 'problems', '1']
# ['God', 'attack', 'Moses', '1']
# ['God', 'attended', 'season', '1']
# ['God', 'blessed', 'Africa', '41']
# ['God', 'blessed', 'Australia', '9']
# ['God', 'blessed', 'Charlotte', '1']
# ['God', 'blessed', 'Decider', '2']
# ['God', 'blessed', 'Earth', '3']
# ['God', 'blessed', 'Esau', '2']
# ['God', 'blessed', 'Father', '4']
# ['God', 'blessed', 'Flag', '5']
# ['God', 'blessed', 'Frist', '1']
# ['God', 'blessed', 'Gambians', '1']
# ['God', 'blessed', 'Hughie', '1']
# ['God', 'blessed', 'Interesting', '1']
# ['God', 'blessed', 'Japan', '1']
# ['God', 'blessed', 'Kama', '1']
# ['God', 'blessed', 'Maira', '1']
# ['God', 'blessed', 'Marks', '1']
# ['God', 'blessed', 'Maybelline', '1']
# ['God', 'blessed', 'Mill', '1']
# ['God', 'blessed', 'Perry', '1']
# ['God', 'blessed', 'Rachelle', '2']
# ['God', 'blessed', 'Randy', '2']
# ['God', 'blessed', 'Sanity', '1']
# ['God', 'blessed', 'Smirnoff', '2']
# ['God', 'blessed', 'Staff', '2']
# ['God', 'blessed', 'Taiwan', '4']
# ['God', 'blessed', 'Theresa', '1']
# ['God', 'blessed', 'Tivo', '1']
# ['God', 'blessed', 'WOMEN', '1']
# ['God', 'blessed', 'Ward', '1']
# ['God', 'blessed', 'World', '1']
# ['God', 'blessed', 'additionally', '1']
# ['God', 'blessed', 'cheapness', '1']
# ['God', 'blessed', 'creator', '1']
# ['God', 'blessed', 'david', '1']
# ['God', 'blessed', 'decisional', '8']
# ['God', 'blessed', 'editors', '6']
# ['God', 'blessed', 'eyesed', '1']
# ['God', 'blessed', 'firefighters', '2']
# ['God', 'blessed', 'fr', '1']
# ['God', 'blessed', 'generationer', '2']
# ['God', 'blessed', 'juicer', '1']
# ['God', 'blessed', 'manners', '1']
# ['God', 'blessed', 'martyrs', '1']
# ['God', 'blessed', 'meeks', '1']
# ['God', 'blessed', 'modem', '1']
# ['God', 'blessed', 'offer', '1']
# ['God', 'blessed', 'paparazzi', '1']
# ['God', 'blessed', 'peace', '3']
# ['God', 'blessed', 'pigeon', '1']
# ['God', 'blessed', 'reformationism', '2']
# ['God', 'blessed', 'sinners', '2']
# ['God', 'blessed', 'stateses', '1']
# ['God', 'blessed', 'storms', '1']
# ['God', 'blew', 'Spirit', '1']
# ['God', 'bore', 'guilt', '1']
# ['God', 'broke', 'curse', '1']
# ['God', 'broke', 'promises', '1']
# ['God', 'built', 'foundationalism', '1']
# ['God', 'built', 'hill', '2']
# ['God', 'catch', 'men', '2']
# ['God', 'challenge', 'Gentiles', '1']
# ['God', 'challenge', 'Job', '1']
# ['God', 'cleared', 'confusional', '2']
# ['God', 'closed', 'Sea', '1']
# ['God', 'commanded', 'Pope', '1']
# ['God', 'commanded', 'events', '1']
# ['God', 'commanded', 'famine', '1']
# ['God', 'commanded', 'light', '13']
# ['God', 'commanded', 'mankind', '4']
# ['God', 'commanded', 'somethingism', '23']
# ['God', 'commanded', 'watersed', '5']
# ['God', 'contain', 'causeed', '2']
# ['God', 'deceive', 'Church', '1']
# ['God', 'destroyed', 'dragons', '1']
# ['God', 'destroyed', 'everything', '3']
# ['God', 'destroyed', 'soul', '2']
# ['God', 'disarmed', 'rulers', '1']
# ['God', 'drew', 'people', '2']
# ['God', 'dropped', 'passage', '1']
# ['God', 'employed', 'process', '1']
# ['God', 'employed', 'sovereignty', '1']
# ['God', 'exercise', 'mind', '1']
# ['God', 'exercise', 'providence', '2']
# ['God', 'extended', 'opportunity', '1']
# ['God', 'fear', 'Catholic', '1']
# ['God', 'fear', 'everything', '1']
# ['God', 'feel', 'power', '1']
# ['God', 'feel', 'things', '1']
# ['God', 'filled', 'David', '1']
# ['God', 'filled', 'dreams', '1']
# ['God', 'filled', 'pagesize', '1']
# ['God', 'fixed', 'life', '1']
# ['God', 'fixed', 'problems', '1']
# ['God', 'fool', 'humanity', '1']
# ['God', 'forced', 'Jews', '2']
# ['God', 'forced', 'issue', '1']
# ['God', 'forgave', 'Jews', '1']
# ['God', 'forgive', 'Fred', '1']
# ['God', 'forgive', 'laziness', '2']
# ['God', 'get', 'advantage', '1']
# ['God', 'get', 'time', '1']
# ['God', 'get', 'truth', '1']
# ['God', 'get', 'wants', '2']
# ['God', 'hanged', 'lot', '2']
# ['God', 'hate', 'Psychic', '1']
# ['God', 'hate', 'beese', '1']
# ['God', 'hate', 'cheesees', '1']
# ['God', 'hate', 'humanity', '1']
# ['God', 'hate', 'process', '1']
# ['God', 'hate', 'slander', '1']
# ['God', 'hate', 'suffering', '1']
# ['God', 'healed', 'Camilla', '1']
# ['God', 'healed', 'mother', '3']
# ['God', 'heard', 'sound', '3']
# ['God', 'held', 'anything', '1']
# ['God', 'hid', 'Himself', '1']
# ['God', 'hold', 'Man', '1']
# ['God', 'hold', 'patent', '2']
# ['God', 'hold', 'revenge', '2']
# ['God', 'lay', 'plan', '6']
# ['God', 'lay', 'wisdom', '1']
# ['God', 'laid', 'messagees', '3']
# ['God', 'lead', 'children', '5']
# ['God', 'lead', 'creation', '2']
# ['God', 'lead', 'others', '2']
# ['God', 'learn', 'nothingness', '1']
# ['God', 'led', 'family', '2']
# ['God', 'lighten', 'burden', '2']
# ['God', 'look', 'category', '1']
# ['God', 'lost', 'bet', '1']
# ['God', 'lost', 'place', '2']
# ['God', 'loved', 'Aloha', '1']
# ['God', 'loved', 'Americans', '4']
# ['God', 'loved', 'everyone', '243']
# ['God', 'loved', 'humor', '7']
# ['God', 'loved', 'kids', '16']
# ['God', 'loved', 'named', '1']
# ['God', 'loved', 'outcasts', '2']
# ['God', 'loved', 'piety', '2']
# ['God', 'loved', 'state', '1']
# ['God', 'loved', 'trinity', '1']
# ['God', 'loved', 'waye', '4']
# ['God', 'manipulate', 'elementse', '2']
# ['God', 'move', 'Sun', '1']
# ['God', 'move', 'throne', '1']
# ['God', 'multiplied', 'everything', '2']
# ['God', 'nod', 'heads', '3']
# ['God', 'obey', 'voice', '1']
# ['God', 'observed', 'faith', '1']
# ['God', 'order', 'Moses', '15']
# ['God', 'order', 'whaling', '2']
# ['God', 'owed', 'forgiveness', '3']
# ['God', 'permitted', 'Pope', '1']
# ['God', 'permitted', 'enemyes', '1']
# ['God', 'permitted', 'pain', '2']
# ['God', 'permitted', 'somethingism', '8']
# ['God', 'plan', 'Christmas', '1']
# ['God', 'plan', 'pattern', '1']
# ['God', 'plant', 'thinks', '1']
# ['God', 'poured', 'answers', '1']
# ['God', 'poured', 'spirit', '12']
# ['God', 'prepare', 'plan', '4']
# ['God', 'punish', 'angels', '1']
# ['God', 'punish', 'hammer', '1']
# ['God', 'raised', 'Dorcas', '1']
# ['God', 'raised', 'onee', '2']
# ['God', 'remove', 'causeed', '1']
# ['God', 'remove', 'consequence', '1']
# ['God', 'remove', 'defect', '2']
# ['God', 'remove', 'sicknesse', '4']
# ['God', 'replace', 'Time', '1']
# ['God', 'seal', 'promises', '1']
# ['God', 'see', 'adultery', '1']
# ['God', 'see', 'hatred', '7']
# ['God', 'see', 'nakedness', '1']
# ['God', 'see', 'wickedness', '7']
# ['God', 'shut', 'mouth', '2']
# ['God', 'speak', 'Sabbath', '1']
# ['God', 'speak', 'spirit', '3']
# ['God', 'speak', 'truth', '38']
# ['God', 'spoke', 'hearts', '5']
# ['God', 'stir', 'adversary', '1']
# ['God', 'strengthened', 'union', '3']
# ['God', 'suffered', 'earth', '4']
# ['God', 'taught', 'Kabbalah', '3']
# ['God', 'taught', 'men', '3']
# ['God', 'tell', 'conditions', '1']
# ['God', 'tell', 'kind', '1']
# ['God', 'threw', 'earthquake', '1']
# ['God', 'told', 'wind', '2']
# ['God', 'treated', 'others', '2']
# ['God', 'trick', 'devil', '3']
# ['God', 'turn', 'faucet', '4']
# ['God', 'turn', 'fire', '2']
# ['God', 'turn', 'focused', '2']
# ['God', 'turn', 'questionable', '1']
# ['God', 'turn', 'watersed', '7']
# ['God', 'wait', 'daye', '1']
# ['God', 'washed', 'pain', '4']
# ['God', 'whispered', 'named', '4']
# ['God', 'whispered', 'words', '2']

# %% [markdown]
# We can also filter out some useless nouns such as numbers like 10 or 2,000 or nouns that do not make
# sense in the corpus such as 10:00 or 3-5. There are lots of ways of doing this. Below will be
# one example.

# %%
with open('tutorial_data.txt','r') as txt:
    puncs=list(string.punctuation)
    for line in txt:
        lines=line.split()
        valid=True
        if len(lines[0])<=2 or len(lines[2])<=2:
            #Normally when the nouns have less than two characters, it is invalid.
            continue
        if lines[0].isdigit() or lines[2].isdigit():
            #Check whether it only consists of digits.
            continue
        for punc in puncs:
            #Check whether it contains punctuation. We also filter this out.
            if punc in lines[0] or punc in lines[2]:
                valid=False
                break
        if valid:
            print(lines)
# Out:
# ['Foyle', 'cost', 'lot', '1']
# ['Foyle', 'is', 'wrecked', '1']
# ['Antonio', 'is', 'pastor', '1']
# ['Cullen', 'joined', 'Society', '2']
# ['Edward', 'offer', 'Mass', '1']
# ['Luiz', 'was', 'celebrant', '2']
# ['Mathew', 'introduced', 'bishops', '1']
# ['Peter', 'hold', 'book', '1']
# ['Tony', 'allow', 'family', '1']
# ['Dimension', 'give', 'students', '1']
# ['Geometry', 'contain', 'wealth', '1']
# ['arts', 'is', 'matter', '1']
# ['patterns', 'filled', 'screen', '2']
# ['Fractals', 'are', 'things', '1']
# ['navigate', 'examinee', 'positione', '1']
# ['Decimal', 'render', 'men', '1']
# ['crystallization', 'is', 'removal', '8']
# ['Decimals', 'are', 'typed', '9']
# ['Version', 'Listen', 'previews', '1']
# ['weapons', 'have', 'chance', '1']
# ['Fragility', 'heighten', 'beauty', '1']
# ['Fragment', 'is', 'translationally', '2']
# ['programs', 'implementation', 'computationally', '1']
# ['Fragmentation', 'is', 'concerning', '2']
# ['Problem', 'is', 'phenomenon', '1']
# ['thinking', 'is', 'exceptionalism', '1']
# ['Fragonard', 'illustrate', 'works', '1']
# ['Fragos', 'scream', 'warning', '1']
# ['Fragrance', 's', 'growth', '1']
# ['Crafts', 'find', 'somethingism', '1']
# ['room', 'allow', 'marye', '1']
# ['Fragrances', 'have', 'mysteryes', '2']
# ['Fragrant', 'greeted', 'nose', '1']
# ['Fragrant', 'is', 'bodye', '1']
# ['Hostas', 'tolerate', 'sun', '1']
# ['pork', 'features', 'sauerkraut', '1']
# ['vanilla', 'toast', 'nuts', '4']
# ['Fraktal', 'is', 'onee', '1']
# ['Frame', 'began', 'explanationes', '1']
# ['Frame', 'create', 'Set', '1']
# ['Frame', 'is', 'chance', '1']
# ['Frame', 'is', 'set', '1']
# ['Frame', 'struck', 'relationship', '2']
# ['Construction', 'require', 'experiencee', '1']
# ['info', 'contain', 'collectiones', '1']
# ['objectives', 'is', 'convenience', '1']
# ['timeline', 'adds', 'motion', '34']
# ['Framed', 'are', 'hypothesised', '3']
# ['Framed', 'was', 'elegance', '1']
# ['Framer', 'is', 'mapping', '1']
# ['Framers', 'built', 'Constitution', '1']
# ['Framers', 'designate', 'Constitution', '1']
# ['Framers', 'link', 'protectionism', '1']
# ['Frames', 'are', 'custom', '1']
# ['Frames', 'are', 'metal', '2']
# ['Frames', 'are', 'part', '2']
# ['Frames', 'are', 'solution', '1']
# ['Frames', 'are', 'tools', '1']
# ['Frames', 'choose', 'options', '1']
# ['Frames', 'have', 'effect', '1']
# ['Frames', 'hold', 'objects', '1']
# ['Frames', 'include', 'image', '1']
# ['Frames', 'is', 'band', '1']
# ['Frames', 'is', 'future', '1']
# ['Frames', 'make', 'website', '2']
# ['Frames', 'offer', 'opportunity', '1']
# ['Direct', 'release', 'footage', '2']
# ['frame', 'is', 'structure', '1']
# ['CFC', 'provide', 'arrayer', '1']
# ['Framework', 'Base', 'Learning', '1']
# ['Framework', 'compile', 'application', '1']
# ['Framework', 'died', 'Microsoft', '1']
# ['Framework', 'emphasise', 'importance', '1']
# ['Framework', 'is', 'sizes', '1']
# ['Framework', 'promisee', 'world', '1']
# ['Framework', 'trace', 'destruction', '1']
# ['Framework', 'was', 'theme', '1']
# ['Class', 'deserial', 'instance', '1']
# ['Convention', 'is', 'alliance', '1']
# ['Microsoft', 'got', 'copy', '2']
# ['Scott', 'kicking', 'things', '2']
# ['Source', 'forced', 'brilliance', '1']
# ['usage', 'is', 'plus', '1']
# ['Frameworks', 'take', 'view', '1']
# ['Odd', 'Make', 'frames', '1']
# ['Tips', 'look', 'days', '1']
# ['Framingham', 'is', 'site', '1']
# ['Framingham', 'made', 'pitch', '1']
# ['State', 'give', 'professors', '1']
# ['Frampton', 'contribute', 'supports', '1']
# ['Fran', 'find', 'mother', '1']
# ['Fran', 'finishe', 'kitchen', '1']
# ['Fran', 'had', 'dreams', '1']
# ['Fran', 'manage', 'place', '1']
# ['Fran', 'rememberance', 'detail', '1']
# ['Fran', 'retiring', 'months', '1']
# ['Fran', 'show', 'pictures', '1']
# ['Drescher', 'has', 'waye', '1']
# ['Healy', 'took', 'moments', '1']
# ['Hill', 'need', 'vacationers', '1']
# ['Petersen', 'was', 'Scoutmaster', '1']
# ['Casey', 'got', 'life', '2']
# ['Francais', 'are', 'times', '2']
# ['France', 'DO', 'gained', '1']
# ['France', 'awards', 'tribes', '2']
# ['France', 'becamee', 'part', '2']
# ['France', 'beginning', 'seriese', '1']
# ['France', 'bring', 'talk', '2']
# ['France', 'broke', 'terms', '1']
# ['France', 'claim', 'victory', '1']
# ['France', 'commanded', 'divisional', '1']
# ['France', 'comprisees', 'Normandy', '1']
# ['France', 'condemnation', 'war', '2']
# ['France', 'consideration', 'commitment', '1']
# ['France', 'controlled', 'lands', '1']
# ['France', 'development', 'softwareed', '2']
# ['France', 'dominateed', 'cities', '3']
# ['France', 'employed', 'mixture', '1']
# ['France', 'ensure', 'creation', '1']
# ['France', 'exported', 'components', '1']
# ['France', 'find', 'England', '5']
# ['France', 'gave', 'concurrence', '1']
# ['France', 'gave', 'lands', '1']
# ['France', 'grabbing', 'spoils', '1']
# ['France', 'has', 'issue', '1']
# ['France', 'has', 'politics', '1']
# ['France', 'has', 'shortage', '4']
# ['France', 'has', 'worries', '7']
# ['France', 'had', 'Italy', '1']
# ['France', 'had', 'army', '3']
# ['France', 'had', 'backing', '1']
# ['France', 'had', 'opportunity', '1']
# ['France', 'had', 'threshold', '1']
# ['France', 'have', 'couple', '1']
# ['France', 'have', 'problems', '1']
# ['France', 'have', 'systems', '1']
# ['France', 'hears', 'tramped', '3']
# ['France', 'invents', 'periscope', '2']
# ['France', 'is', 'traders', '1']
# ['France', 'is', 'trustee', '1']
# ['France', 'left', 'system', '1']
# ['France', 'liberate', 'region', '3']
# ['France', 'made', 'attempt', '1']
# ['France', 'made', 'home', '1']
# ['France', 'make', 'decisional', '1']
# ['France', 'need', 'someone', '3']
# ['France', 'obtain', 'foothold', '1']
# ['France', 'oppose', 'deadline', '1']
# ['France', 'pardons', 'men', '1']
# ['France', 'prohibit', 'sale', '2']
# ['France', 'provide', 'aircraft', '11']
# ['France', 'purchased', 'village', '1']
# ['France', 'recall', 'ambassador', '1']
# ['France', 'reverse', 'colours', '1']
# ['France', 'running', 'penalty', '2']
# ['France', 'set', 'example', '1']
# ['France', 'spend', 'onee', '2']
# ['France', 'supply', 'force', '1']
# ['France', 'threatens', 'Spain', '2']
# ['France', 'useful', 'failure', '6']
# ['France', 'useful', 'nerve', '1']
# ['France', 'violate', 'agreement', '1']
# ['France', 'voice', 'supports', '1']
# ['France', 'was', 'presidente', '2']
# ['France', 'was', 'superpower', '5']
# ['France', 'won', 'battle', '1']
# ['France', 'won', 'prize', '1']
# ['The', 'received', 'reported', '1']
# ['Youth', 'offer', 'travelers', '1']
# ['organizer', 'useful', 'power', '1']
# ['winners', 'describe', 'battle', '2']
# ['Frances', 'answered', 'tailored', '1']
# ['Frances', 'felt', 'eyesed', '1']
# ['Frances', 'give', 'goods', '1']
# ['Frances', 'had', 'man', '1']
# ['Frances', 'had', 'son', '1']
# ['Frances', 'is', 'wife', '1']
# ['Frances', 'learn', 'code', '2']
# ['Frances', 'loved', 'cats', '1']
# ['Frances', 'lowered', 'hands', '4']
# ['Frances', 'lowered', 'heads', '7']
# ['Frances', 'milk', 'cows', '1']
# ['Frances', 'recollects', 'declaration', '2']
# ['Frances', 'saw', 'classes', '1']
# ['Frances', 'underwent', 'lobotomy', '1']
# ['Frances', 'was', 'effect', '1']
# ['Frances', 'was', 'sheriff', '1']
# ['Anderton', 'explore', 'messagees', '1']
# ['Brandon', 'married', 'Master', '1']
# ['Cirino', 'is', 'students', '1']
# ['Forde', 'is', 'Professor', '1']
# ['Griffiths', 'photograph', 'fairies', '2']
# ['Maxwell', 'has', 'gen', '1']
# ['Moore', 'handle', 'sets', '1']
# ['Payne', 'is', 'onee', '2']
# ['Payne', 'trace', 'heritage', '1']
# ['Perkins', 'be', 'secretary', '1']
# ['Rose', 'was', 'onee', '1']
# ['Siedliska', 'desiree', 'happiness', '1']
# ['Smith', 'read', 'namese', '1']
# ['Yates', 'found', 'number', '1']
# ['Francesca', 'had', 'doubt', '1']
# ['Francesca', 'kept', 'everybody', '1']
# ['Francesca', 'show', 'interesting', '1']
# ['Spencer', 'resigned', 'positione', '1']
# ['Woodman', 'visiting', 'Rome', '1']
# ['Francesco', 'beginning', 'onee', '2']
# ['Francesco', 'is', 'saints', '1']
# ['Franchise', 'displays', 'Million', '1']
# ['Franchise', 'imdb', 'ship', '1']
# ['Franchise', 'is', 'Building', '1']
# ['Ideas', 'added', 'section', '1']
# ['New', 'is', 'home', '1']
# ['tax', 'beginning', 'date', '2']
# ['Franchisee', 'evaluatees', 'importance', '1']
# ['Franchising', 'is', 'methods', '9']
# ['Franchot', 'loved', 'women', '1']
# ['Franchot', 'notifying', 'MGM', '1']
# ['Francia', 'was', 'result', '1']
# ['Francica', 'explore', 'topics', '1']
# ['Francie', 'lost', 'count', '1']
# ['Francie', 'transformers', 'experiences', '1']
# ['Francine', 'is', 'graduate', '1']
# ['Frensky', 'is', 'monkey', '1']
# ['Tate', 'told', 'investigators', '1']
# ['Ward', 'got', 'messagees', '1']
# ['Francis', 'Admit', 'woman', '1']
# ['Francis', 'McDonald', 'managerment', '3']
# ['Francis', 'approaching', 'people', '2']
# ['Francis', 'attack', 'France', '7']
# ['Francis', 'attended', 'number', '1']
# ['Francis', 'becamee', 'vassal', '7']
# ['Francis', 'begat', 'Joan', '1']
# ['Francis', 'called', 'creation', '5']
# ['Francis', 'capture', 'imagination', '2']
# ['Francis', 'discoverers', 'stigmata', '2']
# ['Francis', 'distributed', 'Communion', '1']
# ['Francis', 'emphasize', 'spirit', '1']
# ['Francis', 'felt', 'cowards', '1']
# ['Francis', 'gave', 'scandal', '2']
# ['Francis', 'has', 'collectiones', '1']
# ['Francis', 'had', 'affinity', '1']
# ['Francis', 'had', 'fights', '1']
# ['Francis', 'is', 'rookiee', '1']
# ['Francis', 'is', 'waye', '2']
# ['Francis', 'knock', 'lights', '1']
# ['Francis', 'left', 'MNI', '1']
# ['Francis', 'loved', 'Ben', '1']
# ['Francis', 'married', 'daughter', '1']
# ['Francis', 'met', 'Sultan', '2']
# ['Francis', 'missed', 'friends', '1']
# ['Francis', 'own', 'GameCube', '3']
# ['Francis', 'performer', 'internship', '3']
# ['Francis', 'practically', 'waye', '1']
# ['Francis', 'seeking', 'sheltering', '2']
# ['Francis', 'take', 'pride', '1']
# ['Ayers', 'built', 'cabin', '1']
# ['Bacon', 'was', 'Rosicrucian', '3']
# ['Barker', 'led', 'troopses', '1']
# ['Bartow', 'left', 'room', '1']
# ['Borgia', 'was', 'duke', '1']
# ['Fukuyama', 'is', 'onee', '1']
# ['Gomez', 'embarked', 'survivors', '1']
# ['Irving', 'development', 'TortoiseCVS', '2']
# ['Johnson', 'disses', 'suckering', '1']
# ['Lickerish', 'joined', 'band', '1']
# ['Moore', 'is', 'authorization', '1']
# ['Payton', 'had', 'points', '1']
# ['Scott', 'was', 'witnesse', '1']
# ['Technology', 'is', 'onee', '1']
# ['Xavier', 'do', 'Minho', '1']
# ['junior', 'ran', 'recorded', '1']
# ['order', 'had', 'monastery', '5']
# ['Franciscans', 'enters', 'province', '1']
# ['Franciscans', 'prepare', 'materials', '1']
# ['Francisco', 'found', 'waye', '2']
# ['Francisco', 'give', 'moneyer', '1']
# ['Francisco', 'make', 'witnesses', '1']
# ['Francisco', 'set', 'hook', '1']
# ['Arcaute', 'declines', 'comment', '2']
# ['Garcia', 'led', 'Jazz', '1']
# ['Gonzalo', 'useful', 'flag', '1']
# ['Sightseeing', 'Include', 'Tours', '1']
# ['Francisella', 'causeed', 'tularemia', '1']
# ['Franck', 'circulate', 'petitioner', '1']
# ['Franck', 'is', 'cooke', '1']
# ['Franck', 'was', 'onee', '1']
# ['Muller', 'is', 'watchmaker', '1']
# ['Franco', 'added', 'potbelly', '1']
# ['Franco', 'anticipate', 'need', '2']
# ['Franco', 'gained', 'reputation', '29']
# ['Franco', 'has', 'everything', '1']
# ['Franco', 'like', 'worked', '1']
# ['Franco', 'pay', 'attention', '1']
# ['Franco', 'received', 'shots', '1']
# ['Franco', 'sings', 'Camino', '1']
# ['Prati', 'announce', 'launching', '1']
# ['Roma', 'bring', 'touch', '1']
# ['Kevorkian', 'abandoned', 'study', '1']
# ['Martin', 'transformers', 'Pondicherry', '1']
# ['Pinon', 'is', 'onee', '3']
# ['two', 'may', 'fruit', '2']
# ['Francoise', 'is', 'stepmother', '1']
# ['Francona', 'give', 'pitchers', '4']
# ['Franchising', 'find', 'franchisee', '1']
# ['Frangipani', 'is', 'onee', '3']
# ['Franjo', 'selective', 'Kamelot', '1']
# ['Frank', 'accepted', 'positione', '2']
# ['Frank', 'address', 'comment', '1']
# ['Frank', 'ask', 'Natasha', '1']
# ['Frank', 'ask', 'Peter', '1']
# ['Frank', 'become', 'family', '1']
# ['Frank', 'bring', 'recorded', '1']
# ['Frank', 'buys', 'property', '1']
# ['Frank', 'called', 'agent', '1']
# ['Frank', 'called', 'number', '3']
# ['Frank', 'chide', 'Joe', '1']
# ['Frank', 'closed', 'catalog', '1']
# ['Frank', 'collecting', 'things', '1']
# ['Frank', 'continueed', 'picnic', '1']
# ['Frank', 'development', 'ability', '1']
# ['Frank', 'displays', 'lot', '1']
# ['Frank', 'earned', 'doctorate', '3']
# ['Frank', 'elevate', 'medium', '1']
# ['Frank', 'emphasize', 'significance', '1']
# ['Frank', 'escort', 'team', '1']
# ['Frank', 'exhibition', 'products', '1']
# ['Frank', 'explain', 'decisional', '1']
# ['Frank', 'fold', 'arms', '1']
# ['Frank', 'found', 'time', '4']
# ['Frank', 'found', 'worked', '6']
# ['Frank', 'gave', 'ticket', '1']
# ['Frank', 'get', 'home', '1']
# ['Frank', 'give', 'listed', '1']
# ['Frank', 'got', 'jobs', '2']
# ['Frank', 'has', 'boyfriend', '2']
# ['Frank', 'has', 'cancer', '1']
# ['Frank', 'has', 'degreees', '1']
# ['Frank', 'has', 'interesting', '1']
# ['Frank', 'had', 'fleets', '1']
# ['Frank', 'is', 'descendant', '2']
# ['Frank', 'is', 'economist', '2']
# ['Frank', 'is', 'healer', '1']
# ['Frank', 'is', 'king', '1']
# ['Frank', 'is', 'moron', '1']
# ['Frank', 'is', 'professor', '5']
# ['Frank', 'is', 'proofreader', '1']
# ['Frank', 'is', 'specialist', '2']
# ['Frank', 'is', 'sweetness', '2']
# ['Frank', 'joined', 'MCS', '1']
# ['Frank', 'know', 'post', '1']
# ['Frank', 'lose', 'interesting', '1']
# ['Frank', 'made', 'appearance', '1']
# ['Frank', 'made', 'sandcastle', '1']
# ['Frank', 'made', 'shake', '1']
# ['Frank', 'magnify', 'office', '1']
# ['Frank', 'met', 'Rosa', '1']
# ['Frank', 'own', 'lands', '1']
# ['Frank', 'own', 'property', '1']
# ['Frank', 'pursued', 'Pepper', '2']
# ['Frank', 'put', 'bladed', '1']
# ['Frank', 'release', 'worked', '1']
# ['Frank', 'rememberance', 'woman', '1']
# ['Frank', 'reminding', 'students', '4']
# ['Frank', 'representation', 'progress', '2']
# ['Frank', 'smoke', 'cigars', '1']
# ['Frank', 'take', 'family', '2']
# ['Frank', 'useful', 'combination', '1']
# ['Frank', 'use', 'metaphor', '2']
# ['Frank', 'visiting', 'Vicalvi', '1']
# ['Frank', 'was', 'Justice', '1']
# ['Frank', 'was', 'bunting', '1']
# ['Frank', 'was', 'darling', '2']
# ['Frank', 'was', 'founder', '15']
# ['Frank', 'was', 'leader', '3']
# ['Frank', 'was', 'students', '1']
# ['Alvarado', 'rode', 'winners', '1']
# ['Armington', 'studying', 'arts', '1']
# ['Barlow', 'blackmails', 'McNulty', '1']
# ['Barr', 'was', 'pilot', '1']
# ['Baumgartner', 'is', 'owners', '1']
# ['Belknap', 'drank', 'alcohol', '2']
# ['Black', 'contributions', 'tracks', '1']
# ['Black', 'has', 'song', '1']
# ['Carter', 'highlighting', 'need', '1']
# ['Caruso', 'is', 'member', '4']
# ['Chief', 'mine', 'engineer', '1']
# ['Churchill', 'was', 'villains', '1']
# ['Cohen', 'is', 'onee', '1']
# ['Crean', 'second', 'motion', '1']
# ['Daniel', 'had', 'jurisdictionally', '1']
# ['Donelson', 'acquires', 'property', '1']
# ['Doyle', 'provide', 'MythBusters', '1']
# ['Fenton', 'becamee', 'foreman', '1']
# ['Ford', 'is', 'onee', '1']
# ['Gibson', 'is', 'moron', '2']
# ['Gilbane', 'present', 'assessment', '1']
# ['Groom', 'was', 'managerment', '1']
# ['Hanson', 'was', 'member', '1']
# ['Henry', 'had', 'onee', '1']
# ['Herbert', 'point', 'dilemma', '1']
# ['Jones', 'was', 'someone', '1']
# ['King', 'is', 'onee', '1']
# ['Knight', 'emphasize', 'instability', '1']
# ['Knight', 'was', 'host', '1']
# ['Knudsen', 'investigate', 'relationship', '1']
# ['Leslie', 'tossed', 'nuggeting', '1']
# ['Lloyd', 'attended', 'Kindergarten', '1']
# ['Lloyd', 'inspiration', 'architecture', '1']
# ['Lloyd', 'visiting', 'site', '1']
# ['Lovejoy', 'portrayed', 'man', '2']
# ['Luke', 'lost', 'life', '1']
# ['Manley', 'was', 'designer', '1']
# ['Martin', 'can', 'coached', '1']
# ['Martin', 'create', 'works', '3']
# ['McCourt', 'painted', 'picturees', '7']
# ['McDonald', 'net', 'fishing', '1']
# ['Mead', 'joined', 'firm', '1']
# ['Miller', 'make', 'appearance', '1']
# ['Miller', 'writing', 'seriese', '1']
# ['Miller', 'given', 'breath', '1']
# ['Mixter', 'was', 'pharmacist', '1']
# ['Morison', 'publishes', 'Stone', '2']
# ['Neal', 'has', 'cancer', '1']
# ['Nugent', 'spent', 'life', '1']
# ['Paul', 'plats', 'town', '2']
# ['Picarazzi', 'pleased', 'crowd', '1']
# ['Reese', 'hold', 'onee', '1']
# ['Rich', 'attack', 'Conservatism', '17']
# ['Riesling', 'was', 'favorite', '2']
# ['Robinson', 'put', 'namese', '1']
# ['Simon', 'praise', 'dedication', '1']
# ['Stella', 'offer', 'saviors', '1']
# ['Stronach', 'is', 'owners', '1']
# ['Tate', 'like', 'Lawson', '1']
# ['Thomas', 'has', 'total', '1']
# ['Trovato', 'ask', 'council', '1']
# ['Warner', 'closed', 'concerts', '2']
# ['Wilson', 'is', 'founder', '1']
# ['Work', 'made', 'determination', '2']
# ['Young', 'expressed', 'gratitude', '1']
# ['Zappa', 'facing', 'bat', '1']
# ['Potente', 'made', 'film', '1']
# ['Franke', 'find', 'supports', '1']
# ['Franke', 'left', 'Eurex', '1']
# ['Frankel', 'handle', 'numbers', '1']
# ['Franken', 'promotee', 'GOP', '1']
# ['Franken', 'raised', 'hands', '2']
# ['Franken', 'seeking', 'November', '1']
# ['Frankenberg', 'beginning', 'book', '1']
# ['Frankenstein', "'m", 'rising', '1']
# ['Frankenstein', 'is', 'result', '2']
# ['Frankenstein', 'view', 'tales', '3']
# ['Steven', 'kicking', 'Turn', '1']
# ['Frankfort', 'found', 'cartouche', '1']
# ['Frankfurt', 'do', 'dropped', '1']
# ['Frankfurt', 'was', 'heart', '1']
# ['International', 'experienced', 'onee', '1']
# ['Subversion', 'is', 'technique', '1']
# ['Frankfurter', 'got', 'jobs', '1']
# ['Frankfurter', 'has', 'intentionally', '1']
# ['Franki', 'have', 'loved', '1']
# ['Frankie', 'capture', 'zeitgeist', '1']
# ['Frankie', 'has', 'heat', '1']
# ['Frankie', 'maintained', 'contact', '1']
# ['Frankie', 'missed', 'jobs', '1']
# ['Frankie', 'was', 'everything', '1']
# ['Frankie', 'was', 'priest', '1']
# ['Vazquez', 'resonate', 'heart', '1']
# ['Frankincense', 'was', 'antidote', '1']
# ['Story', 'has', 'onee', '1']
# ['Frankland', 'hands', 'advantage', '1']
# ['Franklin', 'accepted', 'offer', '1']
# ['Franklin', 'appointed', 'Johnson', '1']
# ['Franklin', 'beat', 'Loreauville', '1']
# ['Franklin', 'believe', 'supply', '1']
# ['Franklin', 'bestowed', 'attention', '1']
# ['Franklin', 'bought', 'newspaper', '1']
# ['Franklin', 'compare', 'creation', '2']
# ['Franklin', 'continueed', 'involvement', '1']
# ['Franklin', 'demand', 'cessationism', '2']
# ['Franklin', 'denied', 'wrongdoing', '1']
# ['Franklin', 'did', 'worked', '1']
# ['Franklin', 'filed', 'Motion', '1']
# ['Franklin', 'including', 'instructions', '1']
# ['Franklin', 'is', 'grandfather', '1']
# ['Franklin', 'led', 'waye', '2']
# ['Franklin', 'like', 'ideas', '1']
# ['Franklin', 'made', 'experimental', '1']
# ['Franklin', 'made', 'treaty', '1']
# ['Franklin', 'offer', 'kind', '2']
# ['Franklin', 'organize', 'militia', '2']
# ['Franklin', 'performer', 'autopsy', '1']
# ['Franklin', 'prepare', 'foundationalism', '1']
# ['Franklin', 'produced', 'wealth', '1']
# ['Franklin', 'provide', 'namese', '1']
# ['Franklin', 'received', 'called', '1']
# ['Franklin', 'recorded', 'attributes', '2']
# ['Franklin', 'shucks', 'corn', '1']
# ['Franklin', 'started', 'life', '1']
# ['Franklin', 'understood', 'virtue', '1']
# ['Franklin', 'was', 'lobbyist', '1']
# ['Franklin', 'wearing', 'bifocals', '1']
# ['Betty', 'is', 'member', '2']
# ['Center', 'carrying', 'missions', '2']
# ['Conservation', 'welcome', 'comments', '2']
# ['County', 'Find', 'answers', '1']
# ['Delano', 'FDR', 'Memorial', '1']
# ['Delano', 'announced', 'decisional', '1']
# ['Delano', 'energize', 'national', '1']
# ['Delano', 'is', 'onee', '2']
# ['Institute', 'present', 'options', '1']
# ['Institute', 'present', 'Heart', '2']
# ['Junior', 'camryn', 'tapioca', '1']
# ['McDonald', 'summarize', 'discussions', '1']
# ['Morales', 'following', 'Francis', '1']
# ['Owens', 'was', 'principales', '1']
# ['Pierce', 'was', 'onee', '1']
# ['Research', 'is', 'programs', '1']
# ['Scholarship', 'was', 'push', '1']
# ['School', 'enjoy', 'supports', '1']
# ['Society', 'is', 'listed', '2']
# ['Street', 'meeting', 'Columbia', '1']
# ['Templeton', 'make', 'informationally', '1']
# ['apatite', 'contain', 'chlorine', '1']
# ['case', 'is', 'point', '3']
# ['indictment', 'point', 'waye', '1']
# ['kids', 'are', 'Justin', '4']
# ['Frankly', "'s", 'loaded', '2']
# ['Frankly', 'abandoned', 'mom', '1']
# ['Frankly', 'are', 'plenty', '2']
# ['Frankly', 'deserve', 'attention', '2']
# ['Frankly', 'enjoy', 'book', '3']
# ['Frankly', 'get', 'chance', '1']
# ['Frankly', 'got', 'attention', '1']
# ['Frankly', 'is', 'fishing', '1']
# ['Frankly', 'is', 'gobbledygook', '1']
# ['Frankly', 'lament', 'Cleland', '1']
# ['Frankly', 'look', 'fun', '4']
# ['Frankly', 'make', 'kind', '1']
# ['Frankly', 'missed', 'times', '1']
# ['Frankly', 'preferred', 'sake', '1']
# ['Frankly', 'save', 'time', '2']
# ['Frankly', 'thinks', 'IBM', '1']
# ['Frankly', 'thought', 'carnage', '1']
# ['Frankly', 'was', 'drawing', '1']
# ['Frankly', 'was', 'shit', '2']
# ['Frankly', 'wanted', 'leaders', '1']
# ['Frankly', 'were', 'people', '1']
# ['speaking', 'is', 'reason', '4']
# ['speaking', 'made', 'lot', '1']
# ['speaking', 'satsfi', 'air', '1']
# ['Franks', 'crossed', 'Rhine', '4']
# ['Franks', 'defeate', 'Saxons', '2']
# ['Franks', 'direct', 'invasione', '2']
# ['Franks', 'divide', 'Peloponnese', '1']
# ['Franks', 'recall', 'race', '1']
# ['Franks', 'spent', 'bulk', '1']
# ['Franks', 'stop', 'Moors', '2']
# ['Franks', 'take', 'time', '1']
# ['mayor', 'built', 'castle', '4']
# ['Frankweiler', 'made', 'dealing', '1']
# ['Franky', 'douglas', 'guitar', '1']
# ['Franky', 'show', 'use', '1']
# ['Frannie', 'feel', 'sanity', '1']
# ['Frannie', 'is', 'firm', '1']
# ['Frannie', 'like', 'waye', '1']
# ['Frannie', 'resemble', 'characterization', '1']
# ['Franny', "'s", 'time', '1']
# ['Lambi', 'is', 'onee', '1']
# ['Nauta', 'emphasise', 'need', '3']
# ['Franti', 'made', 'called', '1']
# ['Frantic', 'called', 'sister', '25']
# ['Frantic', 'is', 'forte', '1']
# ['Frantisek', 'make', 'mistake', '1']
# ['Frantz', 'was', 'onee', '3']
# ['Franz', 'knew', 'Hebrew', '1']
# ['Franz', 'loved', 'motorbike', '1']
# ['Franz', 'played', 'guitar', '1']
# ['Franz', 'took', 'watch', '1']
# ['Ackermann', 'is', 'onee', '1']
# ['Ferdinand', 'married', 'Sophie', '18']
# ['Ferdinand', 'went', 'mainstream', '1']
# ['Joseph', 'had', 'responsibility', '2']
# ['Lisp', 'was', 'Lisp', '1']
# ['Mertens', 'declines', 'chair', '10']
# ['Walter', 'do', 'shots', '1']
# ['Franzen', 'dropped', 'onee', '1']
# ['Fraport', 'manage', 'airports', '1']
# ['Fraps', 'are', 'waye', '1']
# ['Romantica', 'provideed', 'news', '1']
# ['Fraser', 'abandoned', 'project', '2']
# ['Fraser', 'becamee', 'center', '3']
# ['Fraser', 'cover', 'topics', '1']
# ['Fraser', 'has', 'cash', '1']
# ['Fraser', 'received', 'nomination', '3']
# ['Fraser', 'trace', 'developmental', '1']
# ['Fraser', 'treate', 'children', '1']
# ['Hansen', 'drill', 'couple', '1']
# ['Island', 'is', 'island', '1']
# ['Island', 'is', 'nature', '2']
# ['Valley', 'time', 'visiting', '1']
# ['Zoo', 'is', 'daye', '1']
# ['twins', 'are', 'result', '4']
# ['Fraternity', 'include', 'Coed', '1']
# ['Fraternity', 'was', 'objectives', '1']
# ['Phi', 'has', 'poles', '1']
# ['Fraternization', 'is', 'issue', '1']
# ['Fratricide', 'beginning', 'weekend', '1']
# ['Frau', 'is', 'twenty', '2']
# ['Fraud', 'assistant', 'paye', '1']
# ['Fraud', 'is', 'exchange', '4']
# ['Fraud', 'pay', 'online', '1']
# ['Eliminator', 'mentioned', 'daye', '1']
# ['Protection', 'are', 'victim', '1']
# ['Review', 'put', 'need', '1']
# ['Sciences', 'won', 'fans', '2']
# ['detection', 'has', 'touch', '1']
# ['liquidation', 'running', 'tractor', '1']
# ['prevention', 'offer', 'tips', '1']
# ['Consultants', 'find', 'consultantion', '1']
# ['informationally', 'Given', 'system', '1']
# ['Frauke', 'is', 'chairman', '1']
# ['Frauke', 'is', 'geniuses', '1']
# ['Anna', 'took', 'interesting', '1']
# ['Ursula', 'has', 'ability', '2']
# ['family', 'sold', 'business', '1']
# ['The', 'Help', 'answers', '1']
# ['Frazer', 'raised', 'family', '1']
# ['Frazier', 'attributed', 'resignation', '1']
# ['Frazier', 'had', 'brothers', '1']
# ['Frazier', 'is', 'insider', '1']
# ['Out', 'is', 'programme', '1']
# ['Freakin', 'take', 'responsibility', '1']
# ['Freaking', 'buys', 'onee', '1']
# ['Frec', 'was', 'video', '2']
# ['Freckles', 'dot', 'nose', '3']
# ['Fred', 'ask', 'members', '1']
# ['Fred', 'bemoaned', 'fact', '1']
# ['Fred', 'bet', 'savings', '1']
# ['Fred', 'climbing', 'peak', '1']
# ['Fred', 'commend', 'Eric', '1']
# ['Fred', 'delayed', 'release', '1']
# ['Fred', 'dining', 'daye', '1']
# ['Fred', 'doubt', 'loved', '1']
# ['Fred', 'employed', 'staff', '1']
# ['Fred', 'enforced', 'pace', '1']
# ['Fred', 'enters', 'ring', '1']
# ['Fred', 'experienced', 'attachment', '1']
# ['Fred', 'expressed', 'interesting', '1']
# ['Fred', 'following', 'lap', '1']
# ['Fred', 'gave', 'Christopher', '1']
# ['Fred', 'has', 'based', '1']
# ['Fred', 'had', 'nose', '1']
# ['Fred', 'have', 'shops', '1']
# ['Fred', 'hung', 'heads', '1']
# ['Fred', 'invited', 'Ray', '1']
# ['Fred', 'is', 'Algonquin', '1']
# ['Fred', 'is', 'animale', '1']
# ['Fred', 'is', 'answered', '1']
# ['Fred', 'is', 'example', '1']
# ['Fred', 'is', 'sweetie', '1']
# ['Fred', 'killed', 'two', '1']
# ['Fred', 'left', 'Michaelhouse', '1']
# ['Fred', 'like', 'Jack', '1']
# ['Fred', 'made', 'part', '1']
# ['Fred', 'make', 'sort', '1']
# ['Fred', 'measurements', 'block', '1']
# ['Fred', 'met', 'cheers', '2']
# ['Fred', 'played', 'guitar', '1']
# ['Fred', 'positione', 'chair', '1']
# ['Fred', 'rose', 'hands', '1']
# ['Fred', 'scanning', 'area', '1']
# ['Fred', 'shared', 'examples', '1']
# ['Fred', 'shut', 'mind', '1']
# ['Fred', 'started', 'adventure', '1']
# ['Fred', 'stretche', 'wings', '1']
# ['Fred', 'take', 'Renee', '1']
# ['Fred', 'take', 'drinks', '1']
# ['Fred', 'taught', 'methods', '1']
# ['Fred', 'told', 'Cordelia', '1']
# ['Fred', 'turn', 'pressure', '1']
# ['Fred', 'was', 'driver', '1']
# ['Fred', 'was', 'substance', '1']
# ['Fred', 'was', 'two', '1']
# ['Fred', 'went', 'river', '1']
# ['Abrahams', 'wrote', 'reported', '1']
# ['Alan', 'is', 'physicist', '2']
# ['Barnes', 'had', 'column', '1']
# ['Bear', 'help', 'developmental', '1']
# ['Brooks', 'coins', 'notion', '1']
# ['Brown', 'knock', 'pair', '6']
# ['Clark', 'information', 'board', '1']
# ['Couples', 'designate', 'course', '1']
# ['Couples', 'did', 'somethingism', '1']
# ['Couples', 'had', 'issues', '2']
# ['Delany', 'muffled', 'chuckle', '1']
# ['Evers', 'is', 'Professor', '1']
# ['Gray', 'took', 'oath', '1']
# ['Hall', 'filled', 'form', '1']
# ['Hammond', 'signed', 'group', '1']
# ['Haney', 'called', 'time', '1']
# ['Hutchinson', 'has', 'onee', '1']
# ['Jetson', 'was', 'relic', '1']
# ['Kogan', 'teache', 'arts', '1']
# ['Krueger', 'hit', 'air', '1']
# ['Lemieux', 'was', 'uncle', '1']
# ['Luskin', 'distill', 'process', '1']
# ['McAllister', 'thought', 'ideas', '1']
# ['Myer', 'pick', 'juice', '1']
# ['Pentland', 'was', 'coached', '1']
# ['Phelps', 'protest', 'funeral', '1']
# ['Reed', 'was', 'onee', '1']
# ['Rio', 'does', 'everything', '1']
# ['Rogers', 'complete', 'programs', '1']
# ['Singer', 'had', 'linkse', '1']
# ['Small', 'is', 'ministereal', '1']
# ['Stecker', 'accepted', 'positione', '2']
# ['Thompson', 'endorse', 'McCain', '3']
# ['Thompson', 'has', 'resume', '1']
# ['Thompson', 'is', 'member', '6']
# ['Thompson', 'joined', 'firm', '1']
# ['Thompson', 'is', 'congressman', '1']
# ['Thompson', 'promotee', 'fairness', '3']
# ['Thompson', 'has', 'marbles', '1']
# ['Thornburg', 'are', 'members', '2']
# ['Weiss', 'made', 'observationally', '1']
# ['fans', 'saw', 'magic', '1']
# ['Freda', 'blink', 'tearse', '2']
# ['Freda', 'had', 'doubt', '1']
# ['Band', 'played', 'mixed', '2']
# ['Freddie', 'encounter', 'Bentley', '1']
# ['Freddie', 'held', 'positione', '1']
# ['Freddie', 'is', 'daughter', '1']
# ['Freddie', 'misrepresentations', 'Dev', '1']
# ['Freddie', 'shook', 'heads', '3']
# ['Freddie', 'wracked', 'brain', '1']
# ['Frog', 'has', 'problems', '2']
# ['Mac', 'use', 'variety', '5']
# ['Mac', 'is', 'departure', '2']
# ['Frogs', 'have', 'variety', '20']
# ['Freddy', 'drove', 'van', '1']
# ['Freddy', 'has', 'patches', '1']
# ['Freddy', 'hid', 'belly', '1']
# ['Freddy', 'hold', 'hands', '1']
# ['Freddy', 'is', 'king', '1']
# ['Freddy', 'stop', 'van', '1']
# ['Freddy', 'was', 'eight', '1']
# ['Freddy', 'wearing', 'chains', '1']
# ['Freddy', 'wrote', 'lyrics', '2']
# ['Mercury', 'sang', 'song', '1']
# ['Napster', 'announced', 'debut', '1']
# ['Sanchez', 'had', 'onee', '14']
# ['Frederic', 'felt', 'called', '1']
# ['Frederic', 'hold', 'Master', '1']
# ['Frederic', 'received', 'sympathy', '1']
# ['Frederic', 'see', 'bevy', '1']
# ['Frederic', 'spend', 'time', '1']
# ['Frederick', 'crossed', 'border', '22']
# ['Frederick', 'fire', 'shots', '1']
# ['Frederick', 'found', 'ally', '1']
# ['Frederick', 'had', 'children', '2']
# ['Frederick', 'had', 'place', '1']
# ['Frederick', 'loaded', 'lunch', '1']
# ['Frederick', 'made', 'changes', '1']
# ['Frederick', 'press', 'worked', '1']
# ['Frederick', 'received', 'MFA', '1']
# ['Frederick', 'recognize', 'Louis', '7']
# ['Frederick', 'spent', 'morninge', '2']
# ['Boucher', 'drafted', 'bill', '1']
# ['Clotilda', 'is', 'net', '2']
# ['Cook', 'is', 'onee', '1']
# ['County', 'has', 'priority', '1']
# ['Delany', 'wanted', 'nothingness', '1']
# ['Douglass', 'find', 'needs', '1']
# ['Douglass', 'made', 'home', '1']
# ['Douglass', 'requirements', 'introductiones', '1']
# ['Funston', 'dealt', 'resistance', '1']
# ['Henry', 'prove', 'politician', '2']
# ['Luis', 'is', 'professor', '1']
# ['McKinley', 'invents', 'waye', '1']
# ['Neumann', 'was', 'man', '1']
# ['Parrot', 'reaching', 'peak', '1']
# ['Weaver', 'was', 'man', '1']
# ['Wentworth', 'is', 'onee', '3']
# ['William', 'central', 'administratione', '1']
# ['Wiseman', 'took', 'awards', '1']
# ['comfortable', 'facing', 'jacket', '1']
# ['police', 'are', 'onee', '1']
# ['Fredericks', 'include', 'chapter', '1']
# ['Fredericksburg', 'has', 'proliferation', '1']
# ['Fredericksburg', 'is', 'city', '4']
# ['Castle', 'funds', 'rebuilding', '2']
# ['Elementary', 'received', 'recognition', '1']
# ['Fredi', 'began', 'career', '1']
# ['Fredrick', 'provide', 'strains', '1']
# ['Malm', 'is', 'authorization', '2']
# ['Fredrikstad', 'was', 'fortress', '1']
# ['Fredy', 'accepted', 'forgiveness', '1']
# ['Free', 'Be', 'bee', '1']
# ['Free', 'Check', 'box', '1']
# ['Free', 'Come', 'Home', '1']
# ['Free', 'Include', 'Nonfiction', '1']
# ['Free', 'Take', 'Initiative', '1']
# ['Free', 'accelerate', 'Space', '1']
# ['Free', 'acne', 'diet', '1']
# ['Free', 'animate', 'signature', '2']
# ['Free', 'are', 'materiale', '1']
# ['Free', 'become', 'mania', '2']
# ['Free', 'california', 'home', '1']
# ['Free', 'collecting', 'news', '7']
# ['Free', 'competency', 'funding', '1']
# ['Free', 'designate', 'greye', '1']
# ['Free', 'download', 'music', '8']
# ['Free', 'expanding', 'result', '1']
# ['Free', 'explore', 'town', '1']
# ['Free', 'find', 'Free', '1']
# ['Free', 'get', 'strategy', '1']
# ['Free', 'give', 'donatione', '3']
# ['Free', 'giveaways', 'daye', '1']
# ['Free', 'have', 'problems', '1']
# ['Free', 'hit', 'counter', '28']
# ['Free', 'hunting', 'hayfield', '1']
# ['Free', 'include', 'quality', '1']
# ['Free', 'information', 'consent', '1']
# ['Free', 'is', 'Ryzom', '2']
# ['Free', 'is', 'chain', '2']
# ['Free', 'is', 'future', '4']
# ['Free', 'is', 'solution', '1']
# ['Free', 'is', 'system', '3']
# ['Free', 'licence', 'use', '2']
# ['Free', 'madness', 'events', '1']
# ['Free', 'make', 'pressure', '1']
# ['Free', 'move', 'world', '1']
# ['Free', 'offer', 'number', '1']
# ['Free', 'photoblogs', 'drives', '1']
# ['Free', 'pick', 'monster', '1']
# ['Free', 'post', 'named', '1']
# ['Free', 'reaching', 'goals', '3']
# ['Free', 'read', 'ephedra', '1']
# ['Free', 'receive', 'frames', '1']
# ['Free', 'recommendations', 'march', '1']
# ['Free', 'rememberance', 'ely', '1']
# ['Free', 'reward', 'materials', '1']
# ['Free', 's', 'slots', '1']
# ['Free', 'ship', 'pharmacy', '1']
# ['Free', 'sold', 'worked', '1']
# ['Free', 'stands', 'kids', '1']
# ['Free', 'submit', 'requesting', '484']
# ['Free', 'take', 'flight', '1']
# ['Free', 'turn', 'ideas', '1']
# ['Free', 'was', 'chairman', '1']
# ['Free', 'was', 'impetuses', '1']
# ['Free', 'worked', 'need', '2']
# ['Free', 'yarn', 'time', '3']
# ['Access', 'meaning', 'access', '1']
# ['Admission', 'was', 'responsibility', '1']
# ['Affidavit', 'leave', 'trails', '1']
# ['Air', 'are', 'satellite', '1']
# ['Amphetamine', 'relateed', 'downloads', '1']
# ['Animated', 'gave', 'answers', '1']
# ['Animated', 'lowered', 'eyesed', '1']
# ['Antivirus', 'expend', 'port', '1']
# ['Apple', 'crossed', 'mind', '1']
# ['Application', 'provideed', 'step', '1']
# ['Arabic', 'was', 'agee', '1']
# ['Article', 'Submit', 'articles', '2']
# ['Articles', 'provideed', 'tonsing', '1']
# ['Asian', 'cries', 'Wilder', '1']
# ['Atkins', 'allow', 'listed', '3']
# ['Auctions', 'are', 'property', '5']
# ['AutoCAD', 'Get', 'area', '1']
# ['Award', 'is', 'hopeful', '1']
# ['Azithromycin', 'relateed', 'downloads', '1']
# ['BPEL', 'is', 'cornerstone', '2']
# ['Baby', 'keep', 'deck', '1']
# ['Baldness', 'relateed', 'downloads', '2']
# ['Banners', 'reserve', 'right', '3']
# ['Banquet', 'attended', 'end', '1']
# ['Bartending', 'are', 'fun', '1']
# ['Best', 'redesigned', 'Avalon', '1']
# ['Birth', 'was', 'letter', '1']
# ['Blackjack', 'introduce', 'games', '4']
# ['Boobs', 'save', 'time', '1']
# ['Book', 'Submit', 'form', '1']
# ['Books', 'result', 'Scoliosis', '1']
# ['Bridal', 'cries', 'Frances', '1']
# ['Building', 'interrupt', 'Rose', '1']
# ['Calendar', 'download', 'acquaintance', '1']
# ['Calendars', 'ask', 'Rose', '1']
# ['Cash', 'Make', 'moneyer', '9']
# ['Casino', 'rewrite', 'number', '1']
# ['Christian', 'Blog', 'Subscribe', '1']
# ['Christian', 'is', 'optional', '1']
# ['Christmas', 'is', 'article', '1']
# ['Christmas', 'forgot', 'bailiff', '1']
# ['Christmas', 'light', 'results', '1']
# ['Classified', 'forgets', 'friends', '1']
# ['Clinic', 'is', 'waye', '1']
# ['Competitive', 'featureed', 'highlights', '1']
# ['Computer', 'Download', 'Thousands', '1']
# ['Congress', 'stresses', 'need', '1']
# ['Content', 'Give', 'visitors', '1']
# ['Copy', 'please', 'click', '1']
# ['Countries', 'carrying', 'threat', '1']
# ['Cover', 'Help', 'Access', '1']
# ['Credit', "'s", 'gifts', '1']
# ['Criminal', 'exclaim', 'colonel', '1']
# ['Daily', 'Extend', 'Horoscope', '8']
# ['Dash', 'relateed', 'downloads', '1']
# ['Demo', 'Give', 'IntelliCAD', '1']
# ['Depression', 'echo', 'practitioner', '1']
# ['Derry', 'met', 'countryside', '1']
# ['Dictionary', 'has', 'lots', '1']
# ['Diet', 'exclaim', 'Gershom', '1']
# ['Dissertations', 'is', 'onee', '1']
# ['Dive', 'Tee', 'Time', '1']
# ['Download', 'Enjoi', 'variety', '1']
# ['Download', 'filled', 'gaps', '1']
# ['Download', 'based', 'Life', '1']
# ['Download', 'learn', 'Urdu', '1']
# ['Downloads', 'is', 'tool', '1']
# ['Dvd', 'stretching', 'arms', '1']
# ['Editions', 'have', 'limitation', '1']
# ['Ela', 'has', 'chance', '1']
# ['Email', 'read', 'threads', '2']
# ['Embroidery', 'furnished', 'materiale', '1']
# ['Encyclopedia', 'is', 'formationism', '1']
# ['Enterprise', 'is', 'liberatore', '2']
# ['Entry', 'based', 'casino', '1']
# ['Family', 'is', 'picturees', '1']
# ['Fast', 'relateed', 'downloads', '1']
# ['File', 'studying', 'privacy', '1']
# ['Flu', 'show', 'interesting', '1']
# ['Food', 'grasp', 'arms', '1']
# ['Ford', 'named', 'Jaguar', '1']
# ['French', 'were', 'fore', '1']
# ['French', 'occupy', 'Syria', '1']
# ['Fundraising', 'Get', 'everything', '3']
# ['Funny', 'converted', 'innocence', '1']
# ['Funny', 'was', 'reason', '1']
# ['Gift', 'ask', 'questionable', '1']
# ['Gig', 'Select', 'site', '1']
# ['Glitter', 'demand', 'Spike', '1']
# ['Groups', 'loved', 'FREE', '1']
# ['Hair', 'relateed', 'downloads', '1']
# ['Hand', 'Quilt', 'Patterns', '1']
# ['Herbal', 'online', 'Website', '1']
# ['Hgh', 'relateed', 'downloads', '2']
# ['Hip', 'hop', 'lessons', '1']
# ['History', 'is', 'distribution', '1']
# ['Hit', 'hit', 'counter', '1']
# ['Hot', 'did', 'fire', '1']
# ['ISP', 'is', 'waye', '1']
# ['Information', 'are', 'click', '1']
# ['Insert', 'appended', 'texts', '1']
# ['Internet', 'cries', 'father', '1']
# ['Internet', 'set', 'engineeering', '1']
# ['Internet', 'offer', 'access', '3']
# ['Jeep', 'tires', 'part', '1']
# ['Kids', 'is', 'place', '1']
# ['Lake', 'christmas', 'cards', '1']
# ['Legal', 'please', 'contact', '1']
# ['Legal', 'answered', 'Cap', '1']
# ['Library', 'Check', 'site', '1']
# ['Life', 'offer', 'listings', '1']
# ['Linda', 'Find', 'Apartment', '1']
# ['Live', 'is', 'site', '2']
# ['Local', 'repeate', 'Lawton', '1']
# ['Lotrel', 'relateed', 'downloads', '1']
# ['Lunch', 'inhabitants', 'Gore', '1']
# ['Lupus', 'relateed', 'downloads', '1']
# ['MSN', 'is', 'tool', '1']
# ['Masons', 'have', 'duty', '1']
# ['Medication', 'Add', 'Spirituality', '1']
# ['Melissa', 'demand', 'Esther', '1']
# ['Microsoft', 'gave', 'pittance', '1']
# ['Microsoft', 'got', 'computerized', '1']
# ['Mobility', 'is', 'project', '1']
# ['Mom', 'stir', 'multitude', '1']
# ['Money', 'continueed', 'discussione', '2']
# ['Mortgage', 'took', 'moneyer', '1']
# ['Mortgage', 'Can', 'Mortgages', '1']
# ['Network', 'is', 'project', '1']
# ['Newsletter', 'offer', 'today', '2']
# ['Nutrition', 'offer', 'wealth', '1']
# ['Online', 'had', 'beauty', '1']
# ['Online', 'Pass', 'hands', '1']
# ['Online', 'offer', 'lining', '1']
# ['Online', 'are', 'tracks', '2']
# ['Online', 'spell', 'checked', '2']
# ['Online', 'is', 'Bridge', '1']
# ['PDF', 'eBook', 'Home', '1']
# ['Pain', 'relateed', 'downloads', '1']
# ['Palace', 'disbanding', 'capitol', '1']
# ['Parent', 'Get', 'obligation', '1']
# ['PayPal', 'nest', 'Protection', '1']
# ['Personal', 'was', 'commodore', '1']
# ['Personal', 'is', 'connectionism', '1']
# ['Photo', 'mount', 'charger', '1']
# ['Pictures', 'mutters', 'Jack', '1']
# ['Play', 'is', 'book', '1']
# ['Polyphonic', 'get', 'number', '12']
# ['Popular', 'relateed', 'downloads', '1']
# ['Pregnancy', 'online', 'source', '1']
# ['Premium', 'Lead', 'Click', '1']
# ['Press', 'exposed', 'Comcast', '1']
# ['Printed', 'Please', 'note', '1']
# ['Pritikin', 'online', 'source', '1']
# ['Programme', 'form', 'airports', '1']
# ['Psp', 'shook', 'heads', '1']
# ['Quote', 'has', 'years', '1']
# ['Radical', 'is', 'atoms', '7']
# ['Radio', 'is', 'group', '1']
# ['Reads', 'Please', 'note', '1']
# ['Real', 'Help', 'fear', '1']
# ['Records', 'was', 'rage', '1']
# ['Registration', 'take', 'seconds', '2']
# ['Republic', 'has', 'significance', '1']
# ['Residential', 'is', 'forerunner', '1']
# ['Resume', 'exclaim', 'Eve', '1']
# ['Reverse', 'Look', 'Ups', '1']
# ['Ringtones', 'mcgraw', 'ringtones', '1']
# ['Ringtones', 'find', 'center', '1']
# ['Ringtones', 'experienced', 'anguish', '1']
# ['Roaming', 'offer', 'chance', '1']
# ['SIP', 'make', 'entry', '1']
# ['Sample', 'were', 'children', '1']
# ['Sample', 'essays', 'mistake', '1']
# ['Samples', 'was', 'consorts', '1']
# ['Service', 'has', 'nose', '1']
# ['Setup', 'Get', 'informationally', '1']
# ['Sheet', 'download', 'lessons', '3']
# ['Smileys', 'Get', 'Smileys', '1']
# ['Sms', 'said', 'elder', '1']
# ['Sms', 'uploaded', 'pic', '1']
# ['Software', 'take', 'controlled', '2']
# ['Software', 'has', 'interpretatione', '1']
# ['Software', 'is', 'part', '1']
# ['Software', 'need', 'help', '26']
# ['Software', 'is', 'matter', '10']
# ['Software', 'is', 'utility', '1']
# ['Solitaire', 'expressed', 'service', '1']
# ['Song', 'wav', 'proceedings', '1']
# ['Sony', 'ntelos', 'ringtones', '1']
# ['Sony', 'filled', 'link', '2']
# ['Speech', 'was', 'Christian', '1']
# ['Sprint', 'give', 'commanded', '1']
# ['Stampin', 'see', 'charts', '1']
# ['State', 'achievements', 'autonomy', '6']
# ['State', 'took', 'part', '1']
# ['Stock', 'Is', 'onee', '1']
# ['Surveys', 'Allow', 'users', '1']
# ['Term', 'Find', 'insurance', '1']
# ['Testosterone', 'relateed', 'downloads', '2']
# ['Texas', 'dispute', 'point', '1']
# ['Tibet', 'Take', 'Action', '1']
# ['Tibet', 'told', 'Standard', '1']
# ['Tobradex', 'relateed', 'downloads', '1']
# ['Trade', 'is', 'blueprints', '1']
# ['Trade', 'is', 'sham', '1']
# ['Trade', 'promotee', 'rules', '2']
# ['Trappers', 'scours', 'mountains', '1']
# ['Trial', 'incorporate', 'number', '1']
# ['Trials', 'online', 'adventures', '1']
# ['Trials', 'rate', 'service', '2']
# ['Tuition', 'target', 'students', '1']
# ['UPS', 'ground', 'shipping', '1']
# ['Unclaimed', 'abandoned', 'funds', '1']
# ['Underground', 'exclaim', 'Paul', '1']
# ['Valentine', 'is', 'time', '1']
# ['Video', 'offer', 'firewood', '1']
# ['Vioxx', 'relateed', 'downloads', '1']
# ['Virtual', 'round', 'point', '1']
# ['Visual', 'Check', 'set', '2']
# ['Weather', 'WA', 'Clear', '1']
# ['Web', 'is', 'collectiones', '2']
# ['Web', 'is', 'collectiones', '1']
# ['Website', 'use', 'frames', '1']
# ['Wedding', 'word', 'ideas', '1']
# ['White', 'depending', 'center', '1']
# ['White', 'lose', 'weight', '1']
# ['Zantac', 'relateed', 'downloads', '1']
# ['Zip', 'cries', 'Roderick', '1']
# ['Zithromax', 'relateed', 'downloads', '2']
# ['Zone', 'have', 'pretexts', '1']
# ['ads', 'Visit', 'shops', '1']
# ['agency', 'is', 'functions', '5']
# ['arrowhead', 'joined', 'Bond', '1']
# ['articles', 'make', 'moneyer', '2']
# ['artwork', 'make', 'place', '1']
# ['astrology', 'chatting', 'room', '2']
# ['autographs', 'was', 'internet', '1']
# ['banking', 'include', 'restrictions', '2']
# ['bare', 'have', 'parts', '1']
# ['beautifull', 'brides', 'ads', '1']
# ['board', 'are', 'part', '1']
# ['booze', 'is', 'tempting', '1']
# ['broadband', 'relateed', 'downloads', '1']
# ['buye', 'download', 'instructions', '1']
# ['called', 'saw', 'bingo', '1']
# ['car', 'quote', 'auto', '3']
# ['car', 'selective', 'onee', '1']
# ['carse', 'middot', 'properties', '1']
# ['casino', 'are', 'waye', '1']
# ['cell', 'sprint', 'http', '1']
# ['clips', 'Find', 'licensees', '1']
# ['collections', 's', 'flashlight', '1']
# ['communicationes', 'is', 'default', '1']
# ['conversione', 'make', 'difference', '1']
# ['coupons', 'online', 'games', '1']
# ['credit', 'reported', 'sites', '1']
# ['data', 'acquire', 'data', '1']
# ['diet', 'relateed', 'downloads', '1']
# ['diving', 'is', 'exercise', '1']
# ['download', 'is', 'Diva', '1']
# ['download', 'is', 'Diva', '1']
# ['download', 'is', 'Diva', '1']
# ['email', 'is', 'Adobe', '1']
# ['enterprise', 'is', 'basises', '1']
# ['exercise', 'meaning', 'freedom', '1']
# ['forum', 'relateed', 'downloads', '1']
# ['fruits', 'relateed', 'downloads', '1']
# ['funds', 'had', 'application', '1']
# ['funnye', 'put', 'picturees', '2']
# ['gaming', 'deserve', 'reputation', '2']
# ['girls', 'relateed', 'downloads', '1']
# ['hair', 'relateed', 'downloads', '1']
# ['including', 's', 'party', '1']
# ['info', 'Find', 'shops', '3']
# ['instant', 'reported', 'Calculators', '2']
# ['jasmine', 'hopeful', 'boost', '2']
# ['jazz', 'representation', 'freedom', '2']
# ['keywords', 'appears', 'They', '2']
# ['life', 'Optimize', 'system', '1']
# ['listed', 'serveed', 'membership', '1']
# ['meditationes', 'download', 'Worl', '1']
# ['membership', 'promotee', 'research', '1']
# ['migration', 'is', 'positione', '1']
# ['music', 'have', 'onee', '1']
# ['named', 'net', 'biz', '1']
# ['offers', 'info', 'Colleges', '1']
# ['online', 'is', 'women', '1']
# ['online', 'gine', 'system', '1']
# ['online', 'ensure', 'authors', '1']
# ['online', 'ged', 'diploma', '2']
# ['online', 'Add', 'items', '1']
# ['online', 'provideed', 'informationally', '1']
# ['online', 'need', 'seat', '1']
# ['online', 'know', 'home', '1']
# ['online', 'is', 'onee', '1']
# ['online', 'launche', 'makers', '1']
# ['patients', 'apply', 'eleven', '1']
# ['poker', 'include', 'informationally', '1']
# ['poker', 'variant', 'casino', '1']
# ['poker', 'win', 'prize', '1']
# ['poker', 'accepted', 'bonuses', '1']
# ['poker', 'is', 'raise', '1']
# ['press', 'get', 'beating', '2']
# ['price', 'cause', 'rhetoric', '1']
# ['prize', 'drawing', 'terms', '2']
# ['publicity', 'help', 'everyone', '1']
# ['puppy', 'had', 'kicking', '1']
# ['quotations', 'collecting', 'informationally', '1']
# ['quotes', 'relateed', 'downloads', '1']
# ['race', 'illustrate', 'midwayer', '1']
# ['racketeering', 'have', 'site', '1']
# ['rangee', 'is', 'backwardness', '1']
# ['rangee', 'are', 'onee', '1']
# ['real', 'lead', 'Unique', '6']
# ['reported', 'explore', 'costs', '1']
# ['ringtones', 'chatting', 'contact', '1']
# ['ringtones', 'is', 'summary', '1']
# ['salsa', 'enhance', 'eveninger', '4']
# ['schools', 'accreditation', 'schools', '1']
# ['secrets', 'relateed', 'downloads', '1']
# ['seriese', 'reported', 'Click', '1']
# ['shield', 'relateed', 'downloads', '1']
# ['shipping', 'are', 'part', '4']
# ['shipping', 'is', 'keyes', '2']
# ['shipping', 'punch', 'tin', '1']
# ['signed', 'win', 'moneyer', '1']
# ['slots', 'spin', 'slots', '1']
# ['softwareed', 'Attend', 'onee', '1']
# ['softwareed', 'need', 'vision', '1']
# ['softwareed', 'offer', 'freedom', '2']
# ['softwareed', 'supports', 'competition', '1']
# ['softwareed', 'contribute', 'time', '2']
# ['speech', 'include', 'dance', '1']
# ['speech', 'is', 'methods', '2']
# ['spillway', 'outweighs', 'Toshiba', '1']
# ['spironolactone', 'relateed', 'downloads', '1']
# ['storyes', 'depict', 'time', '1']
# ['study', 'sefer', 'offers', '1']
# ['stuff', 'project', 'Use', '1']
# ['talented', 'classify', 'ads', '1']
# ['testosterone', 'is', 'measuremental', '1']
# ['testosterone', 'relateed', 'downloads', '1']
# ['texas', 'apply', 'school', '1']
# ['trade', 'accelerate', 'rate', '1']
# ['trade', 'ease', 'passage', '1']
# ['traffic', 'has', 'cost', '3']
# ['training', 'is', 'trademarked', '2']
# ['transition', 'is', 'onee', '1']
# ['transportation', 'exposee', 'products', '1']
# ['treatments', 'Find', 'Information', '1']
# ['trial', 'Find', 'Information', '3']
# ['true', 'pc', 'ringtones', '1']
# ['typicall', 'are', 'theism', '1']
# ['typing', 'Are', 'light', '1']
# ['versions', 'allow', 'maximum', '2']
# ['vibe', 'is', 'organizationally', '1']
# ['webmaster', 'find', 'rangee', '2']
# ['website', 'create', 'website', '1']
# ['weight', 'Find', 'Price', '1']
# ['will', 'is', 'culprit', '1']
# ['will', 'was', 'denial', '4']
# ['worked', 'was', 'ride', '1']
# ['xxx', 'value', 'business', '1']
# ['oxidation', 'causeed', 'depletion', '1']
# ['children', 'was', 'rules', '1']
# ['horses', 'eating', 'lot', '2']
# ['Arabs', 'refute', 'premises', '1']
# ['FreeAdvice', 'find', 'lawyer', '1']
# ['FreeMarker', 'has', 'access', '2']
# ['FreeNAS', 'recognize', 'drives', '3']
# ['Blog', 'visiting', 'blog', '1']
# ['FreeSurfer', 'supports', 'conversione', '1']
# ['site', 'is', 'place', '1']
# ['Freebee', 'has', 'manners', '1']
# ['Freebie', 'are', 'companies', '1']
# ['Stop', 'is', 'pride', '1']
# ['Freed', 'can', 'crowd', '1']
# ['Freed', 'demonstrate', 'prowess', '1']
# ['Freed', 'is', 'nose', '1']
# ['Freedman', 'saw', 'need', '1']
# ['Center', 'is', 'partnership', '1']
# ['Freedmen', 'is', 'part', '1']
# ['Freedom', 'are', 'minority', '1']
# ['Freedom', 'are', 'nature', '1']
# ['Freedom', 'are', 'tools', '1']
# ['Freedom', 'broadcast', 'alerted', '1']
# ['Freedom', 'choose', 'loaned', '1']
# ['Freedom', 'enriche', 'humanity', '1']
# ['Freedom', 'exercise', 'choice', '1']
# ['Freedom', 'gave', 'substance', '2']
# ['Freedom', 'get', 'copy', '2']
# ['Freedom', 'got', 'minutes', '1']
# ['Freedom', 'have', 'bishops', '2']
# ['Freedom', 'have', 'fun', '6']
# ['Freedom', 'imply', 'freedom', '5']
# ['Freedom', 'is', 'conversationally', '1']
# ['Freedom', 'is', 'copy', '1']
# ['Freedom', 'is', 'corollary', '3']
# ['Freedom', 'is', 'creation', '2']
# ['Freedom', 'is', 'enterprise', '1']
# ['Freedom', 'is', 'fragrance', '1']
# ['Freedom', 'is', 'future', '1']
# ['Freedom', 'is', 'implication', '1']
# ['Freedom', 'is', 'incentive', '1']
# ['Freedom', 'is', 'nonsense', '2']
# ['Freedom', 'is', 'proclamation', '1']
# ['Freedom', 'is', 'progenitor', '1']
# ['Freedom', 'is', 'renunciation', '1']
# ['Freedom', 'is', 'salvationism', '1']
# ['Freedom', 'lick', 'blood', '2']
# ['Freedom', 'made', 'presentation', '1']
# ['Freedom', 'meaning', 'loved', '3']
# ['Freedom', 'meaning', 'restraints', '1']
# ['Freedom', 'meaning', 'right', '22']
# ['Freedom', 'permitted', 'ubiquity', '1']
# ['Freedom', 'present', 'results', '2']
# ['Freedom', 'provideed', 'anonymity', '2']
# ['Freedom', 'provideed', 'groups', '1']
# ['Freedom', 'require', 'knowledge', '1']
# ['Freedom', 'send', 'requesting', '2']
# ['Freedom', 'serveed', 'Gal', '1']
# ['Freedom', 'supersede', 'rules', '1']
# ['Freedom', 'took', 'root', '1']
# ['Freedom', 'utilize', 'semantics', '1']
# ['Freedom', 'was', 'heritage', '1']
# ['Freedom', 'was', 'issue', '1']
# ['Freedom', 'was', 'leader', '1']
# ['Freedom', 'was', 'materiale', '1']
# ['Freedom', 'was', 'result', '1']
# ['Freedom', 'yielding', 'peace', '1']
# ['Pharmacy', 'is', 'onee', '20']
# ['Pledge', 'take', 'words', '2']
# ['Press', 'played', 'host', '1']
# ['Riders', 'left', 'Montgomery', '1']
# ['Shrine', 'is', 'collectiones', '2']
# ['cannon', 'lead', 'stores', '1']
# ['fighters', 'capture', 'heart', '1']
# ['winners', 'is', 'listed', '1']
# ['Freeganism', 'is', 'lifestyle', '1']
# ['Raceway', 'reconstructed', 'racetrack', '1']
# ['Township', 'is', 'onee', '1']
# ['women', 'reduceed', 'risk', '1']
# ['stalker', 'ambushe', 'fixation', '1']
# ['Freel', 'get', 'chances', '1']
# ['Scottish', 'saw', 'scoops', '1']
# ['illustrator', 'forced', 'retirement', '1']
# ['writer', 'teache', 'yoga', '1']
# ['registeration', 'get', 'projects', '1']
# ['Freelancing', 'save', 'moneyer', '1']
# ['Freeland', 'questionable', 'Boyd', '1']
# ['Freelon', 'transformers', 'museum', '1']
# ['Freely', 'shared', 'stories', '1']
# ['Freeman', 'becamee', 'publisher', '1']
# ['Freeman', 'blending', 'sense', '1']
# ['Freeman', 'give', 'hopeful', '1']
# ['Freeman', 'has', 'answered', '2']
# ['Freeman', 'have', 'saye', '1']
# ['Freeman', 'is', 'guye', '1']
# ['Freeman', 'like', 'Williams', '1']
# ['Freeman', 'need', 'break', '1']
# ['Freeman', 'quoted', 'Turner', '2']
# ['Freeman', 'recognize', 'difference', '1']
# ['Freeman', 'revealed', 'origins', '2']
# ['Freeman', 'trace', 'historyes', '2']
# ['Freeman', 'uploaded', 'tracks', '1']
# ['Freeman', 'was', 'pastor', '1']
# ...
# ['God', 'instigate', 'Sabbath', '2']
# ['God', 'institute', 'union', '2']
# ['God', 'interpretations', 'Word', '9']
# ['God', 'interrupt', 'thoughts', '2']
# ['God', 'introduced', 'Christianity', '1']
# ['God', 'introduced', 'number', '2']
# ['God', 'introduce', 'informationally', '1']
# ['God', 'invents', 'psychology', '2']
# ['God', 'invents', 'vodka', '1']
# ['God', 'invoke', 'ideas', '1']
# ['God', 'is', 'Author', '92']
# ['God', 'is', 'Divine', '8']
# ['God', 'is', 'End', '1']
# ['God', 'is', 'LOT', '1']
# ['God', 'is', 'Mercifull', '1']
# ['God', 'is', 'Nation', '2']
# ['God', 'is', 'Seen', '3']
# ['God', 'is', 'adversary', '2']
# ['God', 'is', 'apprenticees', '4']
# ['God', 'is', 'archangel', '1']
# ['God', 'is', 'blessedness', '4']
# ['God', 'is', 'bliss', '7']
# ['God', 'is', 'chump', '2']
# ['God', 'is', 'comparison', '1']
# ['God', 'is', 'containerization', '2']
# ['God', 'is', 'dangerous', '2']
# ['God', 'is', 'determiner', '3']
# ['God', 'is', 'endlessness', '1']
# ['God', 'is', 'enigma', '2']
# ['God', 'is', 'exacting', '1']
# ['God', 'is', 'fairytale', '2']
# ['God', 'is', 'flowering', '1']
# ['God', 'is', 'gained', '1']
# ['God', 'is', 'gecko', '1']
# ['God', 'is', 'homeboy', '2']
# ['God', 'is', 'hub', '1']
# ['God', 'is', 'illusionism', '20']
# ['God', 'is', 'island', '4']
# ['God', 'is', 'king', '99']
# ['God', 'is', 'lands', '1']
# ['God', 'is', 'magician', '1']
# ['God', 'is', 'mediatore', '2']
# ['God', 'is', 'memory', '2']
# ['God', 'is', 'mindfullness', '24']
# ['God', 'is', 'nature', '35']
# ['God', 'is', 'optional', '2']
# ['God', 'is', 'provider', '132']
# ['God', 'is', 'recipient', '1']
# ['God', 'is', 'substitutionism', '1']
# ['God', 'is', 'utterance', '1']
# ['God', 'is', 'value', '1']
# ['God', 'is', 'wafflers', '2']
# ['God', 'joined', 'Satan', '1']
# ['God', 'joined', 'issue', '1']
# ['God', 'justified', 'believers', '2']
# ['God', 'keep', 'records', '3']
# ['God', 'kept', 'affectionately', '1']
# ['God', 'kept', 'watch', '1']
# ['God', 'knew', 'Cyrus', '1']
# ['God', 'knew', 'contents', '1']
# ['God', 'knew', 'experiencee', '1']
# ['God', 'knew', 'ingratitude', '2']
# ['God', 'knew', 'kind', '12']
# ['God', 'knew', 'need', '10']
# ['God', 'knew', 'road', '1']
# ['God', 'know', 'Beware', '1']
# ['God', 'know', 'Life', '2']
# ['God', 'know', 'article', '2']
# ['God', 'know', 'backwards', '1']
# ['God', 'know', 'citizens', '2']
# ['God', 'know', 'concepts', '1']
# ['God', 'know', 'creatures', '5']
# ['God', 'know', 'daddy', '1']
# ['God', 'know', 'disasters', '2']
# ['God', 'know', 'fact', '3']
# ['God', 'know', 'inventiones', '1']
# ['God', 'know', 'keywords', '1']
# ['God', 'know', 'language', '3']
# ['God', 'know', 'mind', '9']
# ['God', 'know', 'sir', '2']
# ['God', 'know', 'situationally', '21']
# ['God', 'know', 'step', '1']
# ['God', 'know', 'stresses', '3']
# ['God', 'know', 'values', '2']
# ['God', 'know', 'word', '2']
# ['God', 'know', 'years', '1']
# ['God', 'lacks', 'personality', '1']
# ['God', 'lay', 'plan', '6']
# ['God', 'lay', 'wisdom', '1']
# ['God', 'laid', 'messagees', '3']
# ['God', 'lead', 'children', '5']
# ['God', 'lead', 'creation', '2']
# ['God', 'lead', 'others', '2']
# ['God', 'learn', 'nothingness', '1']
# ['God', 'leaveth', 'point', '1']
# ['God', 'led', 'family', '2']
# ['God', 'left', 'Satanstoe', '1']
# ['God', 'left', 'resting', '11']
# ['God', 'let', 'dreams', '1']
# ['God', 'let', 'hopeful', '2']
# ['God', 'lifting', 'spiritseers', '1']
# ['God', 'lighten', 'burden', '2']
# ['God', 'like', 'flesh', '1']
# ['God', 'look', 'category', '1']
# ['God', 'lost', 'bet', '1']
# ['God', 'lost', 'place', '2']
# ['God', 'loved', 'Aloha', '1']
# ['God', 'loved', 'Americans', '4']
# ['God', 'loved', 'everyone', '243']
# ['God', 'loved', 'humor', '7']
# ['God', 'loved', 'kids', '16']
# ['God', 'loved', 'named', '1']
# ['God', 'loved', 'outcasts', '2']
# ['God', 'loved', 'piety', '2']
# ['God', 'loved', 'state', '1']
# ['God', 'loved', 'trinity', '1']
# ['God', 'loved', 'waye', '4']
# ['God', 'made', 'MEN', '2']
# ['God', 'made', 'Man', '65']
# ['God', 'made', 'Mexx', '1']
# ['God', 'made', 'Queensland', '1']
# ['God', 'made', 'Son', '1']
# ['God', 'made', 'Woman', '4']
# ['God', 'made', 'dark', '1']
# ['God', 'made', 'honoring', '2']
# ['God', 'made', 'judgment', '2']
# ['God', 'made', 'law', '17']
# ['God', 'made', 'likeness', '3']
# ['God', 'made', 'loved', '6']
# ['God', 'made', 'nuts', '1']
# ['God', 'made', 'opposites', '1']
# ['God', 'made', 'parts', '2']
# ['God', 'made', 'references', '1']
# ['God', 'made', 'sounds', '5']
# ['God', 'made', 'space', '148']
# ['God', 'made', 'throated', '1']
# ['God', 'made', 'vegetationally', '1']
# ['God', 'magnify', 'Word', '2']
# ['God', 'maintained', 'faithfulness', '2']
# ['God', 'make', 'service', '1']
# ['God', 'make', 'snow', '1']
# ['God', 'manifested', 'Rom', '2']
# ['God', 'manipulate', 'elementse', '2']
# ['God', 'marks', 'lane', '1']
# ['God', 'meaning', 'Love', '1']
# ['God', 'meaning', 'injustice', '2']
# ['God', 'meaning', 'life', '1']
# ['God', 'mendes', 'things', '2']
# ['God', 'misdirected', 'Satan', '1']
# ['God', 'molded', 'Israelites', '1']
# ['God', 'move', 'Sun', '1']
# ['God', 'move', 'throne', '1']
# ['God', 'multiplied', 'everything', '2']
# ['God', 'named', 'Obama', '2']
# ['God', 'need', 'encouragement', '1']
# ['God', 'need', 'nobody', '1']
# ['God', 'neglect', 'gifts', '4']
# ['God', 'nod', 'heads', '3']
# ['God', 'notifying', 'creatures', '1']
# ['God', 'obey', 'voice', '1']
# ['God', 'observed', 'faith', '1']
# ['God', 'offer', 'Church', '1']
# ['God', 'offer', 'mysteryes', '1']
# ['God', 'offer', 'named', '1']
# ['God', 'offer', 'possibility', '6']
# ['God', 'offer', 'storyes', '1']
# ['God', 'offer', 'truth', '10']
# ['God', 'orchestrate', 'events', '9']
# ['God', 'ordained', 'confusional', '1']
# ['God', 'ordained', 'doubt', '1']
# ['God', 'ordained', 'purpose', '1']
# ['God', 'order', 'Moses', '15']
# ['God', 'order', 'whaling', '2']
# ['God', 'organize', 'seasons', '1']
# ['God', 'outline', 'terms', '1']
# ['God', 'overcome', 'everything', '1']
# ['God', 'overlooked', 'ignorance', '4']
# ['God', 'oversee', 'oppressional', '1']
# ['God', 'oversee', 'world', '1']
# ['God', 'overthrew', 'tower', '2']
# ['God', 'owed', 'forgiveness', '3']
# ['God', 'owees', 'pardons', '2']
# ['God', 'penetrate', 'communityism', '2']
# ['God', 'permitted', 'Pope', '1']
# ['God', 'permitted', 'enemyes', '1']
# ['God', 'permitted', 'pain', '2']
# ['God', 'permitted', 'somethingism', '8']
# ['God', 'pervade', 'thing', '1']
# ['God', 'place', 'Jesus', '2']
# ['God', 'place', 'Mohammed', '1']
# ['God', 'place', 'foot', '1']
# ['God', 'place', 'world', '1']
# ['God', 'plan', 'Christmas', '1']
# ['God', 'plan', 'pattern', '1']
# ['God', 'plant', 'thinks', '1']
# ['God', 'poured', 'answers', '1']
# ['God', 'poured', 'spirit', '12']
# ['God', 'pre-design', 'universe', '1']
# ['God', 'pre-plan', 'raped', '3']
# ['God', 'precede', 'choice', '2']
# ['God', 'predestination', 'damnatione', '1']
# ['God', 'predestination', 'process', '1']
# ['God', 'predestination', 'qualification', '2']
# ['God', 'predetermine', 'things', '4']
# ['God', 'preferred', 'tolerance', '1']
# ['God', 'prepare', 'plan', '4']
# ['God', 'present', 'grant', '1']
# ['God', 'produced', 'vegetationally', '1']
# ['God', 'produce', 'agee', '1']
# ['God', 'produce', 'righteousness', '1']
# ['God', 'produce', 'saints', '1']
# ['God', 'produce', 'spirit', '1']
# ['God', 'promise', 'Solomon', '1']
# ['God', 'promisee', 'David', '1']
# ['God', 'promisee', 'Israel', '1']
# ['God', 'promisee', 'Moshe', '1']
# ['God', 'prop', 'eyesed', '1']
# ['God', 'proposeth', 'instance', '2']
# ['God', 'protective', 'Christians', '1']
# ['God', 'protective', 'brood', '1']
# ['God', 'protective', 'loved', '5']
# ['God', 'prove', 'promisee', '2']
# ['God', 'provide', 'stairs', '1']
# ['God', 'provide', 'symbolism', '1']
# ['God', 'provide', 'witnesses', '1']
# ['God', 'provideed', 'Purple', '1']
# ['God', 'provideed', 'narrative', '1']
# ['God', 'provideed', 'onee', '3']
# ['God', 'provideed', 'training', '1']
# ['God', 'punish', 'angels', '1']
# ['God', 'punish', 'hammer', '1']
# ['God', 'punishe', 'carelessness', '1']
# ['God', 'purge', 'earth', '1']
# ['God', 'purge', 'world', '1']
# ['God', 'put', 'Man', '2']
# ['God', 'put', 'Son', '1']
# ['God', 'put', 'enmity', '12']
# ['God', 'put', 'evil', '2']
# ['God', 'put', 'heart', '1']
# ['God', 'put', 'kind', '3']
# ['God', 'put', 'law', '9']
# ['God', 'put', 'motion', '1']
# ['God', 'put', 'understanding', '3']
# ['God', 'put', 'wall', '2']
# ['God', 'quickened', 'spirit', '1']
# ['God', 'raineth', 'snares', '1']
# ['God', 'raised', 'Dorcas', '1']
# ['God', 'raised', 'onee', '2']
# ['God', 'reaching', 'heart', '2']
# ['God', 'reacheed', 'goal', '2']
# ['God', 'read', 'Quran', '1']
# ['God', 'received', 'Glory', '2']
# ['God', 'receive', 'tithe', '1']
# ['God', 'recommendations', 'meat', '1']
# ['God', 'recorded', 'times', '1']
# ['God', 'redeems', 'faithfull', '2']
# ['God', 'refine', 'ugliness', '1']
# ['God', 'regulate', 'measure', '1']
# ['God', 'reissue', 'law', '1']
# ['God', 'reiterate', 'provisions', '1']
# ['God', 'remained', 'dispenser', '1']
# ['God', 'rememberance', 'Rahab', '1']
# ['God', 'rememberance', 'sinful', '10']
# ['God', 'removal', 'ABRAHAM', '1']
# ['God', 'removal', 'grass', '1']
# ['God', 'remove', 'causeed', '1']
# ['God', 'remove', 'consequence', '1']
# ['God', 'remove', 'defect', '2']
# ['God', 'remove', 'sicknesse', '4']
# ['God', 'replace', 'Time', '1']
# ['God', 'reprobate', 'others', '1']
# ['God', 'requirements', 'Israelites', '5']
# ['God', 'require', 'life', '5']
# ['God', 'require', 'preparedness', '4']
# ['God', 'respite', 'soul', '1']
# ['God', 'resume', 'programs', '2']
# ['God', 'returns', 'people', '2']
# ['God', 'revealed', 'data', '1']
# ['God', 'revealed', 'details', '6']
# ['God', 'revealed', 'essence', '2']
# ['God', 'revealed', 'reason', '2']
# ['God', 'revealed', 'rules', '1']
# ['God', 'revealed', 'understanding', '2']
# ['God', 'reveald', 'Word', '1']
# ['God', 'reviews', 'deeds', '1']
# ['God', 'reward', 'Russell', '1']
# ['God', 'reward', 'onee', '2']
# ['God', 'ritual', 'covenantal', '1']
# ['God', 'root', 'selfishness', '1']
# ['God', 'round', 'team', '1']
# ['God', 'satisfied', 'God', '3']
# ['God', 'save', 'Mordechai', '1']
# ['God', 'save', 'SBC', '1']
# ['God', 'save', 'countrye', '20']
# ['God', 'saw', 'Light', '1']
# ['God', 'saw', 'anything', '1']
# ['God', 'saw', 'change', '1']
# ['God', 'saw', 'dancing', '1']
# ['God', 'saw', 'faith', '10']
# ['God', 'scandal', 'people', '1']
# ['God', 'scattering', 'seed', '1']
# ['God', 'seal', 'promises', '1']
# ['God', 'security', 'forgiveness', '1']
# ['God', 'see', 'adultery', '1']
# ['God', 'see', 'hatred', '7']
# ['God', 'see', 'nakedness', '1']
# ['God', 'see', 'wickedness', '7']
# ['God', 'seeking', 'response', '2']
# ['God', 'seem', 'nonexistent', '1']
# ['God', 'selective', 'people', '4']
# ['God', 'send', 'Adam', '13']
# ['God', 'send', 'Plagues', '1']
# ['God', 'send', 'army', '1']
# ['God', 'send', 'believers', '1']
# ['God', 'send', 'hell', '2']
# ['God', 'send', 'professor', '2']
# ['God', 'send', 'watchmen', '1']
# ['God', 'sent', 'Maureen', '1']
# ['God', 'sent', 'PAGE', '1']
# ['God', 'sent', 'encouragement', '2']
# ['God', 'sent', 'friends', '2']
# ['God', 'sent', 'home', '4']
# ['God', 'sent', 'sacrifice', '1']
# ['God', 'sent', 'tailored', '1']
# ['God', 'sent', 'verse', '7']
# ['God', 'serveed', 'moneyer', '1']
# ['God', 'set', 'Judas', '1']
# ['God', 'set', 'depth', '1']
# ['God', 'set', 'kingdom', '11']
# ['God', 'set', 'teaching', '1']
# ['God', 'shaped', 'Christians', '2']
# ['God', 'shaped', 'thinking', '4']
# ['God', 'shone', 'spotlight', '1']
# ['God', 'show', 'Grace', '3']
# ['God', 'show', 'Jesus', '1']
# ['God', 'show', 'earth', '3']
# ['God', 'show', 'existence', '1']
# ['God', 'show', 'onee', '3']
# ['God', 'show', 'promises', '1']
# ['God', 'show', 'world', '6']
# ['God', 'shown', 'impotence', '1']
# ['God', 'shut', 'mouth', '2']
# ['God', 'simplify', 'son', '1']
# ['God', 'smiting', 'kittens', '2']
# ['God', 'smiting', 'sinner', '1']
# ['God', 'solve', 'problems', '21']
# ['God', 'sort', 'electioneering', '4']
# ['God', 'spared', 'Jamaica', '1']
# ['God', 'spared', 'daye', '1']
# ['God', 'spared', 'effort', '1']
# ['God', 'speak', 'Sabbath', '1']
# ['God', 'speak', 'spirit', '3']
# ['God', 'speak', 'truth', '38']
# ['God', 'speed', 'hour', '2']
# ['God', 'speed', 'right', '4']
# ['God', 'spoke', 'hearts', '5']
# ['God', 'stacks', 'deck', '2']
# ['God', 'state', 'daye', '2']
# ['God', 'state', 'kind', '1']
# ['God', 'stir', 'adversary', '1']
# ['God', 'strengthened', 'union', '3']
# ['God', 'stretche', 'schedule', '1']
# ['God', 'struck', 'Pharoah', '1']
# ['God', 'suffered', 'earth', '4']
# ['God', 'supports', 'decisional', '1']
# ['God', 'supports', 'society', '1']
# ['God', 'surpassed', 'ability', '1']
# ['God', 'surpassed', 'judgment', '1']
# ['God', 'sustained', 'widow', '1']
# ['God', 'take', 'Light', '1']
# ['God', 'take', 'believer', '1']
# ['God', 'take', 'covenantal', '1']
# ['God', 'take', 'faith', '3']
# ['God', 'take', 'focused', '1']
# ['God', 'take', 'fruit', '4']
# ['God', 'take', 'mercyful', '3']
# ['God', 'take', 'moments', '4']
# ['God', 'take', 'someone', '2']
# ['God', 'taught', 'Kabbalah', '3']
# ['God', 'taught', 'men', '3']
# ['God', 'teache', 'forgiveness', '1']
# ['God', 'tell', 'conditions', '1']
# ['God', 'tell', 'kind', '1']
# ['God', 'tempted', 'individuall', '1']
# ['God', 'testing', 'belief', '3']
# ['God', 'testing', 'believers', '1']
# ['God', 'threatens', 'returns', '1']
# ['God', 'threw', 'earthquake', '1']
# ['God', 'ties', 'hands', '1']
# ['God', 'told', 'wind', '2']
# ['God', 'tolerate', 'deeds', '1']
# ['God', 'took', 'Peter', '1']
# ['God', 'took', 'case', '1']
# ['God', 'took', 'chargees', '1']
# ['God', 'took', 'heart', '3']
# ['God', 'took', 'laughter', '1']
# ['God', 'took', 'none', '1']
# ['God', 'took', 'prophetic', '1']
# ['God', 'took', 'sincerity', '3']
# ['God', 'took', 'territory', '2']
# ['God', 'took', 'treatments', '2']
# ['God', 'topple', 'tyranny', '1']
# ['God', 'tossed', 'lumps', '1']
# ['God', 'transcend', 'contingency', '1']
# ['God', 'transformers', 'believers', '1']
# ['God', 'treated', 'others', '2']
# ['God', 'trick', 'devil', '3']
# ['God', 'turn', 'faucet', '4']
# ['God', 'turn', 'fire', '2']
# ['God', 'turn', 'focused', '2']
# ['God', 'turn', 'questionable', '1']
# ['God', 'turn', 'watersed', '7']
# ['God', 'understand', 'mysteries', '1']
# ['God', 'understand', 'value', '1']
# ['God', 'unleashing', 'Power', '1']
# ['God', 'useful', 'TESOL', '2']
# ['God', 'useful', 'chief', '1']
# ['God', 'useful', 'churches', '1']
# ['God', 'useful', 'dad', '1']
# ['God', 'useful', 'deceptionism', '1']
# ['God', 'useful', 'humilitye', '2']
# ['God', 'useful', 'jargon', '1']
# ['God', 'useful', 'ribs', '2']
# ['God', 'useful', 'signed', '4']
# ['God', 'use', 'Bible', '7']
# ['God', 'use', 'God', '1']
# ['God', 'use', 'Scriptures', '1']
# ['God', 'use', 'heat', '7']
# ['God', 'use', 'marriage', '8']
# ['God', 'use', 'rocks', '1']
# ['God', 'use', 'spiritseers', '1']
# ['God', 'use', 'styles', '1']
# ['God', 'use', 'title', '1']
# ['God', 'use', 'woman', '3']
# ['God', 'utterance', 'ban', '2']
# ['God', 'varying', 'style', '1']
# ['God', 'view', 'blood', '3']
# ['God', 'vindicated', 'Joshua', '2']
# ['God', 'vindicated', 'death', '1']
# ['God', 'violate', 'laws', '25']
# ['God', 'violate', 'pledgee', '2']
# ['God', 'was', 'Southerner', '2']
# ['God', 'was', 'blessing', '9']
# ['God', 'was', 'brilliance', '1']
# ['God', 'was', 'centre', '4']
# ['God', 'was', 'designer', '3']
# ['God', 'was', 'engineer', '2']
# ['God', 'was', 'finished', '3']
# ['God', 'was', 'heaven', '1']
# ['God', 'was', 'instrument', '2']
# ['God', 'was', 'winners', '1']
# ['God', 'wait', 'daye', '1']
# ['God', 'wanted', 'USA', '1']
# ['God', 'wanted', 'difference', '1']
# ['God', 'wanted', 'dreams', '3']
# ['God', 'wanted', 'fetuses', '2']
# ['God', 'wanted', 'gifts', '1']
# ['God', 'wanted', 'loads', '2']
# ['God', 'wanted', 'matter', '1']
# ['God', 'wanted', 'person', '15']
# ['God', 'wanted', 'religions', '15']
# ['God', 'wanted', 'someplace', '1']
# ['God', 'wanted', 'soul', '8']
# ['God', 'wanted', 'things', '13']
# ['God', 'warns', 'Jews', '3']
# ['God', 'washed', 'pain', '4']
# ['God', 'waving', 'hands', '1']
# ['God', 'weeds', 'men', '1']
# ['God', 'weighs', 'things', '1']
# ['God', 'went', 'lot', '1']
# ['God', 'were', 'Father', '53']
# ['God', 'were', 'nigh', '2']
# ['God', 'were', 'sculptor', '1']
# ['God', 'were', 'symbols', '1']
# ['God', 'whispered', 'named', '4']
# ['God', 'whispered', 'words', '2']
# ['God', 'will', 'bonded', '1']
# ['God', 'wipes', 'sinful', '1']
# ['God', 'wire', 'member', '1']
# ['God', 'withdrawal', 'condemnation', '1']

# %% [markdown]
# And of course, we can combine all these filters together in to one filter. Here will be a class that is responsible for all the things we did above.

# %%
database_path='./verbs484.txt'
tutorial_data_path='./tutorial_data.txt'

def load_484verb(path):
    database=set()
    with open(path,'r') as txt:
        for line in txt:
            lines=line.split()
            database.add(lines[0])
            if len(lines)>1:
                database.add(lines[1])  
    return database

def generate_text(path,database):
    #A combination with above methods. I also write the output to the file so that
    #we are able to reuse that latter on.
    with open(path,'r') as txt,open('filtered_data.txt','w') as output:
        puncs=list(string.punctuation)
        for line in txt:
            lines=line.split()
            valid=True
            if len(lines[0])<=2 or len(lines[2])<=2 or int(lines[-1])<4:
                continue
            if lines[0].isdigit() or lines[2].isdigit():
                continue
            for punc in puncs:
                if punc in lines[0] or punc in lines[2]:
                    valid=False
                    break
            if valid:
                output.write((' '.join(lines[:-1])))
                output.write('\n')
            
    
            

verb_database=load_484verb(database_path)
generate_text(tutorial_data_path,verb_database)

# %% [markdown]
# If you check the data right now, you will find that although the data is still not perfectly noiseless, it's definitely making much more sense than before. Now that we've cleaned our data, we can start to tokenize it and prepare the input. Here is a step by step of what below code is doing with an example.
#
# First, I would like to create two dictionaries. The first one convert every unique word into its unique ID, the second do exactly the opposite thing, which is convert every unique ID into a unique word. The purpose of index_to_word dictionary is to transform every unique word into valid inputs and word_to_index dictionary can be used to test
# your result in the future.
#
# Let's have an example first. Say we originally have two SVOs:
#
# ("Dogs like bones","Cats like milk").
#
# I'll transform these two SVOs into index dictinary that hold :
#
# {0:Dogs,1:like,2:bones,3:Cats,4:milk} and word dictionary {Dogs:0,like:1,bones:2,Cats:3,milk:4}.
#
# As you would see, the world "like" appear here twice so it will only count as once. Then I use index dictionary to transform two SVOs, so "Dogs like bones" will become [0,1,2] and "Cats like milk" will become [3,1,4]. I will eventually output a list of lists [[0,1,2],[3,1,4]] along with two dictionaries. To see why we transfer to this form. I will recommend to look at http://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html this tuorial about word embeddings.
#
# If you don't know what is pickle, here will be a link to it https://docs.python.org/3/library/pickle.html.
# But basically its a libaray that lets you serialize and deserialize objects so that you can dump in one place and
# load it in another, and below will be one example class that handle all these stuffs.

# %%
data_path=['./filtered_data.txt']
class Dictionary(object):
    def __init__(self):
        self.dict_index={}
        self.dict_word={}
        self.dict_index2vec={}
        self.count=0
        
        
        self.generate_tokens()

        
        self.active_lists=self.generate_text()
        self.output_pickle()


    def generate_tokens(self):
        for path in data_path:
            #The for loop here is just for easy modification. If I want to
            #add more data source, I'm able to add it in my data_path list.
            with open(path,'r') as data:
                for line in data:
                    words=line.split()
                    for word in words:
                        if word not in self.dict_word:
                            self.dict_index[self.count]=word
                            self.dict_word[word]=self.count
                            self.count+=1
    
    
    def generate_text(self):
        lists=[]
        for path in data_path:
            with open(path,'r') as active:
                for line in active:
                    tmp=[]
                    for word in line.split():
                        tmp.append(self.dict_word[word])
                    if len(tmp)>0:
                        lists.append(tmp)
        return lists
                
    def output_pickle(self):
        data_dir = './preprocessed_data'
        pickle.dump(self.dict_index,open(data_dir+'/index_to_word.p','wb'))
        pickle.dump(self.dict_word,open(data_dir+'/word_to_index.p','wb'))
        pickle.dump(self.active_lists,open(data_dir+'/active_lists.p','wb'))

a=Dictionary()

# %% [markdown]
# After we save the structures, we can finally load into the model and prepare for training.
# Here will be one sample batching function that transforom list of lists into PyTorch variable.
# For people who are not familiar with PyTorch tensor and variable, here will be a quick index to
# what it is. http://pytorch.org/tutorials/beginner/former_torchies_tutorial.html

# %%
def batchify(path):
    active_lists=pickle.load(open(path,'rb'))
    np_arr=np.array(active_lists)
    #Change list of lists into torch variable.
    return Variable(torch.LongTensor(np_arr))

train_data=batchify('./preprocessed_data/active_lists.p')
#print(train_data)

# %% [markdown]
# Below will be a function that will be called when training, which will slice the training data into
# batches. Notice that after slicing, what it will return is a batch with shape [batch_size x steps]
# where sometimes a model wants its input to be [steps x batch_size]. In that case, you can either choose to
# specify batch_first=True paremeter in the model's parameter or transpose the batch. Also, since our task is to
# predict the object, we want to seperate that out, so our input will be subject and verb. Our output will be object.

# %%
def get_batch(batch_size,train_data,cur_pos):
    max_size=min(len(train_data),cur_pos+batch_size)
    #There might be less than batch_size's data in the end,
    #so we take min of the length of data and current position plus batch_size.
    input_data=train_data[cur_pos:max_size,:2]
    target_data=train_data[cur_pos:max_size,2]
    
    return input_data,target_data


batch_size=5
my_input,my_target=get_batch(batch_size,train_data,0)
print(my_input,my_target)
# Out:
# Variable containing:
#   0   1
#   3   4
#   6   7
#   9  10
#  12  13
# [torch.LongTensor of size 5x2]
#  Variable containing:
#   2
#   5
#   8
#  11
#  14
# [torch.LongTensor of size 5]

# %% [markdown]
# For your reference, here will be a sample train function. The commented section is just what might be like
# in the real train function.

# %%
def train(batch_size,train_data):
    for i in range(0,len(train_data),batch_size):
        my_input,my_target=get_batch(batch_size,train_data,i)
        
        #print(my_input,my_target)
        
        ##output=rnn_model(my_input)
        ##loss=loss_layer(output,my_target)
        ##rnn_model.zero_grad()
        ##loss.backward()
        ##update_parameter()

        
batch_size=5
epoch=1
train_data=batchify('./preprocessed_data/active_lists.p')

print('Training Start')
for e in range(epoch):
    train(batch_size,train_data)

print('Training Complete')
# Out:
# Training Start
# Training Complete
